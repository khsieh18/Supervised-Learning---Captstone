# %% [markdown]
# ## 1. Data Exploration/Cleaning
# - Checking null values
# - Remove outliers
#
# ## 2. Features Selection
# - Filter Method - Correlation Matrix
# - Wrapper Method - Recursive Method
# - Embedded Method - XGBoost Feature Importance
#
#
# ## 3.	Models
# - Ridge Regression
# - LASSO Regression
# - Elastic Net Regression
# - Decision Tree
# - Random Forest
# - XGBoost
#
# ## 4.	Models Evaluation
# - RMSE (Root Mean Squred Error)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from scipy import stats
from scipy.stats import norm


from sklearn.preprocessing import StandardScaler
from sklearn import ensemble, tree, linear_model
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split, cross_val_score



import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('train.csv')

# %%
from IPython.display import display
pd.options.display.max_columns=None
df=df.reindex_axis(sorted(df.columns),axis=1)
df.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0       856       854          0   NaN             3     1Fam       TA
# 1      1262         0          0   NaN             3     1Fam       TA
# 2       920       866          0   NaN             3     1Fam       TA
# 3       961       756          0   NaN             3     1Fam       Gd
# 4      1145      1053          0   NaN             4     1Fam       TA
#
#   BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# 0           No         706           0          GLQ          Unf
# 1           Gd         978           0          ALQ          Unf
# 2           Mn         486           0          GLQ          Unf
# 3           No         216           0          ALQ          Unf
# 4           Av         655           0          GLQ          Unf
#
#    BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF CentralAir Condition1  \
# 0             1             0       Gd        150          Y       Norm
# 1             0             1       Gd        284          Y      Feedr
# 2             1             0       Gd        434          Y       Norm
# 3             1             0       TA        540          Y       Norm
# 4             1             0       Gd        490          Y       Norm
#
#   Condition2 Electrical  EnclosedPorch ExterCond ExterQual Exterior1st  \
# 0       Norm      SBrkr              0        TA        Gd     VinylSd
# 1       Norm      SBrkr              0        TA        TA     MetalSd
# 2       Norm      SBrkr              0        TA        Gd     VinylSd
# 3       Norm      SBrkr            272        TA        TA     Wd Sdng
# 4       Norm      SBrkr              0        TA        Gd     VinylSd
#
#   Exterior2nd Fence FireplaceQu  Fireplaces Foundation  FullBath Functional  \
# 0     VinylSd   NaN         NaN           0      PConc         2        Typ
# 1     MetalSd   NaN          TA           1     CBlock         2        Typ
# 2     VinylSd   NaN          TA           1      PConc         2        Typ
# 3     Wd Shng   NaN          Gd           1     BrkTil         1        Typ
# 4     VinylSd   NaN          TA           1      PConc         2        Typ
#
#    GarageArea  GarageCars GarageCond GarageFinish GarageQual GarageType  \
# 0         548           2         TA          RFn         TA     Attchd
# 1         460           2         TA          RFn         TA     Attchd
# 2         608           2         TA          RFn         TA     Attchd
# 3         642           3         TA          Unf         TA     Detchd
# 4         836           3         TA          RFn         TA     Attchd
#
#    GarageYrBlt  GrLivArea  HalfBath Heating HeatingQC HouseStyle  Id  \
# 0       2003.0       1710         1    GasA        Ex     2Story   1
# 1       1976.0       1262         0    GasA        Ex     1Story   2
# 2       2001.0       1786         1    GasA        Ex     2Story   3
# 3       1998.0       1717         0    GasA        Gd     2Story   4
# 4       2000.0       2198         1    GasA        Ex     2Story   5
#
#    KitchenAbvGr KitchenQual LandContour LandSlope  LotArea LotConfig  \
# 0             1          Gd         Lvl       Gtl     8450    Inside
# 1             1          TA         Lvl       Gtl     9600       FR2
# 2             1          Gd         Lvl       Gtl    11250    Inside
# 3             1          Gd         Lvl       Gtl     9550    Corner
# 4             1          Gd         Lvl       Gtl    14260       FR2
#
#    LotFrontage LotShape  LowQualFinSF  MSSubClass MSZoning  MasVnrArea  \
# 0         65.0      Reg             0          60       RL       196.0
# 1         80.0      Reg             0          20       RL         0.0
# 2         68.0      IR1             0          60       RL       162.0
# 3         60.0      IR1             0          70       RL         0.0
# 4         84.0      IR1             0          60       RL       350.0
#
#   MasVnrType MiscFeature  MiscVal  MoSold Neighborhood  OpenPorchSF  \
# 0    BrkFace         NaN        0       2      CollgCr           61
# 1       None         NaN        0       5      Veenker            0
# 2    BrkFace         NaN        0       9      CollgCr           42
# 3       None         NaN        0       2      Crawfor           35
# 4    BrkFace         NaN        0      12      NoRidge           84
#
#    OverallCond  OverallQual PavedDrive  PoolArea PoolQC RoofMatl RoofStyle  \
# 0            5            7          Y         0    NaN  CompShg     Gable
# 1            8            6          Y         0    NaN  CompShg     Gable
# 2            5            7          Y         0    NaN  CompShg     Gable
# 3            5            7          Y         0    NaN  CompShg     Gable
# 4            5            8          Y         0    NaN  CompShg     Gable
#
#   SaleCondition  SalePrice SaleType  ScreenPorch Street  TotRmsAbvGrd  \
# 0        Normal     208500       WD            0   Pave             8
# 1        Normal     181500       WD            0   Pave             6
# 2        Normal     223500       WD            0   Pave             6
# 3       Abnorml     140000       WD            0   Pave             7
# 4        Normal     250000       WD            0   Pave             9
#
#    TotalBsmtSF Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          856    AllPub           0       2003          2003    2008
# 1         1262    AllPub         298       1976          1976    2007
# 2          920    AllPub           0       2001          2002    2008
# 3          756    AllPub           0       1915          1970    2006
# 4         1145    AllPub         192       2000          2000    2008

# %%
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### Remove "Id" from dataset

# %%
df=df.drop(columns=['Id'])

# %%
df.shape
# Out:
# (1460, 80)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Checking NAs

# %%
null_cols=df.columns[df.isnull().any()]
df[null_cols].isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageType        81
# GarageQual        81
# GarageFinish      81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtFinType1      37
# BsmtCond          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %%
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
dg
# Out:
# PoolQC          99.520548
# MiscFeature     96.301370
# Alley           93.767123
# Fence           80.753425
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageType       5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtQual         2.534247
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# MasVnrArea       0.547945
# MasVnrType       0.547945
# Electrical       0.068493
# dtype: float64

# %%
featureName=dg.index.values
featureName
# Out:
# array(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu',
#        'LotFrontage', 'GarageYrBlt', 'GarageType', 'GarageQual',
#        'GarageFinish', 'GarageCond', 'BsmtFinType2', 'BsmtExposure',
#        'BsmtQual', 'BsmtFinType1', 'BsmtCond', 'MasVnrArea', 'MasVnrType',
#        'Electrical'], dtype=object)

# %%
def missingness(featureName):
    for i in featureName:
        print(i)
        print(df[i].value_counts(dropna=False))
        print("Value missing: %2.1f %%" % (df[i].isnull().sum()/len(df)*100))
        print()

# %% [markdown]
# ### Checking unique values of feature with more than 70% missning values

# %%
missingness(featureName)
# Out:
# PoolQC
# NaN    1453
# Gd        3
# Ex        2
# Fa        2
# Name: PoolQC, dtype: int64
# Value missing: 99.5 %
#
# MiscFeature
# NaN     1406
# Shed      49
# Gar2       2
# Othr       2
# TenC       1
# Name: MiscFeature, dtype: int64
# Value missing: 96.3 %
#
# Alley
# NaN     1369
# Grvl      50
# Pave      41
# Name: Alley, dtype: int64
# Value missing: 93.8 %
#
# Fence
# NaN      1179
# MnPrv     157
# GdPrv      59
# GdWo       54
# MnWw       11
# Name: Fence, dtype: int64
# Value missing: 80.8 %
#
# FireplaceQu
# NaN    690
# Gd     380
# TA     313
# Fa      33
# Ex      24
# Po      20
# Name: FireplaceQu, dtype: int64
# Value missing: 47.3 %
#
# LotFrontage
# NaN       259
#  60.0     143
#  70.0      70
#  80.0      69
#  50.0      57
#  75.0      53
#  65.0      44
#  85.0      40
#  78.0      25
#  21.0      23
#  90.0      23
#  68.0      19
#  24.0      19
#  64.0      19
#  73.0      18
#  72.0      17
#  79.0      17
#  63.0      17
#  55.0      17
#  100.0     16
#  51.0      15
#  66.0      15
#  74.0      15
#  52.0      14
#  59.0      13
#  71.0      12
#  67.0      12
#  57.0      12
#  82.0      12
#  43.0      12
#          ...
#  129.0      2
#  313.0      2
#  118.0      2
#  122.0      2
#  121.0      2
#  101.0      2
#  109.0      2
#  115.0      2
#  116.0      2
#  114.0      2
#  153.0      1
#  149.0      1
#  150.0      1
#  111.0      1
#  182.0      1
#  46.0       1
#  112.0      1
#  141.0      1
#  33.0       1
#  152.0      1
#  160.0      1
#  168.0      1
#  128.0      1
#  144.0      1
#  39.0       1
#  106.0      1
#  38.0       1
#  138.0      1
#  140.0      1
#  137.0      1
# Name: LotFrontage, Length: 111, dtype: int64
# Value missing: 17.7 %
#
# GarageYrBlt
# NaN        81
#  2005.0    65
#  2006.0    59
#  2004.0    53
#  2003.0    50
#  2007.0    49
#  1977.0    35
#  1998.0    31
#  1999.0    30
#  1976.0    29
#  2008.0    29
#  2000.0    27
#  2002.0    26
#  1968.0    26
#  1950.0    24
#  1993.0    22
#  1962.0    21
#  2009.0    21
#  1966.0    21
#  1965.0    21
#  1958.0    21
#  1970.0    20
#  1996.0    20
#  1957.0    20
#  2001.0    20
#  1997.0    19
#  1978.0    19
#  1960.0    19
#  1954.0    19
#  1974.0    18
#            ..
#  1916.0     5
#  1922.0     5
#  1936.0     5
#  1945.0     4
#  1946.0     4
#  1982.0     4
#  1931.0     4
#  1928.0     4
#  1935.0     4
#  1932.0     3
#  1952.0     3
#  1921.0     3
#  1938.0     3
#  2010.0     3
#  1910.0     3
#  1924.0     3
#  1923.0     3
#  1947.0     2
#  1918.0     2
#  1929.0     2
#  1914.0     2
#  1915.0     2
#  1934.0     2
#  1937.0     2
#  1942.0     2
#  1906.0     1
#  1927.0     1
#  1900.0     1
#  1908.0     1
#  1933.0     1
# Name: GarageYrBlt, Length: 98, dtype: int64
# Value missing: 5.5 %
#
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# NaN         81
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64
# Value missing: 5.5 %
#
# GarageQual
# TA     1311
# NaN      81
# Fa       48
# Gd       14
# Ex        3
# Po        3
# Name: GarageQual, dtype: int64
# Value missing: 5.5 %
#
# GarageFinish
# Unf    605
# RFn    422
# Fin    352
# NaN     81
# Name: GarageFinish, dtype: int64
# Value missing: 5.5 %
#
# GarageCond
# TA     1326
# NaN      81
# Fa       35
# Gd        9
# Po        7
# Ex        2
# Name: GarageCond, dtype: int64
# Value missing: 5.5 %
#
# BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      46
# NaN      38
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64
# Value missing: 2.6 %
#
# BsmtExposure
# No     953
# Av     221
# Gd     134
# Mn     114
# NaN     38
# Name: BsmtExposure, dtype: int64
# Value missing: 2.6 %
#
# BsmtQual
# TA     649
# Gd     618
# Ex     121
# NaN     37
# Fa      35
# Name: BsmtQual, dtype: int64
# Value missing: 2.5 %
#
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# NaN     37
# Name: BsmtFinType1, dtype: int64
# Value missing: 2.5 %
#
# BsmtCond
# TA     1311
# Gd       65
# Fa       45
# NaN      37
# Po        2
# Name: BsmtCond, dtype: int64
# Value missing: 2.5 %
#
# MasVnrArea
#  0.0       861
#  72.0        8
#  180.0       8
# NaN          8
#  108.0       8
#  120.0       7
#  16.0        7
#  106.0       6
#  80.0        6
#  340.0       6
#  200.0       6
#  132.0       5
#  170.0       5
#  360.0       5
#  84.0        5
#  320.0       5
#  270.0       4
#  183.0       4
#  100.0       4
#  168.0       4
#  252.0       4
#  178.0       4
#  246.0       4
#  196.0       4
#  288.0       4
#  216.0       4
#  160.0       4
#  220.0       4
#  336.0       4
#  210.0       4
#           ...
#  24.0        1
#  760.0       1
#  138.0       1
#  27.0        1
#  541.0       1
#  275.0       1
#  365.0       1
#  562.0       1
#  161.0       1
#  247.0       1
#  452.0       1
#  278.0       1
#  375.0       1
#  225.0       1
#  604.0       1
#  762.0       1
#  290.0       1
#  109.0       1
#  299.0       1
#  731.0       1
#  167.0       1
#  309.0       1
#  202.0       1
#  1129.0      1
#  651.0       1
#  337.0       1
#  415.0       1
#  293.0       1
#  259.0       1
#  621.0       1
# Name: MasVnrArea, Length: 328, dtype: int64
# Value missing: 0.5 %
#
# MasVnrType
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# NaN          8
# Name: MasVnrType, dtype: int64
# Value missing: 0.5 %
#
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# NaN         1
# Name: Electrical, dtype: int64
# Value missing: 0.1 %

# %% [markdown]
# ### Remove columns with more than 70% of missing values

# %%
df=df.drop(columns=['PoolQC','MiscFeature','Alley','Fence'])

# %%
df.shape
# Out:
# (1460, 76)

# %% [markdown]
# ### Checking the rest of features with missing values

# %%
null_cols=df.columns[df.isnull().any()]
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
print(dg)
nullCol=dg.index.values
nullCol
# Out:
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageType       5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtQual         2.534247
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# MasVnrType       0.547945
# MasVnrArea       0.547945
# Electrical       0.068493
# dtype: float64
# array(['FireplaceQu', 'LotFrontage', 'GarageYrBlt', 'GarageType',
#        'GarageQual', 'GarageFinish', 'GarageCond', 'BsmtFinType2',
#        'BsmtExposure', 'BsmtQual', 'BsmtFinType1', 'BsmtCond',
#        'MasVnrType', 'MasVnrArea', 'Electrical'], dtype=object)

# %% [markdown]
# ### It looks like "FireplaceQu" has "NaN" value when "Fireplaces" has "zero" value.
# ### Let's check if the number of missing value in "FireplaceQu" is the same as the number of rows with zero value in "Fireplaces"

# %%
df['FireplaceQu'].isnull().sum()
# Out:
# 690

# %%
len(df.loc[df['Fireplaces']==0])
# Out:
# 690

# %% [markdown]
# ### It turns out the number is the same.
# ### We can go ahead and replace the "NaN" in "FireplaceQu" with "0"

# %% [markdown]
# ### Also, we will change the datatype of "FireplaceQu" to a "Ordinal" Variable

# %% [markdown]
# ### First we will need to replace "NaN" with "0" value

# %%
df['FireplaceQu'].fillna(0,inplace=True)

# %%
df['FireplaceQu'].value_counts()
# Out:
# 0     690
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %% [markdown]
# ### Replace string values to ordinal value in "FireplaceQu"

# %%
#quality={'Po':1,'Fa':2,'TA':3,'Gd':4,"Ex":5}
df.FireplaceQu[df.FireplaceQu=='Po']=1
df.FireplaceQu[df.FireplaceQu=='Fa']=2
df.FireplaceQu[df.FireplaceQu=='TA']=3
df.FireplaceQu[df.FireplaceQu=='Gd']=4
df.FireplaceQu[df.FireplaceQu=='Ex']=5

# %%
df.FireplaceQu.dtypes
# Out:
# dtype('O')

# %% [markdown]
# ### Let's change the datatype of "FireplaceQu" to "int"

# %%
df=df.astype({"FireplaceQu":int})

# %%
df.FireplaceQu.dtypes
# Out:
# dtype('int32')

# %%
df['LotFrontage'].isnull().sum()
# Out:
# 259

# %% [markdown]
# ### Some Lot just does not have LotFronage.
# ### Change "NaN" value to "zero" in "LotFrontage"

# %%
df['LotFrontage'].fillna(0,inplace=True)

# %% [markdown]
# ### Check if the number of "0" value is the same as the number "NaN" value

# %%
df['LotFrontage'].value_counts()
# Out:
# 0.0      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 67.0      12
# 57.0      12
# 82.0      12
# 43.0      12
#         ...
# 129.0      2
# 313.0      2
# 118.0      2
# 122.0      2
# 121.0      2
# 101.0      2
# 109.0      2
# 115.0      2
# 116.0      2
# 114.0      2
# 153.0      1
# 149.0      1
# 150.0      1
# 111.0      1
# 182.0      1
# 46.0       1
# 112.0      1
# 141.0      1
# 33.0       1
# 152.0      1
# 160.0      1
# 168.0      1
# 128.0      1
# 144.0      1
# 39.0       1
# 106.0      1
# 38.0       1
# 138.0      1
# 140.0      1
# 137.0      1
# Name: LotFrontage, Length: 111, dtype: int64

# %% [markdown]
# ### Double check all the missing values again

# %%
null_cols=df.columns[df.isnull().any()]
df[null_cols].isnull().sum().sort_values(ascending=False)
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
dg
# Out:
# GarageYrBlt     5.547945
# GarageType      5.547945
# GarageQual      5.547945
# GarageFinish    5.547945
# GarageCond      5.547945
# BsmtFinType2    2.602740
# BsmtExposure    2.602740
# BsmtQual        2.534247
# BsmtFinType1    2.534247
# BsmtCond        2.534247
# MasVnrType      0.547945
# MasVnrArea      0.547945
# Electrical      0.068493
# dtype: float64

# %% [markdown]
# ### All the remaining variables have less than 6% of missing values.
# ### We will remove all the rows with any missing values.

# %%
df_miss=df.dropna()

# %%
df_miss.isnull().sum()
# Out:
# 1stFlrSF         0
# 2ndFlrSF         0
# 3SsnPorch        0
# BedroomAbvGr     0
# BldgType         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtFinType1     0
# BsmtFinType2     0
# BsmtFullBath     0
# BsmtHalfBath     0
# BsmtQual         0
# BsmtUnfSF        0
# CentralAir       0
# Condition1       0
# Condition2       0
# Electrical       0
# EnclosedPorch    0
# ExterCond        0
# ExterQual        0
# Exterior1st      0
# Exterior2nd      0
# FireplaceQu      0
# Fireplaces       0
# Foundation       0
# FullBath         0
# Functional       0
# GarageArea       0
#                 ..
# LotConfig        0
# LotFrontage      0
# LotShape         0
# LowQualFinSF     0
# MSSubClass       0
# MSZoning         0
# MasVnrArea       0
# MasVnrType       0
# MiscVal          0
# MoSold           0
# Neighborhood     0
# OpenPorchSF      0
# OverallCond      0
# OverallQual      0
# PavedDrive       0
# PoolArea         0
# RoofMatl         0
# RoofStyle        0
# SaleCondition    0
# SalePrice        0
# SaleType         0
# ScreenPorch      0
# Street           0
# TotRmsAbvGrd     0
# TotalBsmtSF      0
# Utilities        0
# WoodDeckSF       0
# YearBuilt        0
# YearRemodAdd     0
# YrSold           0
# Length: 76, dtype: int64

# %%
df_miss.shape
# Out:
# (1338, 76)

# %%
len(df)-len(df_miss)
# Out:
# 122

# %% [markdown]
# ### Checking the percentage of data removed

# %%
(len(df)-len(df_miss))/len(df)*100
# Out:
# 8.356164383561644

# %% [markdown]
# ## Convert all string categorical variables to ordinal categorical variables

# %%
cat_col=df_miss.select_dtypes(include=['object']).columns
cat_col
# Out:
# Index(['BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'BsmtQual', 'CentralAir', 'Condition1', 'Condition2', 'Electrical',
#        'ExterCond', 'ExterQual', 'Exterior1st', 'Exterior2nd', 'Foundation',
#        'Functional', 'GarageCond', 'GarageFinish', 'GarageQual', 'GarageType',
#        'Heating', 'HeatingQC', 'HouseStyle', 'KitchenQual', 'LandContour',
#        'LandSlope', 'LotConfig', 'LotShape', 'MSZoning', 'MasVnrType',
#        'Neighborhood', 'PavedDrive', 'RoofMatl', 'RoofStyle', 'SaleCondition',
#        'SaleType', 'Street', 'Utilities'],
#       dtype='object')

# %%
for item1 in cat_col:
    df_mean=pd.concat([df_miss[item1],df_miss['SalePrice']],axis=1)
    df_mean.head()

    g1=df_mean.groupby(item1).mean()
    g1

    df_g1=pd.DataFrame()
    df_g1=pd.DataFrame(g1)
    df_g1

    df_g2=df_g1.sort_values('SalePrice')
    df_g2

    df_g2.index

    g_col=df_g2.index.values

    df_miss[item1].value_counts()

    i=0
    for item2 in g_col:
        df_miss.loc[df_miss[item1]==item2,item1]=i
        i=i+1

# %%
df_miss[cat_col].dtypes
# Out:
# BldgType         int64
# BsmtCond         int64
# BsmtExposure     int64
# BsmtFinType1     int64
# BsmtFinType2     int64
# BsmtQual         int64
# CentralAir       int64
# Condition1       int64
# Condition2       int64
# Electrical       int64
# ExterCond        int64
# ExterQual        int64
# Exterior1st      int64
# Exterior2nd      int64
# Foundation       int64
# Functional       int64
# GarageCond       int64
# GarageFinish     int64
# GarageQual       int64
# GarageType       int64
# Heating          int64
# HeatingQC        int64
# HouseStyle       int64
# KitchenQual      int64
# LandContour      int64
# LandSlope        int64
# LotConfig        int64
# LotShape         int64
# MSZoning         int64
# MasVnrType       int64
# Neighborhood     int64
# PavedDrive       int64
# RoofMatl         int64
# RoofStyle        int64
# SaleCondition    int64
# SaleType         int64
# Street           int64
# Utilities        int64
# dtype: object

# %%
for item in cat_col:
    print(df_miss[item].value_counts())
    print()
# Out:
# 4    1138
# 3     112
# 1      38
# 2      28
# 0      22
# Name: BldgType, dtype: int64
#
# 2    1237
# 3      62
# 1      38
# 0       1
# Name: BsmtCond, dtype: int64
#
# 0    887
# 2    213
# 3    127
# 1    111
# Name: BsmtExposure, dtype: int64
#
# 5    402
# 4    392
# 3    209
# 1    141
# 0    125
# 2     69
# Name: BsmtFinType1, dtype: int64
#
# 3    1176
# 2      53
# 1      46
# 0      32
# 5      19
# 4      12
# Name: BsmtFinType2, dtype: int64
#
# 1    594
# 2    592
# 3    120
# 0     32
# Name: BsmtQual, dtype: int64
#
# 1    1277
# 0      61
# Name: CentralAir, dtype: int64
#
# 4    1162
# 2      63
# 0      43
# 3      26
# 7      19
# 1      10
# 8       8
# 6       5
# 5       2
# Name: Condition1, dtype: int64
#
# 4    1324
# 2       5
# 6       2
# 1       2
# 0       2
# 7       1
# 5       1
# 3       1
# Name: Condition2, dtype: int64
#
# 4    1242
# 3      76
# 2      17
# 1       2
# 0       1
# Name: Electrical, dtype: int64
#
# 2    1183
# 1     137
# 0      16
# 3       2
# Name: ExterCond, dtype: int64
#
# 1    803
# 2    477
# 3     51
# 0      7
# Name: ExterQual, dtype: int64
#
# 10    486
# 6     211
# 3     201
# 4     183
# 8     100
# 11     52
# 9      44
# 7      21
# 5      20
# 2      15
# 12      2
# 13      1
# 1       1
# 0       1
# Name: Exterior1st, dtype: int64
#
# 12    475
# 7     197
# 3     197
# 4     176
# 9     127
# 13     51
# 8      32
# 6      23
# 11     22
# 1      16
# 14     10
# 2       6
# 10      2
# 5       2
# 15      1
# 0       1
# Name: Exterior2nd, dtype: int64
#
# 4    620
# 1    580
# 0    129
# 2      6
# 3      3
# Name: Foundation, dtype: int64
#
# 5    1254
# 2      30
# 3      28
# 6      11
# 4      10
# 0       4
# 1       1
# Name: Functional, dtype: int64
#
# 4    1287
# 1      33
# 3       9
# 0       7
# 2       2
# Name: GarageCond, dtype: int64
#
# 0    580
# 1    413
# 2    345
# Name: GarageFinish, dtype: int64
#
# 2    1270
# 1      48
# 3      14
# 4       3
# 0       3
# Name: GarageQual, dtype: int64
#
# 4    852
# 1    369
# 5     85
# 3     19
# 0      7
# 2      6
# Name: GarageType, dtype: int64
#
# 3    1318
# 2      16
# 0       3
# 1       1
# Name: Heating, dtype: int64
#
# 4    704
# 2    380
# 3    217
# 1     36
# 0      1
# Name: HeatingQC, dtype: int64
#
# 5    657
# 6    426
# 2    134
# 4     64
# 1     30
# 0     11
# 3     10
# 7      6
# Name: HouseStyle, dtype: int64
#
# 1    650
# 2    568
# 3     97
# 0     23
# Name: KitchenQual, dtype: int64
#
# 1    1206
# 0      52
# 3      48
# 2      32
# Name: LandContour, dtype: int64
#
# 0    1265
# 1      61
# 2      12
# Name: LandSlope, dtype: int64
#
# 0    957
# 2    244
# 4     90
# 1     43
# 3      4
# Name: LotConfig, dtype: int64
#
# 0    829
# 1    459
# 3     40
# 2     10
# Name: LotShape, dtype: int64
#
# 3    1066
# 2     191
# 4      62
# 1      11
# 0       8
# Name: MSZoning, dtype: int64
#
# 1    763
# 2    432
# 3    128
# 0     15
# Name: MasVnrType, dtype: int64
#
# 10    209
# 16    146
# 3     100
# 19     83
# 14     77
# 23     75
# 12     73
# 5      70
# 7      69
# 13     53
# 17     50
# 4      47
# 11     42
# 24     41
# 21     37
# 2      29
# 18     26
# 22     25
# 8      20
# 15     17
# 1      15
# 0      12
# 20     11
# 9       9
# 6       2
# Name: Neighborhood, dtype: int64
#
# 2    1257
# 0      54
# 1      27
# Name: PavedDrive, dtype: int64
#
# 3    1314
# 4       9
# 7       6
# 5       5
# 6       1
# 2       1
# 1       1
# 0       1
# Name: RoofMatl, dtype: int64
#
# 1    1037
# 4     272
# 3      11
# 0      10
# 2       6
# 5       2
# Name: RoofStyle, dtype: int64
#
# 4    1104
# 5     120
# 2      86
# 1      20
# 3       7
# 0       1
# Name: SaleCondition, dtype: int64
#
# 4    1158
# 8     117
# 1      42
# 2       6
# 6       4
# 5       4
# 3       4
# 7       2
# 0       1
# Name: SaleType, dtype: int64
#
# 1    1333
# 0       5
# Name: Street, dtype: int64
#
# 1    1337
# 0       1
# Name: Utilities, dtype: int64

# %%
df_miss.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0       856       854          0             3         4         2
# 1      1262         0          0             3         4         2
# 2       920       866          0             3         4         2
# 3       961       756          0             3         4         3
# 4      1145      1053          0             4         4         2
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0             0         706           0             5             3
# 1             3         978           0             3             3
# 2             1         486           0             5             3
# 3             0         216           0             3             3
# 4             2         655           0             5             3
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0             1             0         2        150           1           4
# 1             0             1         2        284           1           2
# 2             1             0         2        434           1           4
# 3             1             0         1        540           1           4
# 4             1             0         2        490           1           4
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0           4           4              0          2          2           10
# 1           4           4              0          2          1            3
# 2           4           4              0          2          2           10
# 3           4           4            272          2          1            4
# 4           4           4              0          2          2           10
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0           12            0           0           4         2           5
# 1            3            3           1           1         2           5
# 2           12            3           1           4         2           5
# 3            8            4           1           0         1           5
# 4           12            3           1           4         2           5
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0         548           2           4             1           2           4
# 1         460           2           4             1           2           4
# 2         608           2           4             1           2           4
# 3         642           3           4             0           2           1
# 4         836           3           4             1           2           4
#
#    GarageYrBlt  GrLivArea  HalfBath  Heating  HeatingQC  HouseStyle  \
# 0       2003.0       1710         1        3          4           6
# 1       1976.0       1262         0        3          4           5
# 2       2001.0       1786         1        3          4           6
# 3       1998.0       1717         0        3          3           6
# 4       2000.0       2198         1        3          4           6
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope  LotArea  LotConfig  \
# 0             1            2            1          0     8450          0
# 1             1            1            1          0     9600          1
# 2             1            2            1          0    11250          0
# 3             1            2            1          0     9550          2
# 4             1            2            1          0    14260          1
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0         65.0         0             0          60         3       196.0
# 1         80.0         0             0          20         3         0.0
# 2         68.0         1             0          60         3       162.0
# 3         60.0         1             0          70         3         0.0
# 4         84.0         1             0          60         3       350.0
#
#    MasVnrType  MiscVal  MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0           2        0       2            16           61            5
# 1           1        0       5            20            0            8
# 2           2        0       9            16           42            5
# 3           1        0       2            17           35            5
# 4           2        0      12            24           84            5
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0            7           2         0         3          1              4
# 1            6           2         0         3          1              4
# 2            7           2         0         3          1              4
# 3            7           2         0         3          1              2
# 4            8           2         0         3          1              4
#
#    SalePrice  SaleType  ScreenPorch  Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0     208500         4            0       1             8          856
# 1     181500         4            0       1             6         1262
# 2     223500         4            0       1             6          920
# 3     140000         4            0       1             7          756
# 4     250000         4            0       1             9         1145
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          1           0       2003          2003    2008
# 1          1         298       1976          1976    2007
# 2          1           0       2001          2002    2008
# 3          1           0       1915          1970    2006
# 4          1         192       2000          2000    2008

# %% [markdown]
# ## Start working on Outliers

# %%
df_miss.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0       856       854          0             3         4         2
# 1      1262         0          0             3         4         2
# 2       920       866          0             3         4         2
# 3       961       756          0             3         4         3
# 4      1145      1053          0             4         4         2
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0             0         706           0             5             3
# 1             3         978           0             3             3
# 2             1         486           0             5             3
# 3             0         216           0             3             3
# 4             2         655           0             5             3
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0             1             0         2        150           1           4
# 1             0             1         2        284           1           2
# 2             1             0         2        434           1           4
# 3             1             0         1        540           1           4
# 4             1             0         2        490           1           4
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0           4           4              0          2          2           10
# 1           4           4              0          2          1            3
# 2           4           4              0          2          2           10
# 3           4           4            272          2          1            4
# 4           4           4              0          2          2           10
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0           12            0           0           4         2           5
# 1            3            3           1           1         2           5
# 2           12            3           1           4         2           5
# 3            8            4           1           0         1           5
# 4           12            3           1           4         2           5
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0         548           2           4             1           2           4
# 1         460           2           4             1           2           4
# 2         608           2           4             1           2           4
# 3         642           3           4             0           2           1
# 4         836           3           4             1           2           4
#
#    GarageYrBlt  GrLivArea  HalfBath  Heating  HeatingQC  HouseStyle  \
# 0       2003.0       1710         1        3          4           6
# 1       1976.0       1262         0        3          4           5
# 2       2001.0       1786         1        3          4           6
# 3       1998.0       1717         0        3          3           6
# 4       2000.0       2198         1        3          4           6
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope  LotArea  LotConfig  \
# 0             1            2            1          0     8450          0
# 1             1            1            1          0     9600          1
# 2             1            2            1          0    11250          0
# 3             1            2            1          0     9550          2
# 4             1            2            1          0    14260          1
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0         65.0         0             0          60         3       196.0
# 1         80.0         0             0          20         3         0.0
# 2         68.0         1             0          60         3       162.0
# 3         60.0         1             0          70         3         0.0
# 4         84.0         1             0          60         3       350.0
#
#    MasVnrType  MiscVal  MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0           2        0       2            16           61            5
# 1           1        0       5            20            0            8
# 2           2        0       9            16           42            5
# 3           1        0       2            17           35            5
# 4           2        0      12            24           84            5
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0            7           2         0         3          1              4
# 1            6           2         0         3          1              4
# 2            7           2         0         3          1              4
# 3            7           2         0         3          1              2
# 4            8           2         0         3          1              4
#
#    SalePrice  SaleType  ScreenPorch  Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0     208500         4            0       1             8          856
# 1     181500         4            0       1             6         1262
# 2     223500         4            0       1             6          920
# 3     140000         4            0       1             7          756
# 4     250000         4            0       1             9         1145
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          1           0       2003          2003    2008
# 1          1         298       1976          1976    2007
# 2          1           0       2001          2002    2008
# 3          1           0       1915          1970    2006
# 4          1         192       2000          2000    2008

# %%
df_miss.dtypes
# Out:
# 1stFlrSF           int64
# 2ndFlrSF           int64
# 3SsnPorch          int64
# BedroomAbvGr       int64
# BldgType           int64
# BsmtCond           int64
# BsmtExposure       int64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtFinType1       int64
# BsmtFinType2       int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# BsmtQual           int64
# BsmtUnfSF          int64
# CentralAir         int64
# Condition1         int64
# Condition2         int64
# Electrical         int64
# EnclosedPorch      int64
# ExterCond          int64
# ExterQual          int64
# Exterior1st        int64
# Exterior2nd        int64
# FireplaceQu        int32
# Fireplaces         int64
# Foundation         int64
# FullBath           int64
# Functional         int64
# GarageArea         int64
#                   ...
# LotConfig          int64
# LotFrontage      float64
# LotShape           int64
# LowQualFinSF       int64
# MSSubClass         int64
# MSZoning           int64
# MasVnrArea       float64
# MasVnrType         int64
# MiscVal            int64
# MoSold             int64
# Neighborhood       int64
# OpenPorchSF        int64
# OverallCond        int64
# OverallQual        int64
# PavedDrive         int64
# PoolArea           int64
# RoofMatl           int64
# RoofStyle          int64
# SaleCondition      int64
# SalePrice          int64
# SaleType           int64
# ScreenPorch        int64
# Street             int64
# TotRmsAbvGrd       int64
# TotalBsmtSF        int64
# Utilities          int64
# WoodDeckSF         int64
# YearBuilt          int64
# YearRemodAdd       int64
# YrSold             int64
# Length: 76, dtype: object

# %% [markdown]
# ## Remove out of inter-quartile range values from 'SalePrice'

# %%
Q1=df_miss['SalePrice'].quantile(0.25)
Q3=df_miss['SalePrice'].quantile(0.75)

IQR=Q3-Q1

upper=Q3+1.5*IQR
lower=Q1-1.5*IQR

df_miss=df_miss.drop(df_miss[(df_miss['SalePrice']<lower)|(df_miss['SalePrice']>upper)].index)

# %% [markdown]
# ### Separate data variables to continuous and categorical features

# %%
con_col=['1stFlrSF','2ndFlrSF','3SsnPorch','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF',
        'EnclosedPorch','GarageArea','GarageYrBlt','GrLivArea','LotArea','LotFrontage','LowQualFinSF',
        'MasVnrArea','MiscVal','OpenPorchSF','PoolArea','ScreenPorch','TotalBsmtSF','WoodDeckSF',
         'YearBuilt','YearRemodAdd']
con_col
# Out:
# ['1stFlrSF',
#  '2ndFlrSF',
#  '3SsnPorch',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'EnclosedPorch',
#  'GarageArea',
#  'GarageYrBlt',
#  'GrLivArea',
#  'LotArea',
#  'LotFrontage',
#  'LowQualFinSF',
#  'MasVnrArea',
#  'MiscVal',
#  'OpenPorchSF',
#  'PoolArea',
#  'ScreenPorch',
#  'TotalBsmtSF',
#  'WoodDeckSF',
#  'YearBuilt',
#  'YearRemodAdd']

# %%
for item in con_col:
    plt.scatter(x=df_miss[item],y=df_miss['SalePrice'])
    plt.xlabel(item)
    plt.ylabel('Sale Price')
    plt.show()

# %% [markdown]
# ### Remove Outliers - continuous variables

# %%
df_out=pd.DataFrame()
df_out=df_miss

# %%
df_out=df_out.drop(df_out[df_out['1stFlrSF']>3000].index)

# %%
df_out=df_out.drop(df_out[(df_out['2ndFlrSF']>1500)&(df_out['SalePrice']<300000)].index)

# %%
df_out=df_out.drop(df_out[df_out['BsmtFinSF1']>5000].index)

# %%
df_out=df_out.drop(df_out[(df_out['BsmtFinSF2']>175)&(df_out['SalePrice']>300000)].index)

# %%
df_out=df_out.drop(df_out[df_out['EnclosedPorch']>500].index)

# %%
df_out=df_out.drop(df_out[(df_out['GarageArea']>1200)&(df_out['SalePrice']<300000)].index)

# %%
df_out=df_out.drop(df_out[(df_out['GrLivArea']>4000)&(df_out['SalePrice']<200000)].index)

# %%
df_out=df_out.drop(df_out[df_out['TotalBsmtSF']>4000].index)

# %%
df_out.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0       856       854          0             3         4         2
# 1      1262         0          0             3         4         2
# 2       920       866          0             3         4         2
# 3       961       756          0             3         4         3
# 4      1145      1053          0             4         4         2
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0             0         706           0             5             3
# 1             3         978           0             3             3
# 2             1         486           0             5             3
# 3             0         216           0             3             3
# 4             2         655           0             5             3
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0             1             0         2        150           1           4
# 1             0             1         2        284           1           2
# 2             1             0         2        434           1           4
# 3             1             0         1        540           1           4
# 4             1             0         2        490           1           4
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0           4           4              0          2          2           10
# 1           4           4              0          2          1            3
# 2           4           4              0          2          2           10
# 3           4           4            272          2          1            4
# 4           4           4              0          2          2           10
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0           12            0           0           4         2           5
# 1            3            3           1           1         2           5
# 2           12            3           1           4         2           5
# 3            8            4           1           0         1           5
# 4           12            3           1           4         2           5
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0         548           2           4             1           2           4
# 1         460           2           4             1           2           4
# 2         608           2           4             1           2           4
# 3         642           3           4             0           2           1
# 4         836           3           4             1           2           4
#
#    GarageYrBlt  GrLivArea  HalfBath  Heating  HeatingQC  HouseStyle  \
# 0       2003.0       1710         1        3          4           6
# 1       1976.0       1262         0        3          4           5
# 2       2001.0       1786         1        3          4           6
# 3       1998.0       1717         0        3          3           6
# 4       2000.0       2198         1        3          4           6
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope  LotArea  LotConfig  \
# 0             1            2            1          0     8450          0
# 1             1            1            1          0     9600          1
# 2             1            2            1          0    11250          0
# 3             1            2            1          0     9550          2
# 4             1            2            1          0    14260          1
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0         65.0         0             0          60         3       196.0
# 1         80.0         0             0          20         3         0.0
# 2         68.0         1             0          60         3       162.0
# 3         60.0         1             0          70         3         0.0
# 4         84.0         1             0          60         3       350.0
#
#    MasVnrType  MiscVal  MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0           2        0       2            16           61            5
# 1           1        0       5            20            0            8
# 2           2        0       9            16           42            5
# 3           1        0       2            17           35            5
# 4           2        0      12            24           84            5
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0            7           2         0         3          1              4
# 1            6           2         0         3          1              4
# 2            7           2         0         3          1              4
# 3            7           2         0         3          1              2
# 4            8           2         0         3          1              4
#
#    SalePrice  SaleType  ScreenPorch  Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0     208500         4            0       1             8          856
# 1     181500         4            0       1             6         1262
# 2     223500         4            0       1             6          920
# 3     140000         4            0       1             7          756
# 4     250000         4            0       1             9         1145
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          1           0       2003          2003    2008
# 1          1         298       1976          1976    2007
# 2          1           0       2001          2002    2008
# 3          1           0       1915          1970    2006
# 4          1         192       2000          2000    2008

# %% [markdown]
# ### Wrok on Categorical Variables

# %% [markdown]
# ### Create boxplot

# %%
df_cat=pd.DataFrame()
df_cat=df_out.drop(columns=con_col,axis=1)
cat_col=df_cat.columns

# %%
for item in cat_col:
    sns.boxplot(x=item,y="SalePrice",data=df_out)
    plt.show()

# %% [markdown]
# ### Remove outliers - categorical variable

# %% [markdown]
# ### Log(x+1) transformed the whole dataset

# %%
df_out=np.log1p(df_out)

# %%
df_out.head()
# Out:
# OverallQual    0.767682   2.590803
# PavedDrive     0.243027   0.243027
# PoolArea      -0.056154  18.307298
# RoofMatl      -0.062645  10.982412
# RoofStyle     -0.466046   2.535382
# SaleCondition  0.205654   1.200169
# SalePrice      0.700115   2.198664
# SaleType      -0.032488   2.474740
# ScreenPorch   -0.305055   3.956789
# Street         0.056166   0.056166
# TotRmsAbvGrd   0.470061   2.915670
# TotalBsmtSF    0.707732   2.781998
# Utilities      0.028050   0.028050
# WoodDeckSF     1.017806   1.586030
# YearBuilt      0.953912   1.255357
# YearRemodAdd   0.892774   1.232585
# YrSold         0.893599   1.642686
#
# [76 rows x 8 columns]

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### 1. Filter Method - Correlation Coefficient

# %%
corr=df_out.corr()
corr.sort_values(["SalePrice"],ascending=False,inplace=True)
dc=corr.SalePrice

# %%
dc
# Out:
# SalePrice        1.000000
# OverallQual      0.768249
# GrLivArea        0.702634
# Neighborhood     0.673033
# ExterQual        0.629287
# GarageCars       0.614076
# BsmtQual         0.605526
# KitchenQual      0.604370
# FullBath         0.597020
# YearBuilt        0.583566
# GarageArea       0.583536
# YearRemodAdd     0.560298
# GarageFinish     0.550092
# 1stFlrSF         0.548129
# TotalBsmtSF      0.536401
# Foundation       0.528179
# GarageYrBlt      0.525546
# GarageType       0.503947
# TotRmsAbvGrd     0.497828
# FireplaceQu      0.483908
# OpenPorchSF      0.474638
# Fireplaces       0.457399
# HeatingQC        0.439549
# MSZoning         0.432292
# Exterior1st      0.417857
# Exterior2nd      0.397948
# MasVnrType       0.367136
# LotArea          0.353695
# MasVnrArea       0.344849
# WoodDeckSF       0.308002
#                    ...
# 2ndFlrSF         0.166775
# ExterCond        0.160236
# BldgType         0.159361
# LandContour      0.145601
# Functional       0.134206
# BsmtUnfSF        0.126235
# BsmtFinSF1       0.118646
# LotConfig        0.118407
# RoofStyle        0.117043
# Condition2       0.111942
# BsmtFinType2     0.090856
# Heating          0.086704
# RoofMatl         0.084780
# ScreenPorch      0.079865
# MoSold           0.061856
# LandSlope        0.057304
# 3SsnPorch        0.055021
# Street           0.045436
# PoolArea         0.043288
# Utilities        0.016219
# MSSubClass       0.010356
# LotFrontage     -0.019454
# BsmtHalfBath    -0.030816
# YrSold          -0.031252
# OverallCond     -0.033966
# MiscVal         -0.039746
# BsmtFinSF2      -0.064831
# LowQualFinSF    -0.074069
# KitchenAbvGr    -0.121104
# EnclosedPorch   -0.224669
# Name: SalePrice, Length: 76, dtype: float64

# %%
dc.index
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'Neighborhood', 'ExterQual',
#        'GarageCars', 'BsmtQual', 'KitchenQual', 'FullBath', 'YearBuilt',
#        'GarageArea', 'YearRemodAdd', 'GarageFinish', '1stFlrSF', 'TotalBsmtSF',
#        'Foundation', 'GarageYrBlt', 'GarageType', 'TotRmsAbvGrd',
#        'FireplaceQu', 'OpenPorchSF', 'Fireplaces', 'HeatingQC', 'MSZoning',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'LotArea', 'MasVnrArea',
#        'WoodDeckSF', 'BsmtFinType1', 'CentralAir', 'LotShape', 'HouseStyle',
#        'HalfBath', 'Electrical', 'BsmtExposure', 'SaleType', 'PavedDrive',
#        'BsmtCond', 'GarageCond', 'Condition1', 'SaleCondition', 'GarageQual',
#        'BedroomAbvGr', 'BsmtFullBath', '2ndFlrSF', 'ExterCond', 'BldgType',
#        'LandContour', 'Functional', 'BsmtUnfSF', 'BsmtFinSF1', 'LotConfig',
#        'RoofStyle', 'Condition2', 'BsmtFinType2', 'Heating', 'RoofMatl',
#        'ScreenPorch', 'MoSold', 'LandSlope', '3SsnPorch', 'Street', 'PoolArea',
#        'Utilities', 'MSSubClass', 'LotFrontage', 'BsmtHalfBath', 'YrSold',
#        'OverallCond', 'MiscVal', 'BsmtFinSF2', 'LowQualFinSF', 'KitchenAbvGr',
#        'EnclosedPorch'],
#       dtype='object')

# %%
dc.values
# Out:
# array([ 1.        ,  0.76824932,  0.70263393,  0.67303324,  0.62928715,
#         0.6140762 ,  0.60552597,  0.60437014,  0.59701981,  0.58356596,
#         0.58353614,  0.56029789,  0.55009174,  0.54812857,  0.53640062,
#         0.5281791 ,  0.52554574,  0.50394703,  0.49782776,  0.48390755,
#         0.47463831,  0.45739893,  0.439549  ,  0.4322924 ,  0.41785653,
#         0.39794835,  0.36713628,  0.35369467,  0.3448488 ,  0.30800224,
#         0.30720396,  0.29808636,  0.28901628,  0.2778344 ,  0.27536833,
#         0.26708197,  0.26194069,  0.24156827,  0.22686601,  0.22295286,
#         0.22105277,  0.21755448,  0.21680361,  0.21361146,  0.20456827,
#         0.18463633,  0.1667754 ,  0.16023556,  0.15936121,  0.14560115,
#         0.1342063 ,  0.12623529,  0.11864576,  0.11840672,  0.1170426 ,
#         0.11194159,  0.09085625,  0.08670378,  0.08477998,  0.07986532,
#         0.06185559,  0.0573045 ,  0.05502138,  0.04543624,  0.04328827,
#         0.01621872,  0.01035575, -0.01945351, -0.03081619, -0.03125229,
#        -0.0339665 , -0.0397461 , -0.0648306 , -0.07406902, -0.1211036 ,
#        -0.22466914])

# %%
dc.index.values
# Out:
# array(['SalePrice', 'OverallQual', 'GrLivArea', 'Neighborhood',
#        'ExterQual', 'GarageCars', 'BsmtQual', 'KitchenQual', 'FullBath',
#        'YearBuilt', 'GarageArea', 'YearRemodAdd', 'GarageFinish',
#        '1stFlrSF', 'TotalBsmtSF', 'Foundation', 'GarageYrBlt',
#        'GarageType', 'TotRmsAbvGrd', 'FireplaceQu', 'OpenPorchSF',
#        'Fireplaces', 'HeatingQC', 'MSZoning', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'LotArea', 'MasVnrArea', 'WoodDeckSF',
#        'BsmtFinType1', 'CentralAir', 'LotShape', 'HouseStyle', 'HalfBath',
#        'Electrical', 'BsmtExposure', 'SaleType', 'PavedDrive', 'BsmtCond',
#        'GarageCond', 'Condition1', 'SaleCondition', 'GarageQual',
#        'BedroomAbvGr', 'BsmtFullBath', '2ndFlrSF', 'ExterCond',
#        'BldgType', 'LandContour', 'Functional', 'BsmtUnfSF', 'BsmtFinSF1',
#        'LotConfig', 'RoofStyle', 'Condition2', 'BsmtFinType2', 'Heating',
#        'RoofMatl', 'ScreenPorch', 'MoSold', 'LandSlope', '3SsnPorch',
#        'Street', 'PoolArea', 'Utilities', 'MSSubClass', 'LotFrontage',
#        'BsmtHalfBath', 'YrSold', 'OverallCond', 'MiscVal', 'BsmtFinSF2',
#        'LowQualFinSF', 'KitchenAbvGr', 'EnclosedPorch'], dtype=object)

# %%
dc_new=dc[(dc.values>0.5)&(dc.values<1)]
dc_new
# Out:
# OverallQual     0.768249
# GrLivArea       0.702634
# Neighborhood    0.673033
# ExterQual       0.629287
# GarageCars      0.614076
# BsmtQual        0.605526
# KitchenQual     0.604370
# FullBath        0.597020
# YearBuilt       0.583566
# GarageArea      0.583536
# YearRemodAdd    0.560298
# GarageFinish    0.550092
# 1stFlrSF        0.548129
# TotalBsmtSF     0.536401
# Foundation      0.528179
# GarageYrBlt     0.525546
# GarageType      0.503947
# Name: SalePrice, dtype: float64

# %%
feature_col=dc_new.index.values
feature_col
# Out:
# array(['OverallQual', 'GrLivArea', 'Neighborhood', 'ExterQual',
#        'GarageCars', 'BsmtQual', 'KitchenQual', 'FullBath', 'YearBuilt',
#        'GarageArea', 'YearRemodAdd', 'GarageFinish', '1stFlrSF',
#        'TotalBsmtSF', 'Foundation', 'GarageYrBlt', 'GarageType'],
#       dtype=object)

# %% [markdown]
# ### Select the features to be used in the data analysis

# %%
X=df_out[sorted(feature_col)]
y=df_out['SalePrice']

# %%
X.head()
# Out:
#    1stFlrSF  BsmtQual  ExterQual  Foundation  FullBath  GarageArea  \
# 0 -0.824125  0.734821   1.195598    1.039154  0.858174    0.512128
# 1  0.493595  0.734821  -0.709314   -0.618507  0.858174    0.031604
# 2 -0.579403  0.734821   1.195598    1.039154  0.858174    0.797415
# 3 -0.431410 -0.776426  -0.709314   -1.872480 -1.007698    0.946843
# 4  0.163280  0.734821   1.195598    1.039154  0.858174    1.672108
#
#    GarageCars  GarageFinish  GarageType  GarageYrBlt  GrLivArea  KitchenQual  \
# 0    0.388887      0.478714    0.618652     1.029416   0.614407     0.838286
# 1    0.388887      0.478714    0.618652    -0.054559  -0.394434    -0.764070
# 2    0.388887      0.478714    0.618652     0.949624   0.758827     0.838286
# 3    1.698569     -1.041009   -1.497105     0.829786   0.627974     0.838286
# 4    1.698569      0.478714    0.618652     0.909698   1.448243     0.838286
#
#    Neighborhood  OverallQual  TotalBsmtSF  YearBuilt  YearRemodAdd
# 0      0.677332     0.767682    -0.475745   1.054544      0.892774
# 1      1.016628     0.003225     0.693443   0.143383     -0.429140
# 2      0.677332     0.767682    -0.258607   0.987473      0.844132
# 3      0.769110     0.767682    -0.849813  -1.961839     -0.725350
# 4      1.296584     1.441980     0.400361   0.953912      0.746777

# %%
y.head()
# Out:
# 0    0.678476
# 1    0.259845
# 2    0.888186
# 3   -0.523824
# 4    1.226419
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Specify testing size

# %%
TS=0.2

# %% [markdown]
# ### Create a Result dataframe

# %%
result_col=['Algorithm','Correlation','Recursive','XGBoost']
result=pd.DataFrame(columns=result_col)
result['Algorithm']=['Ridge Regression','LASSO Regression','Elastic Net',
                     'Decision Tree','Random Forest','XGBoost']

# %%
result
# Out:
#           Algorithm Correlation Recursive XGBoost
# 0  Ridge Regression         NaN       NaN     NaN
# 1  LASSO Regression         NaN       NaN     NaN
# 2       Elastic Net         NaN       NaN     NaN
# 3     Decision Tree         NaN       NaN     NaN
# 4     Random Forest         NaN       NaN     NaN
# 5           XGBoost         NaN       NaN     NaN

# %% [markdown]
# ### Split the data to train and test dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=TS, random_state=200)

# %% [markdown]
# ### Ridge Regression

# %%
print(plt.rcParams["figure.figsize"])
plt.rcParams["figure.figsize"] = (8,4)
# Out:
# [6.0, 4.0]

# %%
from sklearn.linear_model import Ridge
RR=Ridge(alpha=0.001,fit_intercept=True)
RR_fit=RR.fit(x_train,y_train)

# %%
y_pred=RR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3830786435292067

# %%
y_pred=RR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][0]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][0]
# Out:
# 0.43191479508953057

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso
LR=Lasso(alpha=0.001,fit_intercept=True)
LR_fit=LR.fit(x_train,y_train)
y_pred=LR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3831230496553783

# %%
y_pred=LR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][1]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][1]
# Out:
# 0.43173309975562046

# %% [markdown]
# ### Elastic Net Model

# %%
from sklearn.linear_model import ElasticNetCV
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)
EN_fit=EN.fit(x_train, y_train)

# %%
y_pred=EN_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3831631530386058

# %%
y_pred=EN_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][2]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][2]
# Out:
# 0.43112008328590856

# %% [markdown]
# ### Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
DT=DecisionTreeRegressor()
DT_fit=DT.fit(x_train,y_train)

# %%
y_pred=DT_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.017613869923474745

# %%
y_pred=DT_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][3]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][3]
# Out:
# 0.6045383445550803

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)
RF_fit=RF.fit(x_train, y_train)

# %%
y_pred=RF_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.15603967525709628

# %%
y_pred=RF_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][4]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][4]
# Out:
# 0.4437594400748211

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=3000, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)
XG_fit=XG.fit(x_train, y_train)

# %%
y_pred=XG_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.10680257440535319

# %%
y_pred=XG_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][5]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][5]
# Out:
# 0.45538433254997623

# %% [markdown]
# ### Wrapper Method - Recursive Feature Elimination Method

# %%
from sklearn.feature_selection import RFECV

# %% [markdown]
# ### Split the data to train and test dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=TS, random_state=200)

# %% [markdown]
# ### Ridge Regression

# %%
RR=Ridge(alpha=0.001,fit_intercept=True)
RM_RR=RFECV(RR, step=1, cv=20, scoring='neg_mean_squared_error')
RM_RR_fit=RM_RR.fit(x_train,y_train)
RM_RR_fit.n_features_
# Out:
# 15

# %%
y_pred=RM_RR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3831329403200081

# %%
y_pred=RM_RR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][0]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][0]
# Out:
# 0.4323258289635714

# %% [markdown]
# ### Lasso Regression

# %%
LR=Lasso(alpha=0.001,fit_intercept=True)
RM_LR=RFECV(LR, step=1, cv=20, scoring='neg_mean_squared_error')
RM_LR_fit=RM_LR.fit(x_train,y_train)
RM_LR_fit.n_features_
# Out:
# 15

# %%
y_pred=RM_LR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.38316577874303137

# %%
y_pred=RM_LR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][1]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][1]
# Out:
# 0.4321356119973078

# %% [markdown]
# ### Elastic Net Model

# %%
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)
RM_EN=RFECV(EN, step=1, cv=20, scoring='neg_mean_squared_error')
RM_EN_fit=RM_EN.fit(x_train,y_train)
RM_EN_fit.n_features_
# Out:
# 15

# %%
y_pred=RM_EN_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3832074011822513

# %%
y_pred=RM_EN_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][2]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][2]
# Out:
# 0.43160745480135465

# %% [markdown]
# ### Decision Tree Model

# %%
DT=DecisionTreeRegressor()
RM_DT=RFECV(DT, step=1, cv=20, scoring='neg_mean_squared_error')
RM_DT_fit=RM_DT.fit(x_train,y_train)
RM_DT_fit.n_features_
# Out:
# 17

# %%
y_pred=RM_DT_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.017613869923474745

# %%
y_pred=RM_DT_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][3]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][3]
# Out:
# 0.6072012353128511

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)
RM_RF=RFECV(RF, step=1, cv=10, scoring='neg_mean_squared_error')
RM_RF_fit=RM_RF.fit(x_train,y_train)
RM_RF_fit.n_features_
# Out:
# 16

# %%
y_pred=RM_RF_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.15503724421869983

# %%
y_pred=RM_RF_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][4]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][4]
# Out:
# 0.44560689525933506

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=300, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)
RM_XG=RFECV(XG, step=1, cv=5, scoring='neg_mean_squared_error')
RM_XG_fit=RM_XG.fit(x_train,y_train)
RM_XG_fit.n_features_

# %%
y_pred=RM_XG_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=RM_XG_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][5]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][5]

# %% [markdown]
# ## Embedded Method - XGBoost Feature Importance

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
df_out_X=df_out.drop(columns=['SalePrice'])
df_out_y=df_out['SalePrice']
model.fit(df_out_X, df_out_y)
print(model.feature_importances_)

# %%
len(model.feature_importances_)

# %%
df_out_X.shape

# %%
df_out_X_col=df_out_X.columns.values

# %%
plt.rcParams["figure.figsize"] = (10,20)
plt.barh(df_out_X_col, model.feature_importances_)
plt.show()

# %%
df_XG=pd.DataFrame()

# %%
df_XG['Feature']=df_out_X_col
df_XG['Feature_Importance']=model.feature_importances_

# %%
df_XG.head()

# %%
df_XG=df_XG.sort_values(by=['Feature_Importance'],ascending=False)

# %%
df_XG

# %%
feature_col_XG=df_XG['Feature'][:12].values

# %%
feature_col_XG

# %% [markdown]
# ### Using the new selected features in the 6 models again.

# %%
X=df_out[feature_col_XG]
y=df_out['SalePrice']

# %%
feature_col_XG

# %% [markdown]
# ### Split the data to train and test dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=TS, random_state=200)

# %% [markdown]
# ### Ridge Regression

# %%
plt.rcParams["figure.figsize"] = (8,4)

# %%
from sklearn.linear_model import Ridge
RR=Ridge(alpha=0.0001,fit_intercept=True)
RR_fit=RR.fit(x_train,y_train)
y_pred=RR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=RR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][0]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][0]

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso
LR=Lasso(alpha=0.0001,fit_intercept=True)
LR_fit=LR.fit(x_train,y_train)
y_pred=LR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=LR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][1]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][1]

# %% [markdown]
# ### Elastic Net Model

# %%
from sklearn.linear_model import ElasticNetCV
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)
EN_fit=EN.fit(x_train, y_train)

# %%
y_pred=EN_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=EN_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][2]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][2]

# %% [markdown]
# ### Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
DT=DecisionTreeRegressor()
DT_fit=DT.fit(x_train,y_train)

# %%
y_pred=DT_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=DT_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][3]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][3]

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)
RF_fit=RF.fit(x_train, y_train)

# %%
y_pred=RF_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=RF_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][4]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][4]

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=3000, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)
XG_fit=XG.fit(x_train, y_train)

# %%
y_pred=XG_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=XG_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][5]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][5]

# %% [markdown]
# ## Examine the result

# %%
print('test-size: ',TS)

# %%
result
