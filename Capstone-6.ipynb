# %% [markdown]
# - 1stFlrSF:	 First Floor square feet
# - 2ndFlrSF:	 Second floor square feet
# - 3SsnPorch:	 Three season porch area in square feet
# - Alley:	 Type of alley access
# - Bedroom:	 Number of bedrooms above basement level
# - BldgType:	 Type of dwelling
# - BsmtCond:	 General condition of the basement
# - BsmtExposure:	 Walkout or garden level basement walls
# - BsmtFinSF1:	 Type 1 finished square feet
# - BsmtFinSF2:	 Type 2 finished square feet
# - BsmtFinType1:	 Quality of basement finished area
# - BsmtFinType2:	 Quality of second finished area (if present)
# - BsmtFullBath:	 Basement full bathrooms
# - BsmtHalfBath:	 Basement half bathrooms
# - BsmtQual:	 Height of the basement
# - BsmtUnfSF:	 Unfinished square feet of basement area
# - CentralAir:	 Central air conditioning
# - Condition1:	 Proximity to main road or railroad
# - Condition2:	 Proximity to main road or railroad (if a second is present)
# - Electrical:	 Electrical system
# - EnclosedPorch:	 Enclosed porch area in square feet
# - ExterCond:	 Present condition of the material on the exterior
# - Exterior1st:	 Exterior covering on house
# - Exterior2nd:	 Exterior covering on house (if more than one material)
# - ExterQual:	 Exterior material quality
# - Fence:	 Fence quality
# - FireplaceQu:	 Fireplace quality
# - Fireplaces:	 Number of fireplaces
# - Foundation:	 Type of foundation
# - FullBath:	 Full bathrooms above grade
# - Functional:	 Home functionality rating
# - GarageArea:	 Size of garage in square feet
# - GarageCars:	 Size of garage in car capacity
# - GarageCond:	 Garage condition
# - GarageFinish:	 Interior finish of the garage
# - GarageQual:	 Garage quality
# - GarageType:	 Garage location
# - GarageYrBlt:	 Year garage was built
# - GrLivArea:	 Above grade (ground) living area square feet
# - HalfBath:	 Half baths above grade
# - - Heating:	 Type of heating
# - HeatingQC:	 Heating quality and condition
# - HouseStyle:	 Style of dwelling
# - Id:	Observation Id
# - Kitchen:	 Number of kitchens
# - KitchenQual:	 Kitchen quality
# - LandContour:	 Flatness of the property
# - LandSlope:	 Slope of property
# - LotArea:	 Lot size in square feet
# - LotConfig:	 Lot configuration
# - LotFrontage:	 Linear feet of street connected to property
# - LotShape:	 General shape of property
# - LowQualFinSF:	 Low quality finished square feet (all floors)
# - MasVnrArea:	 Masonry veneer area in square feet
# - MasVnrType:	 Masonry veneer type
# - MiscFeature:	 Miscellaneous feature not covered in other categories
# - MiscVal:	 $Value of miscellaneous feature
# - MoSold:	 Month Sold
# - MSSubClass:	 The building class
# - MSZoning:	 The general zoning classification
# - Neighborhood:	 Physical locations within Ames city limits
# - OpenPorchSF:	 Open porch area in square feet
# - OverallCond:	 Overall condition rating
# - OverallQual:	 Overall material and finish quality
# - PavedDrive:	 Paved driveway
# - PoolArea:	 Pool area in square feet
# - PoolQC:	 Pool quality
# - RoofMatl:	 Roof material
# - RoofStyle:	 Type of roof
# - SaleCondition:	 Condition of sale
# - SalePrice:	 the property's sale price in dollars. This is the target variable that you're trying to predict.
# - SaleType:	 Type of sale
# - ScreenPorch:	 Screen porch area in square feet
# - Street:	 Type of road access
# - TotalBsmtSF:	 Total square feet of basement area
# - TotRmsAbvGrd:	 Total rooms above grade (does not include bathrooms)
# - Utilities:	 Type of utilities available
# - WoodDeckSF:	 Wood deck area in square feet
# - YearBuilt:	 Original construction date
# - YearRemodAdd:	 Remodel date
# - YrSold:	 Year Sold

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from scipy import stats
from scipy.stats import norm

from sklearn.preprocessing import StandardScaler
from sklearn import ensemble,tree,linear_model
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.utils import shuffle


import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('train.csv')

# %%
from IPython.display import display
pd.options.display.max_columns=None
df=df.reindex_axis(sorted(df.columns),axis=1)
df.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0       856       854          0   NaN             3     1Fam       TA
# 1      1262         0          0   NaN             3     1Fam       TA
# 2       920       866          0   NaN             3     1Fam       TA
# 3       961       756          0   NaN             3     1Fam       Gd
# 4      1145      1053          0   NaN             4     1Fam       TA
#
#   BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# 0           No         706           0          GLQ          Unf
# 1           Gd         978           0          ALQ          Unf
# 2           Mn         486           0          GLQ          Unf
# 3           No         216           0          ALQ          Unf
# 4           Av         655           0          GLQ          Unf
#
#    BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF CentralAir Condition1  \
# 0             1             0       Gd        150          Y       Norm
# 1             0             1       Gd        284          Y      Feedr
# 2             1             0       Gd        434          Y       Norm
# 3             1             0       TA        540          Y       Norm
# 4             1             0       Gd        490          Y       Norm
#
#   Condition2 Electrical  EnclosedPorch ExterCond ExterQual Exterior1st  \
# 0       Norm      SBrkr              0        TA        Gd     VinylSd
# 1       Norm      SBrkr              0        TA        TA     MetalSd
# 2       Norm      SBrkr              0        TA        Gd     VinylSd
# 3       Norm      SBrkr            272        TA        TA     Wd Sdng
# 4       Norm      SBrkr              0        TA        Gd     VinylSd
#
#   Exterior2nd Fence FireplaceQu  Fireplaces Foundation  FullBath Functional  \
# 0     VinylSd   NaN         NaN           0      PConc         2        Typ
# 1     MetalSd   NaN          TA           1     CBlock         2        Typ
# 2     VinylSd   NaN          TA           1      PConc         2        Typ
# 3     Wd Shng   NaN          Gd           1     BrkTil         1        Typ
# 4     VinylSd   NaN          TA           1      PConc         2        Typ
#
#    GarageArea  GarageCars GarageCond GarageFinish GarageQual GarageType  \
# 0         548           2         TA          RFn         TA     Attchd
# 1         460           2         TA          RFn         TA     Attchd
# 2         608           2         TA          RFn         TA     Attchd
# 3         642           3         TA          Unf         TA     Detchd
# 4         836           3         TA          RFn         TA     Attchd
#
#    GarageYrBlt  GrLivArea  HalfBath Heating HeatingQC HouseStyle  Id  \
# 0       2003.0       1710         1    GasA        Ex     2Story   1
# 1       1976.0       1262         0    GasA        Ex     1Story   2
# 2       2001.0       1786         1    GasA        Ex     2Story   3
# 3       1998.0       1717         0    GasA        Gd     2Story   4
# 4       2000.0       2198         1    GasA        Ex     2Story   5
#
#    KitchenAbvGr KitchenQual LandContour LandSlope  LotArea LotConfig  \
# 0             1          Gd         Lvl       Gtl     8450    Inside
# 1             1          TA         Lvl       Gtl     9600       FR2
# 2             1          Gd         Lvl       Gtl    11250    Inside
# 3             1          Gd         Lvl       Gtl     9550    Corner
# 4             1          Gd         Lvl       Gtl    14260       FR2
#
#    LotFrontage LotShape  LowQualFinSF  MSSubClass MSZoning  MasVnrArea  \
# 0         65.0      Reg             0          60       RL       196.0
# 1         80.0      Reg             0          20       RL         0.0
# 2         68.0      IR1             0          60       RL       162.0
# 3         60.0      IR1             0          70       RL         0.0
# 4         84.0      IR1             0          60       RL       350.0
#
#   MasVnrType MiscFeature  MiscVal  MoSold Neighborhood  OpenPorchSF  \
# 0    BrkFace         NaN        0       2      CollgCr           61
# 1       None         NaN        0       5      Veenker            0
# 2    BrkFace         NaN        0       9      CollgCr           42
# 3       None         NaN        0       2      Crawfor           35
# 4    BrkFace         NaN        0      12      NoRidge           84
#
#    OverallCond  OverallQual PavedDrive  PoolArea PoolQC RoofMatl RoofStyle  \
# 0            5            7          Y         0    NaN  CompShg     Gable
# 1            8            6          Y         0    NaN  CompShg     Gable
# 2            5            7          Y         0    NaN  CompShg     Gable
# 3            5            7          Y         0    NaN  CompShg     Gable
# 4            5            8          Y         0    NaN  CompShg     Gable
#
#   SaleCondition  SalePrice SaleType  ScreenPorch Street  TotRmsAbvGrd  \
# 0        Normal     208500       WD            0   Pave             8
# 1        Normal     181500       WD            0   Pave             6
# 2        Normal     223500       WD            0   Pave             6
# 3       Abnorml     140000       WD            0   Pave             7
# 4        Normal     250000       WD            0   Pave             9
#
#    TotalBsmtSF Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          856    AllPub           0       2003          2003    2008
# 1         1262    AllPub         298       1976          1976    2007
# 2          920    AllPub           0       2001          2002    2008
# 3          756    AllPub           0       1915          1970    2006
# 4         1145    AllPub         192       2000          2000    2008

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.dtypes
# Out:
# 1stFlrSF           int64
# 2ndFlrSF           int64
# 3SsnPorch          int64
# Alley             object
# BedroomAbvGr       int64
# BldgType          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtFinType1      object
# BsmtFinType2      object
# BsmtFullBath       int64
# BsmtHalfBath       int64
# BsmtQual          object
# BsmtUnfSF          int64
# CentralAir        object
# Condition1        object
# Condition2        object
# Electrical        object
# EnclosedPorch      int64
# ExterCond         object
# ExterQual         object
# Exterior1st       object
# Exterior2nd       object
# Fence             object
# FireplaceQu       object
# Fireplaces         int64
# Foundation        object
# FullBath           int64
#                   ...
# LotShape          object
# LowQualFinSF       int64
# MSSubClass         int64
# MSZoning          object
# MasVnrArea       float64
# MasVnrType        object
# MiscFeature       object
# MiscVal            int64
# MoSold             int64
# Neighborhood      object
# OpenPorchSF        int64
# OverallCond        int64
# OverallQual        int64
# PavedDrive        object
# PoolArea           int64
# PoolQC            object
# RoofMatl          object
# RoofStyle         object
# SaleCondition     object
# SalePrice          int64
# SaleType          object
# ScreenPorch        int64
# Street            object
# TotRmsAbvGrd       int64
# TotalBsmtSF        int64
# Utilities         object
# WoodDeckSF         int64
# YearBuilt          int64
# YearRemodAdd       int64
# YrSold             int64
# Length: 81, dtype: object

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# ### Checking NAs

# %%
null_cols=df.columns[df.isnull().any()]
df[null_cols].isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageType        81
# GarageQual        81
# GarageFinish      81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtFinType1      37
# BsmtCond          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %%
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
dg
# Out:
# PoolQC          99.520548
# MiscFeature     96.301370
# Alley           93.767123
# Fence           80.753425
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageType       5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtQual         2.534247
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# MasVnrArea       0.547945
# MasVnrType       0.547945
# Electrical       0.068493
# dtype: float64

# %%
featureName=dg.index.values
featureName
# Out:
# array(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu',
#        'LotFrontage', 'GarageYrBlt', 'GarageType', 'GarageQual',
#        'GarageFinish', 'GarageCond', 'BsmtFinType2', 'BsmtExposure',
#        'BsmtQual', 'BsmtFinType1', 'BsmtCond', 'MasVnrArea', 'MasVnrType',
#        'Electrical'], dtype=object)

# %%
def missingness(featureName):
    for i in featureName:
        print(i)
        print(df[i].value_counts(dropna=False))
        print("Value missing: %2.1f %%" % (df[i].isnull().sum()/len(df)*100))
        print()

# %% [markdown]
# ### Checking unique values of feature with more than 70% missning values

# %%
missingness(featureName)
# Out:
# PoolQC
# NaN    1453
# Gd        3
# Fa        2
# Ex        2
# Name: PoolQC, dtype: int64
# Value missing: 99.5 %
#
# MiscFeature
# NaN     1406
# Shed      49
# Othr       2
# Gar2       2
# TenC       1
# Name: MiscFeature, dtype: int64
# Value missing: 96.3 %
#
# Alley
# NaN     1369
# Grvl      50
# Pave      41
# Name: Alley, dtype: int64
# Value missing: 93.8 %
#
# Fence
# NaN      1179
# MnPrv     157
# GdPrv      59
# GdWo       54
# MnWw       11
# Name: Fence, dtype: int64
# Value missing: 80.8 %
#
# FireplaceQu
# NaN    690
# Gd     380
# TA     313
# Fa      33
# Ex      24
# Po      20
# Name: FireplaceQu, dtype: int64
# Value missing: 47.3 %
#
# LotFrontage
# NaN       259
#  60.0     143
#  70.0      70
#  80.0      69
#  50.0      57
#  75.0      53
#  65.0      44
#  85.0      40
#  78.0      25
#  21.0      23
#  90.0      23
#  68.0      19
#  24.0      19
#  64.0      19
#  73.0      18
#  72.0      17
#  79.0      17
#  63.0      17
#  55.0      17
#  100.0     16
#  51.0      15
#  66.0      15
#  74.0      15
#  52.0      14
#  59.0      13
#  71.0      12
#  67.0      12
#  57.0      12
#  82.0      12
#  43.0      12
#          ...
#  129.0      2
#  313.0      2
#  118.0      2
#  122.0      2
#  121.0      2
#  101.0      2
#  109.0      2
#  115.0      2
#  116.0      2
#  114.0      2
#  153.0      1
#  149.0      1
#  150.0      1
#  111.0      1
#  182.0      1
#  46.0       1
#  112.0      1
#  141.0      1
#  33.0       1
#  152.0      1
#  160.0      1
#  168.0      1
#  128.0      1
#  144.0      1
#  39.0       1
#  106.0      1
#  38.0       1
#  138.0      1
#  140.0      1
#  137.0      1
# Name: LotFrontage, Length: 111, dtype: int64
# Value missing: 17.7 %
#
# GarageYrBlt
# NaN        81
#  2005.0    65
#  2006.0    59
#  2004.0    53
#  2003.0    50
#  2007.0    49
#  1977.0    35
#  1998.0    31
#  1999.0    30
#  1976.0    29
#  2008.0    29
#  2000.0    27
#  2002.0    26
#  1968.0    26
#  1950.0    24
#  1993.0    22
#  1962.0    21
#  2009.0    21
#  1966.0    21
#  1965.0    21
#  1958.0    21
#  1970.0    20
#  1996.0    20
#  1957.0    20
#  2001.0    20
#  1997.0    19
#  1978.0    19
#  1960.0    19
#  1954.0    19
#  1974.0    18
#            ..
#  1916.0     5
#  1922.0     5
#  1936.0     5
#  1945.0     4
#  1946.0     4
#  1982.0     4
#  1931.0     4
#  1928.0     4
#  1935.0     4
#  1932.0     3
#  1952.0     3
#  1921.0     3
#  1938.0     3
#  2010.0     3
#  1910.0     3
#  1924.0     3
#  1923.0     3
#  1947.0     2
#  1918.0     2
#  1929.0     2
#  1914.0     2
#  1915.0     2
#  1934.0     2
#  1937.0     2
#  1942.0     2
#  1906.0     1
#  1927.0     1
#  1900.0     1
#  1908.0     1
#  1933.0     1
# Name: GarageYrBlt, Length: 98, dtype: int64
# Value missing: 5.5 %
#
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# NaN         81
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64
# Value missing: 5.5 %
#
# GarageQual
# TA     1311
# NaN      81
# Fa       48
# Gd       14
# Ex        3
# Po        3
# Name: GarageQual, dtype: int64
# Value missing: 5.5 %
#
# GarageFinish
# Unf    605
# RFn    422
# Fin    352
# NaN     81
# Name: GarageFinish, dtype: int64
# Value missing: 5.5 %
#
# GarageCond
# TA     1326
# NaN      81
# Fa       35
# Gd        9
# Po        7
# Ex        2
# Name: GarageCond, dtype: int64
# Value missing: 5.5 %
#
# BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      46
# NaN      38
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64
# Value missing: 2.6 %
#
# BsmtExposure
# No     953
# Av     221
# Gd     134
# Mn     114
# NaN     38
# Name: BsmtExposure, dtype: int64
# Value missing: 2.6 %
#
# BsmtQual
# TA     649
# Gd     618
# Ex     121
# NaN     37
# Fa      35
# Name: BsmtQual, dtype: int64
# Value missing: 2.5 %
#
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# NaN     37
# Name: BsmtFinType1, dtype: int64
# Value missing: 2.5 %
#
# BsmtCond
# TA     1311
# Gd       65
# Fa       45
# NaN      37
# Po        2
# Name: BsmtCond, dtype: int64
# Value missing: 2.5 %
#
# MasVnrArea
#  0.0       861
#  72.0        8
#  180.0       8
# NaN          8
#  108.0       8
#  120.0       7
#  16.0        7
#  106.0       6
#  80.0        6
#  340.0       6
#  200.0       6
#  132.0       5
#  170.0       5
#  360.0       5
#  84.0        5
#  320.0       5
#  270.0       4
#  183.0       4
#  100.0       4
#  168.0       4
#  252.0       4
#  178.0       4
#  246.0       4
#  196.0       4
#  288.0       4
#  216.0       4
#  160.0       4
#  220.0       4
#  336.0       4
#  210.0       4
#           ...
#  24.0        1
#  760.0       1
#  138.0       1
#  27.0        1
#  541.0       1
#  275.0       1
#  365.0       1
#  562.0       1
#  161.0       1
#  247.0       1
#  452.0       1
#  278.0       1
#  375.0       1
#  225.0       1
#  604.0       1
#  762.0       1
#  290.0       1
#  109.0       1
#  299.0       1
#  731.0       1
#  167.0       1
#  309.0       1
#  202.0       1
#  1129.0      1
#  651.0       1
#  337.0       1
#  415.0       1
#  293.0       1
#  259.0       1
#  621.0       1
# Name: MasVnrArea, Length: 328, dtype: int64
# Value missing: 0.5 %
#
# MasVnrType
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# NaN          8
# Name: MasVnrType, dtype: int64
# Value missing: 0.5 %
#
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# NaN         1
# Name: Electrical, dtype: int64
# Value missing: 0.1 %

# %% [markdown]
# ### Remove columns with more than 70% of missing values

# %%
df=df.drop(columns=['PoolQC','MiscFeature','Alley','Fence'])

# %%
df.shape
# Out:
# (1460, 77)

# %% [markdown]
# ### Checking the rest of features with missing values

# %%
null_cols=df.columns[df.isnull().any()]
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
print(dg)
nullCol=dg.index.values
nullCol
# Out:
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageType       5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtQual         2.534247
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# MasVnrType       0.547945
# MasVnrArea       0.547945
# Electrical       0.068493
# dtype: float64
# array(['FireplaceQu', 'LotFrontage', 'GarageYrBlt', 'GarageType',
#        'GarageQual', 'GarageFinish', 'GarageCond', 'BsmtFinType2',
#        'BsmtExposure', 'BsmtQual', 'BsmtFinType1', 'BsmtCond',
#        'MasVnrType', 'MasVnrArea', 'Electrical'], dtype=object)

# %%
df[df.FireplaceQu.isnull()].head()
# Out:
#     1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr BldgType BsmtCond  \
# 0        856       854          0             3     1Fam       TA
# 5        796       566        320             1     1Fam       TA
# 10      1040         0          0             3     1Fam       TA
# 12       912         0          0             2     1Fam       TA
# 15       854         0          0             2     1Fam       TA
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# 0            No         706           0          GLQ          Unf
# 5            No         732           0          GLQ          Unf
# 10           No         906           0          Rec          Unf
# 12           No         737           0          ALQ          Unf
# 15           No           0           0          Unf          Unf
#
#     BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF CentralAir Condition1  \
# 0              1             0       Gd        150          Y       Norm
# 5              1             0       Gd         64          Y       Norm
# 10             1             0       TA        134          Y       Norm
# 12             1             0       TA        175          Y       Norm
# 15             0             0       TA        832          Y       Norm
#
#    Condition2 Electrical  EnclosedPorch ExterCond ExterQual Exterior1st  \
# 0        Norm      SBrkr              0        TA        Gd     VinylSd
# 5        Norm      SBrkr              0        TA        TA     VinylSd
# 10       Norm      SBrkr              0        TA        TA     HdBoard
# 12       Norm      SBrkr              0        TA        TA     HdBoard
# 15       Norm      FuseA              0        TA        TA     Wd Sdng
#
#    Exterior2nd FireplaceQu  Fireplaces Foundation  FullBath Functional  \
# 0      VinylSd         NaN           0      PConc         2        Typ
# 5      VinylSd         NaN           0       Wood         1        Typ
# 10     HdBoard         NaN           0     CBlock         1        Typ
# 12     Plywood         NaN           0     CBlock         1        Typ
# 15     Wd Sdng         NaN           0     BrkTil         1        Typ
#
#     GarageArea  GarageCars GarageCond GarageFinish GarageQual GarageType  \
# 0          548           2         TA          RFn         TA     Attchd
# 5          480           2         TA          Unf         TA     Attchd
# 10         384           1         TA          Unf         TA     Detchd
# 12         352           1         TA          Unf         TA     Detchd
# 15         576           2         TA          Unf         TA     Detchd
#
#     GarageYrBlt  GrLivArea  HalfBath Heating HeatingQC HouseStyle  Id  \
# 0        2003.0       1710         1    GasA        Ex     2Story   1
# 5        1993.0       1362         1    GasA        Ex     1.5Fin   6
# 10       1965.0       1040         0    GasA        Ex     1Story  11
# 12       1962.0        912         0    GasA        TA     1Story  13
# 15       1991.0        854         0    GasA        Ex     1.5Unf  16
#
#     KitchenAbvGr KitchenQual LandContour LandSlope  LotArea LotConfig  \
# 0              1          Gd         Lvl       Gtl     8450    Inside
# 5              1          TA         Lvl       Gtl    14115    Inside
# 10             1          TA         Lvl       Gtl    11200    Inside
# 12             1          TA         Lvl       Gtl    12968    Inside
# 15             1          TA         Lvl       Gtl     6120    Corner
#
#     LotFrontage LotShape  LowQualFinSF  MSSubClass MSZoning  MasVnrArea  \
# 0          65.0      Reg             0          60       RL       196.0
# 5          85.0      IR1             0          50       RL         0.0
# 10         70.0      Reg             0          20       RL         0.0
# 12          NaN      IR2             0          20       RL         0.0
# 15         51.0      Reg             0          45       RM         0.0
#
#    MasVnrType  MiscVal  MoSold Neighborhood  OpenPorchSF  OverallCond  \
# 0     BrkFace        0       2      CollgCr           61            5
# 5        None      700      10      Mitchel           30            5
# 10       None        0       2       Sawyer            0            5
# 12       None        0       9       Sawyer            0            6
# 15       None        0       7      BrkSide          112            8
#
#     OverallQual PavedDrive  PoolArea RoofMatl RoofStyle SaleCondition  \
# 0             7          Y         0  CompShg     Gable        Normal
# 5             5          Y         0  CompShg     Gable        Normal
# 10            5          Y         0  CompShg       Hip        Normal
# 12            5          Y         0  CompShg       Hip        Normal
# 15            7          Y         0  CompShg     Gable        Normal
#
#     SalePrice SaleType  ScreenPorch Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0      208500       WD            0   Pave             8          856
# 5      143000       WD            0   Pave             5          796
# 10     129500       WD            0   Pave             5         1040
# 12     144000       WD          176   Pave             4          912
# 15     132000       WD            0   Pave             5          832
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0     AllPub           0       2003          2003    2008
# 5     AllPub          40       1993          1995    2009
# 10    AllPub           0       1965          1965    2008
# 12    AllPub         140       1962          1962    2008
# 15    AllPub          48       1929          2001    2007

# %%
df['FireplaceQu'].value_counts(dropna=False)
# Out:
# NaN    690
# Gd     380
# TA     313
# Fa      33
# Ex      24
# Po      20
# Name: FireplaceQu, dtype: int64

# %%
df.columns.values
# Out:
# array(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'BedroomAbvGr', 'BldgType',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtFinType1', 'BsmtFinType2', 'BsmtFullBath', 'BsmtHalfBath',
#        'BsmtQual', 'BsmtUnfSF', 'CentralAir', 'Condition1', 'Condition2',
#        'Electrical', 'EnclosedPorch', 'ExterCond', 'ExterQual',
#        'Exterior1st', 'Exterior2nd', 'FireplaceQu', 'Fireplaces',
#        'Foundation', 'FullBath', 'Functional', 'GarageArea', 'GarageCars',
#        'GarageCond', 'GarageFinish', 'GarageQual', 'GarageType',
#        'GarageYrBlt', 'GrLivArea', 'HalfBath', 'Heating', 'HeatingQC',
#        'HouseStyle', 'Id', 'KitchenAbvGr', 'KitchenQual', 'LandContour',
#        'LandSlope', 'LotArea', 'LotConfig', 'LotFrontage', 'LotShape',
#        'LowQualFinSF', 'MSSubClass', 'MSZoning', 'MasVnrArea',
#        'MasVnrType', 'MiscVal', 'MoSold', 'Neighborhood', 'OpenPorchSF',
#        'OverallCond', 'OverallQual', 'PavedDrive', 'PoolArea', 'RoofMatl',
#        'RoofStyle', 'SaleCondition', 'SalePrice', 'SaleType',
#        'ScreenPorch', 'Street', 'TotRmsAbvGrd', 'TotalBsmtSF',
#        'Utilities', 'WoodDeckSF', 'YearBuilt', 'YearRemodAdd', 'YrSold'],
#       dtype=object)

# %% [markdown]
# ### Sklearn SimpleImputer

# %%
from sklearn.impute import SimpleImputer

# %%
imp=SimpleImputer(missing_values=np.nan, strategy='most_frequent')

# %%
df1=pd.DataFrame(imp.fit_transform(df))

# %%
df1.columns=df.columns

# %%
df1.head()
# Out:
#   1stFlrSF 2ndFlrSF 3SsnPorch BedroomAbvGr BldgType BsmtCond BsmtExposure  \
# 0      856      854         0            3     1Fam       TA           No
# 1     1262        0         0            3     1Fam       TA           Gd
# 2      920      866         0            3     1Fam       TA           Mn
# 3      961      756         0            3     1Fam       Gd           No
# 4     1145     1053         0            4     1Fam       TA           Av
#
#   BsmtFinSF1 BsmtFinSF2 BsmtFinType1 BsmtFinType2 BsmtFullBath BsmtHalfBath  \
# 0        706          0          GLQ          Unf            1            0
# 1        978          0          ALQ          Unf            0            1
# 2        486          0          GLQ          Unf            1            0
# 3        216          0          ALQ          Unf            1            0
# 4        655          0          GLQ          Unf            1            0
#
#   BsmtQual BsmtUnfSF CentralAir Condition1 Condition2 Electrical  \
# 0       Gd       150          Y       Norm       Norm      SBrkr
# 1       Gd       284          Y      Feedr       Norm      SBrkr
# 2       Gd       434          Y       Norm       Norm      SBrkr
# 3       TA       540          Y       Norm       Norm      SBrkr
# 4       Gd       490          Y       Norm       Norm      SBrkr
#
#   EnclosedPorch ExterCond ExterQual Exterior1st Exterior2nd FireplaceQu  \
# 0             0        TA        Gd     VinylSd     VinylSd          Gd
# 1             0        TA        TA     MetalSd     MetalSd          TA
# 2             0        TA        Gd     VinylSd     VinylSd          TA
# 3           272        TA        TA     Wd Sdng     Wd Shng          Gd
# 4             0        TA        Gd     VinylSd     VinylSd          TA
#
#   Fireplaces Foundation FullBath Functional GarageArea GarageCars GarageCond  \
# 0          0      PConc        2        Typ        548          2         TA
# 1          1     CBlock        2        Typ        460          2         TA
# 2          1      PConc        2        Typ        608          2         TA
# 3          1     BrkTil        1        Typ        642          3         TA
# 4          1      PConc        2        Typ        836          3         TA
#
#   GarageFinish GarageQual GarageType GarageYrBlt GrLivArea HalfBath Heating  \
# 0          RFn         TA     Attchd        2003      1710        1    GasA
# 1          RFn         TA     Attchd        1976      1262        0    GasA
# 2          RFn         TA     Attchd        2001      1786        1    GasA
# 3          Unf         TA     Detchd        1998      1717        0    GasA
# 4          RFn         TA     Attchd        2000      2198        1    GasA
#
#   HeatingQC HouseStyle Id KitchenAbvGr KitchenQual LandContour LandSlope  \
# 0        Ex     2Story  1            1          Gd         Lvl       Gtl
# 1        Ex     1Story  2            1          TA         Lvl       Gtl
# 2        Ex     2Story  3            1          Gd         Lvl       Gtl
# 3        Gd     2Story  4            1          Gd         Lvl       Gtl
# 4        Ex     2Story  5            1          Gd         Lvl       Gtl
#
#   LotArea LotConfig LotFrontage LotShape LowQualFinSF MSSubClass MSZoning  \
# 0    8450    Inside          65      Reg            0         60       RL
# 1    9600       FR2          80      Reg            0         20       RL
# 2   11250    Inside          68      IR1            0         60       RL
# 3    9550    Corner          60      IR1            0         70       RL
# 4   14260       FR2          84      IR1            0         60       RL
#
#   MasVnrArea MasVnrType MiscVal MoSold Neighborhood OpenPorchSF OverallCond  \
# 0        196    BrkFace       0      2      CollgCr          61           5
# 1          0       None       0      5      Veenker           0           8
# 2        162    BrkFace       0      9      CollgCr          42           5
# 3          0       None       0      2      Crawfor          35           5
# 4        350    BrkFace       0     12      NoRidge          84           5
#
#   OverallQual PavedDrive PoolArea RoofMatl RoofStyle SaleCondition SalePrice  \
# 0           7          Y        0  CompShg     Gable        Normal    208500
# 1           6          Y        0  CompShg     Gable        Normal    181500
# 2           7          Y        0  CompShg     Gable        Normal    223500
# 3           7          Y        0  CompShg     Gable       Abnorml    140000
# 4           8          Y        0  CompShg     Gable        Normal    250000
#
#   SaleType ScreenPorch Street TotRmsAbvGrd TotalBsmtSF Utilities WoodDeckSF  \
# 0       WD           0   Pave            8         856    AllPub          0
# 1       WD           0   Pave            6        1262    AllPub        298
# 2       WD           0   Pave            6         920    AllPub          0
# 3       WD           0   Pave            7         756    AllPub          0
# 4       WD           0   Pave            9        1145    AllPub        192
#
#   YearBuilt YearRemodAdd YrSold
# 0      2003         2003   2008
# 1      1976         1976   2007
# 2      2001         2002   2008
# 3      1915         1970   2006
# 4      2000         2000   2008

# %%
df1.isnull().sum()
# Out:
# 1stFlrSF         0
# 2ndFlrSF         0
# 3SsnPorch        0
# BedroomAbvGr     0
# BldgType         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtFinType1     0
# BsmtFinType2     0
# BsmtFullBath     0
# BsmtHalfBath     0
# BsmtQual         0
# BsmtUnfSF        0
# CentralAir       0
# Condition1       0
# Condition2       0
# Electrical       0
# EnclosedPorch    0
# ExterCond        0
# ExterQual        0
# Exterior1st      0
# Exterior2nd      0
# FireplaceQu      0
# Fireplaces       0
# Foundation       0
# FullBath         0
# Functional       0
# GarageArea       0
#                 ..
# LotConfig        0
# LotFrontage      0
# LotShape         0
# LowQualFinSF     0
# MSSubClass       0
# MSZoning         0
# MasVnrArea       0
# MasVnrType       0
# MiscVal          0
# MoSold           0
# Neighborhood     0
# OpenPorchSF      0
# OverallCond      0
# OverallQual      0
# PavedDrive       0
# PoolArea         0
# RoofMatl         0
# RoofStyle        0
# SaleCondition    0
# SalePrice        0
# SaleType         0
# ScreenPorch      0
# Street           0
# TotRmsAbvGrd     0
# TotalBsmtSF      0
# Utilities        0
# WoodDeckSF       0
# YearBuilt        0
# YearRemodAdd     0
# YrSold           0
# Length: 77, dtype: int64

# %%
df1.shape
# Out:
# (1460, 77)

# %%
df.shape
# Out:
# (1460, 77)

# %%
df=df1

# %% [markdown]
# ### Remove Outliers

# %%
Q1=df.YearBuilt.quantile(0.25)
Q1
# Out:
# 1954.0

# %%
corr=df.corr()["SalePrice"]
corr[np.argsort(corr, axis=0)[::-1]]
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %%
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
# 5       143000
# 6       307000
# 7       200000
# 8       129900
# 9       118000
# 10      129500
# 11      345000
# 12      144000
# 13      279500
# 14      157000
# 15      132000
# 16      149000
# 17       90000
# 18      159000
# 19      139000
# 20      325300
# 21      139400
# 22      230000
# 23      129900
# 24      154000
# 25      256300
# 26      134800
# 27      306000
# 28      207500
# 29       68500
#          ...
# 1430    192140
# 1431    143750
# 1432     64500
# 1433    186500
# 1434    160000
# 1435    174000
# 1436    120500
# 1437    394617
# 1438    149700
# 1439    197000
# 1440    191000
# 1441    149300
# 1442    310000
# 1443    121000
# 1444    179600
# 1445    129000
# 1446    157900
# 1447    240000
# 1448    112000
# 1449     92000
# 1450    136000
# 1451    287090
# 1452    145000
# 1453     84500
# 1454    185000
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: object
