# %% [markdown]
# ## 1. Data Exploration/Cleaning
# - Checking null values
# - Remove outliers
#
# ## 2. Features Selection
# - Filter Method - Correlation Matrix
# - Wrapper Method - Recursive Method
# - Embedded Method - XGBoost Feature Importance
#
#
# ## 3.	Models
# - Ridge Regression
# - LASSO Regression
# - Elastic Net Regression
# - Decision Tree
# - Random Forest
# - XGBoost
#
# ## 4.	Models Evaluation
# - RMSE (Root Mean Squred Error)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from scipy import stats
from scipy.stats import norm


from sklearn.preprocessing import StandardScaler
from sklearn import ensemble, tree, linear_model
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict

from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor

from sklearn.feature_selection import RFECV

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read the dataset

# %%
df=pd.read_csv('train.csv')

# %%
from IPython.display import display
pd.options.display.max_columns=None
df=df.reindex_axis(sorted(df.columns),axis=1)
df.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0       856       854          0   NaN             3     1Fam       TA
# 1      1262         0          0   NaN             3     1Fam       TA
# 2       920       866          0   NaN             3     1Fam       TA
# 3       961       756          0   NaN             3     1Fam       Gd
# 4      1145      1053          0   NaN             4     1Fam       TA
#
#   BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# 0           No         706           0          GLQ          Unf
# 1           Gd         978           0          ALQ          Unf
# 2           Mn         486           0          GLQ          Unf
# 3           No         216           0          ALQ          Unf
# 4           Av         655           0          GLQ          Unf
#
#    BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF CentralAir Condition1  \
# 0             1             0       Gd        150          Y       Norm
# 1             0             1       Gd        284          Y      Feedr
# 2             1             0       Gd        434          Y       Norm
# 3             1             0       TA        540          Y       Norm
# 4             1             0       Gd        490          Y       Norm
#
#   Condition2 Electrical  EnclosedPorch ExterCond ExterQual Exterior1st  \
# 0       Norm      SBrkr              0        TA        Gd     VinylSd
# 1       Norm      SBrkr              0        TA        TA     MetalSd
# 2       Norm      SBrkr              0        TA        Gd     VinylSd
# 3       Norm      SBrkr            272        TA        TA     Wd Sdng
# 4       Norm      SBrkr              0        TA        Gd     VinylSd
#
#   Exterior2nd Fence FireplaceQu  Fireplaces Foundation  FullBath Functional  \
# 0     VinylSd   NaN         NaN           0      PConc         2        Typ
# 1     MetalSd   NaN          TA           1     CBlock         2        Typ
# 2     VinylSd   NaN          TA           1      PConc         2        Typ
# 3     Wd Shng   NaN          Gd           1     BrkTil         1        Typ
# 4     VinylSd   NaN          TA           1      PConc         2        Typ
#
#    GarageArea  GarageCars GarageCond GarageFinish GarageQual GarageType  \
# 0         548           2         TA          RFn         TA     Attchd
# 1         460           2         TA          RFn         TA     Attchd
# 2         608           2         TA          RFn         TA     Attchd
# 3         642           3         TA          Unf         TA     Detchd
# 4         836           3         TA          RFn         TA     Attchd
#
#    GarageYrBlt  GrLivArea  HalfBath Heating HeatingQC HouseStyle  Id  \
# 0       2003.0       1710         1    GasA        Ex     2Story   1
# 1       1976.0       1262         0    GasA        Ex     1Story   2
# 2       2001.0       1786         1    GasA        Ex     2Story   3
# 3       1998.0       1717         0    GasA        Gd     2Story   4
# 4       2000.0       2198         1    GasA        Ex     2Story   5
#
#    KitchenAbvGr KitchenQual LandContour LandSlope  LotArea LotConfig  \
# 0             1          Gd         Lvl       Gtl     8450    Inside
# 1             1          TA         Lvl       Gtl     9600       FR2
# 2             1          Gd         Lvl       Gtl    11250    Inside
# 3             1          Gd         Lvl       Gtl     9550    Corner
# 4             1          Gd         Lvl       Gtl    14260       FR2
#
#    LotFrontage LotShape  LowQualFinSF  MSSubClass MSZoning  MasVnrArea  \
# 0         65.0      Reg             0          60       RL       196.0
# 1         80.0      Reg             0          20       RL         0.0
# 2         68.0      IR1             0          60       RL       162.0
# 3         60.0      IR1             0          70       RL         0.0
# 4         84.0      IR1             0          60       RL       350.0
#
#   MasVnrType MiscFeature  MiscVal  MoSold Neighborhood  OpenPorchSF  \
# 0    BrkFace         NaN        0       2      CollgCr           61
# 1       None         NaN        0       5      Veenker            0
# 2    BrkFace         NaN        0       9      CollgCr           42
# 3       None         NaN        0       2      Crawfor           35
# 4    BrkFace         NaN        0      12      NoRidge           84
#
#    OverallCond  OverallQual PavedDrive  PoolArea PoolQC RoofMatl RoofStyle  \
# 0            5            7          Y         0    NaN  CompShg     Gable
# 1            8            6          Y         0    NaN  CompShg     Gable
# 2            5            7          Y         0    NaN  CompShg     Gable
# 3            5            7          Y         0    NaN  CompShg     Gable
# 4            5            8          Y         0    NaN  CompShg     Gable
#
#   SaleCondition  SalePrice SaleType  ScreenPorch Street  TotRmsAbvGrd  \
# 0        Normal     208500       WD            0   Pave             8
# 1        Normal     181500       WD            0   Pave             6
# 2        Normal     223500       WD            0   Pave             6
# 3       Abnorml     140000       WD            0   Pave             7
# 4        Normal     250000       WD            0   Pave             9
#
#    TotalBsmtSF Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          856    AllPub           0       2003          2003    2008
# 1         1262    AllPub         298       1976          1976    2007
# 2          920    AllPub           0       2001          2002    2008
# 3          756    AllPub           0       1915          1970    2006
# 4         1145    AllPub         192       2000          2000    2008

# %%
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### Remove "Id" from dataset

# %%
df=df.drop(columns=['Id'])

# %%
df.shape
# Out:
# (1460, 80)

# %%
df.columns
# Out:
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'Alley', 'BedroomAbvGr',
#        'BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtFinType1', 'BsmtFinType2', 'BsmtFullBath', 'BsmtHalfBath',
#        'BsmtQual', 'BsmtUnfSF', 'CentralAir', 'Condition1', 'Condition2',
#        'Electrical', 'EnclosedPorch', 'ExterCond', 'ExterQual', 'Exterior1st',
#        'Exterior2nd', 'Fence', 'FireplaceQu', 'Fireplaces', 'Foundation',
#        'FullBath', 'Functional', 'GarageArea', 'GarageCars', 'GarageCond',
#        'GarageFinish', 'GarageQual', 'GarageType', 'GarageYrBlt', 'GrLivArea',
#        'HalfBath', 'Heating', 'HeatingQC', 'HouseStyle', 'KitchenAbvGr',
#        'KitchenQual', 'LandContour', 'LandSlope', 'LotArea', 'LotConfig',
#        'LotFrontage', 'LotShape', 'LowQualFinSF', 'MSSubClass', 'MSZoning',
#        'MasVnrArea', 'MasVnrType', 'MiscFeature', 'MiscVal', 'MoSold',
#        'Neighborhood', 'OpenPorchSF', 'OverallCond', 'OverallQual',
#        'PavedDrive', 'PoolArea', 'PoolQC', 'RoofMatl', 'RoofStyle',
#        'SaleCondition', 'SalePrice', 'SaleType', 'ScreenPorch', 'Street',
#        'TotRmsAbvGrd', 'TotalBsmtSF', 'Utilities', 'WoodDeckSF', 'YearBuilt',
#        'YearRemodAdd', 'YrSold'],
#       dtype='object')

# %% [markdown]
# ## 1. Data Exploration/Cleaning

# %% [markdown]
# ### Checking NAs

# %%
null_cols=df.columns[df.isnull().any()]
print(df[null_cols].isnull().sum().sort_values(ascending=False))
print()
print("Number of variables with NaN value:",len(null_cols.values))
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageType        81
# GarageQual        81
# GarageFinish      81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtFinType1      37
# BsmtCond          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64
#
# Number of variables with NaN value: 19

# %% [markdown]
# ### It looks like "PoolQC" has "NaN" value when "PoolArea" has "zero" value.
# ### Let's check if the number of missing value in "PoolQC" is the same as the number of rows with zero value in "PoolArea"

# %%
df['PoolQC'].isnull().sum()
# Out:
# 1453

# %%
len(df['PoolArea'][df['PoolArea']==0])
# Out:
# 1453

# %% [markdown]
# ### It turns out the number is the same.
# ### We can go ahead and replace the "NaN" in "PoolQC" with "0"

# %%
df['PoolQC'].fillna(0,inplace=True)

# %%
len(df['PoolQC'][df['PoolQC']==0])
# Out:
# 1453

# %%
null_cols=df.columns[df.isnull().any()]
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
dg
# Out:
# MiscFeature     96.301370
# Alley           93.767123
# Fence           80.753425
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageType       5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtQual         2.534247
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# MasVnrArea       0.547945
# MasVnrType       0.547945
# Electrical       0.068493
# dtype: float64

# %% [markdown]
# ### Remove columns with more than 80% of missing values

# %%
df=df.drop(columns=['MiscFeature','Alley','Fence'])

# %%
df.shape
# Out:
# (1460, 77)

# %% [markdown]
# ### Checking the rest of features with missing values

# %%
null_cols=df.columns[df.isnull().any()]
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
print(dg)
nullCol=dg.index.values
nullCol
# Out:
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageType       5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtQual         2.534247
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# MasVnrType       0.547945
# MasVnrArea       0.547945
# Electrical       0.068493
# dtype: float64
# array(['FireplaceQu', 'LotFrontage', 'GarageYrBlt', 'GarageType',
#        'GarageQual', 'GarageFinish', 'GarageCond', 'BsmtFinType2',
#        'BsmtExposure', 'BsmtQual', 'BsmtFinType1', 'BsmtCond',
#        'MasVnrType', 'MasVnrArea', 'Electrical'], dtype=object)

# %% [markdown]
# ### It looks like "FireplaceQu" has "NaN" value when "Fireplaces" has "zero" value.
# ### Let's check if the number of missing value in "FireplaceQu" is the same as the number of rows with zero value in "Fireplaces"

# %%
df['FireplaceQu'].isnull().sum()
# Out:
# 690

# %%
len(df.loc[df['Fireplaces']==0])
# Out:
# 690

# %% [markdown]
# ### It turns out the number is the same.
# ### We can go ahead and replace the "NaN" in "FireplaceQu" with "0"

# %%
df['FireplaceQu'].fillna(0,inplace=True)

# %% [markdown]
# ### Some Lot just does not have LotFronage.
# ### Change "NaN" value to "zero" in "LotFrontage"

# %%
df['LotFrontage'].fillna(0,inplace=True)

# %% [markdown]
# ### Check if the number of "0" value is the same as the number "NaN" value

# %%
len(df['LotFrontage'][df['LotFrontage']==0])
# Out:
# 259

# %% [markdown]
# ### Double check all the missing values again

# %%
null_cols=df.columns[df.isnull().any()]
df[null_cols].isnull().sum().sort_values(ascending=False)
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
dg
# Out:
# GarageYrBlt     5.547945
# GarageType      5.547945
# GarageQual      5.547945
# GarageFinish    5.547945
# GarageCond      5.547945
# BsmtFinType2    2.602740
# BsmtExposure    2.602740
# BsmtQual        2.534247
# BsmtFinType1    2.534247
# BsmtCond        2.534247
# MasVnrType      0.547945
# MasVnrArea      0.547945
# Electrical      0.068493
# dtype: float64

# %% [markdown]
# ### All the remaining variables have less than 6% of missing values.
# ### We will remove all the rows with any missing values.

# %%
df_miss=df.dropna()

# %%
df_miss.isnull().sum()
# Out:
# 1stFlrSF         0
# 2ndFlrSF         0
# 3SsnPorch        0
# BedroomAbvGr     0
# BldgType         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtFinType1     0
# BsmtFinType2     0
# BsmtFullBath     0
# BsmtHalfBath     0
# BsmtQual         0
# BsmtUnfSF        0
# CentralAir       0
# Condition1       0
# Condition2       0
# Electrical       0
# EnclosedPorch    0
# ExterCond        0
# ExterQual        0
# Exterior1st      0
# Exterior2nd      0
# FireplaceQu      0
# Fireplaces       0
# Foundation       0
# FullBath         0
# Functional       0
# GarageArea       0
#                 ..
# LotFrontage      0
# LotShape         0
# LowQualFinSF     0
# MSSubClass       0
# MSZoning         0
# MasVnrArea       0
# MasVnrType       0
# MiscVal          0
# MoSold           0
# Neighborhood     0
# OpenPorchSF      0
# OverallCond      0
# OverallQual      0
# PavedDrive       0
# PoolArea         0
# PoolQC           0
# RoofMatl         0
# RoofStyle        0
# SaleCondition    0
# SalePrice        0
# SaleType         0
# ScreenPorch      0
# Street           0
# TotRmsAbvGrd     0
# TotalBsmtSF      0
# Utilities        0
# WoodDeckSF       0
# YearBuilt        0
# YearRemodAdd     0
# YrSold           0
# Length: 77, dtype: int64

# %%
df_miss.shape
# Out:
# (1338, 77)

# %%
len(df)-len(df_miss)
# Out:
# 122

# %% [markdown]
# ### Checking the percentage of data removed

# %%
(len(df)-len(df_miss))/len(df)*100
# Out:
# 8.356164383561644

# %% [markdown]
# ## Convert all string categorical variables to ordinal categorical variables

# %%
cat_col=df_miss.select_dtypes(include=['object']).columns
cat_col
# Out:
# Index(['BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'BsmtQual', 'CentralAir', 'Condition1', 'Condition2', 'Electrical',
#        'ExterCond', 'ExterQual', 'Exterior1st', 'Exterior2nd', 'FireplaceQu',
#        'Foundation', 'Functional', 'GarageCond', 'GarageFinish', 'GarageQual',
#        'GarageType', 'Heating', 'HeatingQC', 'HouseStyle', 'KitchenQual',
#        'LandContour', 'LandSlope', 'LotConfig', 'LotShape', 'MSZoning',
#        'MasVnrType', 'Neighborhood', 'PavedDrive', 'PoolQC', 'RoofMatl',
#        'RoofStyle', 'SaleCondition', 'SaleType', 'Street', 'Utilities'],
#       dtype='object')

# %%
for item1 in cat_col:
    df_mean=pd.concat([df_miss[item1],df_miss['SalePrice']],axis=1)
    df_mean.head()

    g1=df_mean.groupby(item1).mean()
    g1

    df_g1=pd.DataFrame()
    df_g1=pd.DataFrame(g1)
    df_g1

    df_g2=df_g1.sort_values('SalePrice')
    df_g2

    df_g2.index

    g_col=df_g2.index.values

    df_miss[item1].value_counts()

    i=0
    for item2 in g_col:
        df_miss.loc[df_miss[item1]==item2,item1]=i
        i=i+1

# %%
df_miss[cat_col].dtypes
# Out:
# BldgType         int64
# BsmtCond         int64
# BsmtExposure     int64
# BsmtFinType1     int64
# BsmtFinType2     int64
# BsmtQual         int64
# CentralAir       int64
# Condition1       int64
# Condition2       int64
# Electrical       int64
# ExterCond        int64
# ExterQual        int64
# Exterior1st      int64
# Exterior2nd      int64
# FireplaceQu      int64
# Foundation       int64
# Functional       int64
# GarageCond       int64
# GarageFinish     int64
# GarageQual       int64
# GarageType       int64
# Heating          int64
# HeatingQC        int64
# HouseStyle       int64
# KitchenQual      int64
# LandContour      int64
# LandSlope        int64
# LotConfig        int64
# LotShape         int64
# MSZoning         int64
# MasVnrType       int64
# Neighborhood     int64
# PavedDrive       int64
# PoolQC           int64
# RoofMatl         int64
# RoofStyle        int64
# SaleCondition    int64
# SaleType         int64
# Street           int64
# Utilities        int64
# dtype: object

# %%
for item in cat_col:
    print(df_miss[item].value_counts())
    print()
# Out:
# 4    1138
# 3     112
# 1      38
# 2      28
# 0      22
# Name: BldgType, dtype: int64
#
# 2    1237
# 3      62
# 1      38
# 0       1
# Name: BsmtCond, dtype: int64
#
# 0    887
# 2    213
# 3    127
# 1    111
# Name: BsmtExposure, dtype: int64
#
# 5    402
# 4    392
# 3    209
# 1    141
# 0    125
# 2     69
# Name: BsmtFinType1, dtype: int64
#
# 3    1176
# 2      53
# 1      46
# 0      32
# 5      19
# 4      12
# Name: BsmtFinType2, dtype: int64
#
# 1    594
# 2    592
# 3    120
# 0     32
# Name: BsmtQual, dtype: int64
#
# 1    1277
# 0      61
# Name: CentralAir, dtype: int64
#
# 4    1162
# 2      63
# 0      43
# 3      26
# 7      19
# 1      10
# 8       8
# 6       5
# 5       2
# Name: Condition1, dtype: int64
#
# 4    1324
# 2       5
# 6       2
# 1       2
# 0       2
# 7       1
# 5       1
# 3       1
# Name: Condition2, dtype: int64
#
# 4    1242
# 3      76
# 2      17
# 1       2
# 0       1
# Name: Electrical, dtype: int64
#
# 2    1183
# 1     137
# 0      16
# 3       2
# Name: ExterCond, dtype: int64
#
# 1    803
# 2    477
# 3     51
# 0      7
# Name: ExterQual, dtype: int64
#
# 10    486
# 6     211
# 3     201
# 4     183
# 8     100
# 11     52
# 9      44
# 7      21
# 5      20
# 2      15
# 12      2
# 13      1
# 1       1
# 0       1
# Name: Exterior1st, dtype: int64
#
# 12    475
# 7     197
# 3     197
# 4     176
# 9     127
# 13     51
# 8      32
# 6      23
# 11     22
# 1      16
# 14     10
# 2       6
# 10      2
# 5       2
# 15      1
# 0       1
# Name: Exterior2nd, dtype: int64
#
# 1    608
# 4    370
# 3    304
# 2     33
# 5     23
# Name: FireplaceQu, dtype: int64
#
# 4    620
# 1    580
# 0    129
# 2      6
# 3      3
# Name: Foundation, dtype: int64
#
# 5    1254
# 2      30
# 3      28
# 6      11
# 4      10
# 0       4
# 1       1
# Name: Functional, dtype: int64
#
# 4    1287
# 1      33
# 3       9
# 0       7
# 2       2
# Name: GarageCond, dtype: int64
#
# 0    580
# 1    413
# 2    345
# Name: GarageFinish, dtype: int64
#
# 2    1270
# 1      48
# 3      14
# 4       3
# 0       3
# Name: GarageQual, dtype: int64
#
# 4    852
# 1    369
# 5     85
# 3     19
# 0      7
# 2      6
# Name: GarageType, dtype: int64
#
# 3    1318
# 2      16
# 0       3
# 1       1
# Name: Heating, dtype: int64
#
# 4    704
# 2    380
# 3    217
# 1     36
# 0      1
# Name: HeatingQC, dtype: int64
#
# 5    657
# 6    426
# 2    134
# 4     64
# 1     30
# 0     11
# 3     10
# 7      6
# Name: HouseStyle, dtype: int64
#
# 1    650
# 2    568
# 3     97
# 0     23
# Name: KitchenQual, dtype: int64
#
# 1    1206
# 0      52
# 3      48
# 2      32
# Name: LandContour, dtype: int64
#
# 0    1265
# 1      61
# 2      12
# Name: LandSlope, dtype: int64
#
# 0    957
# 2    244
# 4     90
# 1     43
# 3      4
# Name: LotConfig, dtype: int64
#
# 0    829
# 1    459
# 3     40
# 2     10
# Name: LotShape, dtype: int64
#
# 3    1066
# 2     191
# 4      62
# 1      11
# 0       8
# Name: MSZoning, dtype: int64
#
# 1    763
# 2    432
# 3    128
# 0     15
# Name: MasVnrType, dtype: int64
#
# 10    209
# 16    146
# 3     100
# 19     83
# 14     77
# 23     75
# 12     73
# 5      70
# 7      69
# 13     53
# 17     50
# 4      47
# 11     42
# 24     41
# 21     37
# 2      29
# 18     26
# 22     25
# 8      20
# 15     17
# 1      15
# 0      12
# 20     11
# 9       9
# 6       2
# Name: Neighborhood, dtype: int64
#
# 2    1257
# 0      54
# 1      27
# Name: PavedDrive, dtype: int64
#
# 0    1331
# 1       3
# 3       2
# 2       2
# Name: PoolQC, dtype: int64
#
# 3    1314
# 4       9
# 7       6
# 5       5
# 6       1
# 2       1
# 1       1
# 0       1
# Name: RoofMatl, dtype: int64
#
# 1    1037
# 4     272
# 3      11
# 0      10
# 2       6
# 5       2
# Name: RoofStyle, dtype: int64
#
# 4    1104
# 5     120
# 2      86
# 1      20
# 3       7
# 0       1
# Name: SaleCondition, dtype: int64
#
# 4    1158
# 8     117
# 1      42
# 2       6
# 6       4
# 5       4
# 3       4
# 7       2
# 0       1
# Name: SaleType, dtype: int64
#
# 1    1333
# 0       5
# Name: Street, dtype: int64
#
# 1    1337
# 0       1
# Name: Utilities, dtype: int64

# %%
df_miss.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0       856       854          0             3         4         2
# 1      1262         0          0             3         4         2
# 2       920       866          0             3         4         2
# 3       961       756          0             3         4         3
# 4      1145      1053          0             4         4         2
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0             0         706           0             5             3
# 1             3         978           0             3             3
# 2             1         486           0             5             3
# 3             0         216           0             3             3
# 4             2         655           0             5             3
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0             1             0         2        150           1           4
# 1             0             1         2        284           1           2
# 2             1             0         2        434           1           4
# 3             1             0         1        540           1           4
# 4             1             0         2        490           1           4
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0           4           4              0          2          2           10
# 1           4           4              0          2          1            3
# 2           4           4              0          2          2           10
# 3           4           4            272          2          1            4
# 4           4           4              0          2          2           10
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0           12            1           0           4         2           5
# 1            3            3           1           1         2           5
# 2           12            3           1           4         2           5
# 3            8            4           1           0         1           5
# 4           12            3           1           4         2           5
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0         548           2           4             1           2           4
# 1         460           2           4             1           2           4
# 2         608           2           4             1           2           4
# 3         642           3           4             0           2           1
# 4         836           3           4             1           2           4
#
#    GarageYrBlt  GrLivArea  HalfBath  Heating  HeatingQC  HouseStyle  \
# 0       2003.0       1710         1        3          4           6
# 1       1976.0       1262         0        3          4           5
# 2       2001.0       1786         1        3          4           6
# 3       1998.0       1717         0        3          3           6
# 4       2000.0       2198         1        3          4           6
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope  LotArea  LotConfig  \
# 0             1            2            1          0     8450          0
# 1             1            1            1          0     9600          1
# 2             1            2            1          0    11250          0
# 3             1            2            1          0     9550          2
# 4             1            2            1          0    14260          1
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0         65.0         0             0          60         3       196.0
# 1         80.0         0             0          20         3         0.0
# 2         68.0         1             0          60         3       162.0
# 3         60.0         1             0          70         3         0.0
# 4         84.0         1             0          60         3       350.0
#
#    MasVnrType  MiscVal  MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0           2        0       2            16           61            5
# 1           1        0       5            20            0            8
# 2           2        0       9            16           42            5
# 3           1        0       2            17           35            5
# 4           2        0      12            24           84            5
#
#    OverallQual  PavedDrive  PoolArea  PoolQC  RoofMatl  RoofStyle  \
# 0            7           2         0       0         3          1
# 1            6           2         0       0         3          1
# 2            7           2         0       0         3          1
# 3            7           2         0       0         3          1
# 4            8           2         0       0         3          1
#
#    SaleCondition  SalePrice  SaleType  ScreenPorch  Street  TotRmsAbvGrd  \
# 0              4     208500         4            0       1             8
# 1              4     181500         4            0       1             6
# 2              4     223500         4            0       1             6
# 3              2     140000         4            0       1             7
# 4              4     250000         4            0       1             9
#
#    TotalBsmtSF  Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          856          1           0       2003          2003    2008
# 1         1262          1         298       1976          1976    2007
# 2          920          1           0       2001          2002    2008
# 3          756          1           0       1915          1970    2006
# 4         1145          1         192       2000          2000    2008

# %% [markdown]
# ## Start working on Outliers

# %%
df_miss.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0       856       854          0             3         4         2
# 1      1262         0          0             3         4         2
# 2       920       866          0             3         4         2
# 3       961       756          0             3         4         3
# 4      1145      1053          0             4         4         2
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0             0         706           0             5             3
# 1             3         978           0             3             3
# 2             1         486           0             5             3
# 3             0         216           0             3             3
# 4             2         655           0             5             3
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0             1             0         2        150           1           4
# 1             0             1         2        284           1           2
# 2             1             0         2        434           1           4
# 3             1             0         1        540           1           4
# 4             1             0         2        490           1           4
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0           4           4              0          2          2           10
# 1           4           4              0          2          1            3
# 2           4           4              0          2          2           10
# 3           4           4            272          2          1            4
# 4           4           4              0          2          2           10
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0           12            1           0           4         2           5
# 1            3            3           1           1         2           5
# 2           12            3           1           4         2           5
# 3            8            4           1           0         1           5
# 4           12            3           1           4         2           5
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0         548           2           4             1           2           4
# 1         460           2           4             1           2           4
# 2         608           2           4             1           2           4
# 3         642           3           4             0           2           1
# 4         836           3           4             1           2           4
#
#    GarageYrBlt  GrLivArea  HalfBath  Heating  HeatingQC  HouseStyle  \
# 0       2003.0       1710         1        3          4           6
# 1       1976.0       1262         0        3          4           5
# 2       2001.0       1786         1        3          4           6
# 3       1998.0       1717         0        3          3           6
# 4       2000.0       2198         1        3          4           6
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope  LotArea  LotConfig  \
# 0             1            2            1          0     8450          0
# 1             1            1            1          0     9600          1
# 2             1            2            1          0    11250          0
# 3             1            2            1          0     9550          2
# 4             1            2            1          0    14260          1
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0         65.0         0             0          60         3       196.0
# 1         80.0         0             0          20         3         0.0
# 2         68.0         1             0          60         3       162.0
# 3         60.0         1             0          70         3         0.0
# 4         84.0         1             0          60         3       350.0
#
#    MasVnrType  MiscVal  MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0           2        0       2            16           61            5
# 1           1        0       5            20            0            8
# 2           2        0       9            16           42            5
# 3           1        0       2            17           35            5
# 4           2        0      12            24           84            5
#
#    OverallQual  PavedDrive  PoolArea  PoolQC  RoofMatl  RoofStyle  \
# 0            7           2         0       0         3          1
# 1            6           2         0       0         3          1
# 2            7           2         0       0         3          1
# 3            7           2         0       0         3          1
# 4            8           2         0       0         3          1
#
#    SaleCondition  SalePrice  SaleType  ScreenPorch  Street  TotRmsAbvGrd  \
# 0              4     208500         4            0       1             8
# 1              4     181500         4            0       1             6
# 2              4     223500         4            0       1             6
# 3              2     140000         4            0       1             7
# 4              4     250000         4            0       1             9
#
#    TotalBsmtSF  Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          856          1           0       2003          2003    2008
# 1         1262          1         298       1976          1976    2007
# 2          920          1           0       2001          2002    2008
# 3          756          1           0       1915          1970    2006
# 4         1145          1         192       2000          2000    2008

# %%
df_miss.dtypes
# Out:
# 1stFlrSF           int64
# 2ndFlrSF           int64
# 3SsnPorch          int64
# BedroomAbvGr       int64
# BldgType           int64
# BsmtCond           int64
# BsmtExposure       int64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtFinType1       int64
# BsmtFinType2       int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# BsmtQual           int64
# BsmtUnfSF          int64
# CentralAir         int64
# Condition1         int64
# Condition2         int64
# Electrical         int64
# EnclosedPorch      int64
# ExterCond          int64
# ExterQual          int64
# Exterior1st        int64
# Exterior2nd        int64
# FireplaceQu        int64
# Fireplaces         int64
# Foundation         int64
# FullBath           int64
# Functional         int64
# GarageArea         int64
#                   ...
# LotFrontage      float64
# LotShape           int64
# LowQualFinSF       int64
# MSSubClass         int64
# MSZoning           int64
# MasVnrArea       float64
# MasVnrType         int64
# MiscVal            int64
# MoSold             int64
# Neighborhood       int64
# OpenPorchSF        int64
# OverallCond        int64
# OverallQual        int64
# PavedDrive         int64
# PoolArea           int64
# PoolQC             int64
# RoofMatl           int64
# RoofStyle          int64
# SaleCondition      int64
# SalePrice          int64
# SaleType           int64
# ScreenPorch        int64
# Street             int64
# TotRmsAbvGrd       int64
# TotalBsmtSF        int64
# Utilities          int64
# WoodDeckSF         int64
# YearBuilt          int64
# YearRemodAdd       int64
# YrSold             int64
# Length: 77, dtype: object

# %% [markdown]
# ## Remove out of inter-quartile range values from 'SalePrice'

# %%
Q1=df_miss['SalePrice'].quantile(0.25)
Q3=df_miss['SalePrice'].quantile(0.75)

IQR=Q3-Q1

upper=Q3+1.5*IQR
lower=Q1-1.5*IQR

df_miss=df_miss.drop(df_miss[(df_miss['SalePrice']<lower)|(df_miss['SalePrice']>upper)].index)

# %% [markdown]
# ### Log(x+1) transformed the whole dataset

# %%
df_miss=np.log1p(df_miss)

# %%
df_miss.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0  6.753438  6.751101        0.0      1.386294  1.609438  1.098612
# 1  7.141245  0.000000        0.0      1.386294  1.609438  1.098612
# 2  6.825460  6.765039        0.0      1.386294  1.609438  1.098612
# 3  6.869014  6.629363        0.0      1.386294  1.609438  1.386294
# 4  7.044033  6.960348        0.0      1.609438  1.609438  1.098612
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0      0.000000    6.561031         0.0      1.791759      1.386294
# 1      1.386294    6.886532         0.0      1.386294      1.386294
# 2      0.693147    6.188264         0.0      1.791759      1.386294
# 3      0.000000    5.379897         0.0      1.386294      1.386294
# 4      1.098612    6.486161         0.0      1.791759      1.386294
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 
# 3     2.079442    1.098612       0.0     0.0  1.386294   0.693147
# 4     2.197225    1.098612       0.0     0.0  1.386294   0.693147
#
#    SaleCondition  SalePrice  SaleType  ScreenPorch    Street  TotRmsAbvGrd  \
# 0       1.609438  12.247699  1.609438          0.0  0.693147      2.197225
# 1       1.609438  12.109016  1.609438          0.0  0.693147      1.945910
# 2       1.609438  12.317171  1.609438          0.0  0.693147      1.945910
# 3       1.098612  11.849405  1.609438          0.0  0.693147      2.079442
# 4       1.609438  12.429220  1.609438          0.0  0.693147      2.302585
#
#    TotalBsmtSF  Utilities  WoodDeckSF  YearBuilt  YearRemodAdd    YrSold
# 0     6.753438   0.693147    0.000000   7.602900      7.602900  7.605392
# 1     7.141245   0.693147    5.700444   7.589336      7.589336  7.604894
# 2     6.825460   0.693147    0.000000   7.601902      7.602401  7.605392
# 3     6.629363   0.693147    0.000000   7.557995      7.586296  7.604396
# 4     7.044033   0.693147    5.262690   7.601402      7.601402  7.605392

# %% [markdown]
# ### Separate data variables to continuous and categorical features

# %%
con_col=['1stFlrSF','2ndFlrSF','3SsnPorch','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF',
        'EnclosedPorch','GarageArea','GarageYrBlt','GrLivArea','LotArea','LotFrontage','LowQualFinSF',
        'MasVnrArea','MiscVal','OpenPorchSF','PoolArea','ScreenPorch','TotalBsmtSF','WoodDeckSF',
         'YearBuilt','YearRemodAdd']
con_col
# Out:
# ['1stFlrSF',
#  '2ndFlrSF',
#  '3SsnPorch',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'EnclosedPorch',
#  'GarageArea',
#  'GarageYrBlt',
#  'GrLivArea',
#  'LotArea',
#  'LotFrontage',
#  'LowQualFinSF',
#  'MasVnrArea',
#  'MiscVal',
#  'OpenPorchSF',
#  'PoolArea',
#  'ScreenPorch',
#  'TotalBsmtSF',
#  'WoodDeckSF',
#  'YearBuilt',
#  'YearRemodAdd']

# %% [markdown]
# ### Produce Scatter Plot for all the continuous variables with our target variable "SalePrice"

# %%
for item in con_col:
    plt.scatter(x=df_miss[item],y=df_miss['SalePrice'])
    plt.xlabel(item)
    plt.ylabel('Sale Price')
    plt.show()

# %% [markdown]
# ### Remove Outliers - continuous variables

# %%
df_out=pd.DataFrame()
df_out=df_miss

# %%
df_out=df_out.drop(df_out[df_out['1stFlrSF']>8.0].index)

# %%
df_out=df_out.drop(df_out[(df_out['2ndFlrSF']>6.0)&(df_out['SalePrice']<11.0)].index)

# %%
df_out=df_out.drop(df_out[(df_out['2ndFlrSF']<5.5)&(df_out['SalePrice']>12.0)].index)

# %%
df_out=df_out.drop(df_out[(df_out['2ndFlrSF']==0.0)&(df_out['SalePrice']<10.6)].index)

# %%
df_out=df_out.drop(df_out[(df_out['3SsnPorch']==0.0)&(df_out['SalePrice']<10.7)].index)

# %%
df_out=df_out.drop(df_out[(df_out['BsmtFinSF1']==0.0)&(df_out['SalePrice']<10.7)].index)

# %%
df_out=df_out.drop(df_out[(df_out['BsmtFinSF1']>0.0)&(df_out['BsmtFinSF1']<2.0)].index)

# %%
df_out=df_out.drop(df_out[df_out['BsmtFinSF1']>8].index)

# %%
df_out=df_out.drop(df_out[(df_out['BsmtFinSF2']==0.0)&(df_out['SalePrice']<10.75)].index)

# %%
df_out=df_out.drop(df_out[(df_out['EnclosedPorch']==0.0)&(df_out['SalePrice']<10.75)].index)

# %%
df_out=df_out.drop(df_out[(df_out['GarageArea']>7.0)].index)

# %%
df_out=df_out.drop(df_out[(df_out['GarageArea']>5.0)&(df_out['GarageArea']<6.0)&(df_out['SalePrice']<10.75)].index)

# %%
df_out=df_out.drop(df_out[(df_out['GarageYrBlt']>7.55)&(df_out['GarageYrBlt']<7.60)&(df_out['SalePrice']<10.75)].index)

# %%
df_out=df_out.drop(df_out[(df_out['GrLivArea']>6.0)&(df_out['GrLivArea']<7.5)&(df_out['SalePrice']<10.75)].index)

# %%
df_out=df_out.drop(df_out[(df_out['GrLivArea']>8.25)].index)

# %%
df_out=df_out.drop(df_out[(df_out['LotArea']>8)&(df_out['LotArea']<10)&(df_out['SalePrice']<10.75)].index)

# %%
df_out=df_out.drop(df_out[(df_out['LotFrontage']==0)&(df_out['SalePrice']<10.5)].index)

# %%
df_out=df_out.drop(df_out[(df_out['MasVnrArea']==0)&(df_out['SalePrice']<10.75)].index)

# %%
df_out=df_out.drop(df_out[(df_out['MiscVal']==0)&(df_out['SalePrice']<10.75)].index)

# %%
df_out=df_out.drop(df_out[(df_out['OpenPorchSF']==0)&(df_out['SalePrice']<10.75)].index)

# %%
df_out=df_out.drop(df_out[(df_out['OpenPorchSF']>3)&(df_out['OpenPorchSF']<5)&(df_out['SalePrice']<10.75)].index)

# %%
df_out=df_out.drop(df_out[(df_out['PoolArea']==0)&(df_out['SalePrice']<10.75)].index)

# %%
df_out=df_out.drop(df_out[(df_out['ScreenPorch']==0)&(df_out['SalePrice']<10.75)].index)

# %%
df_out=df_out.drop(df_out[df_out['TotalBsmtSF']>8.5].index)

# %%
df_out=df_out.drop(df_out[df_out['TotalBsmtSF']<5.0].index)

# %%
df_out=df_out.drop(df_out[(df_out['WoodDeckSF']==0)&(df_out['SalePrice']<10.75)].index)

# %% [markdown]
# ## Check the scatter plot again

# %%
for item in con_col:
    plt.scatter(x=df_out[item],y=df_out['SalePrice'])
    plt.xlabel(item)
    plt.ylabel('Sale Price')
    plt.show()

# %%
df_out.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0  6.753438  6.751101   0.000000      1.386294  1.609438  1.098612
# 2  6.825460  6.765039   0.000000      1.386294  1.609438  1.098612
# 3  6.869014  6.629363   0.000000      1.386294  1.609438  1.386294
# 4  7.044033  6.960348   0.000000      1.609438  1.609438  1.098612
# 5  6.680855  6.340359   5.771441      0.693147  1.609438  1.098612
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0      0.000000    6.561031         0.0      1.791759      1.386294
# 2      0.693147    6.188264         0.0      1.791759      1.386294
# 3      0.000000    5.379897         0.0      1.386294      1.386294
# 4      1.098612    6.486161         0.0      1.791759      1.386294
# 5      0.000000    6.597146         0.0      1.791759      1.386294
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0      0.693147           0.0  1.098612   5.017280    0.693147    1.609438
# 2      0.693147           0.0  1.098612   6.075346    0.693147    1.609438
# 3      0.693147           0.0  0.693147   6.293419    0.693147    1.609438
# 4      0.693147           0.0  1.098612   6.196444    0.693147    1.609438
# 5      0.693147           0.0  1.098612   4.174387    0.693147    1.609438
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0    1.609438    1.609438       0.000000   1.098612   1.098612     2.397895
# 2    1.609438    1.609438       0.000000   1.098612   1.098612     2.397895
# 3    1.609438    1.609438       5.609472   1.098612   0.693147     1.609438
# 4    1.609438    1.609438       0.000000   1.098612   1.098612     2.397895
# 5    1.609438    1.609438       0.000000   1.098612   0.693147     2.397895
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0     2.564949     0.693147    0.000000    1.609438  1.098612    1.791759
# 2     2.564949     1.386294    0.693147    1.609438  1.098612    1.791759
# 3     2.197225     1.609438    0.693147    0.000000  0.693147    1.791759
# 4     2.564949     1.386294    0.693147    1.609438  1.098612    1.791759
# 5     2.564949     0.693147    0.000000    1.386294  0.693147    1.791759
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 
# SalePrice      960.0  1.259178e-15  1.000521  -3.160641 -0.594618 -0.150831
# SaleType       960.0  7.753057e-16  1.000521  -7.470306  0.048023  0.048023
# ScreenPorch    960.0  2.035409e-17  1.000521  -0.287748 -0.287748 -0.287748
# Street         960.0 -5.847175e-16  1.000521 -21.886069  0.045691  0.045691
# TotRmsAbvGrd   960.0  1.332268e-15  1.000521  -2.795303 -0.915583 -0.200947
# TotalBsmtSF    960.0  9.473903e-16  1.000521  -5.638614 -0.561544  0.052133
# Utilities      960.0 -2.895832e-15  1.000521 -30.967725  0.032292  0.032292
# WoodDeckSF     960.0 -2.590520e-17  1.000521  -0.862543 -0.862543 -0.862543
# YearBuilt      960.0 -9.438561e-14  1.000521  -2.935120 -0.590034  0.050594
# YearRemodAdd   960.0  2.742991e-14  1.000521  -1.521746 -0.935175  0.203210
# YrSold         960.0 -9.071429e-13  1.000521  -1.352225 -0.601957  0.147938
#
#                     75%        max
# 1stFlrSF       0.616737   3.149838
# 2ndFlrSF       0.865618   1.113137
# 3SsnPorch     -0.107551  10.185294
# BedroomAbvGr   0.164250   2.772116
# BldgType       0.316405   0.316405
# BsmtCond       0.041879   2.803505
# BsmtExposure  -0.538015   2.543914
# BsmtFinSF1     0.777956   1.067223
# BsmtFinSF2    -0.373690   3.495356
# BsmtFinType1   0.579356   0.896716
# BsmtFinType2   0.250804   1.790394
# BsmtFullBath   1.315657   2.520770
# BsmtHalfBath  -0.253578   3.943567
# BsmtQual       0.948216   2.032930
# BsmtUnfSF      0.576725   1.110272
# CentralAir     0.255896   0.255896
# Condition1     0.286087   1.930052
# Condition2     0.079845   5.099986
# Electrical     0.270448   0.270448
# EnclosedPorch -0.441754   2.997810
# ExterCond      0.340629   1.905917
# ExterQual      1.515444   2.983139
# Exterior1st    1.093182   1.305021
# Exterior2nd    1.069903   1.358761
# FireplaceQu    0.807684   1.808302
# Fireplaces     0.854591   2.637513
# Foundation     1.203286   1.203286
# FullBath       0.998244   2.319825
# Functional     0.212267   1.094251
# GarageArea     0.680751   2.477520
# ...                 ...        ...
# LotFrontage    0.563776   1.067679
# LotShape       1.212272   3.095184
# LowQualFinSF  -0.133273   8.422484
# MSSubClass     0.541342   2.102575
# MSZoning       0.338263   1.633233
# MasVnrArea     1.192645   2.217982
# MasVnrType     1.174734   2.421688
# MiscVal       -0.209215   7.077534
# MoSold         0.689545   1.581736
# Neighborhood   0.845902   1.443088
# OpenPorchSF    0.964097   1.959022
# OverallCond    0.336700   2.461241
# OverallQual    1.010784   2.911293
# PavedDrive     0.275360   0.275360
# PoolArea      -0.055969  18.526145
# PoolQC        -0.054070  22.588133
# RoofMatl      -0.006541   8.020105
# RoofStyle     -0.412709   2.773921
# SaleCondition  0.251905   1.240350
# SalePrice      0.591327   2.509454
# SaleType       0.048023   2.793810
# ScreenPorch   -0.287748   4.202390
# Street         0.045691   0.045691
# TotRmsAbvGrd   0.418099   2.668894
# TotalBsmtSF    0.625469   3.164075
# Utilities      0.032292   0.032292
# WoodDeckSF     1.100241   1.720421
# YearBuilt      0.950401   1.445046
# YearRemodAdd   0.946717   1.375792
# YrSold         0.897460   1.646609
#
# [77 rows x 8 columns]

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### 1. Filter Method - Correlation Coefficient

# %%
corr=df_out.corr()
corr.sort_values(["SalePrice"],ascending=False,inplace=True)
dc=corr.SalePrice

# %%
dc
# Out:
# SalePrice        1.000000
# GrLivArea        0.748363
# OverallQual      0.734979
# Neighborhood     0.623216
# ExterQual        0.606335
# FullBath         0.599774
# TotRmsAbvGrd     0.596296
# GarageCars       0.564219
# HalfBath         0.553845
# KitchenQual      0.553735
# BsmtQual         0.546506
# 2ndFlrSF         0.530782
# GarageArea       0.520568
# YearRemodAdd     0.511180
# GarageFinish     0.508524
# YearBuilt        0.507683
# FireplaceQu      0.486192
# Fireplaces       0.474302
# OpenPorchSF      0.470971
# Foundation       0.469178
# GarageYrBlt      0.459985
# GarageType       0.450240
# HeatingQC        0.420561
# MSZoning         0.396955
# BedroomAbvGr     0.392467
# LotArea          0.378546
# Exterior1st      0.372626
# 1stFlrSF         0.361227
# TotalBsmtSF      0.356014
# Exterior2nd      0.349757
#                    ...
# BsmtExposure     0.157282
# Functional       0.125318
# LotConfig        0.124689
# ExterCond        0.119644
# Condition2       0.114200
# BsmtFullBath     0.104627
# BsmtFinType2     0.099223
# LandContour      0.097938
# Street           0.096309
# BsmtUnfSF        0.090894
# MoSold           0.090496
# PoolArea         0.086457
# PoolQC           0.080330
# ScreenPorch      0.079209
# Heating          0.077347
# BsmtFinSF1       0.076537
# 3SsnPorch        0.062520
# RoofMatl         0.034996
# LandSlope        0.028560
# OverallCond      0.028404
# Utilities        0.011598
# RoofStyle       -0.001155
# BsmtHalfBath    -0.008245
# MiscVal         -0.017395
# LowQualFinSF    -0.044391
# YrSold          -0.055770
# BsmtFinSF2      -0.057801
# LotFrontage     -0.058526
# KitchenAbvGr    -0.109450
# EnclosedPorch   -0.201020
# Name: SalePrice, Length: 77, dtype: float64

# %%
dc.index
# Out:
# Index(['SalePrice', 'GrLivArea', 'OverallQual', 'Neighborhood', 'ExterQual',
#        'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'HalfBath', 'KitchenQual',
#        'BsmtQual', '2ndFlrSF', 'GarageArea', 'YearRemodAdd', 'GarageFinish',
#        'YearBuilt', 'FireplaceQu', 'Fireplaces', 'OpenPorchSF', 'Foundation',
#        'GarageYrBlt', 'GarageType', 'HeatingQC', 'MSZoning', 'BedroomAbvGr',
#        'LotArea', 'Exterior1st', '1stFlrSF', 'TotalBsmtSF', 'Exterior2nd',
#        'HouseStyle', 'MasVnrArea', 'LotShape', 'MasVnrType', 'WoodDeckSF',
#        'CentralAir', 'BsmtFinType1', 'Electrical', 'BsmtCond', 'SaleType',
#        'GarageQual', 'SaleCondition', 'MSSubClass', 'GarageCond', 'PavedDrive',
#        'Condition1', 'BldgType', 'BsmtExposure', 'Functional', 'LotConfig',
#        'ExterCond', 'Condition2', 'BsmtFullBath', 'BsmtFinType2',
#        'LandContour', 'Street', 'BsmtUnfSF', 'MoSold', 'PoolArea', 'PoolQC',
#        'ScreenPorch', 'Heating', 'BsmtFinSF1', '3SsnPorch', 'RoofMatl',
#        'LandSlope', 'OverallCond', 'Utilities', 'RoofStyle', 'BsmtHalfBath',
#        'MiscVal', 'LowQualFinSF', 'YrSold', 'BsmtFinSF2', 'LotFrontage',
#        'KitchenAbvGr', 'EnclosedPorch'],
#       dtype='object')

# %%
dc.values
# Out:
# array([ 1.        ,  0.74836303,  0.73497909,  0.6232164 ,  0.60633451,
#         0.59977376,  0.59629634,  0.56421859,  0.55384543,  0.55373503,
#         0.54650641,  0.53078187,  0.52056849,  0.51117962,  0.50852449,
#         0.5076834 ,  0.48619198,  0.47430201,  0.47097078,  0.46917766,
#         0.45998465,  0.45023972,  0.42056115,  0.39695468,  0.3924674 ,
#         0.37854606,  0.37262607,  0.36122721,  0.35601413,  0.34975696,
#         0.29510875,  0.29267427,  0.28771405,  0.28313867,  0.27280296,
#         0.26178961,  0.24967241,  0.24822506,  0.23559592,  0.23282079,
#         0.21263698,  0.21049015,  0.20797004,  0.19729925,  0.19511275,
#         0.17880903,  0.1761496 ,  0.15728214,  0.12531848,  0.12468927,
#         0.1196443 ,  0.11419967,  0.10462739,  0.09922339,  0.09793797,
#         0.09630864,  0.09089385,  0.09049609,  0.08645701,  0.08032973,
#         0.07920947,  0.07734682,  0.07653677,  0.06252038,  0.03499565,
#         0.02855998,  0.02840433,  0.01159794, -0.00115547, -0.0082453 ,
#        -0.01739453, -0.04439082, -0.05576971, -0.0578008 , -0.05852583,
#        -0.10945004, -0.20101951])

# %%
dc.index.values
# Out:
# array(['SalePrice', 'GrLivArea', 'OverallQual', 'Neighborhood',
#        'ExterQual', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'HalfBath',
#        'KitchenQual', 'BsmtQual', '2ndFlrSF', 'GarageArea',
#        'YearRemodAdd', 'GarageFinish', 'YearBuilt', 'FireplaceQu',
#        'Fireplaces', 'OpenPorchSF', 'Foundation', 'GarageYrBlt',
#        'GarageType', 'HeatingQC', 'MSZoning', 'BedroomAbvGr', 'LotArea',
#        'Exterior1st', '1stFlrSF', 'TotalBsmtSF', 'Exterior2nd',
#        'HouseStyle', 'MasVnrArea', 'LotShape', 'MasVnrType', 'WoodDeckSF',
#        'CentralAir', 'BsmtFinType1', 'Electrical', 'BsmtCond', 'SaleType',
#        'GarageQual', 'SaleCondition', 'MSSubClass', 'GarageCond',
#        'PavedDrive', 'Condition1', 'BldgType', 'BsmtExposure',
#        'Functional', 'LotConfig', 'ExterCond', 'Condition2',
#        'BsmtFullBath', 'BsmtFinType2', 'LandContour', 'Street',
#        'BsmtUnfSF', 'MoSold', 'PoolArea', 'PoolQC', 'ScreenPorch',
#        'Heating', 'BsmtFinSF1', '3SsnPorch', 'RoofMatl', 'LandSlope',
#        'OverallCond', 'Utilities', 'RoofStyle', 'BsmtHalfBath', 'MiscVal',
#        'LowQualFinSF', 'YrSold', 'BsmtFinSF2', 'LotFrontage',
#        'KitchenAbvGr', 'EnclosedPorch'], dtype=object)

# %% [markdown]
# ### Select the features with more than 0.5 of correleation coefficient

# %%
dc_new=dc[(dc.values>0.5)&(dc.values<1)]
dc_new
# Out:
# GrLivArea       0.748363
# OverallQual     0.734979
# Neighborhood    0.623216
# ExterQual       0.606335
# FullBath        0.599774
# TotRmsAbvGrd    0.596296
# GarageCars      0.564219
# HalfBath        0.553845
# KitchenQual     0.553735
# BsmtQual        0.546506
# 2ndFlrSF        0.530782
# GarageArea      0.520568
# YearRemodAdd    0.511180
# GarageFinish    0.508524
# YearBuilt       0.507683
# Name: SalePrice, dtype: float64

# %%
len(dc_new)
# Out:
# 15

# %%
feature_col=dc_new.index.values
feature_col
# Out:
# array(['GrLivArea', 'OverallQual', 'Neighborhood', 'ExterQual',
#        'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'HalfBath',
#        'KitchenQual', 'BsmtQual', '2ndFlrSF', 'GarageArea',
#        'YearRemodAdd', 'GarageFinish', 'YearBuilt'], dtype=object)

# %% [markdown]
# ### Select the features to be used in the data analysis

# %%
X=df_out[sorted(feature_col)]
y=df_out['SalePrice']

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Create a Result dataframe to show the result in the end

# %%
result_col=['Algorithm','Correlation','Recursive','XGBoost']
result=pd.DataFrame(columns=result_col)
result['Algorithm']=['Ridge Regression','LASSO Regression','Elastic Net',
                     'Decision Tree','Random Forest','XGBoost']

# %%
result
# Out:
#           Algorithm Correlation Recursive XGBoost
# 0  Ridge Regression         NaN       NaN     NaN
# 1  LASSO Regression         NaN       NaN     NaN
# 2       Elastic Net         NaN       NaN     NaN
# 3     Decision Tree         NaN       NaN     NaN
# 4     Random Forest         NaN       NaN     NaN
# 5           XGBoost         NaN       NaN     NaN

# %% [markdown]
# ### Adjust the figure size for appropriate display

# %%
print(plt.rcParams["figure.figsize"])
plt.rcParams["figure.figsize"] = (8,4)
# Out:
# [6.0, 4.0]

# %% [markdown]
# ### Ridge Regression

# %%
RR=Ridge(alpha=0.001,fit_intercept=True)

# %%
y_pred=cross_val_predict(RR,X,y,cv=4)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
plt.xlabel('Stadardized_Log_SalePrice')
plt.ylabel('Residual')
result['Correlation'][0]=np.sqrt(mean_squared_error(y_pred,y))
result['Correlation'][0]
# Out:
# 0.4332804835325762

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso
LR=Lasso(alpha=0.0001,fit_intercept=True)

# %%
y_pred=cross_val_predict(LR,X,y,cv=4)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
plt.xlabel('Stadardized_Log_SalePrice')
plt.ylabel('Residual')
result['Correlation'][1]=np.sqrt(mean_squared_error(y_pred,y))
result['Correlation'][1]
# Out:
# 0.43326942364251236

# %% [markdown]
# ### Elastic Net Model

# %%
from sklearn.linear_model import ElasticNetCV
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)

# %%
y_pred=cross_val_predict(EN,X,y,cv=4)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
plt.xlabel('Stadardized_Log_SalePrice')
plt.ylabel('Residual')
result['Correlation'][2]=np.sqrt(mean_squared_error(y_pred,y))
result['Correlation'][2]
# Out:
# 0.43363312055361536

# %% [markdown]
# ### Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
DT=DecisionTreeRegressor()

# %%
y_pred=cross_val_predict(DT,X,y,cv=4)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
plt.xlabel('Stadardized_Log_SalePrice')
plt.ylabel('Residual')
result['Correlation'][3]=np.sqrt(mean_squared_error(y_pred,y))
result['Correlation'][3]
# Out:
# 0.6208556744508086

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)

# %%
y_pred=cross_val_predict(RF,X,y,cv=4)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
plt.xlabel('Stadardized_Log_SalePrice')
plt.ylabel('Residual')
result['Correlation'][4]=np.sqrt(mean_squared_error(y_pred,y))
result['Correlation'][4]
# Out:
# 0.4257089814183621

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=3000, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)

# %%
y_pred=cross_val_predict(XG,X,y,cv=4)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
plt.xlabel('Stadardized_Log_SalePrice')
plt.ylabel('Residual')
result['Correlation'][5]=np.sqrt(mean_squared_error(y_pred,y))
result['Correlation'][5]
# Out:
# 0.4347985037287813

# %% [markdown]
# ### Wrapper Method - Recursive Feature Elimination Method

# %% [markdown]
# ### Select the features to be used in the feature emlimination

# %%
X=df_out.drop(columns=['SalePrice'])
y=df_out['SalePrice']

# %% [markdown]
# ### Ridge Regression

# %%
RR=Ridge(alpha=0.001,fit_intercept=True)

# %%
RM_RR=RFECV(RR, step=1, cv=4, scoring='neg_mean_squared_error')
RM_RR.fit(X,y)
RM_RR.n_features_
# Out:
# 38

# %%
y_pred=RM_RR.predict(X)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
plt.xlabel('Stadardized_Log_SalePrice')
plt.ylabel('Residual')
result['Recursive'][0]=np.sqrt(mean_squared_error(y_pred,y))
result['Recursive'][0]
# Out:
# 0.31611579940503276

# %% [markdown]
# ### Lasso Regression

# %%
LR=Lasso(alpha=0.001,fit_intercept=True)

# %%
RM_LR=RFECV(LR, step=1, cv=4, scoring='neg_mean_squared_error')
RM_LR.fit(X,y)
RM_LR.n_features_
# Out:
# 38

# %%
y_pred=RM_LR.predict(X)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
plt.xlabel('Stadardized_Log_SalePrice')
plt.ylabel('Residual')
result['Recursive'][1]=np.sqrt(mean_squared_error(y_pred,y))
result['Recursive'][1]
# Out:
# 0.31648984962095994

# %% [markdown]
# ### Elastic Net Model

# %%
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)

# %%
RM_EN=RFECV(EN, step=1, cv=4, scoring='neg_mean_squared_error')
RM_EN.fit(X,y)
RM_EN.n_features_
# Out:
# 74

# %%
y_pred=RM_EN.predict(X)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
plt.xlabel('Stadardized_Log_SalePrice')
plt.ylabel('Residual')
result['Recursive'][2]=np.sqrt(mean_squared_error(y_pred,y))
result['Recursive'][2]
# Out:
# 0.3182844781079293

# %% [markdown]
# ### Decision Tree Model

# %%
DT=DecisionTreeRegressor()

# %%
RM_DT=RFECV(DT, step=1, cv=4, scoring='neg_mean_squared_error')
RM_DT_fit=RM_DT.fit(X,y)
RM_DT.n_features_
# Out:
# 21

# %%
y_pred=RM_DT.predict(X)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
plt.xlabel('Stadardized_Log_SalePrice')
plt.ylabel('Residual')
result['Recursive'][3]=np.sqrt(mean_squared_error(y_pred,y))
result['Recursive'][3]
# Out:
# 0.0069407856676402015

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)

# %%
RM_RF=RFECV(RF, step=1, cv=4, scoring='neg_mean_squared_error')
RM_RF.fit(X,y)
RM_RF.n_features_
# Out:
# 75

# %%
y_pred=RM_RF.predict(X)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
plt.xlabel('Stadardized_Log_SalePrice')
plt.ylabel('Residual')
result['Recursive'][4]=np.sqrt(mean_squared_error(y_pred,y))
result['Recursive'][4]
# Out:
# 0.14688835186094903

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=300, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)

# %%
RM_XG=RFECV(XG, step=1, cv=4, scoring='neg_mean_squared_error')
RM_XG.fit(X,y)
RM_XG.n_features_
# Out:
# 55

# %%
y_pred=RM_XG.predict(X)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
plt.xlabel('Stadardized_Log_SalePrice')
plt.ylabel('Residual')
result['Recursive'][5]=np.sqrt(mean_squared_error(y_pred,y))
result['Recursive'][5]
# Out:
# 0.1418920246324408

# %% [markdown]
# ## Embedded Method - XGBoost Feature Importance

# %% [markdown]
# ### Select the features to be used in the data analysis

# %%
X=df_out.drop(columns=['SalePrice'])
y=df_out['SalePrice']

# %%
from xgboost import XGBClassifier
model = XGBClassifier()

# %%
model.fit(X,y)
array_importance=model.feature_importances_
print(array_importance)
# Out:
# [6.7940816e-02 4.7353629e-02 0.0000000e+00 5.0303531e-03 1.4128460e-03
#  1.5370523e-03 2.8412179e-03 5.5753078e-02 2.3443929e-03 1.0774892e-02
#  8.2286639e-04 3.5243521e-03 6.6760858e-04 2.0338772e-03 8.5593626e-02
#  3.5709294e-04 2.7480631e-03 0.0000000e+00 1.3817945e-03 4.2230124e-03
#  1.1799593e-03 1.8475679e-03 7.7163130e-03 1.0635160e-02 4.8750951e-03
#  2.7325375e-03 3.1206820e-03 1.8630937e-03 8.3839212e-04 6.5472215e-02
#  1.5370523e-03 8.2286639e-04 6.5829311e-03 2.7946406e-04 5.2166623e-03
#  2.4794672e-02 9.0173736e-02 2.9033211e-03 0.0000000e+00 8.0113029e-03
#  4.7819405e-03 9.3154682e-05 2.8877952e-03 1.2575883e-03 1.0868046e-04
#  9.2067882e-02 5.5737551e-03 3.5383254e-02 4.9527241e-03 0.0000000e+00
#  1.0153861e-02 1.4283718e-03 2.7123539e-02 8.5391791e-04 2.7946406e-04
#  2.1968979e-02 1.8755144e-02 3.3225171e-02 7.7007869e-03 9.3620457e-03
#  7.2971167e-04 0.0000000e+00 0.0000000e+00 0.0000000e+00 1.9872999e-03
#  8.8496949e-04 1.0868047e-03 2.2512381e-03 0.0000000e+00 1.1240665e-02
#  6.0053717e-02 0.0000000e+00 3.3132017e-02 2.7278796e-02 3.1688116e-02
#  1.4765018e-02]

# %%
len(model.feature_importances_)
# Out:
# 76

# %%
X.shape
# Out:
# (960, 76)

# %%
X_col=X.columns.values

# %%
df_XG=pd.DataFrame()
df_XG['Features']=X_col
df_XG['Importance']=array_importance

# %%
df_XG=df_XG.sort_values(by='Importance',ascending=True)
plt.rcParams["figure.figsize"] = (10,20)
plt.barh(df_XG['Features'],df_XG['Importance'])
plt.show()

# %%
df_XG=df_XG.sort_values(by='Importance',ascending=False)

# %%
df_XG
# Out:
#          Features  Importance
# 45        LotArea    0.092068
# 36      GrLivArea    0.090174
# 14      BsmtUnfSF    0.085594
# 0        1stFlrSF    0.067941
# 29     GarageArea    0.065472
# 70    TotalBsmtSF    0.060054
# 7      BsmtFinSF1    0.055753
# 1        2ndFlrSF    0.047354
# 47    LotFrontage    0.035383
# 57    OpenPorchSF    0.033225
# 72     WoodDeckSF    0.033132
# 74   YearRemodAdd    0.031688
# 73      YearBuilt    0.027279
# 52     MasVnrArea    0.027124
# 35    GarageYrBlt    0.024795
# 55         MoSold    0.021969
# 56   Neighborhood    0.018755
# 75         YrSold    0.014765
# 69   TotRmsAbvGrd    0.011241
# 9    BsmtFinType1    0.010775
# 23    Exterior2nd    0.010635
# 50     MSSubClass    0.010154
# 59    OverallQual    0.009362
# 39      HeatingQC    0.008011
# 22    Exterior1st    0.007716
# 58    OverallCond    0.007701
# 32   GarageFinish    0.006583
# 46      LotConfig    0.005574
# 34     GarageType    0.005217
# 3    BedroomAbvGr    0.005030
# ..            ...         ...
# 21      ExterQual    0.001848
# 5        BsmtCond    0.001537
# 30     GarageCars    0.001537
# 51       MSZoning    0.001428
# 4        BldgType    0.001413
# 18     Electrical    0.001382
# 43    LandContour    0.001258
# 20      ExterCond    0.001180
# 66       SaleType    0.001087
# 65  SaleCondition    0.000885
# 53     MasVnrType    0.000854
# 28     Functional    0.000838
# 31     GarageCond    0.000823
# 10   BsmtFinType2    0.000823
# 60     PavedDrive    0.000730
# 12   BsmtHalfBath    0.000668
# 15     CentralAir    0.000357
# 33     GarageQual    0.000279
# 54        MiscVal    0.000279
# 44      LandSlope    0.000109
# 41   KitchenAbvGr    0.000093
# 49   LowQualFinSF    0.000000
# 62         PoolQC    0.000000
# 61       PoolArea    0.000000
# 63       RoofMatl    0.000000
# 68         Street    0.000000
# 17     Condition2    0.000000
# 2       3SsnPorch    0.000000
# 71      Utilities    0.000000
# 38        Heating    0.000000
#
# [76 rows x 2 columns]

# %%
feature_XG_col=df_XG['Features'][:12].values

# %%
feature_XG_col
# Out:
# array(['LotArea', 'GrLivArea', 'BsmtUnfSF', '1stFlrSF', 'GarageArea',
#        'TotalBsmtSF', 'BsmtFinSF1', '2ndFlrSF', 'LotFrontage',
#        'OpenPorchSF', 'WoodDeckSF', 'YearRemodAdd'], dtype=object)

# %%
len(feature_XG_col)
# Out:
# 12

# %% [markdown]
# ### Select the features to be used in the data analysis

# %%
X=df_out[feature_XG_col]
y=df_out['SalePrice']

# %% [markdown]
# ### Adjust figure size

# %%
plt.rcParams["figure.figsize"] = (8,4)

# %% [markdown]
# ### Ridge Regression

# %%
RR=Ridge(alpha=0.001,fit_intercept=True)

# %%
y_pred=cross_val_predict(RR,X,y,cv=4)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][0]=np.sqrt(mean_squared_error(y_pred,y))
result['XGBoost'][0]
# Out:
# 0.49402008031185807

# %% [markdown]
# ### Lasso Regression

# %%
LR=Lasso(alpha=0.0001,fit_intercept=True)

# %%
y_pred=cross_val_predict(LR,X,y,cv=4)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][1]=np.sqrt(mean_squared_error(y_pred,y))
result['XGBoost'][1]
# Out:
# 0.4939910843579629

# %% [markdown]
# ### Elastic Net Model

# %%
EN = ElasticNet(alpha=0.0001,fit_intercept=True,max_iter=50000,tol=0.0001)

# %%
y_pred=cross_val_predict(EN,X,y,cv=4)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][2]=np.sqrt(mean_squared_error(y_pred,y))
result['XGBoost'][2]
# Out:
# 0.4940028414807493

# %% [markdown]
# ### Decision Tree Model

# %%
DT=DecisionTreeRegressor()

# %%
y_pred=cross_val_predict(DT,X,y,cv=4)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][3]=np.sqrt(mean_squared_error(y_pred,y))
result['XGBoost'][3]
# Out:
# 0.6680844193024079

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)

# %%
y_pred=cross_val_predict(RF,X,y,cv=4)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][4]=np.sqrt(mean_squared_error(y_pred,y))
result['XGBoost'][4]
# Out:
# 0.46785964864191565

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=3000, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)

# %%
y_pred=cross_val_predict(XG,X,y,cv=4)
y_err=y_pred-y
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][5]=np.sqrt(mean_squared_error(y_pred,y))
result['XGBoost'][5]
# Out:
# 0.45558492381751897

# %% [markdown]
# ## Examine the result

# %%
result
# Out:
#           Algorithm Correlation   Recursive   XGBoost
# 0  Ridge Regression     0.43328    0.316116   0.49402
# 1  LASSO Regression    0.433269     0.31649  0.493991
# 2       Elastic Net    0.433633    0.318284  0.494003
# 3     Decision Tree    0.620856  0.00694079  0.668084
# 4     Random Forest    0.425709    0.146888   0.46786
# 5           XGBoost    0.434799    0.141892  0.455585
