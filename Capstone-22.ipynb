# %% [markdown]
# - 1stFlrSF:	 First Floor square feet
# - 2ndFlrSF:	 Second floor square feet
# - 3SsnPorch:	 Three season porch area in square feet
# - Alley:	 Type of alley access
# - Bedroom:	 Number of bedrooms above basement level
# - BldgType:	 Type of dwelling
# - BsmtCond:	 General condition of the basement
# - BsmtExposure:	 Walkout or garden level basement walls
# - BsmtFinSF1:	 Type 1 finished square feet
# - BsmtFinSF2:	 Type 2 finished square feet
# - BsmtFinType1:	 Quality of basement finished area
# - BsmtFinType2:	 Quality of second finished area (if present)
# - BsmtFullBath:	 Basement full bathrooms
# - BsmtHalfBath:	 Basement half bathrooms
# - BsmtQual:	 Height of the basement
# - BsmtUnfSF:	 Unfinished square feet of basement area
# - CentralAir:	 Central air conditioning
# - Condition1:	 Proximity to main road or railroad
# - Condition2:	 Proximity to main road or railroad (if a second is present)
# - Electrical:	 Electrical system
# - EnclosedPorch:	 Enclosed porch area in square feet
# - ExterCond:	 Present condition of the material on the exterior
# - Exterior1st:	 Exterior covering on house
# - Exterior2nd:	 Exterior covering on house (if more than one material)
# - ExterQual:	 Exterior material quality
# - Fence:	 Fence quality
# - FireplaceQu:	 Fireplace quality
# - Fireplaces:	 Number of fireplaces
# - Foundation:	 Type of foundation
# - FullBath:	 Full bathrooms above grade
# - Functional:	 Home functionality rating
# - GarageArea:	 Size of garage in square feet
# - GarageCars:	 Size of garage in car capacity
# - GarageCond:	 Garage condition
# - GarageFinish:	 Interior finish of the garage
# - GarageQual:	 Garage quality
# - GarageType:	 Garage location
# - GarageYrBlt:	 Year garage was built
# - GrLivArea:	 Above grade (ground) living area square feet
# - HalfBath:	 Half baths above grade
# - - Heating:	 Type of heating
# - HeatingQC:	 Heating quality and condition
# - HouseStyle:	 Style of dwelling
# - Id:	Observation Id
# - Kitchen:	 Number of kitchens
# - KitchenQual:	 Kitchen quality
# - LandContour:	 Flatness of the property
# - LandSlope:	 Slope of property
# - LotArea:	 Lot size in square feet
# - LotConfig:	 Lot configuration
# - LotFrontage:	 Linear feet of street connected to property
# - LotShape:	 General shape of property
# - LowQualFinSF:	 Low quality finished square feet (all floors)
# - MasVnrArea:	 Masonry veneer area in square feet
# - MasVnrType:	 Masonry veneer type
# - MiscFeature:	 Miscellaneous feature not covered in other categories
# - MiscVal:	 $Value of miscellaneous feature
# - MoSold:	 Month Sold
# - MSSubClass:	 The building class
# - MSZoning:	 The general zoning classification
# - Neighborhood:	 Physical locations within Ames city limits
# - OpenPorchSF:	 Open porch area in square feet
# - OverallCond:	 Overall condition rating
# - OverallQual:	 Overall material and finish quality
# - PavedDrive:	 Paved driveway
# - PoolArea:	 Pool area in square feet
# - PoolQC:	 Pool quality
# - RoofMatl:	 Roof material
# - RoofStyle:	 Type of roof
# - SaleCondition:	 Condition of sale
# - SalePrice:	 the property's sale price in dollars. This is the target variable that you're trying to predict.
# - SaleType:	 Type of sale
# - ScreenPorch:	 Screen porch area in square feet
# - Street:	 Type of road access
# - TotalBsmtSF:	 Total square feet of basement area
# - TotRmsAbvGrd:	 Total rooms above grade (does not include bathrooms)
# - Utilities:	 Type of utilities available
# - WoodDeckSF:	 Wood deck area in square feet
# - YearBuilt:	 Original construction date
# - YearRemodAdd:	 Remodel date
# - YrSold:	 Year Sold

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from scipy import stats
from scipy.stats import norm


from sklearn.preprocessing import StandardScaler
from sklearn import ensemble, tree, linear_model
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split, cross_val_score



import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('train.csv')

# %%
from IPython.display import display
pd.options.display.max_columns=None
df=df.reindex_axis(sorted(df.columns),axis=1)
df.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0       856       854          0   NaN             3     1Fam       TA
# 1      1262         0          0   NaN             3     1Fam       TA
# 2       920       866          0   NaN             3     1Fam       TA
# 3       961       756          0   NaN             3     1Fam       Gd
# 4      1145      1053          0   NaN             4     1Fam       TA
#
#   BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# 0           No         706           0          GLQ          Unf
# 1           Gd         978           0          ALQ          Unf
# 2           Mn         486           0          GLQ          Unf
# 3           No         216           0          ALQ          Unf
# 4           Av         655           0          GLQ          Unf
#
#    BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF CentralAir Condition1  \
# 0             1             0       Gd        150          Y       Norm
# 1             0             1       Gd        284          Y      Feedr
# 2             1             0       Gd        434          Y       Norm
# 3             1             0       TA        540          Y       Norm
# 4             1             0       Gd        490          Y       Norm
#
#   Condition2 Electrical  EnclosedPorch ExterCond ExterQual Exterior1st  \
# 0       Norm      SBrkr              0        TA        Gd     VinylSd
# 1       Norm      SBrkr              0        TA        TA     MetalSd
# 2       Norm      SBrkr              0        TA        Gd     VinylSd
# 3       Norm      SBrkr            272        TA        TA     Wd Sdng
# 4       Norm      SBrkr              0        TA        Gd     VinylSd
#
#   Exterior2nd Fence FireplaceQu  Fireplaces Foundation  FullBath Functional  \
# 0     VinylSd   NaN         NaN           0      PConc         2        Typ
# 1     MetalSd   NaN          TA           1     CBlock         2        Typ
# 2     VinylSd   NaN          TA           1      PConc         2        Typ
# 3     Wd Shng   NaN          Gd           1     BrkTil         1        Typ
# 4     VinylSd   NaN          TA           1      PConc         2        Typ
#
#    GarageArea  GarageCars GarageCond GarageFinish GarageQual GarageType  \
# 0         548           2         TA          RFn         TA     Attchd
# 1         460           2         TA          RFn         TA     Attchd
# 2         608           2         TA          RFn         TA     Attchd
# 3         642           3         TA          Unf         TA     Detchd
# 4         836           3         TA          RFn         TA     Attchd
#
#    GarageYrBlt  GrLivArea  HalfBath Heating HeatingQC HouseStyle  Id  \
# 0       2003.0       1710         1    GasA        Ex     2Story   1
# 1       1976.0       1262         0    GasA        Ex     1Story   2
# 2       2001.0       1786         1    GasA        Ex     2Story   3
# 3       1998.0       1717         0    GasA        Gd     2Story   4
# 4       2000.0       2198         1    GasA        Ex     2Story   5
#
#    KitchenAbvGr KitchenQual LandContour LandSlope  LotArea LotConfig  \
# 0             1          Gd         Lvl       Gtl     8450    Inside
# 1             1          TA         Lvl       Gtl     9600       FR2
# 2             1          Gd         Lvl       Gtl    11250    Inside
# 3             1          Gd         Lvl       Gtl     9550    Corner
# 4             1          Gd         Lvl       Gtl    14260       FR2
#
#    LotFrontage LotShape  LowQualFinSF  MSSubClass MSZoning  MasVnrArea  \
# 0         65.0      Reg             0          60       RL       196.0
# 1         80.0      Reg             0          20       RL         0.0
# 2         68.0      IR1             0          60       RL       162.0
# 3         60.0      IR1             0          70       RL         0.0
# 4         84.0      IR1             0          60       RL       350.0
#
#   MasVnrType MiscFeature  MiscVal  MoSold Neighborhood  OpenPorchSF  \
# 0    BrkFace         NaN        0       2      CollgCr           61
# 1       None         NaN        0       5      Veenker            0
# 2    BrkFace         NaN        0       9      CollgCr           42
# 3       None         NaN        0       2      Crawfor           35
# 4    BrkFace         NaN        0      12      NoRidge           84
#
#    OverallCond  OverallQual PavedDrive  PoolArea PoolQC RoofMatl RoofStyle  \
# 0            5            7          Y         0    NaN  CompShg     Gable
# 1            8            6          Y         0    NaN  CompShg     Gable
# 2            5            7          Y         0    NaN  CompShg     Gable
# 3            5            7          Y         0    NaN  CompShg     Gable
# 4            5            8          Y         0    NaN  CompShg     Gable
#
#   SaleCondition  SalePrice SaleType  ScreenPorch Street  TotRmsAbvGrd  \
# 0        Normal     208500       WD            0   Pave             8
# 1        Normal     181500       WD            0   Pave             6
# 2        Normal     223500       WD            0   Pave             6
# 3       Abnorml     140000       WD            0   Pave             7
# 4        Normal     250000       WD            0   Pave             9
#
#    TotalBsmtSF Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          856    AllPub           0       2003          2003    2008
# 1         1262    AllPub         298       1976          1976    2007
# 2          920    AllPub           0       2001          2002    2008
# 3          756    AllPub           0       1915          1970    2006
# 4         1145    AllPub         192       2000          2000    2008

# %%
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### Remove "Id" from dataset

# %%
df=df.drop(columns=['Id'])

# %%
df.shape
# Out:
# (1460, 80)

# %% [markdown]
# ## Log Transformation of "SalePrice'

# %%
y=df['SalePrice']
sns.distplot(y)

# %%
sns.distplot(np.log(y))

# %%
df['SalePrice']=np.log(df['SalePrice'])

# %%
df.dtypes
# Out:
# 1stFlrSF           int64
# 2ndFlrSF           int64
# 3SsnPorch          int64
# Alley             object
# BedroomAbvGr       int64
# BldgType          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtFinType1      object
# BsmtFinType2      object
# BsmtFullBath       int64
# BsmtHalfBath       int64
# BsmtQual          object
# BsmtUnfSF          int64
# CentralAir        object
# Condition1        object
# Condition2        object
# Electrical        object
# EnclosedPorch      int64
# ExterCond         object
# ExterQual         object
# Exterior1st       object
# Exterior2nd       object
# Fence             object
# FireplaceQu       object
# Fireplaces         int64
# Foundation        object
# FullBath           int64
#                   ...
# LotShape          object
# LowQualFinSF       int64
# MSSubClass         int64
# MSZoning          object
# MasVnrArea       float64
# MasVnrType        object
# MiscFeature       object
# MiscVal            int64
# MoSold             int64
# Neighborhood      object
# OpenPorchSF        int64
# OverallCond        int64
# OverallQual        int64
# PavedDrive        object
# PoolArea           int64
# PoolQC            object
# RoofMatl          object
# RoofStyle         object
# SaleCondition     object
# SalePrice        float64
# SaleType          object
# ScreenPorch        int64
# Street            object
# TotRmsAbvGrd       int64
# TotalBsmtSF        int64
# Utilities         object
# WoodDeckSF         int64
# YearBuilt          int64
# YearRemodAdd       int64
# YrSold             int64
# Length: 80, dtype: object

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Checking NAs

# %%
null_cols=df.columns[df.isnull().any()]
df[null_cols].isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageType        81
# GarageQual        81
# GarageFinish      81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtFinType1      37
# BsmtCond          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %%
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
dg
# Out:
# PoolQC          99.520548
# MiscFeature     96.301370
# Alley           93.767123
# Fence           80.753425
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageType       5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtQual         2.534247
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# MasVnrArea       0.547945
# MasVnrType       0.547945
# Electrical       0.068493
# dtype: float64

# %%
featureName=dg.index.values
featureName
# Out:
# array(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu',
#        'LotFrontage', 'GarageYrBlt', 'GarageType', 'GarageQual',
#        'GarageFinish', 'GarageCond', 'BsmtFinType2', 'BsmtExposure',
#        'BsmtQual', 'BsmtFinType1', 'BsmtCond', 'MasVnrArea', 'MasVnrType',
#        'Electrical'], dtype=object)

# %%
def missingness(featureName):
    for i in featureName:
        print(i)
        print(df[i].value_counts(dropna=False))
        print("Value missing: %2.1f %%" % (df[i].isnull().sum()/len(df)*100))
        print()

# %% [markdown]
# ### Checking unique values of feature with more than 70% missning values

# %%
missingness(featureName)
# Out:
# PoolQC
# NaN    1453
# Gd        3
# Fa        2
# Ex        2
# Name: PoolQC, dtype: int64
# Value missing: 99.5 %
#
# MiscFeature
# NaN     1406
# Shed      49
# Othr       2
# Gar2       2
# TenC       1
# Name: MiscFeature, dtype: int64
# Value missing: 96.3 %
#
# Alley
# NaN     1369
# Grvl      50
# Pave      41
# Name: Alley, dtype: int64
# Value missing: 93.8 %
#
# Fence
# NaN      1179
# MnPrv     157
# GdPrv      59
# GdWo       54
# MnWw       11
# Name: Fence, dtype: int64
# Value missing: 80.8 %
#
# FireplaceQu
# NaN    690
# Gd     380
# TA     313
# Fa      33
# Ex      24
# Po      20
# Name: FireplaceQu, dtype: int64
# Value missing: 47.3 %
#
# LotFrontage
# NaN       259
#  60.0     143
#  70.0      70
#  80.0      69
#  50.0      57
#  75.0      53
#  65.0      44
#  85.0      40
#  78.0      25
#  21.0      23
#  90.0      23
#  68.0      19
#  24.0      19
#  64.0      19
#  73.0      18
#  72.0      17
#  79.0      17
#  63.0      17
#  55.0      17
#  100.0     16
#  51.0      15
#  66.0      15
#  74.0      15
#  52.0      14
#  59.0      13
#  71.0      12
#  67.0      12
#  57.0      12
#  82.0      12
#  43.0      12
#          ...
#  129.0      2
#  313.0      2
#  118.0      2
#  122.0      2
#  121.0      2
#  101.0      2
#  109.0      2
#  115.0      2
#  116.0      2
#  114.0      2
#  153.0      1
#  149.0      1
#  150.0      1
#  111.0      1
#  182.0      1
#  46.0       1
#  112.0      1
#  141.0      1
#  33.0       1
#  152.0      1
#  160.0      1
#  168.0      1
#  128.0      1
#  144.0      1
#  39.0       1
#  106.0      1
#  38.0       1
#  138.0      1
#  140.0      1
#  137.0      1
# Name: LotFrontage, Length: 111, dtype: int64
# Value missing: 17.7 %
#
# GarageYrBlt
# NaN        81
#  2005.0    65
#  2006.0    59
#  2004.0    53
#  2003.0    50
#  2007.0    49
#  1977.0    35
#  1998.0    31
#  1999.0    30
#  1976.0    29
#  2008.0    29
#  2000.0    27
#  2002.0    26
#  1968.0    26
#  1950.0    24
#  1993.0    22
#  1962.0    21
#  2009.0    21
#  1966.0    21
#  1965.0    21
#  1958.0    21
#  1970.0    20
#  1996.0    20
#  1957.0    20
#  2001.0    20
#  1997.0    19
#  1978.0    19
#  1960.0    19
#  1954.0    19
#  1974.0    18
#            ..
#  1916.0     5
#  1922.0     5
#  1936.0     5
#  1945.0     4
#  1946.0     4
#  1982.0     4
#  1931.0     4
#  1928.0     4
#  1935.0     4
#  1932.0     3
#  1952.0     3
#  1921.0     3
#  1938.0     3
#  2010.0     3
#  1910.0     3
#  1924.0     3
#  1923.0     3
#  1947.0     2
#  1918.0     2
#  1929.0     2
#  1914.0     2
#  1915.0     2
#  1934.0     2
#  1937.0     2
#  1942.0     2
#  1906.0     1
#  1927.0     1
#  1900.0     1
#  1908.0     1
#  1933.0     1
# Name: GarageYrBlt, Length: 98, dtype: int64
# Value missing: 5.5 %
#
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# NaN         81
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64
# Value missing: 5.5 %
#
# GarageQual
# TA     1311
# NaN      81
# Fa       48
# Gd       14
# Po        3
# Ex        3
# Name: GarageQual, dtype: int64
# Value missing: 5.5 %
#
# GarageFinish
# Unf    605
# RFn    422
# Fin    352
# NaN     81
# Name: GarageFinish, dtype: int64
# Value missing: 5.5 %
#
# GarageCond
# TA     1326
# NaN      81
# Fa       35
# Gd        9
# Po        7
# Ex        2
# Name: GarageCond, dtype: int64
# Value missing: 5.5 %
#
# BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      46
# NaN      38
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64
# Value missing: 2.6 %
#
# BsmtExposure
# No     953
# Av     221
# Gd     134
# Mn     114
# NaN     38
# Name: BsmtExposure, dtype: int64
# Value missing: 2.6 %
#
# BsmtQual
# TA     649
# Gd     618
# Ex     121
# NaN     37
# Fa      35
# Name: BsmtQual, dtype: int64
# Value missing: 2.5 %
#
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# NaN     37
# Name: BsmtFinType1, dtype: int64
# Value missing: 2.5 %
#
# BsmtCond
# TA     1311
# Gd       65
# Fa       45
# NaN      37
# Po        2
# Name: BsmtCond, dtype: int64
# Value missing: 2.5 %
#
# MasVnrArea
#  0.0       861
#  72.0        8
#  180.0       8
# NaN          8
#  108.0       8
#  120.0       7
#  16.0        7
#  106.0       6
#  80.0        6
#  340.0       6
#  200.0       6
#  132.0       5
#  170.0       5
#  360.0       5
#  84.0        5
#  320.0       5
#  270.0       4
#  183.0       4
#  100.0       4
#  168.0       4
#  252.0       4
#  178.0       4
#  246.0       4
#  196.0       4
#  288.0       4
#  216.0       4
#  160.0       4
#  220.0       4
#  336.0       4
#  210.0       4
#           ...
#  24.0        1
#  760.0       1
#  138.0       1
#  27.0        1
#  541.0       1
#  275.0       1
#  365.0       1
#  562.0       1
#  161.0       1
#  247.0       1
#  452.0       1
#  278.0       1
#  375.0       1
#  225.0       1
#  604.0       1
#  762.0       1
#  290.0       1
#  109.0       1
#  299.0       1
#  731.0       1
#  167.0       1
#  309.0       1
#  202.0       1
#  1129.0      1
#  651.0       1
#  337.0       1
#  415.0       1
#  293.0       1
#  259.0       1
#  621.0       1
# Name: MasVnrArea, Length: 328, dtype: int64
# Value missing: 0.5 %
#
# MasVnrType
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# NaN          8
# Name: MasVnrType, dtype: int64
# Value missing: 0.5 %
#
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# NaN         1
# Name: Electrical, dtype: int64
# Value missing: 0.1 %

# %% [markdown]
# ### Remove columns with more than 70% of missing values

# %%
df=df.drop(columns=['PoolQC','MiscFeature','Alley','Fence'])

# %%
df.shape
# Out:
# (1460, 76)

# %% [markdown]
# ### Checking the rest of features with missing values

# %%
null_cols=df.columns[df.isnull().any()]
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
print(dg)
nullCol=dg.index.values
nullCol
# Out:
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageType       5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtQual         2.534247
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# MasVnrType       0.547945
# MasVnrArea       0.547945
# Electrical       0.068493
# dtype: float64
# array(['FireplaceQu', 'LotFrontage', 'GarageYrBlt', 'GarageType',
#        'GarageQual', 'GarageFinish', 'GarageCond', 'BsmtFinType2',
#        'BsmtExposure', 'BsmtQual', 'BsmtFinType1', 'BsmtCond',
#        'MasVnrType', 'MasVnrArea', 'Electrical'], dtype=object)

# %% [markdown]
# ### It looks like "FireplaceQu" has "NaN" value when "Fireplaces" has "zero" value.
# ### Let's check if the number of missing value in "FireplaceQu" is the same as the number of rows with zero value in "Fireplaces"

# %%
df['FireplaceQu'].isnull().sum()
# Out:
# 690

# %%
len(df.loc[df['Fireplaces']==0])
# Out:
# 690

# %% [markdown]
# ### It turns out the number is the same.
# ### We can go ahead and replace the "NaN" in "FireplaceQu" with "0"

# %% [markdown]
# ### Also, we will change the datatype of "FireplaceQu" to a "Ordinal" Variable

# %% [markdown]
# ### First we will need to replace "NaN" with "0" value

# %%
df['FireplaceQu'].fillna(0,inplace=True)

# %%
df['FireplaceQu'].value_counts()
# Out:
# 0     690
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %% [markdown]
# ### Replace string values to ordinal value in "FireplaceQu"

# %%
#quality={'Po':1,'Fa':2,'TA':3,'Gd':4,"Ex":5}
df.FireplaceQu[df.FireplaceQu=='Po']=1
df.FireplaceQu[df.FireplaceQu=='Fa']=2
df.FireplaceQu[df.FireplaceQu=='TA']=3
df.FireplaceQu[df.FireplaceQu=='Gd']=4
df.FireplaceQu[df.FireplaceQu=='Ex']=5

# %%
df.FireplaceQu.dtypes
# Out:
# dtype('O')

# %% [markdown]
# ### Let's change the datatype of "FireplaceQu" to "int"

# %%
df=df.astype({"FireplaceQu":int})

# %%
df.FireplaceQu.dtypes
# Out:
# dtype('int32')

# %%
df['LotFrontage'].isnull().sum()
# Out:
# 259

# %% [markdown]
# ### Some Lot just does not have LotFronage.
# ### Change "NaN" value to "zero" in "LotFrontage"

# %%
df['LotFrontage'].fillna(0,inplace=True)

# %% [markdown]
# ### Check if the number of "0" value is the same as the number "NaN" value

# %%
df['LotFrontage'].value_counts()
# Out:
# 0.0      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 67.0      12
# 57.0      12
# 82.0      12
# 43.0      12
#         ...
# 129.0      2
# 313.0      2
# 118.0      2
# 122.0      2
# 121.0      2
# 101.0      2
# 109.0      2
# 115.0      2
# 116.0      2
# 114.0      2
# 153.0      1
# 149.0      1
# 150.0      1
# 111.0      1
# 182.0      1
# 46.0       1
# 112.0      1
# 141.0      1
# 33.0       1
# 152.0      1
# 160.0      1
# 168.0      1
# 128.0      1
# 144.0      1
# 39.0       1
# 106.0      1
# 38.0       1
# 138.0      1
# 140.0      1
# 137.0      1
# Name: LotFrontage, Length: 111, dtype: int64

# %% [markdown]
# ### Double check all the missing values again

# %%
null_cols=df.columns[df.isnull().any()]
df[null_cols].isnull().sum().sort_values(ascending=False)
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
dg
# Out:
# GarageYrBlt     5.547945
# GarageType      5.547945
# GarageQual      5.547945
# GarageFinish    5.547945
# GarageCond      5.547945
# BsmtFinType2    2.602740
# BsmtExposure    2.602740
# BsmtQual        2.534247
# BsmtFinType1    2.534247
# BsmtCond        2.534247
# MasVnrType      0.547945
# MasVnrArea      0.547945
# Electrical      0.068493
# dtype: float64

# %% [markdown]
# ### All the remaining variables have less than 6% of missing values.
# ### We will remove all the rows with any missing values.

# %%
df_miss=df.dropna()

# %%
df_miss.isnull().sum()
# Out:
# 1stFlrSF         0
# 2ndFlrSF         0
# 3SsnPorch        0
# BedroomAbvGr     0
# BldgType         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtFinType1     0
# BsmtFinType2     0
# BsmtFullBath     0
# BsmtHalfBath     0
# BsmtQual         0
# BsmtUnfSF        0
# CentralAir       0
# Condition1       0
# Condition2       0
# Electrical       0
# EnclosedPorch    0
# ExterCond        0
# ExterQual        0
# Exterior1st      0
# Exterior2nd      0
# FireplaceQu      0
# Fireplaces       0
# Foundation       0
# FullBath         0
# Functional       0
# GarageArea       0
#                 ..
# LotConfig        0
# LotFrontage      0
# LotShape         0
# LowQualFinSF     0
# MSSubClass       0
# MSZoning         0
# MasVnrArea       0
# MasVnrType       0
# MiscVal          0
# MoSold           0
# Neighborhood     0
# OpenPorchSF      0
# OverallCond      0
# OverallQual      0
# PavedDrive       0
# PoolArea         0
# RoofMatl         0
# RoofStyle        0
# SaleCondition    0
# SalePrice        0
# SaleType         0
# ScreenPorch      0
# Street           0
# TotRmsAbvGrd     0
# TotalBsmtSF      0
# Utilities        0
# WoodDeckSF       0
# YearBuilt        0
# YearRemodAdd     0
# YrSold           0
# Length: 76, dtype: int64

# %%
df_miss.shape
# Out:
# (1338, 76)

# %%
len(df)-len(df_miss)
# Out:
# 122

# %% [markdown]
# ### Checking the percentage of data removed

# %%
(len(df)-len(df_miss))/len(df)*100
# Out:
# 8.356164383561644

# %% [markdown]
# ## Start working on Outliers

# %%
df_miss.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr BldgType BsmtCond BsmtExposure  \
# 0       856       854          0             3     1Fam       TA           No
# 1      1262         0          0             3     1Fam       TA           Gd
# 2       920       866          0             3     1Fam       TA           Mn
# 3       961       756          0             3     1Fam       Gd           No
# 4      1145      1053          0             4     1Fam       TA           Av
#
#    BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  BsmtFullBath  \
# 0         706           0          GLQ          Unf             1
# 1         978           0          ALQ          Unf             0
# 2         486           0          GLQ          Unf             1
# 3         216           0          ALQ          Unf             1
# 4         655           0          GLQ          Unf             1
#
#    BsmtHalfBath BsmtQual  BsmtUnfSF CentralAir Condition1 Condition2  \
# 0             0       Gd        150          Y       Norm       Norm
# 1             1       Gd        284          Y      Feedr       Norm
# 2             0       Gd        434          Y       Norm       Norm
# 3             0       TA        540          Y       Norm       Norm
# 4             0       Gd        490          Y       Norm       Norm
#
#   Electrical  EnclosedPorch ExterCond ExterQual Exterior1st Exterior2nd  \
# 0      SBrkr              0        TA        Gd     VinylSd     VinylSd
# 1      SBrkr              0        TA        TA     MetalSd     MetalSd
# 2      SBrkr              0        TA        Gd     VinylSd     VinylSd
# 3      SBrkr            272        TA        TA     Wd Sdng     Wd Shng
# 4      SBrkr              0        TA        Gd     VinylSd     VinylSd
#
#    FireplaceQu  Fireplaces Foundation  FullBath Functional  GarageArea  \
# 0            0           0      PConc         2        Typ         548
# 1            3           1     CBlock         2        Typ         460
# 2            3           1      PConc         2        Typ         608
# 3            4           1     BrkTil         1        Typ         642
# 4            3           1      PConc         2        Typ         836
#
#    GarageCars GarageCond GarageFinish GarageQual GarageType  GarageYrBlt  \
# 0           2         TA          RFn         TA     Attchd       2003.0
# 1           2         TA          RFn         TA     Attchd       1976.0
# 2           2         TA          RFn         TA     Attchd       2001.0
# 3           3         TA          Unf         TA     Detchd       1998.0
# 4           3         TA          RFn         TA     Attchd       2000.0
#
#    GrLivArea  HalfBath Heating HeatingQC HouseStyle  KitchenAbvGr KitchenQual  \
# 0       1710         1    GasA        Ex     2Story             1          Gd
# 1       1262         0    GasA        Ex     1Story             1          TA
# 2       1786         1    GasA        Ex     2Story             1          Gd
# 3       1717         0    GasA        Gd     2Story             1          Gd
# 4       2198         1    GasA        Ex     2Story             1          Gd
#
#   LandContour LandSlope  LotArea LotConfig  LotFrontage LotShape  \
# 0         Lvl       Gtl     8450    Inside         65.0      Reg
# 1         Lvl       Gtl     9600       FR2         80.0      Reg
# 2         Lvl       Gtl    11250    Inside         68.0      IR1
# 3         Lvl       Gtl     9550    Corner         60.0      IR1
# 4         Lvl       Gtl    14260       FR2         84.0      IR1
#
#    LowQualFinSF  MSSubClass MSZoning  MasVnrArea MasVnrType  MiscVal  MoSold  \
# 0             0          60       RL       196.0    BrkFace        0       2
# 1             0          20       RL         0.0       None        0       5
# 2             0          60       RL       162.0    BrkFace        0       9
# 3             0          70       RL         0.0       None        0       2
# 4             0          60       RL       350.0    BrkFace        0      12
#
#   Neighborhood  OpenPorchSF  OverallCond  OverallQual PavedDrive  PoolArea  \
# 0      CollgCr           61            5            7          Y         0
# 1      Veenker            0            8            6          Y         0
# 2      CollgCr           42            5            7          Y         0
# 3      Crawfor           35            5            7          Y         0
# 4      NoRidge           84            5            8          Y         0
#
#   RoofMatl RoofStyle SaleCondition  SalePrice SaleType  ScreenPorch Street  \
# 0  CompShg     Gable        Normal  12.247694       WD            0   Pave
# 1  CompShg     Gable        Normal  12.109011       WD            0   Pave
# 2  CompShg     Gable        Normal  12.317167       WD            0   Pave
# 3  CompShg     Gable       Abnorml  11.849398       WD            0   Pave
# 4  CompShg     Gable        Normal  12.429216       WD            0   Pave
#
#    TotRmsAbvGrd  TotalBsmtSF Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  \
# 0             8          856    AllPub           0       2003          2003
# 1             6         1262    AllPub         298       1976          1976
# 2             6          920    AllPub           0       2001          2002
# 3             7          756    AllPub           0       1915          1970
# 4             9         1145    AllPub         192       2000          2000
#
#    YrSold
# 0    2008
# 1    2007
# 2    2008
# 3    2006
# 4    2008

# %%
df_miss.dtypes
# Out:
# 1stFlrSF           int64
# 2ndFlrSF           int64
# 3SsnPorch          int64
# BedroomAbvGr       int64
# BldgType          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtFinType1      object
# BsmtFinType2      object
# BsmtFullBath       int64
# BsmtHalfBath       int64
# BsmtQual          object
# BsmtUnfSF          int64
# CentralAir        object
# Condition1        object
# Condition2        object
# Electrical        object
# EnclosedPorch      int64
# ExterCond         object
# ExterQual         object
# Exterior1st       object
# Exterior2nd       object
# FireplaceQu        int32
# Fireplaces         int64
# Foundation        object
# FullBath           int64
# Functional        object
# GarageArea         int64
#                   ...
# LotConfig         object
# LotFrontage      float64
# LotShape          object
# LowQualFinSF       int64
# MSSubClass         int64
# MSZoning          object
# MasVnrArea       float64
# MasVnrType        object
# MiscVal            int64
# MoSold             int64
# Neighborhood      object
# OpenPorchSF        int64
# OverallCond        int64
# OverallQual        int64
# PavedDrive        object
# PoolArea           int64
# RoofMatl          object
# RoofStyle         object
# SaleCondition     object
# SalePrice        float64
# SaleType          object
# ScreenPorch        int64
# Street            object
# TotRmsAbvGrd       int64
# TotalBsmtSF        int64
# Utilities         object
# WoodDeckSF         int64
# YearBuilt          int64
# YearRemodAdd       int64
# YrSold             int64
# Length: 76, dtype: object

# %% [markdown]
# ### Select continuous variables

# %%
df_miss.select_dtypes(exclude=['object']).head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0       856       854          0             3         706           0
# 1      1262         0          0             3         978           0
# 2       920       866          0             3         486           0
# 3       961       756          0             3         216           0
# 4      1145      1053          0             4         655           0
#
#    BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  FireplaceQu  \
# 0             1             0        150              0            0
# 1             0             1        284              0            3
# 2             1             0        434              0            3
# 3             1             0        540            272            4
# 4             1             0        490              0            3
#
#    Fireplaces  FullBath  GarageArea  GarageCars  GarageYrBlt  GrLivArea  \
# 0           0         2         548           2       2003.0       1710
# 1           1         2         460           2       1976.0       1262
# 2           1         2         608           2       2001.0       1786
# 3           1         1         642           3       1998.0       1717
# 4           1         2         836           3       2000.0       2198
#
#    HalfBath  KitchenAbvGr  LotArea  LotFrontage  LowQualFinSF  MSSubClass  \
# 0         1             1     8450         65.0             0          60
# 1         0             1     9600         80.0             0          20
# 2         1             1    11250         68.0             0          60
# 3         0             1     9550         60.0             0          70
# 4         1             1    14260         84.0             0          60
#
#    MasVnrArea  MiscVal  MoSold  OpenPorchSF  OverallCond  OverallQual  \
# 0       196.0        0       2           61            5            7
# 1         0.0        0       5            0            8            6
# 2       162.0        0       9           42            5            7
# 3         0.0        0       2           35            5            7
# 4       350.0        0      12           84            5            8
#
#    PoolArea  SalePrice  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  \
# 0         0  12.247694            0             8          856           0
# 1         0  12.109011            0             6         1262         298
# 2         0  12.317167            0             6          920           0
# 3         0  11.849398            0             7          756           0
# 4         0  12.429216            0             9         1145         192
#
#    YearBuilt  YearRemodAdd  YrSold
# 0       2003          2003    2008
# 1       1976          1976    2007
# 2       2001          2002    2008
# 3       1915          1970    2006
# 4       2000          2000    2008

# %% [markdown]
# ### Pair Plot

# %%
con_col=df_miss.select_dtypes(exclude=['object']).columns
con_col
# Out:
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'BedroomAbvGr', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtFullBath', 'BsmtHalfBath', 'BsmtUnfSF',
#        'EnclosedPorch', 'FireplaceQu', 'Fireplaces', 'FullBath', 'GarageArea',
#        'GarageCars', 'GarageYrBlt', 'GrLivArea', 'HalfBath', 'KitchenAbvGr',
#        'LotArea', 'LotFrontage', 'LowQualFinSF', 'MSSubClass', 'MasVnrArea',
#        'MiscVal', 'MoSold', 'OpenPorchSF', 'OverallCond', 'OverallQual',
#        'PoolArea', 'SalePrice', 'ScreenPorch', 'TotRmsAbvGrd', 'TotalBsmtSF',
#        'WoodDeckSF', 'YearBuilt', 'YearRemodAdd', 'YrSold'],
#       dtype='object')

# %%
for item in con_col:
    plt.scatter(x=df_miss[item],y=df_miss['SalePrice'])
    plt.xlabel(item)
    plt.ylabel('Sale Price')
    plt.show()

# %%
for item in con_col:
    plt.scatter(x=np.log1p(df_miss[item]),y=df_miss['SalePrice'])
    plt.xlabel(item)
    plt.ylabel('Sale Price')
    plt.show()

# %% [markdown]
# ### Select Categorical Variables

# %%
cat_col=df_miss.select_dtypes(include=['object']).columns
cat_col
# Out:
# Index(['BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'BsmtQual', 'CentralAir', 'Condition1', 'Condition2', 'Electrical',
#        'ExterCond', 'ExterQual', 'Exterior1st', 'Exterior2nd', 'Foundation',
#        'Functional', 'GarageCond', 'GarageFinish', 'GarageQual', 'GarageType',
#        'Heating', 'HeatingQC', 'HouseStyle', 'KitchenQual', 'LandContour',
#        'LandSlope', 'LotConfig', 'LotShape', 'MSZoning', 'MasVnrType',
#        'Neighborhood', 'PavedDrive', 'RoofMatl', 'RoofStyle', 'SaleCondition',
#        'SaleType', 'Street', 'Utilities'],
#       dtype='object')

# %%
for item in cat_col:
    sns.boxplot(x=item,y="SalePrice",data=df_miss)
    plt.show()

# %%
df_mean=pd.concat([df_miss['BldgType'],df_miss['SalePrice']],axis=1)
df_mean.head()
# Out:
#   BldgType  SalePrice
# 0     1Fam  12.247694
# 1     1Fam  12.109011
# 2     1Fam  12.317167
# 3     1Fam  11.849398
# 4     1Fam  12.429216

# %%
g1=df_mean.groupby('BldgType').mean()
g1
# Out:
#           SalePrice
# BldgType
# 1Fam      12.082016
# 2fmCon    11.757630
# Duplex    11.868405
# Twnhs     11.823556
# TwnhsE    12.065535

# %%
df_g1=pd.DataFrame()
df_g1=pd.DataFrame(g1)
df_g1
# Out:
#           SalePrice
# BldgType
# 1Fam      12.082016
# 2fmCon    11.757630
# Duplex    11.868405
# Twnhs     11.823556
# TwnhsE    12.065535

# %%
df_g2=df_g1.sort_values('SalePrice')
df_g2
# Out:
#           SalePrice
# BldgType
# 2fmCon    11.757630
# Twnhs     11.823556
# Duplex    11.868405
# TwnhsE    12.065535
# 1Fam      12.082016

# %%
df_g2.index
# Out:
# Index(['2fmCon', 'Twnhs', 'Duplex', 'TwnhsE', '1Fam'], dtype='object', name='BldgType')

# %%
g_col=df_g2.index.values

# %%
df_miss['BldgType'].value_counts()
# Out:
# 1Fam      1138
# TwnhsE     112
# Twnhs       38
# Duplex      28
# 2fmCon      22
# Name: BldgType, dtype: int64

# %%
i=0
for item in g_col:
    df_miss.loc[df_miss['BldgType']==item,'BldgType']=i
    i=i+1

# %%
df_miss['BldgType'].value_counts()
# Out:
# 4    1138
# 3     112
# 1      38
# 2      28
# 0      22
# Name: BldgType, dtype: int64

# %%
df_miss.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType BsmtCond  \
# 0       856       854          0             3         4       TA
# 1      1262         0          0             3         4       TA
# 2       920       866          0             3         4       TA
# 3       961       756          0             3         4       Gd
# 4      1145      1053          0             4         4       TA
#
#   BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# 0           No         706           0          GLQ          Unf
# 1           Gd         978           0          ALQ          Unf
# 2           Mn         486           0          GLQ          Unf
# 3           No         216           0          ALQ          Unf
# 4           Av         655           0          GLQ          Unf
#
#    BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF CentralAir Condition1  \
# 0             1             0       Gd        150          Y       Norm
# 1             0             1       Gd        284          Y      Feedr
# 2             1             0       Gd        434          Y       Norm
# 3             1             0       TA        540          Y       Norm
# 4             1             0       Gd        490          Y       Norm
#
#   Condition2 Electrical  EnclosedPorch ExterCond ExterQual Exterior1st  \
# 0       Norm      SBrkr              0        TA        Gd     VinylSd
# 1       Norm      SBrkr              0        TA        TA     MetalSd
# 2       Norm      SBrkr              0        TA        Gd     VinylSd
# 3       Norm      SBrkr            272        TA        TA     Wd Sdng
# 4       Norm      SBrkr              0        TA        Gd     VinylSd
#
#   Exterior2nd  FireplaceQu  Fireplaces Foundation  FullBath Functional  \
# 0     VinylSd            0           0      PConc         2        Typ
# 1     MetalSd            3           1     CBlock         2        Typ
# 2     VinylSd            3           1      PConc         2        Typ
# 3     Wd Shng            4           1     BrkTil         1        Typ
# 4     VinylSd            3           1      PConc         2        Typ
#
#    GarageArea  GarageCars GarageCond GarageFinish GarageQual GarageType  \
# 0         548           2         TA          RFn         TA     Attchd
# 1         460           2         TA          RFn         TA     Attchd
# 2         608           2         TA          RFn         TA     Attchd
# 3         642           3         TA          Unf         TA     Detchd
# 4         836           3         TA          RFn         TA     Attchd
#
#    GarageYrBlt  GrLivArea  HalfBath Heating HeatingQC HouseStyle  \
# 0       2003.0       1710         1    GasA        Ex     2Story
# 1       1976.0       1262         0    GasA        Ex     1Story
# 2       2001.0       1786         1    GasA        Ex     2Story
# 3       1998.0       1717         0    GasA        Gd     2Story
# 4       2000.0       2198         1    GasA        Ex     2Story
#
#    KitchenAbvGr KitchenQual LandContour LandSlope  LotArea LotConfig  \
# 0             1          Gd         Lvl       Gtl     8450    Inside
# 1             1          TA         Lvl       Gtl     9600       FR2
# 2             1          Gd         Lvl       Gtl    11250    Inside
# 3             1          Gd         Lvl       Gtl     9550    Corner
# 4             1          Gd         Lvl       Gtl    14260       FR2
#
#    LotFrontage LotShape  LowQualFinSF  MSSubClass MSZoning  MasVnrArea  \
# 0         65.0      Reg             0          60       RL       196.0
# 1         80.0      Reg             0          20       RL         0.0
# 2         68.0      IR1             0          60       RL       162.0
# 3         60.0      IR1             0          70       RL         0.0
# 4         84.0      IR1             0          60       RL       350.0
#
#   MasVnrType  MiscVal  MoSold Neighborhood  OpenPorchSF  OverallCond  \
# 0    BrkFace        0       2      CollgCr           61            5
# 1       None        0       5      Veenker            0            8
# 2    BrkFace        0       9      CollgCr           42            5
# 3       None        0       2      Crawfor           35            5
# 4    BrkFace        0      12      NoRidge           84            5
#
#    OverallQual PavedDrive  PoolArea RoofMatl RoofStyle SaleCondition  \
# 0            7          Y         0  CompShg     Gable        Normal
# 1            6          Y         0  CompShg     Gable        Normal
# 2            7          Y         0  CompShg     Gable        Normal
# 3            7          Y         0  CompShg     Gable       Abnorml
# 4            8          Y         0  CompShg     Gable        Normal
#
#    SalePrice SaleType  ScreenPorch Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0  12.247694       WD            0   Pave             8          856
# 1  12.109011       WD            0   Pave             6         1262
# 2  12.317167       WD            0   Pave             6          920
# 3  11.849398       WD            0   Pave             7          756
# 4  12.429216       WD            0   Pave             9         1145
#
#   Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0    AllPub           0       2003          2003    2008
# 1    AllPub         298       1976          1976    2007
# 2    AllPub           0       2001          2002    2008
# 3    AllPub           0       1915          1970    2006
# 4    AllPub         192       2000          2000    2008

# %% [markdown]
# ## Convert all 'object' datatype variables to 'numerical" variables.

# %% [markdown]
# ### First we need to convert "object" datatype to "categorical" datatype.

# %%
df_miss.select_dtypes(include=['object']).head()
# Out:
#   BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 BsmtQual CentralAir  \
# 0       TA           No          GLQ          Unf       Gd          Y
# 1       TA           Gd          ALQ          Unf       Gd          Y
# 2       TA           Mn          GLQ          Unf       Gd          Y
# 3       Gd           No          ALQ          Unf       TA          Y
# 4       TA           Av          GLQ          Unf       Gd          Y
#
#   Condition1 Condition2 Electrical ExterCond ExterQual Exterior1st  \
# 0       Norm       Norm      SBrkr        TA        Gd     VinylSd
# 1      Feedr       Norm      SBrkr        TA        TA     MetalSd
# 2       Norm       Norm      SBrkr        TA        Gd     VinylSd
# 3       Norm       Norm      SBrkr        TA        TA     Wd Sdng
# 4       Norm       Norm      SBrkr        TA        Gd     VinylSd
#
#   Exterior2nd Foundation Functional GarageCond GarageFinish GarageQual  \
# 0     VinylSd      PConc        Typ         TA          RFn         TA
# 1     MetalSd     CBlock        Typ         TA          RFn         TA
# 2     VinylSd      PConc        Typ         TA          RFn         TA
# 3     Wd Shng     BrkTil        Typ         TA          Unf         TA
# 4     VinylSd      PConc        Typ         TA          RFn         TA
#
#   GarageType Heating HeatingQC HouseStyle KitchenQual LandContour LandSlope  \
# 0     Attchd    GasA        Ex     2Story          Gd         Lvl       Gtl
# 1     Attchd    GasA        Ex     1Story          TA         Lvl       Gtl
# 2     Attchd    GasA        Ex     2Story          Gd         Lvl       Gtl
# 3     Detchd    GasA        Gd     2Story          Gd         Lvl       Gtl
# 4     Attchd    GasA        Ex     2Story          Gd         Lvl       Gtl
#
#   LotConfig LotShape MSZoning MasVnrType Neighborhood PavedDrive RoofMatl  \
# 0    Inside      Reg       RL    BrkFace      CollgCr          Y  CompShg
# 1       FR2      Reg       RL       None      Veenker          Y  CompShg
# 2    Inside      IR1       RL    BrkFace      CollgCr          Y  CompShg
# 3    Corner      IR1       RL       None      Crawfor          Y  CompShg
# 4       FR2      IR1       RL    BrkFace      NoRidge          Y  CompShg
#
#   RoofStyle SaleCondition SaleType Street Utilities
# 0     Gable        Normal       WD   Pave    AllPub
# 1     Gable        Normal       WD   Pave    AllPub
# 2     Gable        Normal       WD   Pave    AllPub
# 3     Gable       Abnorml       WD   Pave    AllPub
# 4     Gable        Normal       WD   Pave    AllPub

# %%
df_enc_col=list(df_miss.select_dtypes(include=['object']).columns.values)
df_enc_col
# Out:
# ['BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'BsmtQual',
#  'CentralAir',
#  'Condition1',
#  'Condition2',
#  'Electrical',
#  'ExterCond',
#  'ExterQual',
#  'Exterior1st',
#  'Exterior2nd',
#  'Foundation',
#  'Functional',
#  'GarageCond',
#  'GarageFinish',
#  'GarageQual',
#  'GarageType',
#  'Heating',
#  'HeatingQC',
#  'HouseStyle',
#  'KitchenQual',
#  'LandContour',
#  'LandSlope',
#  'LotConfig',
#  'LotShape',
#  'MSZoning',
#  'MasVnrType',
#  'Neighborhood',
#  'PavedDrive',
#  'RoofMatl',
#  'RoofStyle',
#  'SaleCondition',
#  'SaleType',
#  'Street',
#  'Utilities']

# %%
df_enc=pd.DataFrame()
df_enc[df_enc_col]=df_miss[df_enc_col]
df_enc[df_enc_col].head()
# Out:
#   BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 BsmtQual CentralAir  \
# 0       TA           No          GLQ          Unf       Gd          Y
# 1       TA           Gd          ALQ          Unf       Gd          Y
# 2       TA           Mn          GLQ          Unf       Gd          Y
# 3       Gd           No          ALQ          Unf       TA          Y
# 4       TA           Av          GLQ          Unf       Gd          Y
#
#   Condition1 Condition2 Electrical ExterCond ExterQual Exterior1st  \
# 0       Norm       Norm      SBrkr        TA        Gd     VinylSd
# 1      Feedr       Norm      SBrkr        TA        TA     MetalSd
# 2       Norm       Norm      SBrkr        TA        Gd     VinylSd
# 3       Norm       Norm      SBrkr        TA        TA     Wd Sdng
# 4       Norm       Norm      SBrkr        TA        Gd     VinylSd
#
#   Exterior2nd Foundation Functional GarageCond GarageFinish GarageQual  \
# 0     VinylSd      PConc        Typ         TA          RFn         TA
# 1     MetalSd     CBlock        Typ         TA          RFn         TA
# 2     VinylSd      PConc        Typ         TA          RFn         TA
# 3     Wd Shng     BrkTil        Typ         TA          Unf         TA
# 4     VinylSd      PConc        Typ         TA          RFn         TA
#
#   GarageType Heating HeatingQC HouseStyle KitchenQual LandContour LandSlope  \
# 0     Attchd    GasA        Ex     2Story          Gd         Lvl       Gtl
# 1     Attchd    GasA        Ex     1Story          TA         Lvl       Gtl
# 2     Attchd    GasA        Ex     2Story          Gd         Lvl       Gtl
# 3     Detchd    GasA        Gd     2Story          Gd         Lvl       Gtl
# 4     Attchd    GasA        Ex     2Story          Gd         Lvl       Gtl
#
#   LotConfig LotShape MSZoning MasVnrType Neighborhood PavedDrive RoofMatl  \
# 0    Inside      Reg       RL    BrkFace      CollgCr          Y  CompShg
# 1       FR2      Reg       RL       None      Veenker          Y  CompShg
# 2    Inside      IR1       RL    BrkFace      CollgCr          Y  CompShg
# 3    Corner      IR1       RL       None      Crawfor          Y  CompShg
# 4       FR2      IR1       RL    BrkFace      NoRidge          Y  CompShg
#
#   RoofStyle SaleCondition SaleType Street Utilities
# 0     Gable        Normal       WD   Pave    AllPub
# 1     Gable        Normal       WD   Pave    AllPub
# 2     Gable        Normal       WD   Pave    AllPub
# 3     Gable       Abnorml       WD   Pave    AllPub
# 4     Gable        Normal       WD   Pave    AllPub

# %%
df_enc[df_enc_col]=df_enc[df_enc_col].astype('category',copy=True)

# %%
for item in df_enc_col:
    print(df_enc[item].dtypes)
# Out:
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category
# category

# %% [markdown]
# ### Then we need to convert "Category" variable to "Numerical" values with "Label Encoding" technique.

# %%
for item in df_enc_col:
    df_enc[item]=df_enc[item].cat.codes

# %%
df_enc[df_enc_col].head()
# Out:
#    BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinType2  BsmtQual  CentralAir  \
# 0         3             3             2             5         2           1
# 1         3             1             0             5         2           1
# 2         3             2             2             5         2           1
# 3         1             3             0             5         3           1
# 4         3             0             2             5         2           1
#
#    Condition1  Condition2  Electrical  ExterCond  ExterQual  Exterior1st  \
# 0           2           2           4          3          2           11
# 1           1           2           4          3          3            7
# 2           2           2           4          3          2           11
# 3           2           2           4          3          3           12
# 4           2           2           4          3          2           11
#
#    Exterior2nd  Foundation  Functional  GarageCond  GarageFinish  GarageQual  \
# 0           13           2           6           4             1           4
# 1            8           1           6           4             1           4
# 2           13           2           6           4             1           4
# 3           15           0           6           4             2           4
# 4           13           2           6           4             1           4
#
#    GarageType  Heating  HeatingQC  HouseStyle  KitchenQual  LandContour  \
# 0           1        0          0           5            2            3
# 1           1        0          0           2            3            3
# 2           1        0          0           5            2            3
# 3           5        0          2           5            2            3
# 4           1        0          0           5            2            3
#
#    LandSlope  LotConfig  LotShape  MSZoning  MasVnrType  Neighborhood  \
# 0          0          4         3         3           1             5
# 1          0          2         3         3           2            24
# 2          0          4         0         3           1             5
# 3          0          0         0         3           2             6
# 4          0          2         0         3           1            15
#
#    PavedDrive  RoofMatl  RoofStyle  SaleCondition  SaleType  Street  Utilities
# 0           2         1          1              4         8       1          0
# 1           2         1          1              4         8       1          0
# 2           2         1          1              4         8       1          0
# 3           2         1          1              0         8       1          0
# 4           2         1          1              4         8       1          0

# %% [markdown]
# ### Combine encoded variables to original dataset

# %%
df_out=pd.DataFrame()
df_out=df_miss
df_out[df_enc_col]=df_enc[df_enc_col]
df_out.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0       856       854          0             3         4         3
# 1      1262         0          0             3         4         3
# 2       920       866          0             3         4         3
# 3       961       756          0             3         4         1
# 4      1145      1053          0             4         4         3
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0             3         706           0             2             5
# 1             1         978           0             0             5
# 2             2         486           0             2             5
# 3             3         216           0             0             5
# 4             0         655           0             2             5
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0             1             0         2        150           1           2
# 1             0             1         2        284           1           1
# 2             1             0         2        434           1           2
# 3             1             0         3        540           1           2
# 4             1             0         2        490           1           2
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0           2           4              0          3          2           11
# 1           2           4              0          3          3            7
# 2           2           4              0          3          2           11
# 3           2           4            272          3          3           12
# 4           2           4              0          3          2           11
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0           13            0           0           2         2           6
# 1            8            3           1           1         2           6
# 2           13            3           1           2         2           6
# 3           15            4           1           0         1           6
# 4           13            3           1           2         2           6
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0         548           2           4             1           4           1
# 1         460           2           4             1           4           1
# 2         608           2           4             1           4           1
# 3         642           3           4             2           4           5
# 4         836           3           4             1           4           1
#
#    GarageYrBlt  GrLivArea  HalfBath  Heating  HeatingQC  HouseStyle  \
# 0       2003.0       1710         1        0          0           5
# 1       1976.0       1262         0        0          0           2
# 2       2001.0       1786         1        0          0           5
# 3       1998.0       1717         0        0          2           5
# 4       2000.0       2198         1        0          0           5
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope  LotArea  LotConfig  \
# 0             1            2            3          0     8450          4
# 1             1            3            3          0     9600          2
# 2             1            2            3          0    11250          4
# 3             1            2            3          0     9550          0
# 4             1            2            3          0    14260          2
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0         65.0         3             0          60         3       196.0
# 1         80.0         3             0          20         3         0.0
# 2         68.0         0             0          60         3       162.0
# 3         60.0         0             0          70         3         0.0
# 4         84.0         0             0          60         3       350.0
#
#    MasVnrType  MiscVal  MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0           1        0       2             5           61            5
# 1           2        0       5            24            0            8
# 2           1        0       9             5           42            5
# 3           2        0       2             6           35            5
# 4           1        0      12            15           84            5
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0            7           2         0         1          1              4
# 1            6           2         0         1          1              4
# 2            7           2         0         1          1              4
# 3            7           2         0         1          1              0
# 4            8           2         0         1          1              4
#
#    SalePrice  SaleType  ScreenPorch  Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0  12.247694         8            0       1             8          856
# 1  12.109011         8            0       1             6         1262
# 2  12.317167         8            0       1             6          920
# 3  11.849398         8            0       1             7          756
# 4  12.429216         8            0       1             9         1145
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          0           0       2003          2003    2008
# 1          0         298       1976          1976    2007
# 2          0           0       2001          2002    2008
# 3          0           0       1915          1970    2006
# 4          0         192       2000          2000    2008

# %% [markdown]
# ## Standardize all the continuous variables

# %%
scaler=StandardScaler()
array_out=scaler.fit_transform(df_out)

# %%
values=array_out
col=df_out.columns
df_out=pd.DataFrame(data=values,columns=col)

# %%
df_out.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0 -0.828516  1.128813  -0.118688      0.174239  0.354171  0.279034
# 1  0.221935 -0.811389  -0.118688      0.174239  0.354171  0.279034
# 2 -0.662928  1.156076  -0.118688      0.174239  0.354171  0.279034
# 3 -0.556848  0.906167  -0.118688      0.174239  0.354171 -2.845214
# 4 -0.080781  1.580921  -0.118688      1.462256  0.354171  0.279034
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0      0.650093    0.527157   -0.296255     -0.384924       0.31751
# 1     -1.082625    1.120240   -0.296255     -1.485412       0.31751
# 2     -0.216266    0.047458   -0.296255     -0.384924       0.31751
# 3      0.650093   -0.541263   -0.296255     -1.485412       0.31751
# 4     -1.948985    0.415954   -0.296255     -0.384924       0.31751
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0      1.088949     -0.250577 -0.274488  -0.983421    0.218559   -0.059866
# 1     -0.851149      3.888586 -0.274488  -0.678727    0.218559   -1.188047
# 2      1.088949     -0.250577 -0.274488  -0.337652    0.218559   -0.059866
# 3      1.088949     -0.250577  0.866087  -0.096626    0.218559   -0.059866
# 4      1.088949     -0.250577 -0.274488  -0.210318    0.218559   -0.059866
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0   -0.036109    0.274964      -0.349612   0.341632  -0.741877     0.752602
# 1   -0.036109    0.274964      -0.349612   0.341632   0.688427    -0.538400
# 2   -0.036109    0.274964      -0.349612   0.341632  -0.741877     0.752602
# 3   -0.036109    0.274964       4.122511   0.341632   0.688427     1.075352
# 4   -0.036109    0.274964      -0.349612   0.341632  -0.741877     0.752602
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0     0.754323    -1.071535   -1.005546    0.918767  0.775560    0.245509
# 1    -0.674853     0.589137    0.544478   -0.569502  0.775560    0.245509
# 2     0.754323     0.589137    0.544478    0.918767  0.775560    0.245509
# 3     1.325993     1.142695    0.544478   -2.057772 -1.051375    0.245509
# 4     0.754323     0.589137    0.544478    0.918767  0.775560    0.245509
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0    0.249341    0.202747    0.190464     -0.216113    0.225742   -0.706793
# 1   -0.222023    0.202747    0.190464     -0.216113    0.225742   -0.706793
# 2    0.570726    0.202747    0.190464     -0.216113    0.225742   -0.706793
# 3    0.752844    1.779928    0.190464      1.014352    0.225742    1.544847
# 4    1.791989    1.779928    0.190464     -0.216113    0.225742   -0.706793
#
#    GarageYrBlt  GrLivArea  HalfBath   Heating  HeatingQC  HouseStyle  \
# 0     0.985427   0.331321  1.184848 -0.113076  -0.858877    0.995207
# 1    -0.104844  -0.529579 -0.799291 -0.113076  -0.858877   -0.571980
# 2     0.904666   0.477367  1.184848 -0.113076  -0.858877    0.995207
# 3     0.783525   0.344773 -0.799291 -0.113076   0.294337    0.995207
# 4     0.864286   1.269088  1.184848 -0.113076  -0.858877    0.995207
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope   LotArea  LotConfig  \
# 0      -0.17119    -0.390085     0.308907  -0.228303 -0.218363   0.612488
# 1      -0.17119     0.815306     0.308907  -0.228303 -0.107067  -0.614322
# 2      -0.17119    -0.390085     0.308907  -0.228303  0.052620   0.612488
# 3      -0.17119    -0.390085     0.308907  -0.228303 -0.111906  -1.841132
# 4      -0.17119    -0.390085     0.308907  -0.228303  0.343926  -0.614322
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0     0.203108  0.772893      -0.10374    0.093701 -0.038318    0.461582
# 1     0.629552  0.772893      -0.10374   -0.876298 -0.038318   -0.594820
# 2     0.288397 -1.341893      -0.10374    0.093701 -0.038318    0.278328
# 3     0.060960 -1.341893      -0.10374    0.336201 -0.038318   -0.594820
# 4     0.743270 -1.341893      -0.10374    0.093701 -0.038318    1.291612
#
#    MasVnrType   MiscVal    MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0   -1.184869 -0.084535 -1.605319     -1.219747     0.202294    -0.553402
# 1    0.394170 -0.084535 -0.493561      1.922891    -0.731311     2.230251
# 2   -1.184869 -0.084535  0.988784     -1.219747    -0.088501    -0.553402
# 3    0.394170 -0.084535 -1.605319     -1.054345    -0.195636    -0.553402
# 4   -1.184869 -0.084535  2.100542      0.434273     0.554309    -0.553402
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0     0.589337    0.243685 -0.071771 -0.125687  -0.503885       0.184105
# 1    -0.165963    0.243685 -0.071771 -0.125687  -0.503885       0.184105
# 2     0.589337    0.243685 -0.071771 -0.125687  -0.503885       0.184105
# 3     0.589337    0.243685 -0.071771 -0.125687  -0.503885      -3.591099
# 4     1.344638    0.243685 -0.071771 -0.125687  -0.503885       0.184105
#
#    SalePrice  SaleType  ScreenPorch    Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0   0.488981  0.316441    -0.283203  0.061245      0.915080    -0.591875
# 1   0.120834  0.316441    -0.283203  0.061245     -0.347165     0.409598
# 2   0.673401  0.316441    -0.283203  0.061245     -0.347165    -0.434007
# 3  -0.568330  0.316441    -0.283203  0.061245      0.283958    -0.838543
# 4   0.970845  0.316441    -0.283203  0.061245      1.546203     0.120996
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd    YrSold
# 0  -0.027349   -0.779554   1.014157      0.854216  0.146084
# 1  -0.027349    1.557895   0.100528     -0.476562 -0.605686
# 2  -0.027349   -0.779554   0.946480      0.804928  0.146084
# 3  -0.027349   -0.779554  -1.963596     -0.772291 -1.357457
# 4  -0.027349    0.726453   0.912642      0.706352  0.146084

# %%
df_out['SalePrice'].isnull().sum()
# Out:
# 0

# %%
df_out.describe().T
# Out:
#                 count          mean       std        min       25%       50%  \
# 1stFlrSF       1338.0  5.708770e-17  1.000374  -1.910016 -0.730198 -0.202385
# 2ndFlrSF       1338.0 -1.792288e-17  1.000374  -0.811389 -0.811389 -0.811389
# 3SsnPorch      1338.0 -1.593145e-17  1.000374  -0.118688 -0.118688 -0.118688
# BedroomAbvGr   1338.0 -2.655242e-17  1.000374  -3.689815 -1.113779  0.174239
# BldgType       1338.0 -2.316699e-16  1.000374  -4.768864  0.354171  0.354171
# BsmtCond       1338.0  5.576008e-17  1.000374  -4.407338  0.279034  0.279034
# BsmtExposure   1338.0 -1.579869e-16  1.000374  -1.948985 -1.082625  0.650093
# BsmtFinSF1     1338.0 -5.044960e-17  1.000374  -1.012240 -1.012240 -0.111715
# BsmtFinSF2     1338.0 -3.982863e-17  1.000374  -0.296255 -0.296255 -0.296255
# BsmtFinType1   1338.0  1.048821e-16  1.000374  -1.485412 -0.935168 -0.384924
# BsmtFinType2   1338.0 -1.885222e-16  1.000374  -4.940273  0.317510  0.317510
# BsmtFullBath   1338.0 -1.327621e-17  1.000374  -0.851149 -0.851149 -0.851149
# BsmtHalfBath   1338.0  3.982863e-17  1.000374  -0.250577 -0.250577 -0.250577
# BsmtQual       1338.0 -1.858669e-16  1.000374  -2.555640 -0.274488 -0.274488
# BsmtUnfSF      1338.0  1.360811e-17  1.000374  -1.324496 -0.760585 -0.212591
# CentralAir     1338.0 -2.555670e-16  1.000374  -4.575415  0.218559  0.218559
# Condition1     1338.0 -1.380726e-16  1.000374  -2.316228 -0.059866 -0.059866
# Condition2     1338.0 -2.416270e-16  1.000374  -7.468955 -0.036109 -0.036109
# Electrical     1338.0 -7.965726e-17  1.000374  -3.812838  0.274964  0.274964
# EnclosedPorch  1338.0  3.518196e-17  1.000374  -0.349612 -0.349612 -0.349612
# ExterCond      1338.0  4.859093e-16  1.000374  -7.494431  0.341632  0.341632
# ExterQual      1338.0 -1.486935e-16  1.000374  -3.602484 -0.741877  0.688427
# Exterior1st    1338.0 -9.824395e-17  1.000374  -2.797652 -0.538400  0.752602
# Exterior2nd    1338.0 -1.885222e-16  1.000374  -2.961534 -0.674853  0.754323
# FireplaceQu    1338.0  6.107056e-17  1.000374  -1.071535 -1.071535  0.589137
# Fireplaces     1338.0 -6.903629e-17  1.000374  -1.005546 -1.005546  0.544478
# Foundation     1338.0 -1.168306e-16  1.000374  -2.057772 -0.569502 -0.569502
# FullBath       1338.0  3.684148e-17  1.000374  -2.878310 -1.051375  0.775560
# Functional     1338.0 -5.576008e-17  1.000374  -6.216615  0.245509  0.245509
# GarageArea     1338.0  8.098488e-17  1.000374  -1.828947 -0.663927 -0.093469
# ...               ...           ...       ...        ...       ...       ...
# LotConfig      1338.0 -6.638105e-17  1.000374  -1.841132 -0.614322  0.612488
# LotFrontage    1338.0 -8.098488e-17  1.000374  -1.644815 -0.479202  0.174678
# LotShape       1338.0 -2.788004e-17  1.000374  -1.341893 -1.341893  0.772893
# LowQualFinSF   1338.0  4.513911e-17  1.000374  -0.103740 -0.103740 -0.103740
# MSSubClass     1338.0 -7.169153e-17  1.000374  -0.876298 -0.876298 -0.148798
# MSZoning       1338.0  1.327621e-16  1.000374  -4.844859 -0.038318 -0.038318
# MasVnrArea     1338.0 -2.124194e-17  1.000374  -0.594820 -0.594820 -0.594820
# MasVnrType     1338.0  1.062097e-17  1.000374  -2.763907 -1.184869  0.394170
# MiscVal        1338.0 -1.725907e-17  1.000374  -0.084535 -0.084535 -0.084535
# MoSold         1338.0  1.380726e-16  1.000374  -1.975906 -0.493561 -0.122975
# Neighborhood   1338.0 -7.434677e-17  1.000374  -2.046757 -0.888943 -0.061933
# OpenPorchSF    1338.0  4.779435e-17  1.000374  -0.731311 -0.731311 -0.302771
# OverallCond    1338.0 -1.540040e-16  1.000374  -3.337054 -0.553402 -0.553402
# OverallQual    1338.0  2.655242e-17  1.000374  -3.187164 -0.921263 -0.165963
# PavedDrive     1338.0 -1.619698e-16  1.000374  -4.586695  0.243685  0.243685
# PoolArea       1338.0  1.593145e-17  1.000374  -0.071771 -0.071771 -0.071771
# RoofMatl       1338.0  1.062097e-17  1.000374  -1.774406 -0.125687 -0.125687
# RoofStyle      1338.0 -6.770867e-17  1.000374  -1.688769 -0.503885 -0.503885
# SaleCondition  1338.0  6.903629e-17  1.000374  -3.591099  0.184105  0.184105
# SalePrice      1338.0 -2.708347e-16  1.000374  -4.224877 -0.664871 -0.076454
# SaleType       1338.0  1.593145e-17  1.000374  -4.746610  0.316441  0.316441
# ScreenPorch    1338.0  7.567439e-17  1.000374  -0.283203 -0.283203 -0.283203
# Street         1338.0 -4.135539e-16  1.000374 -16.327890  0.061245  0.061245
# TotRmsAbvGrd   1338.0 -2.708347e-16  1.000374  -2.240532 -0.978287 -0.347165
# TotalBsmtSF    1338.0  2.655242e-18  1.000374  -2.444353 -0.681292 -0.183639
# Utilities      1338.0 -2.655242e-18  1.000374  -0.027349 -0.027349 -0.027349
# WoodDeckSF     1338.0 -5.310484e-17  1.000374  -0.779554 -0.779554 -0.732492
# YearBuilt      1338.0 -5.190998e-16  1.000374  -3.147929 -0.576234  0.100528
# YearRemodAdd   1338.0 -2.923421e-15  1.000374  -1.758052 -0.870867  0.435268
# YrSold         1338.0  1.968596e-14  1.000374  -1.357457 -0.605686  0.146084
#
#                     75%        max
# 1stFlrSF       0.615208   9.096439
# 2ndFlrSF       0.870952   3.880083
# 3SsnPorch     -0.118688  16.695086
# BedroomAbvGr   0.174239   4.038292
# BldgType       0.354171   0.354171
# BsmtCond       0.279034   0.279034
# BsmtExposure   0.650093   0.650093
# BsmtFinSF1     0.586029  11.294219
# BsmtFinSF2    -0.296255   8.576076
# BsmtFinType1   1.265808   1.265808
# BsmtFinType2   0.317510   0.317510
# BsmtFullBath   1.088949   3.029048
# BsmtHalfBath  -0.250577   8.027749
# BsmtQual       0.866087   0.866087
# BsmtUnfSF      0.530383   3.987178
# CentralAir     0.218559   0.218559
# Condition1    -0.059866   6.709218
# Condition2    -0.036109  18.546006
# Electrical     0.274964   0.274964
# EnclosedPorch -0.349612   8.726167
# ExterCond      0.341632   0.341632
# ExterQual      0.688427   0.688427
# Exterior1st    0.752602   1.398102
# Exterior2nd    0.754323   1.325993
# FireplaceQu    1.142695   1.696252
# Fireplaces     0.544478   3.644525
# Foundation     0.918767   3.895307
# FullBath       0.775560   2.602495
# Functional     0.245509   0.245509
# GarageArea     0.436816   4.909422
# ...                 ...        ...
# LotConfig      0.612488   0.612488
# LotFrontage    0.629552   7.253643
# LotShape       0.772893   0.772893
# LowQualFinSF  -0.103740  13.951109
# MSSubClass     0.336201   3.246198
# MSZoning      -0.038318   1.563862
# MasVnrArea     0.343006   8.028869
# MasVnrType     0.394170   1.973208
# MiscVal       -0.084535  30.435304
# MoSold         0.618198   2.100542
# Neighborhood   0.765077   1.922891
# OpenPorchSF    0.340039   7.640523
# OverallCond    0.374482   3.158135
# OverallQual    0.589337   2.855238
# PavedDrive     0.243685   0.243685
# PoolArea      -0.071771  17.522424
# RoofMatl      -0.125687   9.766625
# RoofStyle     -0.503885   4.235649
# SaleCondition  0.184105   1.127906
# SalePrice      0.631501   3.904839
# SaleType       0.316441   0.316441
# ScreenPorch   -0.283203   7.988396
# Street         0.061245   0.061245
# TotRmsAbvGrd   0.283958   3.439571
# TotalBsmtSF    0.562533  12.368074
# Utilities     -0.027349  36.565011
# WoodDeckSF     0.589187   5.942573
# YearBuilt      0.946480   1.251023
# YearRemodAdd   0.903504   1.199233
# YrSold         0.897854   1.649625
#
# [76 rows x 8 columns]

# %%
plt.hist(df_out['SalePrice'])
# Out:
# (array([  2.,   6.,  32., 148., 438., 383., 216.,  89.,  18.,   6.]),
#  array([-4.22487667, -3.41190514, -2.59893361, -1.78596208, -0.97299054,
#         -0.16001901,  0.65295252,  1.46592405,  2.27889558,  3.09186711,
#          3.90483864]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### 1. Filter Method - Correlation Coefficient

# %%
corr=df_out.corr()
corr.sort_values(["SalePrice"],ascending=False,inplace=True)
dc=corr.SalePrice

# %%
dc
# Out:
# SalePrice        1.000000
# OverallQual      0.807486
# GrLivArea        0.704739
# GarageCars       0.660141
# GarageArea       0.612695
# FullBath         0.612604
# 1stFlrSF         0.599786
# TotalBsmtSF      0.589520
# YearBuilt        0.572592
# YearRemodAdd     0.565870
# TotRmsAbvGrd     0.551437
# GarageYrBlt      0.536262
# FireplaceQu      0.527068
# Foundation       0.497078
# Fireplaces       0.470671
# MasVnrArea       0.423314
# OpenPorchSF      0.346072
# BsmtFinSF1       0.342070
# WoodDeckSF       0.317555
# 2ndFlrSF         0.308708
# HalfBath         0.286409
# CentralAir       0.278809
# Electrical       0.263060
# LotArea          0.250126
# SaleCondition    0.238019
# PavedDrive       0.224216
# BsmtFullBath     0.215843
# BedroomAbvGr     0.199379
# BsmtUnfSF        0.194456
# GarageCond       0.193368
#                    ...
# LandSlope        0.060633
# 3SsnPorch        0.053057
# MoSold           0.051261
# BsmtFinType2     0.048822
# MasVnrType       0.015242
# LandContour      0.014661
# Condition2      -0.007270
# MiscVal         -0.011226
# Utilities       -0.016851
# BsmtFinSF2      -0.020503
# LowQualFinSF    -0.023653
# SaleType        -0.023784
# BsmtHalfBath    -0.024876
# YrSold          -0.028239
# Heating         -0.066596
# BsmtFinType1    -0.068896
# LotConfig       -0.070456
# MSSubClass      -0.072901
# OverallCond     -0.081275
# KitchenAbvGr    -0.122327
# EnclosedPorch   -0.152351
# MSZoning        -0.190592
# BsmtExposure    -0.283295
# LotShape        -0.284850
# GarageType      -0.422744
# HeatingQC       -0.449324
# GarageFinish    -0.550217
# BsmtQual        -0.583439
# KitchenQual     -0.586013
# ExterQual       -0.617115
# Name: SalePrice, Length: 76, dtype: float64

# %%
dc.index
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'FullBath', '1stFlrSF', 'TotalBsmtSF', 'YearBuilt', 'YearRemodAdd',
#        'TotRmsAbvGrd', 'GarageYrBlt', 'FireplaceQu', 'Foundation',
#        'Fireplaces', 'MasVnrArea', 'OpenPorchSF', 'BsmtFinSF1', 'WoodDeckSF',
#        '2ndFlrSF', 'HalfBath', 'CentralAir', 'Electrical', 'LotArea',
#        'SaleCondition', 'PavedDrive', 'BsmtFullBath', 'BedroomAbvGr',
#        'BsmtUnfSF', 'GarageCond', 'HouseStyle', 'RoofStyle', 'LotFrontage',
#        'Neighborhood', 'GarageQual', 'BldgType', 'Exterior2nd', 'Exterior1st',
#        'RoofMatl', 'ExterCond', 'Functional', 'ScreenPorch', 'Condition1',
#        'BsmtCond', 'PoolArea', 'Street', 'LandSlope', '3SsnPorch', 'MoSold',
#        'BsmtFinType2', 'MasVnrType', 'LandContour', 'Condition2', 'MiscVal',
#        'Utilities', 'BsmtFinSF2', 'LowQualFinSF', 'SaleType', 'BsmtHalfBath',
#        'YrSold', 'Heating', 'BsmtFinType1', 'LotConfig', 'MSSubClass',
#        'OverallCond', 'KitchenAbvGr', 'EnclosedPorch', 'MSZoning',
#        'BsmtExposure', 'LotShape', 'GarageType', 'HeatingQC', 'GarageFinish',
#        'BsmtQual', 'KitchenQual', 'ExterQual'],
#       dtype='object')

# %%
dc.values
# Out:
# array([ 1.        ,  0.8074857 ,  0.70473894,  0.66014075,  0.61269452,
#         0.61260389,  0.59978615,  0.58952025,  0.57259173,  0.56587019,
#         0.55143677,  0.53626173,  0.52706753,  0.49707807,  0.47067112,
#         0.42331423,  0.34607215,  0.34206958,  0.31755505,  0.30870754,
#         0.28640944,  0.27880933,  0.26306047,  0.25012583,  0.23801919,
#         0.22421613,  0.21584274,  0.19937875,  0.19445612,  0.19336785,
#         0.19233836,  0.18918721,  0.18547878,  0.18520042,  0.1666701 ,
#         0.16507556,  0.13568563,  0.12252142,  0.12243645,  0.1199445 ,
#         0.11653865,  0.1050095 ,  0.09967171,  0.08082215,  0.0697885 ,
#         0.06488613,  0.06063344,  0.05305697,  0.05126082,  0.04882155,
#         0.01524152,  0.01466129, -0.00727027, -0.01122649, -0.01685112,
#        -0.02050253, -0.023653  , -0.02378422, -0.02487607, -0.0282392 ,
#        -0.06659585, -0.06889598, -0.07045565, -0.07290122, -0.08127469,
#        -0.12232653, -0.15235139, -0.19059199, -0.28329463, -0.28485043,
#        -0.42274441, -0.44932407, -0.55021695, -0.58343872, -0.5860134 ,
#        -0.61711523])

# %%
dc.index.values
# Out:
# array(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars',
#        'GarageArea', 'FullBath', '1stFlrSF', 'TotalBsmtSF', 'YearBuilt',
#        'YearRemodAdd', 'TotRmsAbvGrd', 'GarageYrBlt', 'FireplaceQu',
#        'Foundation', 'Fireplaces', 'MasVnrArea', 'OpenPorchSF',
#        'BsmtFinSF1', 'WoodDeckSF', '2ndFlrSF', 'HalfBath', 'CentralAir',
#        'Electrical', 'LotArea', 'SaleCondition', 'PavedDrive',
#        'BsmtFullBath', 'BedroomAbvGr', 'BsmtUnfSF', 'GarageCond',
#        'HouseStyle', 'RoofStyle', 'LotFrontage', 'Neighborhood',
#        'GarageQual', 'BldgType', 'Exterior2nd', 'Exterior1st', 'RoofMatl',
#        'ExterCond', 'Functional', 'ScreenPorch', 'Condition1', 'BsmtCond',
#        'PoolArea', 'Street', 'LandSlope', '3SsnPorch', 'MoSold',
#        'BsmtFinType2', 'MasVnrType', 'LandContour', 'Condition2',
#        'MiscVal', 'Utilities', 'BsmtFinSF2', 'LowQualFinSF', 'SaleType',
#        'BsmtHalfBath', 'YrSold', 'Heating', 'BsmtFinType1', 'LotConfig',
#        'MSSubClass', 'OverallCond', 'KitchenAbvGr', 'EnclosedPorch',
#        'MSZoning', 'BsmtExposure', 'LotShape', 'GarageType', 'HeatingQC',
#        'GarageFinish', 'BsmtQual', 'KitchenQual', 'ExterQual'],
#       dtype=object)

# %%
dc_new=dc[(dc.values>0.5)&(dc.values<1)]
dc_new
# Out:
# OverallQual     0.807486
# GrLivArea       0.704739
# GarageCars      0.660141
# GarageArea      0.612695
# FullBath        0.612604
# 1stFlrSF        0.599786
# TotalBsmtSF     0.589520
# YearBuilt       0.572592
# YearRemodAdd    0.565870
# TotRmsAbvGrd    0.551437
# GarageYrBlt     0.536262
# FireplaceQu     0.527068
# Name: SalePrice, dtype: float64

# %%
feature_col=dc_new.index.values
feature_col
# Out:
# array(['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'FullBath',
#        '1stFlrSF', 'TotalBsmtSF', 'YearBuilt', 'YearRemodAdd',
#        'TotRmsAbvGrd', 'GarageYrBlt', 'FireplaceQu'], dtype=object)

# %% [markdown]
# ### Select the features to be used in the data analysis

# %%
X=df_out[sorted(feature_col)]
y=df_out['SalePrice']

# %%
X.head()
# Out:
#    1stFlrSF  FireplaceQu  FullBath  GarageArea  GarageCars  GarageYrBlt  \
# 0 -0.828516    -1.071535  0.775560    0.249341    0.202747     0.985427
# 1  0.221935     0.589137  0.775560   -0.222023    0.202747    -0.104844
# 2 -0.662928     0.589137  0.775560    0.570726    0.202747     0.904666
# 3 -0.556848     1.142695 -1.051375    0.752844    1.779928     0.783525
# 4 -0.080781     0.589137  0.775560    1.791989    1.779928     0.864286
#
#    GrLivArea  OverallQual  TotRmsAbvGrd  TotalBsmtSF  YearBuilt  YearRemodAdd
# 0   0.331321     0.589337      0.915080    -0.591875   1.014157      0.854216
# 1  -0.529579    -0.165963     -0.347165     0.409598   0.100528     -0.476562
# 2   0.477367     0.589337     -0.347165    -0.434007   0.946480      0.804928
# 3   0.344773     0.589337      0.283958    -0.838543  -1.963596     -0.772291
# 4   1.269088     1.344638      1.546203     0.120996   0.912642      0.706352

# %%
y.head()
# Out:
# 0    0.488981
# 1    0.120834
# 2    0.673401
# 3   -0.568330
# 4    0.970845
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Specify testing size

# %%
TS=0.2

# %% [markdown]
# ### Create a Result dataframe

# %%
result_col=['Algorithm','Correlation','Recursive','XGBoost']
result=pd.DataFrame(columns=result_col)
result['Algorithm']=['Ridge Regression','LASSO Regression','Elastic Net',
                     'Decision Tree','Random Forest','XGBoost']

# %%
result
# Out:
#           Algorithm Correlation Recursive XGBoost
# 0  Ridge Regression         NaN       NaN     NaN
# 1  LASSO Regression         NaN       NaN     NaN
# 2       Elastic Net         NaN       NaN     NaN
# 3     Decision Tree         NaN       NaN     NaN
# 4     Random Forest         NaN       NaN     NaN
# 5           XGBoost         NaN       NaN     NaN

# %% [markdown]
# ### Split the data to train and test dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=TS, random_state=200)

# %% [markdown]
# ### Ridge Regression

# %%
print(plt.rcParams["figure.figsize"])
plt.rcParams["figure.figsize"] = (8,4)
# Out:
# [6.0, 4.0]

# %%
from sklearn.linear_model import Ridge
RR=Ridge(alpha=0.001,fit_intercept=True)
RR_fit=RR.fit(x_train,y_train)

# %%
y_pred=RR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.43226568209525157

# %%
y_pred=RR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][0]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][0]
# Out:
# 0.4221213814737912

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso
LR=Lasso(alpha=0.001,fit_intercept=True)
LR_fit=LR.fit(x_train,y_train)
y_pred=LR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.43228791790320287

# %%
y_pred=LR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][1]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][1]
# Out:
# 0.42230936702453153

# %% [markdown]
# ### Elastic Net Model

# %%
from sklearn.linear_model import ElasticNetCV
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)
EN_fit=EN.fit(x_train, y_train)

# %%
y_pred=EN_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.4347827167101326

# %%
y_pred=EN_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][2]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][2]
# Out:
# 0.42948037739553285

# %% [markdown]
# ### Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
DT=DecisionTreeRegressor()
DT_fit=DT.fit(x_train,y_train)

# %%
y_pred=DT_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.016304336636634453

# %%
y_pred=DT_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][3]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][3]
# Out:
# 0.5895672535999176

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)
RF_fit=RF.fit(x_train, y_train)

# %%
y_pred=RF_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.15131741000599294

# %%
y_pred=RF_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][4]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][4]
# Out:
# 0.4106616784555526

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=3000, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)
XG_fit=XG.fit(x_train, y_train)

# %%
y_pred=XG_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.14857194400247056

# %%
y_pred=XG_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][5]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][5]
# Out:
# 0.42512451634325077

# %% [markdown]
# ### Wrapper Method - Recursive Feature Elimination Method

# %%
from sklearn.feature_selection import RFECV

# %% [markdown]
# ### Split the data to train and test dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=TS, random_state=200)

# %% [markdown]
# ### Ridge Regression

# %%
RR=Ridge(alpha=0.001,fit_intercept=True)
RM_RR=RFECV(RR, step=1, cv=20, scoring='neg_mean_squared_error')
RM_RR_fit=RM_RR.fit(x_train,y_train)
RM_RR_fit.n_features_
# Out:
# 12

# %%
y_pred=RM_RR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.43226568209525157

# %%
y_pred=RM_RR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][0]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][0]
# Out:
# 0.4221213814737912

# %% [markdown]
# ### Lasso Regression

# %%
LR=Lasso(alpha=0.001,fit_intercept=True)
RM_LR=RFECV(LR, step=1, cv=20, scoring='neg_mean_squared_error')
RM_LR_fit=RM_LR.fit(x_train,y_train)
RM_LR_fit.n_features_
# Out:
# 12

# %%
y_pred=RM_LR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.43228791790320287

# %%
y_pred=RM_LR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][1]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][1]
# Out:
# 0.42230936702453153

# %% [markdown]
# ### Elastic Net Model

# %%
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)
RM_EN=RFECV(EN, step=1, cv=20, scoring='neg_mean_squared_error')
RM_EN_fit=RM_EN.fit(x_train,y_train)
RM_EN_fit.n_features_
# Out:
# 10

# %%
y_pred=RM_EN_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.43441531137057326

# %%
y_pred=RM_EN_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][2]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][2]
# Out:
# 0.4266972843962321

# %% [markdown]
# ### Decision Tree Model

# %%
DT=DecisionTreeRegressor()
RM_DT=RFECV(DT, step=1, cv=20, scoring='neg_mean_squared_error')
RM_DT_fit=RM_DT.fit(x_train,y_train)
RM_DT_fit.n_features_
# Out:
# 8

# %%
y_pred=RM_DT_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.016935050850503397

# %%
y_pred=RM_DT_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][3]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][3]
# Out:
# 0.5719716455640969

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)
RM_RF=RFECV(RF, step=1, cv=10, scoring='neg_mean_squared_error')
RM_RF_fit=RM_RF.fit(x_train,y_train)
RM_RF_fit.n_features_
# Out:
# 9

# %%
y_pred=RM_RF_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.15073823826809762

# %%
y_pred=RM_RF_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][4]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][4]
# Out:
# 0.4077947752971224

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=300, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)
RM_XG=RFECV(XG, step=1, cv=5, scoring='neg_mean_squared_error')
RM_XG_fit=RM_XG.fit(x_train,y_train)
RM_XG_fit.n_features_
# Out:
# 12

# %%
y_pred=RM_XG_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.2198801993976736

# %%
y_pred=RM_XG_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][5]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][5]
# Out:
# 0.4210717211196011

# %% [markdown]
# ## Embedded Method - XGBoost Feature Importance

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
df_out_X=df_out.drop(columns=['SalePrice'])
df_out_y=df_out['SalePrice']
model.fit(df_out_X, df_out_y)
print(model.feature_importances_)
# Out:
# [6.4477168e-02 3.5236243e-02 4.3921775e-04 3.9529596e-03 8.7843550e-04
#  5.4902217e-04 6.4674816e-03 5.9096750e-02 1.8447145e-03 9.1576902e-03
#  4.3921775e-04 2.5804043e-03 5.4902217e-04 2.5584435e-03 8.8304728e-02
#  3.6235465e-04 1.2956924e-03 0.0000000e+00 1.2298097e-03 3.1294264e-03
#  1.6251057e-03 1.8227537e-03 7.5655258e-03 1.0047106e-02 7.7741542e-03
#  1.0321618e-03 2.2290300e-03 2.5474629e-03 1.0980443e-03 6.8913266e-02
#  1.3835359e-03 6.0392439e-04 7.2800345e-03 2.4156977e-04 4.7764932e-03
#  2.2509910e-02 9.0786308e-02 2.3278540e-03 0.0000000e+00 8.5867075e-03
#  3.9968817e-03 1.0980444e-05 4.0188422e-03 7.9059193e-04 4.5019819e-04
#  9.7857714e-02 5.2706129e-03 3.3204861e-02 6.7200316e-03 0.0000000e+00
#  7.2361124e-03 1.8776559e-03 3.7465274e-02 3.3819766e-03 3.6235465e-04
#  2.1236178e-02 1.9391464e-02 3.7157822e-02 5.0070826e-03 9.1247484e-03
#  3.9529597e-04 0.0000000e+00 1.9764798e-04 2.4156976e-03 1.4274577e-03
#  8.6745503e-04 1.4274577e-03 0.0000000e+00 8.3231768e-03 6.2720299e-02
#  0.0000000e+00 3.7629981e-02 2.1543631e-02 2.8626017e-02 1.4164773e-02]

# %%
len(model.feature_importances_)
# Out:
# 75

# %%
df_out_X.shape
# Out:
# (1338, 75)

# %%
df_out_X_col=df_out_X.columns.values

# %%
plt.rcParams["figure.figsize"] = (10,20)
plt.barh(df_out_X_col, model.feature_importances_)
plt.show()

# %%
df_XG=pd.DataFrame()

# %%
df_XG['Feature']=df_out_X_col
df_XG['Feature_Importance']=model.feature_importances_

# %%
df_XG.head()
# Out:
#         Feature  Feature_Importance
# 0      1stFlrSF            0.064477
# 1      2ndFlrSF            0.035236
# 2     3SsnPorch            0.000439
# 3  BedroomAbvGr            0.003953
# 4      BldgType            0.000878

# %%
df_XG=df_XG.sort_values(by=['Feature_Importance'],ascending=False)

# %%
df_XG
# Out:
#           Feature  Feature_Importance
# 45        LotArea            0.097858
# 36      GrLivArea            0.090786
# 14      BsmtUnfSF            0.088305
# 29     GarageArea            0.068913
# 0        1stFlrSF            0.064477
# 69    TotalBsmtSF            0.062720
# 7      BsmtFinSF1            0.059097
# 71     WoodDeckSF            0.037630
# 52     MasVnrArea            0.037465
# 57    OpenPorchSF            0.037158
# 1        2ndFlrSF            0.035236
# 47    LotFrontage            0.033205
# 73   YearRemodAdd            0.028626
# 35    GarageYrBlt            0.022510
# 72      YearBuilt            0.021544
# 55         MoSold            0.021236
# 56   Neighborhood            0.019391
# 74         YrSold            0.014165
# 23    Exterior2nd            0.010047
# 9    BsmtFinType1            0.009158
# 59    OverallQual            0.009125
# 39      HeatingQC            0.008587
# 68   TotRmsAbvGrd            0.008323
# 24    FireplaceQu            0.007774
# 22    Exterior1st            0.007566
# 32   GarageFinish            0.007280
# 50     MSSubClass            0.007236
# 48       LotShape            0.006720
# 6    BsmtExposure            0.006467
# 46      LotConfig            0.005271
# ..            ...                 ...
# 21      ExterQual            0.001823
# 20      ExterCond            0.001625
# 66    ScreenPorch            0.001427
# 64  SaleCondition            0.001427
# 30     GarageCars            0.001384
# 16     Condition1            0.001296
# 18     Electrical            0.001230
# 28     Functional            0.001098
# 25     Fireplaces            0.001032
# 4        BldgType            0.000878
# 65       SaleType            0.000867
# 43    LandContour            0.000791
# 31     GarageCond            0.000604
# 5        BsmtCond            0.000549
# 12   BsmtHalfBath            0.000549
# 44      LandSlope            0.000450
# 10   BsmtFinType2            0.000439
# 2       3SsnPorch            0.000439
# 60     PavedDrive            0.000395
# 15     CentralAir            0.000362
# 54        MiscVal            0.000362
# 33     GarageQual            0.000242
# 62       RoofMatl            0.000198
# 41   KitchenAbvGr            0.000011
# 38        Heating            0.000000
# 67         Street            0.000000
# 61       PoolArea            0.000000
# 70      Utilities            0.000000
# 49   LowQualFinSF            0.000000
# 17     Condition2            0.000000
#
# [75 rows x 2 columns]

# %%
feature_col_XG=df_XG['Feature'][:12].values

# %%
feature_col_XG
# Out:
# array(['LotArea', 'GrLivArea', 'BsmtUnfSF', 'GarageArea', '1stFlrSF',
#        'TotalBsmtSF', 'BsmtFinSF1', 'WoodDeckSF', 'MasVnrArea',
#        'OpenPorchSF', '2ndFlrSF', 'LotFrontage'], dtype=object)

# %% [markdown]
# ### Using the new selected features in the 6 models again.

# %%
X=df_out[feature_col_XG]
y=df_out['SalePrice']

# %%
feature_col_XG
# Out:
# array(['LotArea', 'GrLivArea', 'BsmtUnfSF', 'GarageArea', '1stFlrSF',
#        'TotalBsmtSF', 'BsmtFinSF1', 'WoodDeckSF', 'MasVnrArea',
#        'OpenPorchSF', '2ndFlrSF', 'LotFrontage'], dtype=object)

# %% [markdown]
# ### Split the data to train and test dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=TS, random_state=200)

# %% [markdown]
# ### Ridge Regression

# %%
plt.rcParams["figure.figsize"] = (8,4)

# %%
from sklearn.linear_model import Ridge
RR=Ridge(alpha=0.0001,fit_intercept=True)
RR_fit=RR.fit(x_train,y_train)
y_pred=RR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.5956135736325215

# %%
y_pred=RR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][0]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][0]
# Out:
# 0.5494569865912848

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso
LR=Lasso(alpha=0.0001,fit_intercept=True)
LR_fit=LR.fit(x_train,y_train)
y_pred=LR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.5956228911243919

# %%
y_pred=LR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][1]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][1]
# Out:
# 0.5496751541374045

# %% [markdown]
# ### Elastic Net Model

# %%
from sklearn.linear_model import ElasticNetCV
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)
EN_fit=EN.fit(x_train, y_train)

# %%
y_pred=EN_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.5983140950408843

# %%
y_pred=EN_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][2]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][2]
# Out:
# 0.5546080600507451

# %% [markdown]
# ### Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
DT=DecisionTreeRegressor()
DT_fit=DT.fit(x_train,y_train)

# %%
y_pred=DT_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.005215274294468786

# %%
y_pred=DT_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][3]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][3]
# Out:
# 0.6661526500989199

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)
RF_fit=RF.fit(x_train, y_train)

# %%
y_pred=RF_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.1830050421129371

# %%
y_pred=RF_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][4]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][4]
# Out:
# 0.48971625516825334

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=3000, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)
XG_fit=XG.fit(x_train, y_train)

# %%
y_pred=XG_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.15002295093954707

# %%
y_pred=XG_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][5]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][5]
# Out:
# 0.4792206834937262

# %% [markdown]
# ## Examine the result

# %%
print('test-size: ',TS)
# Out:
# test-size:  0.2

# %%
result
# Out:
#           Algorithm Correlation Recursive   XGBoost
# 0  Ridge Regression    0.422121  0.422121  0.549457
# 1  LASSO Regression    0.422309  0.422309  0.549675
# 2       Elastic Net     0.42948  0.426697  0.554608
# 3     Decision Tree    0.589567  0.571972  0.666153
# 4     Random Forest    0.410662  0.407795  0.489716
# 5           XGBoost    0.425125  0.421072  0.479221
