# %% [markdown]
# ## 1. Data Exploration/Cleaning
# - Checking null values
# - Remove outliers
#
# ## 2. Features Selection
# - Filter Method - Correlation Matrix
# - Wrapper Method - Recursive Method
# - Embedded Method - XGBoost Feature Importance
#
#
# ## 3.	Models
# - Ridge Regression
# - LASSO Regression
# - Elastic Net Regression
# - Decision Tree
# - Random Forest
# - XGBoost
#
# ## 4.	Models Evaluation
# - RMSE (Root Mean Squred Error)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from scipy import stats
from scipy.stats import norm


from sklearn.preprocessing import StandardScaler
from sklearn import ensemble, tree, linear_model
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split, cross_val_score



import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('train.csv')

# %%
from IPython.display import display
pd.options.display.max_columns=None
df=df.reindex_axis(sorted(df.columns),axis=1)
df.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0       856       854          0   NaN             3     1Fam       TA
# 1      1262         0          0   NaN             3     1Fam       TA
# 2       920       866          0   NaN             3     1Fam       TA
# 3       961       756          0   NaN             3     1Fam       Gd
# 4      1145      1053          0   NaN             4     1Fam       TA
#
#   BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# 0           No         706           0          GLQ          Unf
# 1           Gd         978           0          ALQ          Unf
# 2           Mn         486           0          GLQ          Unf
# 3           No         216           0          ALQ          Unf
# 4           Av         655           0          GLQ          Unf
#
#    BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF CentralAir Condition1  \
# 0             1             0       Gd        150          Y       Norm
# 1             0             1       Gd        284          Y      Feedr
# 2             1             0       Gd        434          Y       Norm
# 3             1             0       TA        540          Y       Norm
# 4             1             0       Gd        490          Y       Norm
#
#   Condition2 Electrical  EnclosedPorch ExterCond ExterQual Exterior1st  \
# 0       Norm      SBrkr              0        TA        Gd     VinylSd
# 1       Norm      SBrkr              0        TA        TA     MetalSd
# 2       Norm      SBrkr              0        TA        Gd     VinylSd
# 3       Norm      SBrkr            272        TA        TA     Wd Sdng
# 4       Norm      SBrkr              0        TA        Gd     VinylSd
#
#   Exterior2nd Fence FireplaceQu  Fireplaces Foundation  FullBath Functional  \
# 0     VinylSd   NaN         NaN           0      PConc         2        Typ
# 1     MetalSd   NaN          TA           1     CBlock         2        Typ
# 2     VinylSd   NaN          TA           1      PConc         2        Typ
# 3     Wd Shng   NaN          Gd           1     BrkTil         1        Typ
# 4     VinylSd   NaN          TA           1      PConc         2        Typ
#
#    GarageArea  GarageCars GarageCond GarageFinish GarageQual GarageType  \
# 0         548           2         TA          RFn         TA     Attchd
# 1         460           2         TA          RFn         TA     Attchd
# 2         608           2         TA          RFn         TA     Attchd
# 3         642           3         TA          Unf         TA     Detchd
# 4         836           3         TA          RFn         TA     Attchd
#
#    GarageYrBlt  GrLivArea  HalfBath Heating HeatingQC HouseStyle  Id  \
# 0       2003.0       1710         1    GasA        Ex     2Story   1
# 1       1976.0       1262         0    GasA        Ex     1Story   2
# 2       2001.0       1786         1    GasA        Ex     2Story   3
# 3       1998.0       1717         0    GasA        Gd     2Story   4
# 4       2000.0       2198         1    GasA        Ex     2Story   5
#
#    KitchenAbvGr KitchenQual LandContour LandSlope  LotArea LotConfig  \
# 0             1          Gd         Lvl       Gtl     8450    Inside
# 1             1          TA         Lvl       Gtl     9600       FR2
# 2             1          Gd         Lvl       Gtl    11250    Inside
# 3             1          Gd         Lvl       Gtl     9550    Corner
# 4             1          Gd         Lvl       Gtl    14260       FR2
#
#    LotFrontage LotShape  LowQualFinSF  MSSubClass MSZoning  MasVnrArea  \
# 0         65.0      Reg             0          60       RL       196.0
# 1         80.0      Reg             0          20       RL         0.0
# 2         68.0      IR1             0          60       RL       162.0
# 3         60.0      IR1             0          70       RL         0.0
# 4         84.0      IR1             0          60       RL       350.0
#
#   MasVnrType MiscFeature  MiscVal  MoSold Neighborhood  OpenPorchSF  \
# 0    BrkFace         NaN        0       2      CollgCr           61
# 1       None         NaN        0       5      Veenker            0
# 2    BrkFace         NaN        0       9      CollgCr           42
# 3       None         NaN        0       2      Crawfor           35
# 4    BrkFace         NaN        0      12      NoRidge           84
#
#    OverallCond  OverallQual PavedDrive  PoolArea PoolQC RoofMatl RoofStyle  \
# 0            5            7          Y         0    NaN  CompShg     Gable
# 1            8            6          Y         0    NaN  CompShg     Gable
# 2            5            7          Y         0    NaN  CompShg     Gable
# 3            5            7          Y         0    NaN  CompShg     Gable
# 4            5            8          Y         0    NaN  CompShg     Gable
#
#   SaleCondition  SalePrice SaleType  ScreenPorch Street  TotRmsAbvGrd  \
# 0        Normal     208500       WD            0   Pave             8
# 1        Normal     181500       WD            0   Pave             6
# 2        Normal     223500       WD            0   Pave             6
# 3       Abnorml     140000       WD            0   Pave             7
# 4        Normal     250000       WD            0   Pave             9
#
#    TotalBsmtSF Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          856    AllPub           0       2003          2003    2008
# 1         1262    AllPub         298       1976          1976    2007
# 2          920    AllPub           0       2001          2002    2008
# 3          756    AllPub           0       1915          1970    2006
# 4         1145    AllPub         192       2000          2000    2008

# %%
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### Remove "Id" from dataset

# %%
df=df.drop(columns=['Id'])

# %%
df.shape
# Out:
# (1460, 80)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Checking NAs

# %%
null_cols=df.columns[df.isnull().any()]
df[null_cols].isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageType        81
# GarageQual        81
# GarageFinish      81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtFinType1      37
# BsmtCond          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %%
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
dg
# Out:
# PoolQC          99.520548
# MiscFeature     96.301370
# Alley           93.767123
# Fence           80.753425
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageType       5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtQual         2.534247
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# MasVnrArea       0.547945
# MasVnrType       0.547945
# Electrical       0.068493
# dtype: float64

# %%
featureName=dg.index.values
featureName
# Out:
# array(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu',
#        'LotFrontage', 'GarageYrBlt', 'GarageType', 'GarageQual',
#        'GarageFinish', 'GarageCond', 'BsmtFinType2', 'BsmtExposure',
#        'BsmtQual', 'BsmtFinType1', 'BsmtCond', 'MasVnrArea', 'MasVnrType',
#        'Electrical'], dtype=object)

# %%
def missingness(featureName):
    for i in featureName:
        print(i)
        print(df[i].value_counts(dropna=False))
        print("Value missing: %2.1f %%" % (df[i].isnull().sum()/len(df)*100))
        print()

# %% [markdown]
# ### Checking unique values of feature with more than 70% missning values

# %%
missingness(featureName)
# Out:
# PoolQC
# NaN    1453
# Gd        3
# Fa        2
# Ex        2
# Name: PoolQC, dtype: int64
# Value missing: 99.5 %
#
# MiscFeature
# NaN     1406
# Shed      49
# Othr       2
# Gar2       2
# TenC       1
# Name: MiscFeature, dtype: int64
# Value missing: 96.3 %
#
# Alley
# NaN     1369
# Grvl      50
# Pave      41
# Name: Alley, dtype: int64
# Value missing: 93.8 %
#
# Fence
# NaN      1179
# MnPrv     157
# GdPrv      59
# GdWo       54
# MnWw       11
# Name: Fence, dtype: int64
# Value missing: 80.8 %
#
# FireplaceQu
# NaN    690
# Gd     380
# TA     313
# Fa      33
# Ex      24
# Po      20
# Name: FireplaceQu, dtype: int64
# Value missing: 47.3 %
#
# LotFrontage
# NaN       259
#  60.0     143
#  70.0      70
#  80.0      69
#  50.0      57
#  75.0      53
#  65.0      44
#  85.0      40
#  78.0      25
#  21.0      23
#  90.0      23
#  68.0      19
#  24.0      19
#  64.0      19
#  73.0      18
#  72.0      17
#  79.0      17
#  63.0      17
#  55.0      17
#  100.0     16
#  51.0      15
#  66.0      15
#  74.0      15
#  52.0      14
#  59.0      13
#  71.0      12
#  67.0      12
#  57.0      12
#  82.0      12
#  43.0      12
#          ...
#  129.0      2
#  313.0      2
#  118.0      2
#  122.0      2
#  121.0      2
#  101.0      2
#  109.0      2
#  115.0      2
#  116.0      2
#  114.0      2
#  153.0      1
#  149.0      1
#  150.0      1
#  111.0      1
#  182.0      1
#  46.0       1
#  112.0      1
#  141.0      1
#  33.0       1
#  152.0      1
#  160.0      1
#  168.0      1
#  128.0      1
#  144.0      1
#  39.0       1
#  106.0      1
#  38.0       1
#  138.0      1
#  140.0      1
#  137.0      1
# Name: LotFrontage, Length: 111, dtype: int64
# Value missing: 17.7 %
#
# GarageYrBlt
# NaN        81
#  2005.0    65
#  2006.0    59
#  2004.0    53
#  2003.0    50
#  2007.0    49
#  1977.0    35
#  1998.0    31
#  1999.0    30
#  1976.0    29
#  2008.0    29
#  2000.0    27
#  2002.0    26
#  1968.0    26
#  1950.0    24
#  1993.0    22
#  1962.0    21
#  2009.0    21
#  1966.0    21
#  1965.0    21
#  1958.0    21
#  1970.0    20
#  1996.0    20
#  1957.0    20
#  2001.0    20
#  1997.0    19
#  1978.0    19
#  1960.0    19
#  1954.0    19
#  1974.0    18
#            ..
#  1916.0     5
#  1922.0     5
#  1936.0     5
#  1945.0     4
#  1946.0     4
#  1982.0     4
#  1931.0     4
#  1928.0     4
#  1935.0     4
#  1932.0     3
#  1952.0     3
#  1921.0     3
#  1938.0     3
#  2010.0     3
#  1910.0     3
#  1924.0     3
#  1923.0     3
#  1947.0     2
#  1918.0     2
#  1929.0     2
#  1914.0     2
#  1915.0     2
#  1934.0     2
#  1937.0     2
#  1942.0     2
#  1906.0     1
#  1927.0     1
#  1900.0     1
#  1908.0     1
#  1933.0     1
# Name: GarageYrBlt, Length: 98, dtype: int64
# Value missing: 5.5 %
#
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# NaN         81
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64
# Value missing: 5.5 %
#
# GarageQual
# TA     1311
# NaN      81
# Fa       48
# Gd       14
# Po        3
# Ex        3
# Name: GarageQual, dtype: int64
# Value missing: 5.5 %
#
# GarageFinish
# Unf    605
# RFn    422
# Fin    352
# NaN     81
# Name: GarageFinish, dtype: int64
# Value missing: 5.5 %
#
# GarageCond
# TA     1326
# NaN      81
# Fa       35
# Gd        9
# Po        7
# Ex        2
# Name: GarageCond, dtype: int64
# Value missing: 5.5 %
#
# BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      46
# NaN      38
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64
# Value missing: 2.6 %
#
# BsmtExposure
# No     953
# Av     221
# Gd     134
# Mn     114
# NaN     38
# Name: BsmtExposure, dtype: int64
# Value missing: 2.6 %
#
# BsmtQual
# TA     649
# Gd     618
# Ex     121
# NaN     37
# Fa      35
# Name: BsmtQual, dtype: int64
# Value missing: 2.5 %
#
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# NaN     37
# Name: BsmtFinType1, dtype: int64
# Value missing: 2.5 %
#
# BsmtCond
# TA     1311
# Gd       65
# Fa       45
# NaN      37
# Po        2
# Name: BsmtCond, dtype: int64
# Value missing: 2.5 %
#
# MasVnrArea
#  0.0       861
#  72.0        8
#  180.0       8
# NaN          8
#  108.0       8
#  120.0       7
#  16.0        7
#  106.0       6
#  80.0        6
#  340.0       6
#  200.0       6
#  132.0       5
#  170.0       5
#  360.0       5
#  84.0        5
#  320.0       5
#  270.0       4
#  183.0       4
#  100.0       4
#  168.0       4
#  252.0       4
#  178.0       4
#  246.0       4
#  196.0       4
#  288.0       4
#  216.0       4
#  160.0       4
#  220.0       4
#  336.0       4
#  210.0       4
#           ...
#  24.0        1
#  760.0       1
#  138.0       1
#  27.0        1
#  541.0       1
#  275.0       1
#  365.0       1
#  562.0       1
#  161.0       1
#  247.0       1
#  452.0       1
#  278.0       1
#  375.0       1
#  225.0       1
#  604.0       1
#  762.0       1
#  290.0       1
#  109.0       1
#  299.0       1
#  731.0       1
#  167.0       1
#  309.0       1
#  202.0       1
#  1129.0      1
#  651.0       1
#  337.0       1
#  415.0       1
#  293.0       1
#  259.0       1
#  621.0       1
# Name: MasVnrArea, Length: 328, dtype: int64
# Value missing: 0.5 %
#
# MasVnrType
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# NaN          8
# Name: MasVnrType, dtype: int64
# Value missing: 0.5 %
#
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# NaN         1
# Name: Electrical, dtype: int64
# Value missing: 0.1 %

# %% [markdown]
# ### Remove columns with more than 70% of missing values

# %%
df=df.drop(columns=['PoolQC','MiscFeature','Alley','Fence'])

# %%
df.shape
# Out:
# (1460, 76)

# %% [markdown]
# ### Checking the rest of features with missing values

# %%
null_cols=df.columns[df.isnull().any()]
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
print(dg)
nullCol=dg.index.values
nullCol
# Out:
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageType       5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtQual         2.534247
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# MasVnrType       0.547945
# MasVnrArea       0.547945
# Electrical       0.068493
# dtype: float64
# array(['FireplaceQu', 'LotFrontage', 'GarageYrBlt', 'GarageType',
#        'GarageQual', 'GarageFinish', 'GarageCond', 'BsmtFinType2',
#        'BsmtExposure', 'BsmtQual', 'BsmtFinType1', 'BsmtCond',
#        'MasVnrType', 'MasVnrArea', 'Electrical'], dtype=object)

# %% [markdown]
# ### It looks like "FireplaceQu" has "NaN" value when "Fireplaces" has "zero" value.
# ### Let's check if the number of missing value in "FireplaceQu" is the same as the number of rows with zero value in "Fireplaces"

# %%
df['FireplaceQu'].isnull().sum()
# Out:
# 690

# %%
len(df.loc[df['Fireplaces']==0])
# Out:
# 690

# %% [markdown]
# ### It turns out the number is the same.
# ### We can go ahead and replace the "NaN" in "FireplaceQu" with "0"

# %% [markdown]
# ### Also, we will change the datatype of "FireplaceQu" to a "Ordinal" Variable

# %% [markdown]
# ### First we will need to replace "NaN" with "0" value

# %%
df['FireplaceQu'].fillna(0,inplace=True)

# %%
df['FireplaceQu'].value_counts()
# Out:
# 0     690
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %% [markdown]
# ### Replace string values to ordinal value in "FireplaceQu"

# %%
#quality={'Po':1,'Fa':2,'TA':3,'Gd':4,"Ex":5}
df.FireplaceQu[df.FireplaceQu=='Po']=1
df.FireplaceQu[df.FireplaceQu=='Fa']=2
df.FireplaceQu[df.FireplaceQu=='TA']=3
df.FireplaceQu[df.FireplaceQu=='Gd']=4
df.FireplaceQu[df.FireplaceQu=='Ex']=5

# %%
df.FireplaceQu.dtypes
# Out:
# dtype('O')

# %% [markdown]
# ### Let's change the datatype of "FireplaceQu" to "int"

# %%
df=df.astype({"FireplaceQu":int})

# %%
df.FireplaceQu.dtypes
# Out:
# dtype('int32')

# %%
df['LotFrontage'].isnull().sum()
# Out:
# 259

# %% [markdown]
# ### Some Lot just does not have LotFronage.
# ### Change "NaN" value to "zero" in "LotFrontage"

# %%
df['LotFrontage'].fillna(0,inplace=True)

# %% [markdown]
# ### Check if the number of "0" value is the same as the number "NaN" value

# %%
df['LotFrontage'].value_counts()
# Out:
# 0.0      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 67.0      12
# 57.0      12
# 82.0      12
# 43.0      12
#         ...
# 129.0      2
# 313.0      2
# 118.0      2
# 122.0      2
# 121.0      2
# 101.0      2
# 109.0      2
# 115.0      2
# 116.0      2
# 114.0      2
# 153.0      1
# 149.0      1
# 150.0      1
# 111.0      1
# 182.0      1
# 46.0       1
# 112.0      1
# 141.0      1
# 33.0       1
# 152.0      1
# 160.0      1
# 168.0      1
# 128.0      1
# 144.0      1
# 39.0       1
# 106.0      1
# 38.0       1
# 138.0      1
# 140.0      1
# 137.0      1
# Name: LotFrontage, Length: 111, dtype: int64

# %% [markdown]
# ### Double check all the missing values again

# %%
null_cols=df.columns[df.isnull().any()]
df[null_cols].isnull().sum().sort_values(ascending=False)
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
dg
# Out:
# GarageYrBlt     5.547945
# GarageType      5.547945
# GarageQual      5.547945
# GarageFinish    5.547945
# GarageCond      5.547945
# BsmtFinType2    2.602740
# BsmtExposure    2.602740
# BsmtQual        2.534247
# BsmtFinType1    2.534247
# BsmtCond        2.534247
# MasVnrType      0.547945
# MasVnrArea      0.547945
# Electrical      0.068493
# dtype: float64

# %% [markdown]
# ### All the remaining variables have less than 6% of missing values.
# ### We will remove all the rows with any missing values.

# %%
df_miss=df.dropna()

# %%
df_miss.isnull().sum()
# Out:
# 1stFlrSF         0
# 2ndFlrSF         0
# 3SsnPorch        0
# BedroomAbvGr     0
# BldgType         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtFinType1     0
# BsmtFinType2     0
# BsmtFullBath     0
# BsmtHalfBath     0
# BsmtQual         0
# BsmtUnfSF        0
# CentralAir       0
# Condition1       0
# Condition2       0
# Electrical       0
# EnclosedPorch    0
# ExterCond        0
# ExterQual        0
# Exterior1st      0
# Exterior2nd      0
# FireplaceQu      0
# Fireplaces       0
# Foundation       0
# FullBath         0
# Functional       0
# GarageArea       0
#                 ..
# LotConfig        0
# LotFrontage      0
# LotShape         0
# LowQualFinSF     0
# MSSubClass       0
# MSZoning         0
# MasVnrArea       0
# MasVnrType       0
# MiscVal          0
# MoSold           0
# Neighborhood     0
# OpenPorchSF      0
# OverallCond      0
# OverallQual      0
# PavedDrive       0
# PoolArea         0
# RoofMatl         0
# RoofStyle        0
# SaleCondition    0
# SalePrice        0
# SaleType         0
# ScreenPorch      0
# Street           0
# TotRmsAbvGrd     0
# TotalBsmtSF      0
# Utilities        0
# WoodDeckSF       0
# YearBuilt        0
# YearRemodAdd     0
# YrSold           0
# Length: 76, dtype: int64

# %%
df_miss.shape
# Out:
# (1338, 76)

# %%
len(df)-len(df_miss)
# Out:
# 122

# %% [markdown]
# ### Checking the percentage of data removed

# %%
(len(df)-len(df_miss))/len(df)*100
# Out:
# 8.356164383561644

# %% [markdown]
# ## Convert all string categorical variables to ordinal categorical variables

# %%
cat_col=df_miss.select_dtypes(include=['object']).columns
cat_col
# Out:
# Index(['BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'BsmtQual', 'CentralAir', 'Condition1', 'Condition2', 'Electrical',
#        'ExterCond', 'ExterQual', 'Exterior1st', 'Exterior2nd', 'Foundation',
#        'Functional', 'GarageCond', 'GarageFinish', 'GarageQual', 'GarageType',
#        'Heating', 'HeatingQC', 'HouseStyle', 'KitchenQual', 'LandContour',
#        'LandSlope', 'LotConfig', 'LotShape', 'MSZoning', 'MasVnrType',
#        'Neighborhood', 'PavedDrive', 'RoofMatl', 'RoofStyle', 'SaleCondition',
#        'SaleType', 'Street', 'Utilities'],
#       dtype='object')

# %%
for item1 in cat_col:
    df_mean=pd.concat([df_miss[item1],df_miss['SalePrice']],axis=1)
    df_mean.head()

    g1=df_mean.groupby(item1).mean()
    g1

    df_g1=pd.DataFrame()
    df_g1=pd.DataFrame(g1)
    df_g1

    df_g2=df_g1.sort_values('SalePrice')
    df_g2

    df_g2.index

    g_col=df_g2.index.values

    df_miss[item1].value_counts()

    i=0
    for item2 in g_col:
        df_miss.loc[df_miss[item1]==item2,item1]=i
        i=i+1

# %%
df_miss[cat_col].dtypes
# Out:
# BldgType         int64
# BsmtCond         int64
# BsmtExposure     int64
# BsmtFinType1     int64
# BsmtFinType2     int64
# BsmtQual         int64
# CentralAir       int64
# Condition1       int64
# Condition2       int64
# Electrical       int64
# ExterCond        int64
# ExterQual        int64
# Exterior1st      int64
# Exterior2nd      int64
# Foundation       int64
# Functional       int64
# GarageCond       int64
# GarageFinish     int64
# GarageQual       int64
# GarageType       int64
# Heating          int64
# HeatingQC        int64
# HouseStyle       int64
# KitchenQual      int64
# LandContour      int64
# LandSlope        int64
# LotConfig        int64
# LotShape         int64
# MSZoning         int64
# MasVnrType       int64
# Neighborhood     int64
# PavedDrive       int64
# RoofMatl         int64
# RoofStyle        int64
# SaleCondition    int64
# SaleType         int64
# Street           int64
# Utilities        int64
# dtype: object

# %%
for item in cat_col:
    print(df_miss[item].value_counts())
    print()
# Out:
# 4    1138
# 3     112
# 1      38
# 2      28
# 0      22
# Name: BldgType, dtype: int64
#
# 2    1237
# 3      62
# 1      38
# 0       1
# Name: BsmtCond, dtype: int64
#
# 0    887
# 2    213
# 3    127
# 1    111
# Name: BsmtExposure, dtype: int64
#
# 5    402
# 4    392
# 3    209
# 1    141
# 0    125
# 2     69
# Name: BsmtFinType1, dtype: int64
#
# 3    1176
# 2      53
# 1      46
# 0      32
# 5      19
# 4      12
# Name: BsmtFinType2, dtype: int64
#
# 1    594
# 2    592
# 3    120
# 0     32
# Name: BsmtQual, dtype: int64
#
# 1    1277
# 0      61
# Name: CentralAir, dtype: int64
#
# 4    1162
# 2      63
# 0      43
# 3      26
# 7      19
# 1      10
# 8       8
# 6       5
# 5       2
# Name: Condition1, dtype: int64
#
# 4    1324
# 2       5
# 6       2
# 1       2
# 0       2
# 7       1
# 5       1
# 3       1
# Name: Condition2, dtype: int64
#
# 4    1242
# 3      76
# 2      17
# 1       2
# 0       1
# Name: Electrical, dtype: int64
#
# 2    1183
# 1     137
# 0      16
# 3       2
# Name: ExterCond, dtype: int64
#
# 1    803
# 2    477
# 3     51
# 0      7
# Name: ExterQual, dtype: int64
#
# 10    486
# 6     211
# 3     201
# 4     183
# 8     100
# 11     52
# 9      44
# 7      21
# 5      20
# 2      15
# 12      2
# 13      1
# 1       1
# 0       1
# Name: Exterior1st, dtype: int64
#
# 12    475
# 7     197
# 3     197
# 4     176
# 9     127
# 13     51
# 8      32
# 6      23
# 11     22
# 1      16
# 14     10
# 2       6
# 10      2
# 5       2
# 15      1
# 0       1
# Name: Exterior2nd, dtype: int64
#
# 4    620
# 1    580
# 0    129
# 2      6
# 3      3
# Name: Foundation, dtype: int64
#
# 5    1254
# 2      30
# 3      28
# 6      11
# 4      10
# 0       4
# 1       1
# Name: Functional, dtype: int64
#
# 4    1287
# 1      33
# 3       9
# 0       7
# 2       2
# Name: GarageCond, dtype: int64
#
# 0    580
# 1    413
# 2    345
# Name: GarageFinish, dtype: int64
#
# 2    1270
# 1      48
# 3      14
# 4       3
# 0       3
# Name: GarageQual, dtype: int64
#
# 4    852
# 1    369
# 5     85
# 3     19
# 0      7
# 2      6
# Name: GarageType, dtype: int64
#
# 3    1318
# 2      16
# 0       3
# 1       1
# Name: Heating, dtype: int64
#
# 4    704
# 2    380
# 3    217
# 1     36
# 0      1
# Name: HeatingQC, dtype: int64
#
# 5    657
# 6    426
# 2    134
# 4     64
# 1     30
# 0     11
# 3     10
# 7      6
# Name: HouseStyle, dtype: int64
#
# 1    650
# 2    568
# 3     97
# 0     23
# Name: KitchenQual, dtype: int64
#
# 1    1206
# 0      52
# 3      48
# 2      32
# Name: LandContour, dtype: int64
#
# 0    1265
# 1      61
# 2      12
# Name: LandSlope, dtype: int64
#
# 0    957
# 2    244
# 4     90
# 1     43
# 3      4
# Name: LotConfig, dtype: int64
#
# 0    829
# 1    459
# 3     40
# 2     10
# Name: LotShape, dtype: int64
#
# 3    1066
# 2     191
# 4      62
# 1      11
# 0       8
# Name: MSZoning, dtype: int64
#
# 1    763
# 2    432
# 3    128
# 0     15
# Name: MasVnrType, dtype: int64
#
# 10    209
# 16    146
# 3     100
# 19     83
# 14     77
# 23     75
# 12     73
# 5      70
# 7      69
# 13     53
# 17     50
# 4      47
# 11     42
# 24     41
# 21     37
# 2      29
# 18     26
# 22     25
# 8      20
# 15     17
# 1      15
# 0      12
# 20     11
# 9       9
# 6       2
# Name: Neighborhood, dtype: int64
#
# 2    1257
# 0      54
# 1      27
# Name: PavedDrive, dtype: int64
#
# 3    1314
# 4       9
# 7       6
# 5       5
# 6       1
# 2       1
# 1       1
# 0       1
# Name: RoofMatl, dtype: int64
#
# 1    1037
# 4     272
# 3      11
# 0      10
# 2       6
# 5       2
# Name: RoofStyle, dtype: int64
#
# 4    1104
# 5     120
# 2      86
# 1      20
# 3       7
# 0       1
# Name: SaleCondition, dtype: int64
#
# 4    1158
# 8     117
# 1      42
# 2       6
# 6       4
# 5       4
# 3       4
# 7       2
# 0       1
# Name: SaleType, dtype: int64
#
# 1    1333
# 0       5
# Name: Street, dtype: int64
#
# 1    1337
# 0       1
# Name: Utilities, dtype: int64

# %%
df_miss.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0       856       854          0             3         4         2
# 1      1262         0          0             3         4         2
# 2       920       866          0             3         4         2
# 3       961       756          0             3         4         3
# 4      1145      1053          0             4         4         2
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0             0         706           0             5             3
# 1             3         978           0             3             3
# 2             1         486           0             5             3
# 3             0         216           0             3             3
# 4             2         655           0             5             3
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0             1             0         2        150           1           4
# 1             0             1         2        284           1           2
# 2             1             0         2        434           1           4
# 3             1             0         1        540           1           4
# 4             1             0         2        490           1           4
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0           4           4              0          2          2           10
# 1           4           4              0          2          1            3
# 2           4           4              0          2          2           10
# 3           4           4            272          2          1            4
# 4           4           4              0          2          2           10
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0           12            0           0           4         2           5
# 1            3            3           1           1         2           5
# 2           12            3           1           4         2           5
# 3            8            4           1           0         1           5
# 4           12            3           1           4         2           5
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0         548           2           4             1           2           4
# 1         460           2           4             1           2           4
# 2         608           2           4             1           2           4
# 3         642           3           4             0           2           1
# 4         836           3           4             1           2           4
#
#    GarageYrBlt  GrLivArea  HalfBath  Heating  HeatingQC  HouseStyle  \
# 0       2003.0       1710         1        3          4           6
# 1       1976.0       1262         0        3          4           5
# 2       2001.0       1786         1        3          4           6
# 3       1998.0       1717         0        3          3           6
# 4       2000.0       2198         1        3          4           6
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope  LotArea  LotConfig  \
# 0             1            2            1          0     8450          0
# 1             1            1            1          0     9600          1
# 2             1            2            1          0    11250          0
# 3             1            2            1          0     9550          2
# 4             1            2            1          0    14260          1
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0         65.0         0             0          60         3       196.0
# 1         80.0         0             0          20         3         0.0
# 2         68.0         1             0          60         3       162.0
# 3         60.0         1             0          70         3         0.0
# 4         84.0         1             0          60         3       350.0
#
#    MasVnrType  MiscVal  MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0           2        0       2            16           61            5
# 1           1        0       5            20            0            8
# 2           2        0       9            16           42            5
# 3           1        0       2            17           35            5
# 4           2        0      12            24           84            5
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0            7           2         0         3          1              4
# 1            6           2         0         3          1              4
# 2            7           2         0         3          1              4
# 3            7           2         0         3          1              2
# 4            8           2         0         3          1              4
#
#    SalePrice  SaleType  ScreenPorch  Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0     208500         4            0       1             8          856
# 1     181500         4            0       1             6         1262
# 2     223500         4            0       1             6          920
# 3     140000         4            0       1             7          756
# 4     250000         4            0       1             9         1145
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          1           0       2003          2003    2008
# 1          1         298       1976          1976    2007
# 2          1           0       2001          2002    2008
# 3          1           0       1915          1970    2006
# 4          1         192       2000          2000    2008

# %% [markdown]
# ## Start working on Outliers

# %%
df_miss.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0       856       854          0             3         4         2
# 1      1262         0          0             3         4         2
# 2       920       866          0             3         4         2
# 3       961       756          0             3         4         3
# 4      1145      1053          0             4         4         2
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0             0         706           0             5             3
# 1             3         978           0             3             3
# 2             1         486           0             5             3
# 3             0         216           0             3             3
# 4             2         655           0             5             3
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0             1             0         2        150           1           4
# 1             0             1         2        284           1           2
# 2             1             0         2        434           1           4
# 3             1             0         1        540           1           4
# 4             1             0         2        490           1           4
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0           4           4              0          2          2           10
# 1           4           4              0          2          1            3
# 2           4           4              0          2          2           10
# 3           4           4            272          2          1            4
# 4           4           4              0          2          2           10
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0           12            0           0           4         2           5
# 1            3            3           1           1         2           5
# 2           12            3           1           4         2           5
# 3            8            4           1           0         1           5
# 4           12            3           1           4         2           5
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0         548           2           4             1           2           4
# 1         460           2           4             1           2           4
# 2         608           2           4             1           2           4
# 3         642           3           4             0           2           1
# 4         836           3           4             1           2           4
#
#    GarageYrBlt  GrLivArea  HalfBath  Heating  HeatingQC  HouseStyle  \
# 0       2003.0       1710         1        3          4           6
# 1       1976.0       1262         0        3          4           5
# 2       2001.0       1786         1        3          4           6
# 3       1998.0       1717         0        3          3           6
# 4       2000.0       2198         1        3          4           6
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope  LotArea  LotConfig  \
# 0             1            2            1          0     8450          0
# 1             1            1            1          0     9600          1
# 2             1            2            1          0    11250          0
# 3             1            2            1          0     9550          2
# 4             1            2            1          0    14260          1
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0         65.0         0             0          60         3       196.0
# 1         80.0         0             0          20         3         0.0
# 2         68.0         1             0          60         3       162.0
# 3         60.0         1             0          70         3         0.0
# 4         84.0         1             0          60         3       350.0
#
#    MasVnrType  MiscVal  MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0           2        0       2            16           61            5
# 1           1        0       5            20            0            8
# 2           2        0       9            16           42            5
# 3           1        0       2            17           35            5
# 4           2        0      12            24           84            5
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0            7           2         0         3          1              4
# 1            6           2         0         3          1              4
# 2            7           2         0         3          1              4
# 3            7           2         0         3          1              2
# 4            8           2         0         3          1              4
#
#    SalePrice  SaleType  ScreenPorch  Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0     208500         4            0       1             8          856
# 1     181500         4            0       1             6         1262
# 2     223500         4            0       1             6          920
# 3     140000         4            0       1             7          756
# 4     250000         4            0       1             9         1145
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          1           0       2003          2003    2008
# 1          1         298       1976          1976    2007
# 2          1           0       2001          2002    2008
# 3          1           0       1915          1970    2006
# 4          1         192       2000          2000    2008

# %%
df_miss.dtypes
# Out:
# 1stFlrSF           int64
# 2ndFlrSF           int64
# 3SsnPorch          int64
# BedroomAbvGr       int64
# BldgType           int64
# BsmtCond           int64
# BsmtExposure       int64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtFinType1       int64
# BsmtFinType2       int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# BsmtQual           int64
# BsmtUnfSF          int64
# CentralAir         int64
# Condition1         int64
# Condition2         int64
# Electrical         int64
# EnclosedPorch      int64
# ExterCond          int64
# ExterQual          int64
# Exterior1st        int64
# Exterior2nd        int64
# FireplaceQu        int32
# Fireplaces         int64
# Foundation         int64
# FullBath           int64
# Functional         int64
# GarageArea         int64
#                   ...
# LotConfig          int64
# LotFrontage      float64
# LotShape           int64
# LowQualFinSF       int64
# MSSubClass         int64
# MSZoning           int64
# MasVnrArea       float64
# MasVnrType         int64
# MiscVal            int64
# MoSold             int64
# Neighborhood       int64
# OpenPorchSF        int64
# OverallCond        int64
# OverallQual        int64
# PavedDrive         int64
# PoolArea           int64
# RoofMatl           int64
# RoofStyle          int64
# SaleCondition      int64
# SalePrice          int64
# SaleType           int64
# ScreenPorch        int64
# Street             int64
# TotRmsAbvGrd       int64
# TotalBsmtSF        int64
# Utilities          int64
# WoodDeckSF         int64
# YearBuilt          int64
# YearRemodAdd       int64
# YrSold             int64
# Length: 76, dtype: object

# %% [markdown]
# ### Separate data variables to continuous and categorical features

# %%
con_col=['1stFlrSF','2ndFlrSF','3SsnPorch','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF',
        'EnclosedPorch','GarageArea','GarageYrBlt','GrLivArea','LotArea','LotFrontage','LowQualFinSF',
        'MasVnrArea','MiscVal','OpenPorchSF','PoolArea','ScreenPorch','TotalBsmtSF','WoodDeckSF',
         'YearBuilt','YearRemodAdd']
con_col
# Out:
# ['1stFlrSF',
#  '2ndFlrSF',
#  '3SsnPorch',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'EnclosedPorch',
#  'GarageArea',
#  'GarageYrBlt',
#  'GrLivArea',
#  'LotArea',
#  'LotFrontage',
#  'LowQualFinSF',
#  'MasVnrArea',
#  'MiscVal',
#  'OpenPorchSF',
#  'PoolArea',
#  'ScreenPorch',
#  'TotalBsmtSF',
#  'WoodDeckSF',
#  'YearBuilt',
#  'YearRemodAdd']

# %%
for item in con_col:
    plt.scatter(x=df_miss[item],y=df_miss['SalePrice'])
    plt.xlabel(item)
    plt.ylabel('Sale Price')
    plt.show()

# %% [markdown]
# ### Remove Outliers - continuous variables

# %%
df_out=pd.DataFrame()
df_out=df_miss

# %%
df_out=df_out.drop(df_out[df_out['1stFlrSF']>3000].index)

# %%
df_out=df_out.drop(df_out[(df_out['2ndFlrSF']>1500)&(df_out['SalePrice']<300000)].index)

# %%
df_out=df_out.drop(df_out[df_out['BsmtFinSF1']>5000].index)

# %%
df_out=df_out.drop(df_out[(df_out['BsmtFinSF2']>175)&(df_out['SalePrice']>300000)].index)

# %%
df_out=df_out.drop(df_out[df_out['EnclosedPorch']>500].index)

# %%
df_out=df_out.drop(df_out[(df_out['GarageArea']>1200)&(df_out['SalePrice']<300000)].index)

# %%
df_out=df_out.drop(df_out[(df_out['GrLivArea']>4000)&(df_out['SalePrice']<200000)].index)

# %%
df_out=df_out.drop(df_out[df_out['TotalBsmtSF']>4000].index)

# %%
df_out.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0       856       854          0             3         4         2
# 1      1262         0          0             3         4         2
# 2       920       866          0             3         4         2
# 3       961       756          0             3         4         3
# 4      1145      1053          0             4         4         2
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0             0         706           0             5             3
# 1             3         978           0             3             3
# 2             1         486           0             5             3
# 3             0         216           0             3             3
# 4             2         655           0             5             3
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0             1             0         2        150           1           4
# 1             0             1         2        284           1           2
# 2             1             0         2        434           1           4
# 3             1             0         1        540           1           4
# 4             1             0         2        490           1           4
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0           4           4              0          2          2           10
# 1           4           4              0          2          1            3
# 2           4           4              0          2          2           10
# 3           4           4            272          2          1            4
# 4           4           4              0          2          2           10
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0           12            0           0           4         2           5
# 1            3            3           1           1         2           5
# 2           12            3           1           4         2           5
# 3            8            4           1           0         1           5
# 4           12            3           1           4         2           5
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0         548           2           4             1           2           4
# 1         460           2           4             1           2           4
# 2         608           2           4             1           2           4
# 3         642           3           4             0           2           1
# 4         836           3           4             1           2           4
#
#    GarageYrBlt  GrLivArea  HalfBath  Heating  HeatingQC  HouseStyle  \
# 0       2003.0       1710         1        3          4           6
# 1       1976.0       1262         0        3          4           5
# 2       2001.0       1786         1        3          4           6
# 3       1998.0       1717         0        3          3           6
# 4       2000.0       2198         1        3          4           6
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope  LotArea  LotConfig  \
# 0             1            2            1          0     8450          0
# 1             1            1            1          0     9600          1
# 2             1            2            1          0    11250          0
# 3             1            2            1          0     9550          2
# 4             1            2            1          0    14260          1
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0         65.0         0             0          60         3       196.0
# 1         80.0         0             0          20         3         0.0
# 2         68.0         1             0          60         3       162.0
# 3         60.0         1             0          70         3         0.0
# 4         84.0         1             0          60         3       350.0
#
#    MasVnrType  MiscVal  MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0           2        0       2            16           61            5
# 1           1        0       5            20            0            8
# 2           2        0       9            16           42            5
# 3           1        0       2            17           35            5
# 4           2        0      12            24           84            5
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0            7           2         0         3          1              4
# 1            6           2         0         3          1              4
# 2            7           2         0         3          1              4
# 3            7           2         0         3          1              2
# 4            8           2         0         3          1              4
#
#    SalePrice  SaleType  ScreenPorch  Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0     208500         4            0       1             8          856
# 1     181500         4            0       1             6         1262
# 2     223500         4            0       1             6          920
# 3     140000         4            0       1             7          756
# 4     250000         4            0       1             9         1145
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          1           0       2003          2003    2008
# 1          1         298       1976          1976    2007
# 2          1           0       2001          2002    2008
# 3          1           0       1915          1970    2006
# 4          1         192       2000          2000    2008

# %% [markdown]
# ### Wrok on Categorical Variables

# %% [markdown]
# ### Create boxplot

# %%
df_cat=pd.DataFrame()
df_cat=df_out.drop(columns=con_col,axis=1)
cat_col=df_cat.columns

# %%
for item in cat_col:
    sns.boxplot(x=item,y="SalePrice",data=df_out)
    plt.show()

# %% [markdown]
# ### Remove outliers - categorical variable

# %% [markdown]
# ### Log(x+1) transformed the whole dataset

# %%
df_out=np.log1p(df_out)

# %%
df_out.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0  6.753438  6.751101        0.0      1.386294  1.609438  1.098612
# 1  7.141245  0.000000        0.0      1.386294  1.609438  1.098612
# 2  6.825460  6.765039        0.0      1.386294  1.609438  1.098612
# 3  6.869014  6.629363        0.0      1.386294  1.609438  1.386294
# 4  7.044033  6.960348        0.0      1.609438  1.609438  1.098612
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0      0.000000    6.561031         0.0      1.791759      1.386294
# 1      1.386294    6.886532         0.0      1.386294      1.386294
# 2      0.693147    6.188264         0.0      1.791759      1.386294
# 3      0.000000    5.379897         0.0      1.386294      1.386294
# 4      1.098612    6.486161         0.0      1.791759      1.386294
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0      0.693147      0.000000  1.098612   5.017280    0.693147    1.609438
# 1      0.000000      0.693147  1.098612   5.652489    0.693147    1.098612
# 2      0.693147      0.000000  1.098612   6.075346    0.693147    1.609438
# 3      0.693147      0.000000  0.693147   6.293419    0.693147    1.609438
# 4      0.693147      0.000000  1.098612   6.196444    0.693147    1.609438
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0    1.609438    1.609438       0.000000   1.098612   1.098612     2.397895
# 1    1.609438    1.609438       0.000000   1.098612   0.693147     1.386294
# 2    1.609438    1.609438       0.000000   1.098612   1.098612     2.397895
# 3    1.609438    1.609438       5.609472   1.098612   0.693147     1.609438
# 4    1.609438    1.609438       0.000000   1.098612   1.098612     2.397895
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0     2.564949     0.000000    0.000000    1.609438  1.098612    1.791759
# 1     1.386294     1.386294    0.693147    0.693147  1.098612    1.791759
# 2     2.564949     1.386294    0.693147    1.609438  1.098612    1.791759
# 3     2.197225     1.609438    0.693147    0.000000  0.693147    1.791759
# 4     2.564949     1.386294    0.693147    1.609438  1.098612    1.791759
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0    6.308098    1.098612    1.609438      0.693147    1.098612    1.609438
# 1    6.133398    1.098612    1.609438      0.693147    1.098612    1.609438
# 2    6.411818    1.098612    1.609438      0.693147    1.098612    1.609438
# 3    6.466145    1.386294    1.609438      0.000000    1.098612    0.693147
# 4    6.729824    1.386294    1.609438      0.693147    1.098612    1.609438
#
#    GarageYrBlt  GrLivArea  HalfBath   Heating  HeatingQC  HouseStyle  \
# 0     7.602900   7.444833  0.693147  1.386294   1.609438    1.945910
# 1     7.589336   7.141245  0.000000  1.386294   1.609438    1.791759
# 2     7.601902   7.488294  0.693147  1.386294   1.609438    1.945910
# 3     7.600402   7.448916  0.000000  1.386294   1.386294    1.945910
# 4     7.601402   7.695758  0.693147  1.386294   1.609438    1.945910
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope   LotArea  LotConfig  \
# 0      0.693147     1.098612     0.693147        0.0  9.042040   0.000000
# 1      0.693147     0.693147     0.693147        0.0  9.169623   0.693147
# 2      0.693147     1.098612     0.693147        0.0  9.328212   0.000000
# 3      0.693147     1.098612     0.693147        0.0  9.164401   1.098612
# 4      0.693147     1.098612     0.693147        0.0  9.565284   0.693147
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0     4.189655  0.000000           0.0    4.110874  1.386294    5.283204
# 1     4.394449  0.000000           0.0    3.044522  1.386294    0.000000
# 2     4.234107  0.693147           0.0    4.110874  1.386294    5.093750
# 3     4.110874  0.693147           0.0    4.262680  1.386294    0.000000
# 4     4.442651  0.693147           0.0    4.110874  1.386294    5.860786
#
#    MasVnrType  MiscVal    MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0    1.098612      0.0  1.098612      2.833213     4.127134     1.791759
# 1    0.693147      0.0  1.791759      3.044522     0.000000     2.197225
# 2    1.098612      0.0  2.302585      2.833213     3.761200     1.791759
# 3    0.693147      0.0  1.098612      2.890372     3.583519     1.791759
# 4    1.098612      0.0  2.564949      3.218876     4.442651     1.791759
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0     2.079442    1.098612       0.0  1.386294   0.693147       1.609438
# 1     1.945910    1.098612       0.0  1.386294   0.693147       1.609438
# 2     2.079442    1.098612       0.0  1.386294   0.693147       1.609438
# 3     2.079442    1.098612       0.0  1.386294   0.693147       1.098612
# 4     2.197225    1.098612       0.0  1.386294   0.693147       1.609438
#
#    SalePrice  SaleType  ScreenPorch    Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0  12.247699  1.609438          0.0  0.693147      2.197225     6.753438
# 1  12.109016  1.609438          0.0  0.693147      1.945910     7.141245
# 2  12.317171  1.609438          0.0  0.693147      1.945910     6.825460
# 3  11.849405  1.609438          0.0  0.693147      2.079442     6.629363
# 4  12.429220  1.609438          0.0  0.693147      2.302585     7.044033
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd    YrSold
# 0   0.693147    0.000000   7.602900      7.602900  7.605392
# 1   0.693147    5.700444   7.589336      7.589336  7.604894
# 2   0.693147    0.000000   7.601902      7.602401  7.605392
# 3   0.693147    0.000000   7.557995      7.586296  7.604396
# 4   0.693147    5.262690   7.601402      7.601402  7.605392

# %% [markdown]
# ## Standardize all the continuous variables

# %%
scaler=StandardScaler()
array_out=scaler.fit_transform(df_out)

# %%
values=array_out
col=df_out.columns
df_out=pd.DataFrame(data=values,columns=col)

# %%
df_out.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0 -0.855114  1.162035  -0.132148      0.261042   0.31194 -0.009108
# 1  0.407362 -0.883506  -0.132148      0.261042   0.31194 -0.009108
# 2 -0.620652  1.166258  -0.132148      0.261042   0.31194 -0.009108
# 3 -0.478864  1.125149  -0.132148      0.261042   0.31194  2.981157
# 4  0.090895  1.225436  -0.132148      1.259943   0.31194 -0.009108
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0     -0.683970    0.740173   -0.361311      0.801020      0.240776
# 1      1.937046    0.851433   -0.361311      0.059596      0.240776
# 2      0.626538    0.612758   -0.361311      0.801020      0.240776
# 3     -0.683970    0.336450   -0.361311      0.059596      0.240776
# 4      1.393136    0.714582   -0.361311      0.801020      0.240776
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0      1.129992     -0.249635  0.654776  -0.490316    0.219767    0.233494
# 1     -0.858021      3.956223  0.654776  -0.095400    0.219767   -1.369557
# 2      1.129992     -0.249635  0.654776   0.167494    0.219767    0.233494
# 3      1.129992     -0.249635 -0.811105   0.303072    0.219767    0.233494
# 4      1.129992     -0.249635  0.654776   0.242782    0.219767    0.233494
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0    0.064301    0.232193      -0.393484   0.319447   1.070613     0.931305
# 1    0.064301    0.232193      -0.393484   0.319447  -0.740601    -1.560100
# 2    0.064301    0.232193      -0.393484   0.319447   1.070613     0.931305
# 3    0.064301    0.232193       2.928111   0.319447  -0.740601    -1.010534
# 4    0.064301    0.232193      -0.393484   0.319447   1.070613     0.931305
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0     0.917109    -1.097256   -1.070271    1.003207  0.809601    0.195684
# 1    -1.508440     0.754854    0.696223   -0.652656  0.809601    0.195684
# 2     0.917109     0.754854    0.696223    1.003207  0.809601    0.195684
# 3     0.160369     1.052977    0.696223   -1.905269 -1.026972    0.195684
# 4     0.917109     0.754854    0.696223    1.003207  0.809601    0.195684
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0    0.438107    0.315246    0.181821      0.431395    0.129943    0.596821
# 1   -0.027883    0.315246    0.181821      0.431395    0.129943    0.596821
# 2    0.714766    0.315246    0.181821      0.431395    0.129943    0.596821
# 3    0.859675    1.585059    0.181821     -1.072873    0.129943   -1.536561
# 4    1.563004    1.585059    0.181821      0.431395    0.129943    0.596821
#
#    GarageYrBlt  GrLivArea  HalfBath   Heating  HeatingQC  HouseStyle  \
# 0     0.986462   0.522407  1.211505  0.092466   0.823750    0.687480
# 1    -0.093636  -0.440371 -0.804282  0.092466   0.823750    0.218744
# 2     0.906955   0.660234  1.211505  0.092466   0.823750    0.687480
# 3     0.787546   0.535355 -0.804282  0.092466  -0.058388    0.687480
# 4     0.867172   1.318172  1.211505  0.092466   0.823750    0.687480
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope   LotArea  LotConfig  \
# 0     -0.173134     0.752694    -0.039617  -0.233442 -0.149685  -0.609393
# 1     -0.173134    -0.798783    -0.039617  -0.233442  0.104325   0.648905
# 2     -0.173134     0.752694    -0.039617  -0.233442  0.420069  -0.609393
# 3     -0.173134     0.752694    -0.039617  -0.233442  0.093930   1.384962
# 4     -0.173134     0.752694    -0.039617  -0.233442  0.892065   0.648905
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0     0.449714 -0.744089     -0.113163    0.441725  0.270164    1.144055
# 1     0.573522 -0.744089     -0.113163   -1.118857  0.270164   -0.849518
# 2     0.476588  1.061318     -0.113163    0.441725  0.270164    1.072567
# 3     0.402088  1.061318     -0.113163    0.663890  0.270164   -0.849518
# 4     0.602663  1.061318     -0.113163    0.441725  0.270164    1.362001
#
#    MasVnrType   MiscVal    MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0    0.832256 -0.187999 -1.920598      0.630494     0.815957    -0.522240
# 1   -0.720462 -0.187999 -0.286919      0.967652    -1.116057     2.052529
# 2    0.832256 -0.187999  0.917047      0.630494     0.644654    -0.522240
# 3   -0.720462 -0.187999 -1.920598      0.721694     0.561477    -0.522240
# 4    0.832256 -0.187999  1.535414      1.245844     0.963658    -0.522240
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0     0.657994    0.237931 -0.061557 -0.076718  -0.494243       0.179838
# 1    -0.068428    0.237931 -0.061557 -0.076718  -0.494243       0.179838
# 2     0.657994    0.237931 -0.061557 -0.076718  -0.494243       0.179838
# 3     0.657994    0.237931 -0.061557 -0.076718  -0.494243      -2.610751
# 4     1.298744    0.237931 -0.061557 -0.076718  -0.494243       0.179838
#
#    SalePrice  SaleType  ScreenPorch    Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0   0.503904  -0.08176    -0.307331  0.055048      0.973866    -0.519264
# 1   0.132548  -0.08176    -0.307331  0.055048     -0.249157     0.602558
# 2   0.689932  -0.08176    -0.307331  0.055048     -0.249157    -0.310924
# 3  -0.562624  -0.08176    -0.307331  0.055048      0.400674    -0.878179
# 4   0.989970  -0.08176    -0.307331  0.055048      1.486604     0.321349
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd    YrSold
# 0   0.027493   -0.985949   1.011374      0.855911  0.146418
# 1   0.027493    1.205225   0.106200     -0.467288 -0.603413
# 2   0.027493   -0.985949   0.944744      0.807222  0.146418
# 3   0.027493   -0.985949  -1.985191     -0.763785 -1.353618
# 4   0.027493    1.036959   0.911403      0.709772  0.146418

# %%
df_out['SalePrice'].isnull().sum()
# Out:
# 0

# %%
df_out.describe().T
# Out:
#                 count          mean       std        min       25%       50%  \
# 1stFlrSF       1324.0  4.964139e-15  1.000378  -3.032793 -0.713875 -0.049878
# 2ndFlrSF       1324.0 -1.811240e-17  1.000378  -0.883506 -0.883506 -0.883506
# 3SsnPorch      1324.0  1.475825e-17  1.000378  -0.132148 -0.132148 -0.132148
# BedroomAbvGr   1324.0 -3.917645e-16  1.000378  -5.944699 -1.026765  0.261042
# BldgType       1324.0  3.209920e-16  1.000378  -5.847796  0.311940  0.311940
# BsmtCond       1324.0  2.408278e-15  1.000378 -11.428455 -0.009108 -0.009108
# BsmtExposure   1324.0  3.085816e-17  1.000378  -0.683970 -0.683970 -0.683970
# BsmtFinSF1     1324.0 -3.756646e-17  1.000378  -1.502453 -1.502453  0.554763
# BsmtFinSF2     1324.0  3.421231e-17  1.000378  -0.361311 -0.361311 -0.361311
# BsmtFinType1   1324.0  4.749474e-16  1.000378  -2.475348 -0.466452  0.467631
# BsmtFinType2   1324.0 -1.878323e-16  1.000378  -5.211169  0.240776  0.240776
# BsmtFullBath   1324.0  1.059911e-16  1.000378  -0.858021 -0.858021 -0.858021
# BsmtHalfBath   1324.0 -2.549153e-17  1.000378  -0.249635 -0.249635 -0.249635
# BsmtQual       1324.0  7.540125e-16  1.000378  -3.317044 -0.811105  0.654776
# BsmtUnfSF      1324.0 -1.757574e-16  1.000378  -3.609606 -0.179354  0.241513
# CentralAir     1324.0  1.086744e-16  1.000378  -4.550266  0.219767  0.219767
# Condition1     1324.0  9.928278e-16  1.000378  -4.817174  0.233494  0.233494
# Condition2     1324.0  3.112649e-15  1.000378 -19.967937  0.064301  0.064301
# Electrical     1324.0 -8.854951e-17  1.000378 -16.779345  0.232193  0.232193
# EnclosedPorch  1324.0  8.049955e-18  1.000378  -0.393484 -0.393484 -0.393484
# ExterCond      1324.0  3.434648e-16  1.000378  -6.194286  0.319447  0.319447
# ExterQual      1324.0  8.922034e-17  1.000378  -3.836894 -0.740601 -0.740601
# Exterior1st    1324.0  2.535736e-16  1.000378  -4.974313 -1.010534  0.437087
# Exterior2nd    1324.0 -6.037467e-17  1.000378  -4.361289 -1.049234  0.377190
# FireplaceQu    1324.0  1.502658e-16  1.000378  -1.097256 -1.097256  0.754854
# Fireplaces     1324.0  2.146655e-17  1.000378  -1.070271 -1.070271  0.696223
# Foundation     1324.0  2.119822e-16  1.000378  -1.905269 -0.652656 -0.652656
# FullBath       1324.0  9.659947e-17  1.000378  -4.166615 -1.026972  0.809601
# Functional     1324.0  2.012489e-17  1.000378 -11.255004  0.195684  0.195684
# GarageArea     1324.0  7.137627e-16  1.000378  -2.833937 -0.596469  0.107488
# ...               ...           ...       ...        ...       ...       ...
# LotConfig      1324.0  4.159144e-17  1.000378  -0.609393 -0.609393 -0.609393
# LotFrontage    1324.0  1.247743e-16  1.000378  -2.083132  0.176468  0.440484
# LotShape       1324.0 -1.408742e-16  1.000378  -0.744089 -0.744089 -0.744089
# LowQualFinSF   1324.0 -2.146655e-17  1.000378  -0.113163 -0.113163 -0.113163
# MSSubClass     1324.0 -2.106405e-16  1.000378  -1.118857 -1.118857  0.179692
# MSZoning       1324.0  6.520464e-16  1.000378  -8.256818  0.270164  0.270164
# MasVnrArea     1324.0 -5.903301e-17  1.000378  -0.849518 -0.849518 -0.849518
# MasVnrType     1324.0 -4.709224e-16  1.000378  -3.374851 -0.720462 -0.720462
# MiscVal        1324.0 -2.012489e-17  1.000378  -0.187999 -0.187999 -0.187999
# MoSold         1324.0 -4.829973e-17  1.000378  -2.876240 -0.286919  0.076399
# Neighborhood   1324.0  3.622480e-16  1.000378  -3.890086 -0.572199  0.202461
# OpenPorchSF    1324.0  4.226227e-17  1.000378  -1.116057 -1.116057  0.460258
# OverallCond    1324.0  1.399351e-15  1.000378  -4.923838 -0.522240 -0.522240
# OverallQual    1324.0  1.073327e-17  1.000378  -4.677802 -0.907021 -0.068428
# PavedDrive     1324.0  1.261160e-15  1.000378  -4.686969  0.237931  0.237931
# PoolArea       1324.0  5.366637e-18  1.000378  -0.061557 -0.061557 -0.061557
# RoofMatl       1324.0  4.185977e-16  1.000378 -19.965181 -0.076718 -0.076718
# RoofStyle      1324.0  9.123283e-17  1.000378  -2.328936 -0.494243 -0.494243
# SaleCondition  1324.0  1.495950e-15  1.000378  -8.612358  0.179838  0.179838
# SalePrice      1324.0  1.872956e-15  1.000378  -4.251014 -0.660006 -0.074418
# SaleType       1324.0  1.051861e-15  1.000378  -6.660506 -0.081760 -0.081760
# ScreenPorch    1324.0 -3.421231e-17  1.000378  -0.307331 -0.307331 -0.307331
# Street         1324.0  5.634969e-17  1.000378 -18.165902  0.055048  0.055048
# TotRmsAbvGrd   1324.0  1.448992e-16  1.000378  -2.972532 -0.999333 -0.249157
# TotalBsmtSF    1324.0 -1.730740e-16  1.000378  -6.565069 -0.654879 -0.026954
# Utilities      1324.0 -1.432892e-15  1.000378 -36.373067  0.027493  0.027493
# WoodDeckSF     1324.0 -8.586619e-17  1.000378  -0.985949 -0.985949 -0.985949
# YearBuilt      1324.0  3.339927e-14  1.000378  -3.215442 -0.572306  0.106200
# YearRemodAdd   1324.0  7.289771e-14  1.000378  -1.758671 -0.862819  0.416836
# YrSold         1324.0  6.324595e-13  1.000378  -1.353618 -0.603413  0.146418
#
#                     75%        max
# 1stFlrSF       0.751321   3.112216
# 2ndFlrSF       1.117960   1.429357
# 3SsnPorch     -0.132148   8.963133
# BedroomAbvGr   0.261042   2.766160
# BldgType       0.311940   0.311940
# BsmtCond      -0.009108   2.981157
# BsmtExposure   1.393136   1.937046
# BsmtFinSF1     0.752518   1.126477
# BsmtFinSF2    -0.361311   3.408523
# BsmtFinType1   0.801020   0.801020
# BsmtFinType2   0.240776   1.835367
# BsmtFullBath   1.129992   2.292905
# BsmtHalfBath  -0.249635   6.416492
# BsmtQual       0.654776   1.694835
# BsmtUnfSF      0.558020   1.212760
# CentralAir     0.219767   0.219767
# Condition1     0.233494   2.078061
# Condition2     0.064301   5.914309
# Electrical     0.232193   0.232193
# EnclosedPorch -0.393484   3.134740
# ExterCond      0.319447   2.025130
# ExterQual      1.070613   2.355691
# Exterior1st    0.931305   1.525247
# Exterior2nd    0.917109   1.344409
# FireplaceQu    1.052977   1.296561
# Fireplaces     0.696223   2.462717
# Foundation     1.003207   1.003207
# FullBath       0.809601   2.112671
# Functional     0.195684   1.180822
# GarageArea     0.575411   2.570206
# ...                 ...        ...
# LotConfig      1.384962   2.312284
# LotFrontage    0.566012   1.392651
# LotShape       1.061318   2.866725
# LowQualFinSF  -0.113163   9.993110
# MSSubClass     0.663890   2.112138
# MSZoning       0.270164   1.642701
# MasVnrArea     1.096118   1.934654
# MasVnrType     0.832256   1.933927
# MiscVal       -0.187999   7.792432
# MoSold         0.668723   1.535414
# Neighborhood   0.721694   1.245844
# OpenPorchSF    0.872769   1.836067
# OverallCond    0.456642   2.721586
# OverallQual    0.657994   2.390411
# PavedDrive     0.237931   0.237931
# PoolArea      -0.061557  16.754811
# RoofMatl      -0.076718   9.867513
# RoofStyle     -0.494243   2.413677
# SaleCondition  0.179838   1.175842
# SalePrice      0.638919   3.949553
# SaleType      -0.081760   2.320880
# ScreenPorch   -0.307331   3.920191
# Street         0.055048   0.055048
# TotRmsAbvGrd   0.400674   2.763402
# TotalBsmtSF    0.719270   2.728755
# Utilities      0.027493   0.027493
# WoodDeckSF     0.993236   1.610430
# YearBuilt      0.944744   1.244059
# YearRemodAdd   0.904575   1.196053
# YrSold         0.895876   1.644961
#
# [76 rows x 8 columns]

# %% [markdown]
# ## Remove out of inter-quartile range values from 'SalePrice'

# %%
Q1=df_out['SalePrice'].quantile(0.25)

# %%
Q3=df_out['SalePrice'].quantile(0.75)

# %%
IQR=Q3-Q1

# %%
upper=Q3+1.5*IQR
lower=Q1-1.5*IQR

# %%
df_out=df_out.drop(df_out[(df_out['SalePrice']<lower)|(df_out['SalePrice']>upper)].index)

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### 1. Filter Method - Correlation Coefficient

# %%
corr=df_out.corr()
corr.sort_values(["SalePrice"],ascending=False,inplace=True)
dc=corr.SalePrice

# %%
dc
# Out:
# SalePrice        1.000000
# OverallQual      0.786579
# GrLivArea        0.717089
# Neighborhood     0.679426
# ExterQual        0.666802
# GarageCars       0.650076
# BsmtQual         0.644706
# KitchenQual      0.632537
# GarageArea       0.615540
# YearBuilt        0.591912
# 1stFlrSF         0.590572
# FullBath         0.578883
# TotalBsmtSF      0.574439
# YearRemodAdd     0.570058
# GarageFinish     0.568323
# Foundation       0.537551
# GarageYrBlt      0.535761
# TotRmsAbvGrd     0.516747
# FireplaceQu      0.511849
# GarageType       0.504318
# Fireplaces       0.476432
# OpenPorchSF      0.471133
# HeatingQC        0.446296
# Exterior1st      0.421397
# MasVnrType       0.403718
# Exterior2nd      0.401114
# MSZoning         0.384502
# MasVnrArea       0.383663
# LotArea          0.381508
# BsmtExposure     0.328426
#                    ...
# RoofStyle        0.169142
# LandContour      0.168536
# BedroomAbvGr     0.156600
# Functional       0.147912
# 2ndFlrSF         0.144014
# BsmtFinSF1       0.134559
# BsmtUnfSF        0.129661
# ExterCond        0.127134
# Condition2       0.118676
# BsmtFinType2     0.097934
# LotConfig        0.095480
# Heating          0.090693
# RoofMatl         0.089546
# MoSold           0.072713
# 3SsnPorch        0.066073
# ScreenPorch      0.064505
# LandSlope        0.062183
# PoolArea         0.035385
# LotFrontage      0.030470
# Utilities        0.017964
# Street           0.003833
# YrSold          -0.025889
# MSSubClass      -0.030350
# BsmtHalfBath    -0.045134
# MiscVal         -0.047822
# LowQualFinSF    -0.080483
# BsmtFinSF2      -0.089709
# OverallCond     -0.103735
# KitchenAbvGr    -0.130948
# EnclosedPorch   -0.216440
# Name: SalePrice, Length: 76, dtype: float64

# %%
dc.index
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'Neighborhood', 'ExterQual',
#        'GarageCars', 'BsmtQual', 'KitchenQual', 'GarageArea', 'YearBuilt',
#        '1stFlrSF', 'FullBath', 'TotalBsmtSF', 'YearRemodAdd', 'GarageFinish',
#        'Foundation', 'GarageYrBlt', 'TotRmsAbvGrd', 'FireplaceQu',
#        'GarageType', 'Fireplaces', 'OpenPorchSF', 'HeatingQC', 'Exterior1st',
#        'MasVnrType', 'Exterior2nd', 'MSZoning', 'MasVnrArea', 'LotArea',
#        'BsmtExposure', 'WoodDeckSF', 'BsmtFinType1', 'SaleType', 'HouseStyle',
#        'LotShape', 'HalfBath', 'CentralAir', 'SaleCondition', 'Electrical',
#        'Condition1', 'BsmtFullBath', 'GarageQual', 'PavedDrive', 'GarageCond',
#        'BsmtCond', 'BldgType', 'RoofStyle', 'LandContour', 'BedroomAbvGr',
#        'Functional', '2ndFlrSF', 'BsmtFinSF1', 'BsmtUnfSF', 'ExterCond',
#        'Condition2', 'BsmtFinType2', 'LotConfig', 'Heating', 'RoofMatl',
#        'MoSold', '3SsnPorch', 'ScreenPorch', 'LandSlope', 'PoolArea',
#        'LotFrontage', 'Utilities', 'Street', 'YrSold', 'MSSubClass',
#        'BsmtHalfBath', 'MiscVal', 'LowQualFinSF', 'BsmtFinSF2', 'OverallCond',
#        'KitchenAbvGr', 'EnclosedPorch'],
#       dtype='object')

# %%
dc.values
# Out:
# array([ 1.        ,  0.78657866,  0.71708862,  0.67942632,  0.66680221,
#         0.65007557,  0.64470604,  0.63253715,  0.61553977,  0.59191231,
#         0.59057239,  0.57888286,  0.57443871,  0.57005845,  0.56832342,
#         0.53755078,  0.53576133,  0.51674729,  0.51184862,  0.50431799,
#         0.47643233,  0.4711331 ,  0.44629644,  0.42139682,  0.40371804,
#         0.40111425,  0.38450219,  0.38366259,  0.38150848,  0.32842634,
#         0.32237081,  0.32011985,  0.31175214,  0.28884819,  0.28601861,
#         0.27623679,  0.24600213,  0.243544  ,  0.23539382,  0.22345282,
#         0.21735866,  0.20676651,  0.20261891,  0.19269636,  0.18786925,
#         0.17731853,  0.16914231,  0.16853621,  0.15660037,  0.1479123 ,
#         0.14401393,  0.13455938,  0.12966136,  0.12713411,  0.11867618,
#         0.09793442,  0.09547975,  0.09069297,  0.08954617,  0.07271328,
#         0.06607257,  0.0645051 ,  0.06218283,  0.03538499,  0.0304698 ,
#         0.0179636 ,  0.00383302, -0.02588911, -0.0303502 , -0.04513395,
#        -0.04782191, -0.08048255, -0.08970853, -0.10373518, -0.13094771,
#        -0.21643998])

# %%
dc.index.values
# Out:
# array(['SalePrice', 'OverallQual', 'GrLivArea', 'Neighborhood',
#        'ExterQual', 'GarageCars', 'BsmtQual', 'KitchenQual', 'GarageArea',
#        'YearBuilt', '1stFlrSF', 'FullBath', 'TotalBsmtSF', 'YearRemodAdd',
#        'GarageFinish', 'Foundation', 'GarageYrBlt', 'TotRmsAbvGrd',
#        'FireplaceQu', 'GarageType', 'Fireplaces', 'OpenPorchSF',
#        'HeatingQC', 'Exterior1st', 'MasVnrType', 'Exterior2nd',
#        'MSZoning', 'MasVnrArea', 'LotArea', 'BsmtExposure', 'WoodDeckSF',
#        'BsmtFinType1', 'SaleType', 'HouseStyle', 'LotShape', 'HalfBath',
#        'CentralAir', 'SaleCondition', 'Electrical', 'Condition1',
#        'BsmtFullBath', 'GarageQual', 'PavedDrive', 'GarageCond',
#        'BsmtCond', 'BldgType', 'RoofStyle', 'LandContour', 'BedroomAbvGr',
#        'Functional', '2ndFlrSF', 'BsmtFinSF1', 'BsmtUnfSF', 'ExterCond',
#        'Condition2', 'BsmtFinType2', 'LotConfig', 'Heating', 'RoofMatl',
#        'MoSold', '3SsnPorch', 'ScreenPorch', 'LandSlope', 'PoolArea',
#        'LotFrontage', 'Utilities', 'Street', 'YrSold', 'MSSubClass',
#        'BsmtHalfBath', 'MiscVal', 'LowQualFinSF', 'BsmtFinSF2',
#        'OverallCond', 'KitchenAbvGr', 'EnclosedPorch'], dtype=object)

# %%
dc_new=dc[(dc.values>0.5)&(dc.values<1)]
dc_new
# Out:
# OverallQual     0.786579
# GrLivArea       0.717089
# Neighborhood    0.679426
# ExterQual       0.666802
# GarageCars      0.650076
# BsmtQual        0.644706
# KitchenQual     0.632537
# GarageArea      0.615540
# YearBuilt       0.591912
# 1stFlrSF        0.590572
# FullBath        0.578883
# TotalBsmtSF     0.574439
# YearRemodAdd    0.570058
# GarageFinish    0.568323
# Foundation      0.537551
# GarageYrBlt     0.535761
# TotRmsAbvGrd    0.516747
# FireplaceQu     0.511849
# GarageType      0.504318
# Name: SalePrice, dtype: float64

# %%
feature_col=dc_new.index.values
feature_col
# Out:
# array(['OverallQual', 'GrLivArea', 'Neighborhood', 'ExterQual',
#        'GarageCars', 'BsmtQual', 'KitchenQual', 'GarageArea', 'YearBuilt',
#        '1stFlrSF', 'FullBath', 'TotalBsmtSF', 'YearRemodAdd',
#        'GarageFinish', 'Foundation', 'GarageYrBlt', 'TotRmsAbvGrd',
#        'FireplaceQu', 'GarageType'], dtype=object)

# %% [markdown]
# ### Select the features to be used in the data analysis

# %%
X=df_out[sorted(feature_col)]
y=df_out['SalePrice']

# %%
X.head()
# Out:
#    1stFlrSF  BsmtQual  ExterQual  FireplaceQu  Foundation  FullBath  \
# 0 -0.855114  0.654776   1.070613    -1.097256    1.003207  0.809601
# 1  0.407362  0.654776  -0.740601     0.754854   -0.652656  0.809601
# 2 -0.620652  0.654776   1.070613     0.754854    1.003207  0.809601
# 3 -0.478864 -0.811105  -0.740601     1.052977   -1.905269 -1.026972
# 4  0.090895  0.654776   1.070613     0.754854    1.003207  0.809601
#
#    GarageArea  GarageCars  GarageFinish  GarageType  GarageYrBlt  GrLivArea  \
# 0    0.438107    0.315246      0.431395    0.596821     0.986462   0.522407
# 1   -0.027883    0.315246      0.431395    0.596821    -0.093636  -0.440371
# 2    0.714766    0.315246      0.431395    0.596821     0.906955   0.660234
# 3    0.859675    1.585059     -1.072873   -1.536561     0.787546   0.535355
# 4    1.563004    1.585059      0.431395    0.596821     0.867172   1.318172
#
#    KitchenQual  Neighborhood  OverallQual  TotRmsAbvGrd  TotalBsmtSF  \
# 0     0.752694      0.630494     0.657994      0.973866    -0.519264
# 1    -0.798783      0.967652    -0.068428     -0.249157     0.602558
# 2     0.752694      0.630494     0.657994     -0.249157    -0.310924
# 3     0.752694      0.721694     0.657994      0.400674    -0.878179
# 4     0.752694      1.245844     1.298744      1.486604     0.321349
#
#    YearBuilt  YearRemodAdd
# 0   1.011374      0.855911
# 1   0.106200     -0.467288
# 2   0.944744      0.807222
# 3  -1.985191     -0.763785
# 4   0.911403      0.709772

# %%
y.head()
# Out:
# 0    0.503904
# 1    0.132548
# 2    0.689932
# 3   -0.562624
# 4    0.989970
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Specify testing size

# %%
TS=0.2

# %% [markdown]
# ### Create a Result dataframe

# %%
result_col=['Algorithm','Correlation','Recursive','XGBoost']
result=pd.DataFrame(columns=result_col)
result['Algorithm']=['Ridge Regression','LASSO Regression','Elastic Net',
                     'Decision Tree','Random Forest','XGBoost']

# %%
result
# Out:
#           Algorithm Correlation Recursive XGBoost
# 0  Ridge Regression         NaN       NaN     NaN
# 1  LASSO Regression         NaN       NaN     NaN
# 2       Elastic Net         NaN       NaN     NaN
# 3     Decision Tree         NaN       NaN     NaN
# 4     Random Forest         NaN       NaN     NaN
# 5           XGBoost         NaN       NaN     NaN

# %% [markdown]
# ### Split the data to train and test dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=TS, random_state=200)

# %% [markdown]
# ### Ridge Regression

# %%
print(plt.rcParams["figure.figsize"])
plt.rcParams["figure.figsize"] = (8,4)
# Out:
# [6.0, 4.0]

# %%
from sklearn.linear_model import Ridge
RR=Ridge(alpha=0.001,fit_intercept=True)
RR_fit=RR.fit(x_train,y_train)

# %%
y_pred=RR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3389617354320669

# %%
y_pred=RR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][0]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][0]
# Out:
# 0.33064806652899265

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso
LR=Lasso(alpha=0.001,fit_intercept=True)
LR_fit=LR.fit(x_train,y_train)
y_pred=LR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3390308742785151

# %%
y_pred=LR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][1]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][1]
# Out:
# 0.32963610662349563

# %% [markdown]
# ### Elastic Net Model

# %%
from sklearn.linear_model import ElasticNetCV
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)
EN_fit=EN.fit(x_train, y_train)

# %%
y_pred=EN_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3390804567113875

# %%
y_pred=EN_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][2]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][2]
# Out:
# 0.32964296387340164

# %% [markdown]
# ### Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
DT=DecisionTreeRegressor()
DT_fit=DT.fit(x_train,y_train)

# %%
y_pred=DT_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.006640811556405288

# %%
y_pred=DT_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][3]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][3]
# Out:
# 0.4380532520075661

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)
RF_fit=RF.fit(x_train, y_train)

# %%
y_pred=RF_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.12883738570848702

# %%
y_pred=RF_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][4]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][4]
# Out:
# 0.32749301829464533

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=3000, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)
XG_fit=XG.fit(x_train, y_train)

# %%
y_pred=XG_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.0810605869053861

# %%
y_pred=XG_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][5]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][5]
# Out:
# 0.3281071298490637

# %% [markdown]
# ### Wrapper Method - Recursive Feature Elimination Method

# %%
from sklearn.feature_selection import RFECV

# %% [markdown]
# ### Split the data to train and test dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=TS, random_state=200)

# %% [markdown]
# ### Ridge Regression

# %%
RR=Ridge(alpha=0.001,fit_intercept=True)
RM_RR=RFECV(RR, step=1, cv=20, scoring='neg_mean_squared_error')
RM_RR_fit=RM_RR.fit(x_train,y_train)
RM_RR_fit.n_features_
# Out:
# 15

# %%
y_pred=RM_RR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3395045464849862

# %%
y_pred=RM_RR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][0]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][0]
# Out:
# 0.3346069545633398

# %% [markdown]
# ### Lasso Regression

# %%
LR=Lasso(alpha=0.001,fit_intercept=True)
RM_LR=RFECV(LR, step=1, cv=20, scoring='neg_mean_squared_error')
RM_LR_fit=RM_LR.fit(x_train,y_train)
RM_LR_fit.n_features_
# Out:
# 19

# %%
y_pred=RM_LR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3390308742785151

# %%
y_pred=RM_LR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][1]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][1]
# Out:
# 0.32963610662349563

# %% [markdown]
# ### Elastic Net Model

# %%
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)
RM_EN=RFECV(EN, step=1, cv=20, scoring='neg_mean_squared_error')
RM_EN_fit=RM_EN.fit(x_train,y_train)
RM_EN_fit.n_features_
# Out:
# 18

# %%
y_pred=RM_EN_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.33916807689792705

# %%
y_pred=RM_EN_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][2]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][2]
# Out:
# 0.3301105244791726

# %% [markdown]
# ### Decision Tree Model

# %%
DT=DecisionTreeRegressor()
RM_DT=RFECV(DT, step=1, cv=20, scoring='neg_mean_squared_error')
RM_DT_fit=RM_DT.fit(x_train,y_train)
RM_DT_fit.n_features_
# Out:
# 17

# %%
y_pred=RM_DT_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.007176163176406394

# %%
y_pred=RM_DT_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][3]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][3]
# Out:
# 0.42026174822299506

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)
RM_RF=RFECV(RF, step=1, cv=10, scoring='neg_mean_squared_error')
RM_RF_fit=RM_RF.fit(x_train,y_train)
RM_RF_fit.n_features_
# Out:
# 17

# %%
y_pred=RM_RF_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.12880681968096144

# %%
y_pred=RM_RF_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][4]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][4]
# Out:
# 0.32964173409134623

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=300, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)
RM_XG=RFECV(XG, step=1, cv=5, scoring='neg_mean_squared_error')
RM_XG_fit=RM_XG.fit(x_train,y_train)
RM_XG_fit.n_features_
# Out:
# 18

# %%
y_pred=RM_XG_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.14483817750022096

# %%
y_pred=RM_XG_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][5]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][5]
# Out:
# 0.314612667560711

# %% [markdown]
# ## Embedded Method - XGBoost Feature Importance

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
df_out_X=df_out.drop(columns=['SalePrice'])
df_out_y=df_out['SalePrice']
model.fit(df_out_X, df_out_y)
print(model.feature_importances_)
# Out:
# [6.4842165e-02 3.3592522e-02 4.4141116e-04 4.1990653e-03 1.0412775e-03
#  6.1118469e-04 6.1571198e-03 5.7326861e-02 2.1278281e-03 1.1374826e-02
#  8.2623115e-04 2.7729676e-03 6.1118469e-04 2.0372823e-03 8.9402735e-02
#  3.0559234e-04 2.3541928e-03 0.0000000e+00 8.1491290e-04 3.1804240e-03
#  1.2223694e-03 2.1391464e-03 7.5832172e-03 9.0545882e-03 8.2396753e-03
#  1.0073229e-03 3.0219688e-03 2.6258305e-03 4.6404763e-04 6.7932047e-02
#  1.3581882e-03 6.1118469e-04 7.0286239e-03 1.6977353e-04 3.4860163e-03
#  2.1040598e-02 9.1745615e-02 3.0219688e-03 0.0000000e+00 6.8928050e-03
#  3.8934727e-03 1.1318235e-05 4.2330199e-03 7.9227646e-04 3.5086527e-04
#  9.8887421e-02 4.8781591e-03 3.6127806e-02 5.0139781e-03 0.0000000e+00
#  7.5039896e-03 1.4260976e-03 3.7780266e-02 8.1491290e-04 4.3009291e-04
#  2.2489332e-02 1.8867498e-02 3.7452038e-02 5.9647099e-03 9.7449999e-03
#  5.5459351e-04 0.0000000e+00 1.3581882e-04 2.7050581e-03 1.2676422e-03
#  8.6018583e-04 1.8335540e-03 0.0000000e+00 8.5339490e-03 6.2533244e-02
#  0.0000000e+00 3.6229670e-02 2.1515964e-02 2.9936731e-02 1.4566569e-02]

# %%
len(model.feature_importances_)
# Out:
# 75

# %%
df_out_X.shape
# Out:
# (1305, 75)

# %%
df_out_X_col=df_out_X.columns.values

# %%
plt.rcParams["figure.figsize"] = (10,20)
plt.barh(df_out_X_col, model.feature_importances_)
plt.show()

# %%
df_XG=pd.DataFrame()

# %%
df_XG['Feature']=df_out_X_col
df_XG['Feature_Importance']=model.feature_importances_

# %%
df_XG.head()
# Out:
#         Feature  Feature_Importance
# 0      1stFlrSF            0.064842
# 1      2ndFlrSF            0.033593
# 2     3SsnPorch            0.000441
# 3  BedroomAbvGr            0.004199
# 4      BldgType            0.001041

# %%
df_XG=df_XG.sort_values(by=['Feature_Importance'],ascending=False)

# %%
df_XG
# Out:
#           Feature  Feature_Importance
# 45        LotArea            0.098887
# 36      GrLivArea            0.091746
# 14      BsmtUnfSF            0.089403
# 29     GarageArea            0.067932
# 0        1stFlrSF            0.064842
# 69    TotalBsmtSF            0.062533
# 7      BsmtFinSF1            0.057327
# 52     MasVnrArea            0.037780
# 57    OpenPorchSF            0.037452
# 71     WoodDeckSF            0.036230
# 47    LotFrontage            0.036128
# 1        2ndFlrSF            0.033593
# 73   YearRemodAdd            0.029937
# 55         MoSold            0.022489
# 72      YearBuilt            0.021516
# 35    GarageYrBlt            0.021041
# 56   Neighborhood            0.018867
# 74         YrSold            0.014567
# 9    BsmtFinType1            0.011375
# 59    OverallQual            0.009745
# 23    Exterior2nd            0.009055
# 68   TotRmsAbvGrd            0.008534
# 24    FireplaceQu            0.008240
# 22    Exterior1st            0.007583
# 50     MSSubClass            0.007504
# 32   GarageFinish            0.007029
# 39      HeatingQC            0.006893
# 6    BsmtExposure            0.006157
# 58    OverallCond            0.005965
# 48       LotShape            0.005014
# ..            ...                 ...
# 66    ScreenPorch            0.001834
# 51       MSZoning            0.001426
# 30     GarageCars            0.001358
# 64  SaleCondition            0.001268
# 20      ExterCond            0.001222
# 4        BldgType            0.001041
# 25     Fireplaces            0.001007
# 65       SaleType            0.000860
# 10   BsmtFinType2            0.000826
# 18     Electrical            0.000815
# 53     MasVnrType            0.000815
# 43    LandContour            0.000792
# 5        BsmtCond            0.000611
# 31     GarageCond            0.000611
# 12   BsmtHalfBath            0.000611
# 60     PavedDrive            0.000555
# 28     Functional            0.000464
# 2       3SsnPorch            0.000441
# 54        MiscVal            0.000430
# 44      LandSlope            0.000351
# 15     CentralAir            0.000306
# 33     GarageQual            0.000170
# 62       RoofMatl            0.000136
# 41   KitchenAbvGr            0.000011
# 61       PoolArea            0.000000
# 38        Heating            0.000000
# 67         Street            0.000000
# 17     Condition2            0.000000
# 70      Utilities            0.000000
# 49   LowQualFinSF            0.000000
#
# [75 rows x 2 columns]

# %%
feature_col_XG=df_XG['Feature'][:12].values

# %%
feature_col_XG
# Out:
# array(['LotArea', 'GrLivArea', 'BsmtUnfSF', 'GarageArea', '1stFlrSF',
#        'TotalBsmtSF', 'BsmtFinSF1', 'MasVnrArea', 'OpenPorchSF',
#        'WoodDeckSF', 'LotFrontage', '2ndFlrSF'], dtype=object)

# %% [markdown]
# ### Using the new selected features in the 6 models again.

# %%
X=df_out[feature_col_XG]
y=df_out['SalePrice']

# %%
feature_col_XG
# Out:
# array(['LotArea', 'GrLivArea', 'BsmtUnfSF', 'GarageArea', '1stFlrSF',
#        'TotalBsmtSF', 'BsmtFinSF1', 'MasVnrArea', 'OpenPorchSF',
#        'WoodDeckSF', 'LotFrontage', '2ndFlrSF'], dtype=object)

# %% [markdown]
# ### Split the data to train and test dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=TS, random_state=200)

# %% [markdown]
# ### Ridge Regression

# %%
plt.rcParams["figure.figsize"] = (8,4)

# %%
from sklearn.linear_model import Ridge
RR=Ridge(alpha=0.0001,fit_intercept=True)
RR_fit=RR.fit(x_train,y_train)
y_pred=RR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.47852691619085275

# %%
y_pred=RR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][0]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][0]
# Out:
# 0.4702626878791567

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso
LR=Lasso(alpha=0.0001,fit_intercept=True)
LR_fit=LR.fit(x_train,y_train)
y_pred=LR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.4785284161841909

# %%
y_pred=LR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][1]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][1]
# Out:
# 0.4702111264120046

# %% [markdown]
# ### Elastic Net Model

# %%
from sklearn.linear_model import ElasticNetCV
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)
EN_fit=EN.fit(x_train, y_train)

# %%
y_pred=EN_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.481524714610204

# %%
y_pred=EN_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][2]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][2]
# Out:
# 0.4683131668636138

# %% [markdown]
# ### Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
DT=DecisionTreeRegressor()
DT_fit=DT.fit(x_train,y_train)

# %%
y_pred=DT_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.0057477330008048975

# %%
y_pred=DT_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][3]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][3]
# Out:
# 0.6360597206466666

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)
RF_fit=RF.fit(x_train, y_train)

# %%
y_pred=RF_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.16598214586772952

# %%
y_pred=RF_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][4]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][4]
# Out:
# 0.4453869036470329

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=3000, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)
XG_fit=XG.fit(x_train, y_train)

# %%
y_pred=XG_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.1001458378866891

# %%
y_pred=XG_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][5]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][5]
# Out:
# 0.4571147952725547

# %% [markdown]
# ## Examine the result

# %%
print('test-size: ',TS)
# Out:
# test-size:  0.2

# %%
result
# Out:
#           Algorithm Correlation Recursive   XGBoost
# 0  Ridge Regression    0.330648  0.334607  0.470263
# 1  LASSO Regression    0.329636  0.329636  0.470211
# 2       Elastic Net    0.329643  0.330111  0.468313
# 3     Decision Tree    0.438053  0.420262   0.63606
# 4     Random Forest    0.327493  0.329642  0.445387
# 5           XGBoost    0.328107  0.314613  0.457115
