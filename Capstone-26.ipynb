# %% [markdown]
# ## 1. Data Exploration/Cleaning
# - Checking null values
# - Remove outliers
#
# ## 2. Features Selection
# - Filter Method - Correlation Matrix
# - Wrapper Method - Recursive Method
# - Embedded Method - XGBoost Feature Importance
#
#
# ## 3.	Models
# - Ridge Regression
# - LASSO Regression
# - Elastic Net Regression
# - Decision Tree
# - Random Forest
# - XGBoost
#
# ## 4.	Models Evaluation
# - RMSE (Root Mean Squred Error)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from scipy import stats
from scipy.stats import norm


from sklearn.preprocessing import StandardScaler
from sklearn import ensemble, tree, linear_model
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split, cross_val_score



import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('train.csv')

# %%
from IPython.display import display
pd.options.display.max_columns=None
df=df.reindex_axis(sorted(df.columns),axis=1)
df.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0       856       854          0   NaN             3     1Fam       TA
# 1      1262         0          0   NaN             3     1Fam       TA
# 2       920       866          0   NaN             3     1Fam       TA
# 3       961       756          0   NaN             3     1Fam       Gd
# 4      1145      1053          0   NaN             4     1Fam       TA
#
#   BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# 0           No         706           0          GLQ          Unf
# 1           Gd         978           0          ALQ          Unf
# 2           Mn         486           0          GLQ          Unf
# 3           No         216           0          ALQ          Unf
# 4           Av         655           0          GLQ          Unf
#
#    BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF CentralAir Condition1  \
# 0             1             0       Gd        150          Y       Norm
# 1             0             1       Gd        284          Y      Feedr
# 2             1             0       Gd        434          Y       Norm
# 3             1             0       TA        540          Y       Norm
# 4             1             0       Gd        490          Y       Norm
#
#   Condition2 Electrical  EnclosedPorch ExterCond ExterQual Exterior1st  \
# 0       Norm      SBrkr              0        TA        Gd     VinylSd
# 1       Norm      SBrkr              0        TA        TA     MetalSd
# 2       Norm      SBrkr              0        TA        Gd     VinylSd
# 3       Norm      SBrkr            272        TA        TA     Wd Sdng
# 4       Norm      SBrkr              0        TA        Gd     VinylSd
#
#   Exterior2nd Fence FireplaceQu  Fireplaces Foundation  FullBath Functional  \
# 0     VinylSd   NaN         NaN           0      PConc         2        Typ
# 1     MetalSd   NaN          TA           1     CBlock         2        Typ
# 2     VinylSd   NaN          TA           1      PConc         2        Typ
# 3     Wd Shng   NaN          Gd           1     BrkTil         1        Typ
# 4     VinylSd   NaN          TA           1      PConc         2        Typ
#
#    GarageArea  GarageCars GarageCond GarageFinish GarageQual GarageType  \
# 0         548           2         TA          RFn         TA     Attchd
# 1         460           2         TA          RFn         TA     Attchd
# 2         608           2         TA          RFn         TA     Attchd
# 3         642           3         TA          Unf         TA     Detchd
# 4         836           3         TA          RFn         TA     Attchd
#
#    GarageYrBlt  GrLivArea  HalfBath Heating HeatingQC HouseStyle  Id  \
# 0       2003.0       1710         1    GasA        Ex     2Story   1
# 1       1976.0       1262         0    GasA        Ex     1Story   2
# 2       2001.0       1786         1    GasA        Ex     2Story   3
# 3       1998.0       1717         0    GasA        Gd     2Story   4
# 4       2000.0       2198         1    GasA        Ex     2Story   5
#
#    KitchenAbvGr KitchenQual LandContour LandSlope  LotArea LotConfig  \
# 0             1          Gd         Lvl       Gtl     8450    Inside
# 1             1          TA         Lvl       Gtl     9600       FR2
# 2             1          Gd         Lvl       Gtl    11250    Inside
# 3             1          Gd         Lvl       Gtl     9550    Corner
# 4             1          Gd         Lvl       Gtl    14260       FR2
#
#    LotFrontage LotShape  LowQualFinSF  MSSubClass MSZoning  MasVnrArea  \
# 0         65.0      Reg             0          60       RL       196.0
# 1         80.0      Reg             0          20       RL         0.0
# 2         68.0      IR1             0          60       RL       162.0
# 3         60.0      IR1             0          70       RL         0.0
# 4         84.0      IR1             0          60       RL       350.0
#
#   MasVnrType MiscFeature  MiscVal  MoSold Neighborhood  OpenPorchSF  \
# 0    BrkFace         NaN        0       2      CollgCr           61
# 1       None         NaN        0       5      Veenker            0
# 2    BrkFace         NaN        0       9      CollgCr           42
# 3       None         NaN        0       2      Crawfor           35
# 4    BrkFace         NaN        0      12      NoRidge           84
#
#    OverallCond  OverallQual PavedDrive  PoolArea PoolQC RoofMatl RoofStyle  \
# 0            5            7          Y         0    NaN  CompShg     Gable
# 1            8            6          Y         0    NaN  CompShg     Gable
# 2            5            7          Y         0    NaN  CompShg     Gable
# 3            5            7          Y         0    NaN  CompShg     Gable
# 4            5            8          Y         0    NaN  CompShg     Gable
#
#   SaleCondition  SalePrice SaleType  ScreenPorch Street  TotRmsAbvGrd  \
# 0        Normal     208500       WD            0   Pave             8
# 1        Normal     181500       WD            0   Pave             6
# 2        Normal     223500       WD            0   Pave             6
# 3       Abnorml     140000       WD            0   Pave             7
# 4        Normal     250000       WD            0   Pave             9
#
#    TotalBsmtSF Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          856    AllPub           0       2003          2003    2008
# 1         1262    AllPub         298       1976          1976    2007
# 2          920    AllPub           0       2001          2002    2008
# 3          756    AllPub           0       1915          1970    2006
# 4         1145    AllPub         192       2000          2000    2008

# %%
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### Remove "Id" from dataset

# %%
df=df.drop(columns=['Id'])

# %%
df.shape
# Out:
# (1460, 80)

# %% [markdown]
# ## Log Transformation of "SalePrice'

# %%
y=df['SalePrice']
sns.distplot(y)

# %%
sns.distplot(np.log(y))

# %%
df['SalePrice']=np.log(df['SalePrice'])

# %%
df.dtypes
# Out:
# 1stFlrSF           int64
# 2ndFlrSF           int64
# 3SsnPorch          int64
# Alley             object
# BedroomAbvGr       int64
# BldgType          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtFinType1      object
# BsmtFinType2      object
# BsmtFullBath       int64
# BsmtHalfBath       int64
# BsmtQual          object
# BsmtUnfSF          int64
# CentralAir        object
# Condition1        object
# Condition2        object
# Electrical        object
# EnclosedPorch      int64
# ExterCond         object
# ExterQual         object
# Exterior1st       object
# Exterior2nd       object
# Fence             object
# FireplaceQu       object
# Fireplaces         int64
# Foundation        object
# FullBath           int64
#                   ...
# LotShape          object
# LowQualFinSF       int64
# MSSubClass         int64
# MSZoning          object
# MasVnrArea       float64
# MasVnrType        object
# MiscFeature       object
# MiscVal            int64
# MoSold             int64
# Neighborhood      object
# OpenPorchSF        int64
# OverallCond        int64
# OverallQual        int64
# PavedDrive        object
# PoolArea           int64
# PoolQC            object
# RoofMatl          object
# RoofStyle         object
# SaleCondition     object
# SalePrice        float64
# SaleType          object
# ScreenPorch        int64
# Street            object
# TotRmsAbvGrd       int64
# TotalBsmtSF        int64
# Utilities         object
# WoodDeckSF         int64
# YearBuilt          int64
# YearRemodAdd       int64
# YrSold             int64
# Length: 80, dtype: object

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Checking NAs

# %%
null_cols=df.columns[df.isnull().any()]
df[null_cols].isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageType        81
# GarageQual        81
# GarageFinish      81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtFinType1      37
# BsmtCond          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %%
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
dg
# Out:
# PoolQC          99.520548
# MiscFeature     96.301370
# Alley           93.767123
# Fence           80.753425
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageType       5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtQual         2.534247
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# MasVnrArea       0.547945
# MasVnrType       0.547945
# Electrical       0.068493
# dtype: float64

# %%
featureName=dg.index.values
featureName
# Out:
# array(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu',
#        'LotFrontage', 'GarageYrBlt', 'GarageType', 'GarageQual',
#        'GarageFinish', 'GarageCond', 'BsmtFinType2', 'BsmtExposure',
#        'BsmtQual', 'BsmtFinType1', 'BsmtCond', 'MasVnrArea', 'MasVnrType',
#        'Electrical'], dtype=object)

# %%
def missingness(featureName):
    for i in featureName:
        print(i)
        print(df[i].value_counts(dropna=False))
        print("Value missing: %2.1f %%" % (df[i].isnull().sum()/len(df)*100))
        print()

# %% [markdown]
# ### Checking unique values of feature with more than 70% missning values

# %%
missingness(featureName)
# Out:
# PoolQC
# NaN    1453
# Gd        3
# Ex        2
# Fa        2
# Name: PoolQC, dtype: int64
# Value missing: 99.5 %
#
# MiscFeature
# NaN     1406
# Shed      49
# Gar2       2
# Othr       2
# TenC       1
# Name: MiscFeature, dtype: int64
# Value missing: 96.3 %
#
# Alley
# NaN     1369
# Grvl      50
# Pave      41
# Name: Alley, dtype: int64
# Value missing: 93.8 %
#
# Fence
# NaN      1179
# MnPrv     157
# GdPrv      59
# GdWo       54
# MnWw       11
# Name: Fence, dtype: int64
# Value missing: 80.8 %
#
# FireplaceQu
# NaN    690
# Gd     380
# TA     313
# Fa      33
# Ex      24
# Po      20
# Name: FireplaceQu, dtype: int64
# Value missing: 47.3 %
#
# LotFrontage
# NaN       259
#  60.0     143
#  70.0      70
#  80.0      69
#  50.0      57
#  75.0      53
#  65.0      44
#  85.0      40
#  78.0      25
#  21.0      23
#  90.0      23
#  68.0      19
#  24.0      19
#  64.0      19
#  73.0      18
#  72.0      17
#  79.0      17
#  63.0      17
#  55.0      17
#  100.0     16
#  51.0      15
#  66.0      15
#  74.0      15
#  52.0      14
#  59.0      13
#  71.0      12
#  67.0      12
#  57.0      12
#  82.0      12
#  43.0      12
#          ...
#  129.0      2
#  313.0      2
#  118.0      2
#  122.0      2
#  121.0      2
#  101.0      2
#  109.0      2
#  115.0      2
#  116.0      2
#  114.0      2
#  153.0      1
#  149.0      1
#  150.0      1
#  111.0      1
#  182.0      1
#  46.0       1
#  112.0      1
#  141.0      1
#  33.0       1
#  152.0      1
#  160.0      1
#  168.0      1
#  128.0      1
#  144.0      1
#  39.0       1
#  106.0      1
#  38.0       1
#  138.0      1
#  140.0      1
#  137.0      1
# Name: LotFrontage, Length: 111, dtype: int64
# Value missing: 17.7 %
#
# GarageYrBlt
# NaN        81
#  2005.0    65
#  2006.0    59
#  2004.0    53
#  2003.0    50
#  2007.0    49
#  1977.0    35
#  1998.0    31
#  1999.0    30
#  1976.0    29
#  2008.0    29
#  2000.0    27
#  2002.0    26
#  1968.0    26
#  1950.0    24
#  1993.0    22
#  1962.0    21
#  2009.0    21
#  1966.0    21
#  1965.0    21
#  1958.0    21
#  1970.0    20
#  1996.0    20
#  1957.0    20
#  2001.0    20
#  1997.0    19
#  1978.0    19
#  1960.0    19
#  1954.0    19
#  1974.0    18
#            ..
#  1916.0     5
#  1922.0     5
#  1936.0     5
#  1945.0     4
#  1946.0     4
#  1982.0     4
#  1931.0     4
#  1928.0     4
#  1935.0     4
#  1932.0     3
#  1952.0     3
#  1921.0     3
#  1938.0     3
#  2010.0     3
#  1910.0     3
#  1924.0     3
#  1923.0     3
#  1947.0     2
#  1918.0     2
#  1929.0     2
#  1914.0     2
#  1915.0     2
#  1934.0     2
#  1937.0     2
#  1942.0     2
#  1906.0     1
#  1927.0     1
#  1900.0     1
#  1908.0     1
#  1933.0     1
# Name: GarageYrBlt, Length: 98, dtype: int64
# Value missing: 5.5 %
#
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# NaN         81
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64
# Value missing: 5.5 %
#
# GarageQual
# TA     1311
# NaN      81
# Fa       48
# Gd       14
# Ex        3
# Po        3
# Name: GarageQual, dtype: int64
# Value missing: 5.5 %
#
# GarageFinish
# Unf    605
# RFn    422
# Fin    352
# NaN     81
# Name: GarageFinish, dtype: int64
# Value missing: 5.5 %
#
# GarageCond
# TA     1326
# NaN      81
# Fa       35
# Gd        9
# Po        7
# Ex        2
# Name: GarageCond, dtype: int64
# Value missing: 5.5 %
#
# BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      46
# NaN      38
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64
# Value missing: 2.6 %
#
# BsmtExposure
# No     953
# Av     221
# Gd     134
# Mn     114
# NaN     38
# Name: BsmtExposure, dtype: int64
# Value missing: 2.6 %
#
# BsmtQual
# TA     649
# Gd     618
# Ex     121
# NaN     37
# Fa      35
# Name: BsmtQual, dtype: int64
# Value missing: 2.5 %
#
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# NaN     37
# Name: BsmtFinType1, dtype: int64
# Value missing: 2.5 %
#
# BsmtCond
# TA     1311
# Gd       65
# Fa       45
# NaN      37
# Po        2
# Name: BsmtCond, dtype: int64
# Value missing: 2.5 %
#
# MasVnrArea
#  0.0       861
#  72.0        8
#  180.0       8
# NaN          8
#  108.0       8
#  120.0       7
#  16.0        7
#  106.0       6
#  80.0        6
#  340.0       6
#  200.0       6
#  132.0       5
#  170.0       5
#  360.0       5
#  84.0        5
#  320.0       5
#  270.0       4
#  183.0       4
#  100.0       4
#  168.0       4
#  252.0       4
#  178.0       4
#  246.0       4
#  196.0       4
#  288.0       4
#  216.0       4
#  160.0       4
#  220.0       4
#  336.0       4
#  210.0       4
#           ...
#  24.0        1
#  760.0       1
#  138.0       1
#  27.0        1
#  541.0       1
#  275.0       1
#  365.0       1
#  562.0       1
#  161.0       1
#  247.0       1
#  452.0       1
#  278.0       1
#  375.0       1
#  225.0       1
#  604.0       1
#  762.0       1
#  290.0       1
#  109.0       1
#  299.0       1
#  731.0       1
#  167.0       1
#  309.0       1
#  202.0       1
#  1129.0      1
#  651.0       1
#  337.0       1
#  415.0       1
#  293.0       1
#  259.0       1
#  621.0       1
# Name: MasVnrArea, Length: 328, dtype: int64
# Value missing: 0.5 %
#
# MasVnrType
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# NaN          8
# Name: MasVnrType, dtype: int64
# Value missing: 0.5 %
#
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# NaN         1
# Name: Electrical, dtype: int64
# Value missing: 0.1 %

# %% [markdown]
# ### Remove columns with more than 70% of missing values

# %%
df=df.drop(columns=['PoolQC','MiscFeature','Alley','Fence'])

# %%
df.shape
# Out:
# (1460, 76)

# %% [markdown]
# ### Checking the rest of features with missing values

# %%
null_cols=df.columns[df.isnull().any()]
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
print(dg)
nullCol=dg.index.values
nullCol
# Out:
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageType       5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtQual         2.534247
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# MasVnrType       0.547945
# MasVnrArea       0.547945
# Electrical       0.068493
# dtype: float64
# array(['FireplaceQu', 'LotFrontage', 'GarageYrBlt', 'GarageType',
#        'GarageQual', 'GarageFinish', 'GarageCond', 'BsmtFinType2',
#        'BsmtExposure', 'BsmtQual', 'BsmtFinType1', 'BsmtCond',
#        'MasVnrType', 'MasVnrArea', 'Electrical'], dtype=object)

# %% [markdown]
# ### It looks like "FireplaceQu" has "NaN" value when "Fireplaces" has "zero" value.
# ### Let's check if the number of missing value in "FireplaceQu" is the same as the number of rows with zero value in "Fireplaces"

# %%
df['FireplaceQu'].isnull().sum()
# Out:
# 690

# %%
len(df.loc[df['Fireplaces']==0])
# Out:
# 690

# %% [markdown]
# ### It turns out the number is the same.
# ### We can go ahead and replace the "NaN" in "FireplaceQu" with "0"

# %% [markdown]
# ### Also, we will change the datatype of "FireplaceQu" to a "Ordinal" Variable

# %% [markdown]
# ### First we will need to replace "NaN" with "0" value

# %%
df['FireplaceQu'].fillna(0,inplace=True)

# %%
df['FireplaceQu'].value_counts()
# Out:
# 0     690
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %% [markdown]
# ### Replace string values to ordinal value in "FireplaceQu"

# %%
#quality={'Po':1,'Fa':2,'TA':3,'Gd':4,"Ex":5}
df.FireplaceQu[df.FireplaceQu=='Po']=1
df.FireplaceQu[df.FireplaceQu=='Fa']=2
df.FireplaceQu[df.FireplaceQu=='TA']=3
df.FireplaceQu[df.FireplaceQu=='Gd']=4
df.FireplaceQu[df.FireplaceQu=='Ex']=5

# %%
df.FireplaceQu.dtypes
# Out:
# dtype('O')

# %% [markdown]
# ### Let's change the datatype of "FireplaceQu" to "int"

# %%
df=df.astype({"FireplaceQu":int})

# %%
df.FireplaceQu.dtypes
# Out:
# dtype('int32')

# %%
df['LotFrontage'].isnull().sum()
# Out:
# 259

# %% [markdown]
# ### Some Lot just does not have LotFronage.
# ### Change "NaN" value to "zero" in "LotFrontage"

# %%
df['LotFrontage'].fillna(0,inplace=True)

# %% [markdown]
# ### Check if the number of "0" value is the same as the number "NaN" value

# %%
df['LotFrontage'].value_counts()
# Out:
# 0.0      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 67.0      12
# 57.0      12
# 82.0      12
# 43.0      12
#         ...
# 129.0      2
# 313.0      2
# 118.0      2
# 122.0      2
# 121.0      2
# 101.0      2
# 109.0      2
# 115.0      2
# 116.0      2
# 114.0      2
# 153.0      1
# 149.0      1
# 150.0      1
# 111.0      1
# 182.0      1
# 46.0       1
# 112.0      1
# 141.0      1
# 33.0       1
# 152.0      1
# 160.0      1
# 168.0      1
# 128.0      1
# 144.0      1
# 39.0       1
# 106.0      1
# 38.0       1
# 138.0      1
# 140.0      1
# 137.0      1
# Name: LotFrontage, Length: 111, dtype: int64

# %% [markdown]
# ### Double check all the missing values again

# %%
null_cols=df.columns[df.isnull().any()]
df[null_cols].isnull().sum().sort_values(ascending=False)
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
dg
# Out:
# GarageYrBlt     5.547945
# GarageType      5.547945
# GarageQual      5.547945
# GarageFinish    5.547945
# GarageCond      5.547945
# BsmtFinType2    2.602740
# BsmtExposure    2.602740
# BsmtQual        2.534247
# BsmtFinType1    2.534247
# BsmtCond        2.534247
# MasVnrType      0.547945
# MasVnrArea      0.547945
# Electrical      0.068493
# dtype: float64

# %% [markdown]
# ### All the remaining variables have less than 6% of missing values.
# ### We will remove all the rows with any missing values.

# %%
df_miss=df.dropna()

# %%
df_miss.isnull().sum()
# Out:
# 1stFlrSF         0
# 2ndFlrSF         0
# 3SsnPorch        0
# BedroomAbvGr     0
# BldgType         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtFinType1     0
# BsmtFinType2     0
# BsmtFullBath     0
# BsmtHalfBath     0
# BsmtQual         0
# BsmtUnfSF        0
# CentralAir       0
# Condition1       0
# Condition2       0
# Electrical       0
# EnclosedPorch    0
# ExterCond        0
# ExterQual        0
# Exterior1st      0
# Exterior2nd      0
# FireplaceQu      0
# Fireplaces       0
# Foundation       0
# FullBath         0
# Functional       0
# GarageArea       0
#                 ..
# LotConfig        0
# LotFrontage      0
# LotShape         0
# LowQualFinSF     0
# MSSubClass       0
# MSZoning         0
# MasVnrArea       0
# MasVnrType       0
# MiscVal          0
# MoSold           0
# Neighborhood     0
# OpenPorchSF      0
# OverallCond      0
# OverallQual      0
# PavedDrive       0
# PoolArea         0
# RoofMatl         0
# RoofStyle        0
# SaleCondition    0
# SalePrice        0
# SaleType         0
# ScreenPorch      0
# Street           0
# TotRmsAbvGrd     0
# TotalBsmtSF      0
# Utilities        0
# WoodDeckSF       0
# YearBuilt        0
# YearRemodAdd     0
# YrSold           0
# Length: 76, dtype: int64

# %%
df_miss.shape
# Out:
# (1338, 76)

# %%
len(df)-len(df_miss)
# Out:
# 122

# %% [markdown]
# ### Checking the percentage of data removed

# %%
(len(df)-len(df_miss))/len(df)*100
# Out:
# 8.356164383561644

# %% [markdown]
# ## Convert all string categorical variables to ordinal categorical variables

# %%
cat_col=df_miss.select_dtypes(include=['object']).columns
cat_col
for item1 in cat_col:
    df_mean=pd.concat([df_miss[item1],df_miss['SalePrice']],axis=1)
    df_mean.head()

    g1=df_mean.groupby(item1).mean()
    g1

    df_g1=pd.DataFrame()
    df_g1=pd.DataFrame(g1)
    df_g1

    df_g2=df_g1.sort_values('SalePrice')
    df_g2

    df_g2.index

    g_col=df_g2.index.values

    df_miss[item1].value_counts()

    i=0
    for item2 in g_col:
        df_miss.loc[df_miss[item1]==item2,item1]=i
        i=i+1

# %%
df_miss[cat_col].dtypes
# Out:
# BldgType         int64
# BsmtCond         int64
# BsmtExposure     int64
# BsmtFinType1     int64
# BsmtFinType2     int64
# BsmtQual         int64
# CentralAir       int64
# Condition1       int64
# Condition2       int64
# Electrical       int64
# ExterCond        int64
# ExterQual        int64
# Exterior1st      int64
# Exterior2nd      int64
# Foundation       int64
# Functional       int64
# GarageCond       int64
# GarageFinish     int64
# GarageQual       int64
# GarageType       int64
# Heating          int64
# HeatingQC        int64
# HouseStyle       int64
# KitchenQual      int64
# LandContour      int64
# LandSlope        int64
# LotConfig        int64
# LotShape         int64
# MSZoning         int64
# MasVnrType       int64
# Neighborhood     int64
# PavedDrive       int64
# RoofMatl         int64
# RoofStyle        int64
# SaleCondition    int64
# SaleType         int64
# Street           int64
# Utilities        int64
# dtype: object

# %%
for item in cat_col:
    print(df_miss[item].value_counts())
    print()
# Out:
# 4    1138
# 3     112
# 1      38
# 2      28
# 0      22
# Name: BldgType, dtype: int64
#
# 2    1237
# 3      62
# 1      38
# 0       1
# Name: BsmtCond, dtype: int64
#
# 0    887
# 2    213
# 3    127
# 1    111
# Name: BsmtExposure, dtype: int64
#
# 5    402
# 4    392
# 3    209
# 1    141
# 0    125
# 2     69
# Name: BsmtFinType1, dtype: int64
#
# 3    1176
# 1      53
# 2      46
# 0      32
# 5      19
# 4      12
# Name: BsmtFinType2, dtype: int64
#
# 1    594
# 2    592
# 3    120
# 0     32
# Name: BsmtQual, dtype: int64
#
# 1    1277
# 0      61
# Name: CentralAir, dtype: int64
#
# 4    1162
# 2      63
# 0      43
# 3      26
# 7      19
# 1      10
# 8       8
# 6       5
# 5       2
# Name: Condition1, dtype: int64
#
# 4    1324
# 2       5
# 6       2
# 1       2
# 0       2
# 7       1
# 5       1
# 3       1
# Name: Condition2, dtype: int64
#
# 4    1242
# 3      76
# 2      17
# 1       2
# 0       1
# Name: Electrical, dtype: int64
#
# 2    1183
# 1     137
# 0      16
# 3       2
# Name: ExterCond, dtype: int64
#
# 1    803
# 2    477
# 3     51
# 0      7
# Name: ExterQual, dtype: int64
#
# 10    486
# 6     211
# 3     201
# 4     183
# 8     100
# 11     52
# 9      44
# 7      21
# 5      20
# 2      15
# 12      2
# 13      1
# 1       1
# 0       1
# Name: Exterior1st, dtype: int64
#
# 12    475
# 8     197
# 3     197
# 4     176
# 9     127
# 14     51
# 7      32
# 5      23
# 10     22
# 1      16
# 13     10
# 2       6
# 11      2
# 6       2
# 15      1
# 0       1
# Name: Exterior2nd, dtype: int64
#
# 4    620
# 1    580
# 0    129
# 2      6
# 3      3
# Name: Foundation, dtype: int64
#
# 6    1254
# 2      30
# 3      28
# 5      11
# 4      10
# 0       4
# 1       1
# Name: Functional, dtype: int64
#
# 4    1287
# 1      33
# 3       9
# 0       7
# 2       2
# Name: GarageCond, dtype: int64
#
# 0    580
# 1    413
# 2    345
# Name: GarageFinish, dtype: int64
#
# 2    1270
# 1      48
# 4      14
# 3       3
# 0       3
# Name: GarageQual, dtype: int64
#
# 4    852
# 1    369
# 5     85
# 3     19
# 0      7
# 2      6
# Name: GarageType, dtype: int64
#
# 3    1318
# 2      16
# 0       3
# 1       1
# Name: Heating, dtype: int64
#
# 4    704
# 2    380
# 3    217
# 1     36
# 0      1
# Name: HeatingQC, dtype: int64
#
# 5    657
# 6    426
# 2    134
# 4     64
# 1     30
# 0     11
# 3     10
# 7      6
# Name: HouseStyle, dtype: int64
#
# 1    650
# 2    568
# 3     97
# 0     23
# Name: KitchenQual, dtype: int64
#
# 1    1206
# 0      52
# 3      48
# 2      32
# Name: LandContour, dtype: int64
#
# 0    1265
# 1      61
# 2      12
# Name: LandSlope, dtype: int64
#
# 0    957
# 1    244
# 4     90
# 2     43
# 3      4
# Name: LotConfig, dtype: int64
#
# 0    829
# 1    459
# 3     40
# 2     10
# Name: LotShape, dtype: int64
#
# 3    1066
# 2     191
# 4      62
# 1      11
# 0       8
# Name: MSZoning, dtype: int64
#
# 1    763
# 2    432
# 3    128
# 0     15
# Name: MasVnrType, dtype: int64
#
# 10    209
# 15    146
# 3     100
# 19     83
# 14     77
# 23     75
# 13     73
# 5      70
# 8      69
# 12     53
# 17     50
# 4      47
# 11     42
# 24     41
# 21     37
# 0      29
# 18     26
# 22     25
# 7      20
# 16     17
# 2      15
# 1      12
# 20     11
# 9       9
# 6       2
# Name: Neighborhood, dtype: int64
#
# 2    1257
# 0      54
# 1      27
# Name: PavedDrive, dtype: int64
#
# 2    1314
# 4       9
# 7       6
# 5       5
# 6       1
# 3       1
# 1       1
# 0       1
# Name: RoofMatl, dtype: int64
#
# 1    1037
# 3     272
# 4      11
# 0      10
# 2       6
# 5       2
# Name: RoofStyle, dtype: int64
#
# 4    1104
# 5     120
# 1      86
# 2      20
# 3       7
# 0       1
# Name: SaleCondition, dtype: int64
#
# 4    1158
# 7     117
# 1      42
# 2       6
# 6       4
# 5       4
# 3       4
# 8       2
# 0       1
# Name: SaleType, dtype: int64
#
# 1    1333
# 0       5
# Name: Street, dtype: int64
#
# 1    1337
# 0       1
# Name: Utilities, dtype: int64

# %%
df_miss.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0       856       854          0             3         4         2
# 1      1262         0          0             3         4         2
# 2       920       866          0             3         4         2
# 3       961       756          0             3         4         3
# 4      1145      1053          0             4         4         2
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0             0         706           0             5             3
# 1             3         978           0             3             3
# 2             1         486           0             5             3
# 3             0         216           0             3             3
# 4             2         655           0             5             3
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0             1             0         2        150           1           4
# 1             0             1         2        284           1           2
# 2             1             0         2        434           1           4
# 3             1             0         1        540           1           4
# 4             1             0         2        490           1           4
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0           4           4              0          2          2           10
# 1           4           4              0          2          1            3
# 2           4           4              0          2          2           10
# 3           4           4            272          2          1            4
# 4           4           4              0          2          2           10
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0           12            0           0           4         2           6
# 1            3            3           1           1         2           6
# 2           12            3           1           4         2           6
# 3            7            4           1           0         1           6
# 4           12            3           1           4         2           6
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0         548           2           4             1           2           4
# 1         460           2           4             1           2           4
# 2         608           2           4             1           2           4
# 3         642           3           4             0           2           1
# 4         836           3           4             1           2           4
#
#    GarageYrBlt  GrLivArea  HalfBath  Heating  HeatingQC  HouseStyle  \
# 0       2003.0       1710         1        3          4           6
# 1       1976.0       1262         0        3          4           5
# 2       2001.0       1786         1        3          4           6
# 3       1998.0       1717         0        3          3           6
# 4       2000.0       2198         1        3          4           6
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope  LotArea  LotConfig  \
# 0             1            2            1          0     8450          0
# 1             1            1            1          0     9600          2
# 2             1            2            1          0    11250          0
# 3             1            2            1          0     9550          1
# 4             1            2            1          0    14260          2
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0         65.0         0             0          60         3       196.0
# 1         80.0         0             0          20         3         0.0
# 2         68.0         1             0          60         3       162.0
# 3         60.0         1             0          70         3         0.0
# 4         84.0         1             0          60         3       350.0
#
#    MasVnrType  MiscVal  MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0           2        0       2            15           61            5
# 1           1        0       5            20            0            8
# 2           2        0       9            15           42            5
# 3           1        0       2            17           35            5
# 4           2        0      12            24           84            5
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0            7           2         0         2          1              4
# 1            6           2         0         2          1              4
# 2            7           2         0         2          1              4
# 3            7           2         0         2          1              1
# 4            8           2         0         2          1              4
#
#    SalePrice  SaleType  ScreenPorch  Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0  12.247694         4            0       1             8          856
# 1  12.109011         4            0       1             6         1262
# 2  12.317167         4            0       1             6          920
# 3  11.849398         4            0       1             7          756
# 4  12.429216         4            0       1             9         1145
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          1           0       2003          2003    2008
# 1          1         298       1976          1976    2007
# 2          1           0       2001          2002    2008
# 3          1           0       1915          1970    2006
# 4          1         192       2000          2000    2008

# %% [markdown]
# ## Start working on Outliers

# %%
df_miss.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0       856       854          0             3         4         2
# 1      1262         0          0             3         4         2
# 2       920       866          0             3         4         2
# 3       961       756          0             3         4         3
# 4      1145      1053          0             4         4         2
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0             0         706           0             5             3
# 1             3         978           0             3             3
# 2             1         486           0             5             3
# 3             0         216           0             3             3
# 4             2         655           0             5             3
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0             1             0         2        150           1           4
# 1             0             1         2        284           1           2
# 2             1             0         2        434           1           4
# 3             1             0         1        540           1           4
# 4             1             0         2        490           1           4
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0           4           4              0          2          2           10
# 1           4           4              0          2          1            3
# 2           4           4              0          2          2           10
# 3           4           4            272          2          1            4
# 4           4           4              0          2          2           10
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0           12            0           0           4         2           6
# 1            3            3           1           1         2           6
# 2           12            3           1           4         2           6
# 3            7            4           1           0         1           6
# 4           12            3           1           4         2           6
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0         548           2           4             1           2           4
# 1         460           2           4             1           2           4
# 2         608           2           4             1           2           4
# 3         642           3           4             0           2           1
# 4         836           3           4             1           2           4
#
#    GarageYrBlt  GrLivArea  HalfBath  Heating  HeatingQC  HouseStyle  \
# 0       2003.0       1710         1        3          4           6
# 1       1976.0       1262         0        3          4           5
# 2       2001.0       1786         1        3          4           6
# 3       1998.0       1717         0        3          3           6
# 4       2000.0       2198         1        3          4           6
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope  LotArea  LotConfig  \
# 0             1            2            1          0     8450          0
# 1             1            1            1          0     9600          2
# 2             1            2            1          0    11250          0
# 3             1            2            1          0     9550          1
# 4             1            2            1          0    14260          2
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0         65.0         0             0          60         3       196.0
# 1         80.0         0             0          20         3         0.0
# 2         68.0         1             0          60         3       162.0
# 3         60.0         1             0          70         3         0.0
# 4         84.0         1             0          60         3       350.0
#
#    MasVnrType  MiscVal  MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0           2        0       2            15           61            5
# 1           1        0       5            20            0            8
# 2           2        0       9            15           42            5
# 3           1        0       2            17           35            5
# 4           2        0      12            24           84            5
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0            7           2         0         2          1              4
# 1            6           2         0         2          1              4
# 2            7           2         0         2          1              4
# 3            7           2         0         2          1              1
# 4            8           2         0         2          1              4
#
#    SalePrice  SaleType  ScreenPorch  Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0  12.247694         4            0       1             8          856
# 1  12.109011         4            0       1             6         1262
# 2  12.317167         4            0       1             6          920
# 3  11.849398         4            0       1             7          756
# 4  12.429216         4            0       1             9         1145
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          1           0       2003          2003    2008
# 1          1         298       1976          1976    2007
# 2          1           0       2001          2002    2008
# 3          1           0       1915          1970    2006
# 4          1         192       2000          2000    2008

# %%
df_miss.dtypes
# Out:
# 1stFlrSF           int64
# 2ndFlrSF           int64
# 3SsnPorch          int64
# BedroomAbvGr       int64
# BldgType           int64
# BsmtCond           int64
# BsmtExposure       int64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtFinType1       int64
# BsmtFinType2       int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# BsmtQual           int64
# BsmtUnfSF          int64
# CentralAir         int64
# Condition1         int64
# Condition2         int64
# Electrical         int64
# EnclosedPorch      int64
# ExterCond          int64
# ExterQual          int64
# Exterior1st        int64
# Exterior2nd        int64
# FireplaceQu        int32
# Fireplaces         int64
# Foundation         int64
# FullBath           int64
# Functional         int64
# GarageArea         int64
#                   ...
# LotConfig          int64
# LotFrontage      float64
# LotShape           int64
# LowQualFinSF       int64
# MSSubClass         int64
# MSZoning           int64
# MasVnrArea       float64
# MasVnrType         int64
# MiscVal            int64
# MoSold             int64
# Neighborhood       int64
# OpenPorchSF        int64
# OverallCond        int64
# OverallQual        int64
# PavedDrive         int64
# PoolArea           int64
# RoofMatl           int64
# RoofStyle          int64
# SaleCondition      int64
# SalePrice        float64
# SaleType           int64
# ScreenPorch        int64
# Street             int64
# TotRmsAbvGrd       int64
# TotalBsmtSF        int64
# Utilities          int64
# WoodDeckSF         int64
# YearBuilt          int64
# YearRemodAdd       int64
# YrSold             int64
# Length: 76, dtype: object

# %% [markdown]
# ### Select continuous variables

# %%
df_miss.select_dtypes(exclude=['object']).head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0       856       854          0             3         4         2
# 1      1262         0          0             3         4         2
# 2       920       866          0             3         4         2
# 3       961       756          0             3         4         3
# 4      1145      1053          0             4         4         2
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0             0         706           0             5             3
# 1             3         978           0             3             3
# 2             1         486           0             5             3
# 3             0         216           0             3             3
# 4             2         655           0             5             3
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0             1             0         2        150           1           4
# 1             0             1         2        284           1           2
# 2             1             0         2        434           1           4
# 3             1             0         1        540           1           4
# 4             1             0         2        490           1           4
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0           4           4              0          2          2           10
# 1           4           4              0          2          1            3
# 2           4           4              0          2          2           10
# 3           4           4            272          2          1            4
# 4           4           4              0          2          2           10
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0           12            0           0           4         2           6
# 1            3            3           1           1         2           6
# 2           12            3           1           4         2           6
# 3            7            4           1           0         1           6
# 4           12            3           1           4         2           6
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0         548           2           4             1           2           4
# 1         460           2           4             1           2           4
# 2         608           2           4             1           2           4
# 3         642           3           4             0           2           1
# 4         836           3           4             1           2           4
#
#    GarageYrBlt  GrLivArea  HalfBath  Heating  HeatingQC  HouseStyle  \
# 0       2003.0       1710         1        3          4           6
# 1       1976.0       1262         0        3          4           5
# 2       2001.0       1786         1        3          4           6
# 3       1998.0       1717         0        3          3           6
# 4       2000.0       2198         1        3          4           6
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope  LotArea  LotConfig  \
# 0             1            2            1          0     8450          0
# 1             1            1            1          0     9600          2
# 2             1            2            1          0    11250          0
# 3             1            2            1          0     9550          1
# 4             1            2            1          0    14260          2
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0         65.0         0             0          60         3       196.0
# 1         80.0         0             0          20         3         0.0
# 2         68.0         1             0          60         3       162.0
# 3         60.0         1             0          70         3         0.0
# 4         84.0         1             0          60         3       350.0
#
#    MasVnrType  MiscVal  MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0           2        0       2            15           61            5
# 1           1        0       5            20            0            8
# 2           2        0       9            15           42            5
# 3           1        0       2            17           35            5
# 4           2        0      12            24           84            5
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0            7           2         0         2          1              4
# 1            6           2         0         2          1              4
# 2            7           2         0         2          1              4
# 3            7           2         0         2          1              1
# 4            8           2         0         2          1              4
#
#    SalePrice  SaleType  ScreenPorch  Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0  12.247694         4            0       1             8          856
# 1  12.109011         4            0       1             6         1262
# 2  12.317167         4            0       1             6          920
# 3  11.849398         4            0       1             7          756
# 4  12.429216         4            0       1             9         1145
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          1           0       2003          2003    2008
# 1          1         298       1976          1976    2007
# 2          1           0       2001          2002    2008
# 3          1           0       1915          1970    2006
# 4          1         192       2000          2000    2008

# %% [markdown]
# ### Pair Plot

# %%
out_col=df_miss.columns
out_col
# Out:
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'BedroomAbvGr', 'BldgType',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtFinType1',
#        'BsmtFinType2', 'BsmtFullBath', 'BsmtHalfBath', 'BsmtQual', 'BsmtUnfSF',
#        'CentralAir', 'Condition1', 'Condition2', 'Electrical', 'EnclosedPorch',
#        'ExterCond', 'ExterQual', 'Exterior1st', 'Exterior2nd', 'FireplaceQu',
#        'Fireplaces', 'Foundation', 'FullBath', 'Functional', 'GarageArea',
#        'GarageCars', 'GarageCond', 'GarageFinish', 'GarageQual', 'GarageType',
#        'GarageYrBlt', 'GrLivArea', 'HalfBath', 'Heating', 'HeatingQC',
#        'HouseStyle', 'KitchenAbvGr', 'KitchenQual', 'LandContour', 'LandSlope',
#        'LotArea', 'LotConfig', 'LotFrontage', 'LotShape', 'LowQualFinSF',
#        'MSSubClass', 'MSZoning', 'MasVnrArea', 'MasVnrType', 'MiscVal',
#        'MoSold', 'Neighborhood', 'OpenPorchSF', 'OverallCond', 'OverallQual',
#        'PavedDrive', 'PoolArea', 'RoofMatl', 'RoofStyle', 'SaleCondition',
#        'SalePrice', 'SaleType', 'ScreenPorch', 'Street', 'TotRmsAbvGrd',
#        'TotalBsmtSF', 'Utilities', 'WoodDeckSF', 'YearBuilt', 'YearRemodAdd',
#        'YrSold'],
#       dtype='object')

# %%
for item in out_col:
    plt.scatter(x=df_miss[item],y=df_miss['SalePrice'])
    plt.xlabel(item)
    plt.ylabel('Sale Price')
    plt.show()

# %% [markdown]
# ### Remove Outliers

# %%
df_out=pd.DataFrame()
df_out=df_miss

# %%
df_out=df_out.drop(df_out[df_out['1stFlrSF']>3000].index)

# %%
df_out=df_out.drop(df_out[df_out['BsmtFinSF1']>5000].index)

# %%
df_out=df_out.drop(df_out[df_out['EnclosedPorch']>500].index)

# %%
df_out=df_out.drop(df_out[(df_out['GarageArea']>12000)&(df_out['SalePrice']<13.0)].index)

# %%
df_out=df_out.drop(df_out[(df_out['GrLivArea']>4000)&(df_out['SalePrice']<13.0)].index)

# %%
df_out=df_out.drop(df_out[df_out['TotalBsmtSF']>4000].index)

# %% [markdown]
# ## Standardize all the continuous variables

# %%
scaler=StandardScaler()
array_out=scaler.fit_transform(df_out)

# %%
values=array_out
col=df_out.columns
df_out=pd.DataFrame(data=values,columns=col)

# %%
df_out.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0 -0.857498  1.137583  -0.118868      0.176715  0.354768 -0.059168
# 1  0.249690 -0.810582  -0.118868      0.176715  0.354768 -0.059168
# 2 -0.682966  1.164958  -0.118868      0.176715  0.354768 -0.059168
# 3 -0.571156  0.914024  -0.118868      0.176715  0.354768  3.528565
# 4 -0.069377  1.591547  -0.118868      1.464899  0.354768 -0.059168
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0     -0.652487    0.572407   -0.295972      1.009172      0.219484
# 1      2.210728    1.200213   -0.295972     -0.211350      0.219484
# 2      0.301918    0.064622   -0.295972      1.009172      0.219484
# 3     -0.652487   -0.558568   -0.295972     -0.211350      0.219484
# 4      1.256323    0.454693   -0.295972      1.009172      0.219484
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0      1.097278     -0.249285  0.592091  -0.984269    0.218902    0.189757
# 1     -0.849223      3.907547  0.592091  -0.678718    0.218902   -1.835333
# 2      1.097278     -0.249285  0.592091  -0.336683    0.218902    0.189757
# 3      1.097278     -0.249285 -0.873307  -0.094978    0.218902    0.189757
# 4      1.097278     -0.249285  0.592091  -0.208990    0.218902    0.189757
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0    0.056514    0.254085      -0.352673   0.337504   1.004891     0.993532
# 1    0.056514    0.254085      -0.352673   0.337504  -0.740584    -1.428818
# 2    0.056514    0.254085      -0.352673   0.337504   1.004891     0.993532
# 3    0.056514    0.254085       4.282453   0.337504  -0.740584    -1.082768
# 4    0.056514    0.254085      -0.352673   0.337504   1.004891     0.993532
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0     0.968493    -1.068822   -1.005438    1.059385  0.783799    0.240971
# 1    -1.429966     0.593605    0.550541   -0.807484  0.783799    0.240971
# 2     0.968493     0.593605    0.550541    1.059385  0.783799    0.240971
# 3    -0.363984     1.147747    0.550541   -1.429774 -1.050565    0.240971
# 4     0.968493     0.593605    0.550541    1.059385  0.783799    0.240971
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0    0.258534    0.204483    0.189002      0.217787    0.057823    0.570844
# 1   -0.217654    0.204483    0.189002      0.217787    0.057823    0.570844
# 2    0.583208    0.204483    0.189002      0.217787    0.057823    0.570844
# 3    0.767189    1.781248    0.189002     -1.013262    0.057823   -1.546411
# 4    1.816967    1.781248    0.189002      0.217787    0.057823    0.570844
#
#    GarageYrBlt  GrLivArea  HalfBath   Heating  HeatingQC  HouseStyle  \
# 0     0.987603   0.362371  1.185465  0.108462   0.864026    0.858761
# 1    -0.104720  -0.538072 -0.798738  0.108462   0.864026    0.124410
# 2     0.906690   0.515125  1.185465  0.108462   0.864026    0.858761
# 3     0.785321   0.376441 -0.798738  0.108462  -0.195359    0.858761
# 4     0.866234   1.343211  1.185465  0.108462   0.864026    0.858761
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope   LotArea  LotConfig  \
# 0     -0.171454     0.691510    -0.130103  -0.228662 -0.213799  -0.491151
# 1     -0.171454    -0.843389    -0.130103  -0.228662 -0.101113   1.380837
# 2     -0.171454     0.691510    -0.130103  -0.228662  0.060568  -0.491151
# 3     -0.171454     0.691510    -0.130103  -0.228662 -0.106012   0.444843
# 4     -0.171454     0.691510    -0.130103  -0.228662  0.355514   1.380837
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0     0.216800 -0.672037     -0.100147    0.093423   0.25757    0.470115
# 1     0.654291 -0.672037     -0.100147   -0.875486   0.25757   -0.595403
# 2     0.304298  0.834681     -0.100147    0.093423   0.25757    0.285280
# 3     0.070969  0.834681     -0.100147    0.335650   0.25757   -0.595403
# 4     0.770955  0.834681     -0.100147    0.093423   0.25757    1.307307
#
#    MasVnrType   MiscVal    MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0    0.733890 -0.084663 -1.609204      0.422273     0.212402    -0.555574
# 1   -0.738304 -0.084663 -0.495974      1.213219    -0.735706     2.227162
# 2    0.733890 -0.084663  0.988332      0.422273    -0.082910    -0.555574
# 3   -0.738304 -0.084663 -1.609204      0.738651    -0.191710    -0.555574
# 4    0.733890 -0.084663  2.101562      1.845975     0.569886    -0.555574
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0     0.599233    0.244072 -0.060838 -0.114577  -0.504142       0.166171
# 1    -0.160631    0.244072 -0.060838 -0.114577  -0.504142       0.166171
# 2     0.599233    0.244072 -0.060838 -0.114577  -0.504142       0.166171
# 3     0.599233    0.244072 -0.060838 -0.114577  -0.504142      -3.371158
# 4     1.359096    0.244072 -0.060838 -0.114577  -0.504142       0.166171
#
#    SalePrice  SaleType  ScreenPorch    Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0   0.491827 -0.156228    -0.283661  0.061337      0.929555    -0.623629
# 1   0.123329 -0.156228    -0.283661  0.061337     -0.342919     0.463584
# 2   0.676423 -0.156228    -0.283661  0.061337     -0.342919    -0.452246
# 3  -0.566493 -0.156228    -0.283661  0.061337      0.293318    -0.891415
# 4   0.974151 -0.156228    -0.283661  0.061337      1.565792     0.150274
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd    YrSold
# 0    0.02739   -0.777804   1.015982      0.855850  0.144192
# 1    0.02739    1.559482   0.101461     -0.474233 -0.607185
# 2    0.02739   -0.777804   0.948240      0.806588  0.144192
# 3    0.02739   -0.777804  -1.964679     -0.769807 -1.358561
# 4    0.02739    0.728098   0.914369      0.708063  0.144192

# %%
df_out['SalePrice'].isnull().sum()
# Out:
# 0

# %%
df_out.describe().T
# Out:
#                 count          mean       std        min       25%       50%  \
# 1stFlrSF       1334.0  2.303671e-16  1.000375  -1.997410 -0.753869 -0.198912
# 2ndFlrSF       1334.0  2.929524e-17  1.000375  -0.810582 -0.810582 -0.810582
# 3SsnPorch      1334.0  1.065281e-17  1.000375  -0.118868 -0.118868 -0.118868
# BedroomAbvGr   1334.0 -3.728485e-17  1.000375  -3.687838 -1.111469  0.176715
# BldgType       1334.0 -1.318286e-16  1.000375  -4.761565  0.354768  0.354768
# BsmtCond       1334.0 -1.627883e-16  1.000375  -7.234634 -0.059168 -0.059168
# BsmtExposure   1334.0 -3.994805e-18  1.000375  -0.652487 -0.652487 -0.652487
# BsmtFinSF1     1334.0  4.793767e-17  1.000375  -1.057121 -1.057121 -0.110795
# BsmtFinSF2     1334.0 -3.595325e-17  1.000375  -0.295972 -0.295972 -0.295972
# BsmtFinType1   1334.0  2.663204e-17  1.000375  -2.042131 -0.821610  0.398911
# BsmtFinType2   1334.0  6.125368e-17  1.000375  -4.239273  0.219484  0.219484
# BsmtFullBath   1334.0 -2.929524e-17  1.000375  -0.849223 -0.849223 -0.849223
# BsmtHalfBath   1334.0  3.994805e-18  1.000375  -0.249285 -0.249285 -0.249285
# BsmtQual       1334.0 -7.456970e-17  1.000375  -2.338706 -0.873307  0.592091
# BsmtUnfSF      1334.0  1.464762e-17  1.000375  -1.326304 -0.760806 -0.211270
# CentralAir     1334.0 -2.609940e-16  1.000375  -4.568244  0.218902  0.218902
# Condition1     1334.0 -6.658009e-18  1.000375  -3.860424  0.189757  0.189757
# Condition2     1334.0 -1.731082e-16  1.000375 -15.815092  0.056514  0.056514
# Electrical     1334.0 -2.822996e-16  1.000375 -11.044207  0.254085  0.254085
# EnclosedPorch  1334.0  4.660606e-18  1.000375  -0.352673 -0.352673 -0.352673
# ExterCond      1334.0 -7.723291e-17  1.000375  -5.086963  0.337504  0.337504
# ExterQual      1334.0 -1.331602e-16  1.000375  -2.486059 -0.740584 -0.740584
# Exterior1st    1334.0  6.524849e-17  1.000375  -2.466968 -1.082768  0.301432
# Exterior2nd    1334.0 -1.331602e-16  1.000375  -2.229453 -1.163471  0.169007
# FireplaceQu    1334.0  2.663204e-17  1.000375  -1.068822 -1.068822  0.593605
# Fireplaces     1334.0  1.278338e-16  1.000375  -1.005438 -1.005438  0.550541
# Foundation     1334.0 -6.857749e-17  1.000375  -1.429774 -0.807484 -0.807484
# FullBath       1334.0  7.989611e-18  1.000375  -2.884929 -1.050565  0.783799
# Functional     1334.0 -4.860347e-16  1.000375  -7.064820  0.240971  0.240971
# GarageArea     1334.0  7.590130e-17  1.000375  -1.841022 -0.674902 -0.087784
# ...               ...           ...       ...        ...       ...       ...
# LotConfig      1334.0 -1.065281e-17  1.000375  -0.491151 -0.491151 -0.491151
# LotFrontage    1334.0  7.989611e-17  1.000375  -1.678994 -0.483186  0.187634
# LotShape       1334.0  4.527446e-17  1.000375  -0.672037 -0.672037 -0.672037
# LowQualFinSF   1334.0 -1.331602e-17  1.000375  -0.100147 -0.100147 -0.100147
# MSSubClass     1334.0 -2.530043e-17  1.000375  -0.875486 -0.875486 -0.148804
# MSZoning       1334.0  7.456970e-17  1.000375  -5.632688  0.257570  0.257570
# MasVnrArea     1334.0 -4.793767e-17  1.000375  -0.595403 -0.595403 -0.595403
# MasVnrType     1334.0 -8.655412e-18  1.000375  -2.210498 -0.738304 -0.738304
# MiscVal        1334.0  5.326407e-18  1.000375  -0.084663 -0.084663 -0.084663
# MoSold         1334.0 -6.658009e-17  1.000375  -1.980281 -0.495974 -0.124898
# Neighborhood   1334.0  1.071939e-16  1.000375  -1.950565 -0.685052 -0.052295
# OpenPorchSF    1334.0 -4.660606e-18  1.000375  -0.735706 -0.735706 -0.300509
# OverallCond    1334.0 -2.197143e-16  1.000375  -3.338309 -0.555574 -0.555574
# OverallQual    1334.0 -1.438130e-16  1.000375  -3.200085 -0.920494 -0.160631
# PavedDrive     1334.0 -1.970771e-16  1.000375  -4.579512  0.244072  0.244072
# PoolArea       1334.0 -1.065281e-17  1.000375  -0.060838 -0.060838 -0.060838
# RoofMatl       1334.0 -3.142580e-16  1.000375  -4.746270 -0.114577 -0.114577
# RoofStyle      1334.0 -7.989611e-17  1.000375  -1.673752 -0.504142 -0.504142
# SaleCondition  1334.0 -1.837611e-16  1.000375  -4.550268  0.166171  0.166171
# SalePrice      1334.0  1.424814e-15  1.000375  -4.226529 -0.663126 -0.074147
# SaleType       1334.0 -1.091913e-16  1.000375  -3.962760 -0.156228 -0.156228
# ScreenPorch    1334.0 -2.929524e-17  1.000375  -0.283661 -0.283661 -0.283661
# Street         1334.0 -6.717931e-16  1.000375 -16.303374  0.061337  0.061337
# TotRmsAbvGrd   1334.0  7.989611e-18  1.000375  -2.251631 -0.979157 -0.342919
# TotalBsmtSF    1334.0  9.853854e-17  1.000375  -2.634705 -0.724718 -0.185798
# Utilities      1334.0 -2.956156e-16  1.000375 -36.510273  0.027390  0.027390
# WoodDeckSF     1334.0 -4.261126e-17  1.000375  -0.777804 -0.777804 -0.777804
# YearBuilt      1334.0 -2.722460e-15  1.000375  -3.150169 -0.575962  0.101461
# YearRemodAdd   1334.0  2.721794e-15  1.000375  -1.755054 -0.868332  0.437120
# YrSold         1334.0  6.246411e-14  1.000375  -1.358561 -0.607185  0.144192
#
#                     75%        max
# 1stFlrSF       0.662840   4.711164
# 2ndFlrSF       0.875243   3.900146
# 3SsnPorch     -0.118868  16.670109
# BedroomAbvGr   0.176715   4.041268
# BldgType       0.354768   0.354768
# BsmtCond      -0.059168   3.528565
# BsmtExposure   1.256323   2.210728
# BsmtFinSF1     0.632418   3.993029
# BsmtFinSF2    -0.295972   8.566139
# BsmtFinType1   1.009172   1.009172
# BsmtFinType2   0.219484   3.191989
# BsmtFullBath   1.097278   3.043780
# BsmtHalfBath  -0.249285   8.064380
# BsmtQual       0.592091   2.057490
# BsmtUnfSF      0.531516   4.000320
# CentralAir     0.218902   0.218902
# Condition1     0.189757   4.239939
# Condition2     0.056514  11.960219
# Electrical     0.254085   0.254085
# EnclosedPorch -0.352673   6.225116
# ExterCond      0.337504   3.049738
# ExterQual      1.004891   2.750367
# Exterior1st    0.993532   2.031681
# Exterior2nd    0.968493   1.767980
# FireplaceQu    1.147747   1.701890
# Fireplaces     0.550541   3.662501
# Foundation     1.059385   1.059385
# FullBath       0.783799   2.618162
# Functional     0.240971   0.240971
# GarageArea     0.446574   4.814787
# ...                 ...        ...
# LotConfig      0.444843   3.252825
# LotFrontage    0.654291   7.449983
# LotShape       0.834681   3.848116
# LowQualFinSF  -0.100147  14.436043
# MSSubClass     0.335650   3.242374
# MSZoning       0.257570   2.220989
# MasVnrArea     0.350516   8.102698
# MasVnrType     0.733890   2.206083
# MiscVal       -0.084663  30.389849
# MoSold         0.617256   2.101562
# Neighborhood   0.738651   1.845975
# OpenPorchSF    0.352287   7.766186
# OverallCond    0.372005   3.154740
# OverallQual    0.599233   2.878823
# PavedDrive     0.244072   0.244072
# PoolArea      -0.060838  19.667265
# RoofMatl      -0.114577  11.464656
# RoofStyle     -0.504142   4.174298
# SaleCondition  0.166171   1.345281
# SalePrice      0.634483   3.910945
# SaleType      -0.156228   3.650305
# ScreenPorch   -0.283661   7.976558
# Street         0.061337   0.061337
# TotRmsAbvGrd   0.293318   3.474504
# TotalBsmtSF    0.612205   5.369430
# Utilities      0.027390   0.027390
# WoodDeckSF     0.571234   5.943853
# YearBuilt      0.948240   1.253080
# YearRemodAdd   0.905112   1.200686
# YrSold         0.895569   1.646946
#
# [76 rows x 8 columns]

# %%
plt.hist(df_out['SalePrice'])
# Out:
# (array([  2.,   6.,  32., 148., 437., 382., 215.,  89.,  17.,   6.]),
#  array([-4.22652916, -3.41278178, -2.59903441, -1.78528703, -0.97153965,
#         -0.15779227,  0.65595511,  1.46970249,  2.28344987,  3.09719725,
#          3.91094463]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### 1. Filter Method - Correlation Coefficient

# %%
corr=df_out.corr()
corr.sort_values(["SalePrice"],ascending=False,inplace=True)
dc=corr.SalePrice

# %%
dc
# Out:
# SalePrice        1.000000
# OverallQual      0.812396
# Neighborhood     0.732535
# GrLivArea        0.732456
# ExterQual        0.678217
# BsmtQual         0.667651
# KitchenQual      0.664899
# GarageCars       0.661892
# TotalBsmtSF      0.633325
# 1stFlrSF         0.625085
# GarageArea       0.620534
# FullBath         0.612114
# YearBuilt        0.575427
# YearRemodAdd     0.567062
# TotRmsAbvGrd     0.553759
# GarageFinish     0.552925
# GarageYrBlt      0.539944
# Foundation       0.535184
# FireplaceQu      0.526645
# GarageType       0.506498
# Fireplaces       0.473538
# HeatingQC        0.465105
# MasVnrArea       0.430245
# Exterior1st      0.429596
# MasVnrType       0.422561
# Exterior2nd      0.420977
# MSZoning         0.401005
# BsmtFinType1     0.377190
# BsmtFinSF1       0.360892
# OpenPorchSF      0.352263
#                    ...
# BedroomAbvGr     0.196663
# LotFrontage      0.192947
# BsmtUnfSF        0.190535
# BsmtCond         0.186507
# GarageQual       0.179698
# LandContour      0.168679
# BldgType         0.164668
# LotConfig        0.144922
# RoofMatl         0.138005
# ExterCond        0.137844
# Functional       0.133447
# Condition2       0.119059
# BsmtFinType2     0.109501
# ScreenPorch      0.105955
# Heating          0.074185
# PoolArea         0.072483
# Street           0.064900
# LandSlope        0.061331
# 3SsnPorch        0.053471
# MoSold           0.052689
# Utilities        0.016827
# MiscVal         -0.011053
# BsmtFinSF2      -0.020525
# YrSold          -0.026316
# BsmtHalfBath    -0.027004
# LowQualFinSF    -0.030351
# MSSubClass      -0.071797
# OverallCond     -0.079686
# KitchenAbvGr    -0.122224
# EnclosedPorch   -0.172352
# Name: SalePrice, Length: 76, dtype: float64

# %%
dc.index
# Out:
# Index(['SalePrice', 'OverallQual', 'Neighborhood', 'GrLivArea', 'ExterQual',
#        'BsmtQual', 'KitchenQual', 'GarageCars', 'TotalBsmtSF', '1stFlrSF',
#        'GarageArea', 'FullBath', 'YearBuilt', 'YearRemodAdd', 'TotRmsAbvGrd',
#        'GarageFinish', 'GarageYrBlt', 'Foundation', 'FireplaceQu',
#        'GarageType', 'Fireplaces', 'HeatingQC', 'MasVnrArea', 'Exterior1st',
#        'MasVnrType', 'Exterior2nd', 'MSZoning', 'BsmtFinType1', 'BsmtFinSF1',
#        'OpenPorchSF', 'BsmtExposure', 'SaleType', 'WoodDeckSF', '2ndFlrSF',
#        'HouseStyle', 'HalfBath', 'LotShape', 'CentralAir', 'Electrical',
#        'SaleCondition', 'LotArea', 'PavedDrive', 'BsmtFullBath', 'GarageCond',
#        'RoofStyle', 'Condition1', 'BedroomAbvGr', 'LotFrontage', 'BsmtUnfSF',
#        'BsmtCond', 'GarageQual', 'LandContour', 'BldgType', 'LotConfig',
#        'RoofMatl', 'ExterCond', 'Functional', 'Condition2', 'BsmtFinType2',
#        'ScreenPorch', 'Heating', 'PoolArea', 'Street', 'LandSlope',
#        '3SsnPorch', 'MoSold', 'Utilities', 'MiscVal', 'BsmtFinSF2', 'YrSold',
#        'BsmtHalfBath', 'LowQualFinSF', 'MSSubClass', 'OverallCond',
#        'KitchenAbvGr', 'EnclosedPorch'],
#       dtype='object')

# %%
dc.values
# Out:
# array([ 1.        ,  0.81239602,  0.73253451,  0.73245563,  0.6782173 ,
#         0.66765064,  0.664899  ,  0.66189193,  0.63332454,  0.62508526,
#         0.62053445,  0.61211411,  0.57542715,  0.56706237,  0.55375914,
#         0.5529246 ,  0.53994421,  0.53518418,  0.52664509,  0.50649841,
#         0.47353801,  0.46510496,  0.43024495,  0.42959557,  0.42256107,
#         0.42097655,  0.40100498,  0.37719035,  0.36089189,  0.35226341,
#         0.34571313,  0.34532435,  0.31695824,  0.31115748,  0.2939231 ,
#         0.28952057,  0.28339772,  0.27899265,  0.2671788 ,  0.26502857,
#         0.2534835 ,  0.22420559,  0.21511318,  0.21236543,  0.21083403,
#         0.20233882,  0.19666329,  0.1929472 ,  0.19053514,  0.18650742,
#         0.17969783,  0.16867916,  0.16466761,  0.14492247,  0.13800527,
#         0.13784369,  0.13344684,  0.11905878,  0.10950138,  0.1059548 ,
#         0.07418511,  0.07248265,  0.06489977,  0.06133107,  0.05347113,
#         0.05268903,  0.01682732, -0.0110527 , -0.0205252 , -0.02631597,
#        -0.02700372, -0.03035063, -0.07179704, -0.07968595, -0.12222413,
#        -0.17235198])

# %%
dc.index.values
# Out:
# array(['SalePrice', 'OverallQual', 'Neighborhood', 'GrLivArea',
#        'ExterQual', 'BsmtQual', 'KitchenQual', 'GarageCars',
#        'TotalBsmtSF', '1stFlrSF', 'GarageArea', 'FullBath', 'YearBuilt',
#        'YearRemodAdd', 'TotRmsAbvGrd', 'GarageFinish', 'GarageYrBlt',
#        'Foundation', 'FireplaceQu', 'GarageType', 'Fireplaces',
#        'HeatingQC', 'MasVnrArea', 'Exterior1st', 'MasVnrType',
#        'Exterior2nd', 'MSZoning', 'BsmtFinType1', 'BsmtFinSF1',
#        'OpenPorchSF', 'BsmtExposure', 'SaleType', 'WoodDeckSF',
#        '2ndFlrSF', 'HouseStyle', 'HalfBath', 'LotShape', 'CentralAir',
#        'Electrical', 'SaleCondition', 'LotArea', 'PavedDrive',
#        'BsmtFullBath', 'GarageCond', 'RoofStyle', 'Condition1',
#        'BedroomAbvGr', 'LotFrontage', 'BsmtUnfSF', 'BsmtCond',
#        'GarageQual', 'LandContour', 'BldgType', 'LotConfig', 'RoofMatl',
#        'ExterCond', 'Functional', 'Condition2', 'BsmtFinType2',
#        'ScreenPorch', 'Heating', 'PoolArea', 'Street', 'LandSlope',
#        '3SsnPorch', 'MoSold', 'Utilities', 'MiscVal', 'BsmtFinSF2',
#        'YrSold', 'BsmtHalfBath', 'LowQualFinSF', 'MSSubClass',
#        'OverallCond', 'KitchenAbvGr', 'EnclosedPorch'], dtype=object)

# %%
dc_new=dc[(dc.values>0.5)&(dc.values<1)]
dc_new
# Out:
# OverallQual     0.812396
# Neighborhood    0.732535
# GrLivArea       0.732456
# ExterQual       0.678217
# BsmtQual        0.667651
# KitchenQual     0.664899
# GarageCars      0.661892
# TotalBsmtSF     0.633325
# 1stFlrSF        0.625085
# GarageArea      0.620534
# FullBath        0.612114
# YearBuilt       0.575427
# YearRemodAdd    0.567062
# TotRmsAbvGrd    0.553759
# GarageFinish    0.552925
# GarageYrBlt     0.539944
# Foundation      0.535184
# FireplaceQu     0.526645
# GarageType      0.506498
# Name: SalePrice, dtype: float64

# %%
feature_col=dc_new.index.values
feature_col
# Out:
# array(['OverallQual', 'Neighborhood', 'GrLivArea', 'ExterQual',
#        'BsmtQual', 'KitchenQual', 'GarageCars', 'TotalBsmtSF', '1stFlrSF',
#        'GarageArea', 'FullBath', 'YearBuilt', 'YearRemodAdd',
#        'TotRmsAbvGrd', 'GarageFinish', 'GarageYrBlt', 'Foundation',
#        'FireplaceQu', 'GarageType'], dtype=object)

# %% [markdown]
# ### Select the features to be used in the data analysis

# %%
X=df_out[sorted(feature_col)]
y=df_out['SalePrice']

# %%
X.head()
# Out:
#    1stFlrSF  BsmtQual  ExterQual  FireplaceQu  Foundation  FullBath  \
# 0 -0.857498  0.592091   1.004891    -1.068822    1.059385  0.783799
# 1  0.249690  0.592091  -0.740584     0.593605   -0.807484  0.783799
# 2 -0.682966  0.592091   1.004891     0.593605    1.059385  0.783799
# 3 -0.571156 -0.873307  -0.740584     1.147747   -1.429774 -1.050565
# 4 -0.069377  0.592091   1.004891     0.593605    1.059385  0.783799
#
#    GarageArea  GarageCars  GarageFinish  GarageType  GarageYrBlt  GrLivArea  \
# 0    0.258534    0.204483      0.217787    0.570844     0.987603   0.362371
# 1   -0.217654    0.204483      0.217787    0.570844    -0.104720  -0.538072
# 2    0.583208    0.204483      0.217787    0.570844     0.906690   0.515125
# 3    0.767189    1.781248     -1.013262   -1.546411     0.785321   0.376441
# 4    1.816967    1.781248      0.217787    0.570844     0.866234   1.343211
#
#    KitchenQual  Neighborhood  OverallQual  TotRmsAbvGrd  TotalBsmtSF  \
# 0     0.691510      0.422273     0.599233      0.929555    -0.623629
# 1    -0.843389      1.213219    -0.160631     -0.342919     0.463584
# 2     0.691510      0.422273     0.599233     -0.342919    -0.452246
# 3     0.691510      0.738651     0.599233      0.293318    -0.891415
# 4     0.691510      1.845975     1.359096      1.565792     0.150274
#
#    YearBuilt  YearRemodAdd
# 0   1.015982      0.855850
# 1   0.101461     -0.474233
# 2   0.948240      0.806588
# 3  -1.964679     -0.769807
# 4   0.914369      0.708063

# %%
y.head()
# Out:
# 0    0.491827
# 1    0.123329
# 2    0.676423
# 3   -0.566493
# 4    0.974151
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Specify testing size

# %%
TS=0.2

# %% [markdown]
# ### Create a Result dataframe

# %%
result_col=['Algorithm','Correlation','Recursive','XGBoost']
result=pd.DataFrame(columns=result_col)
result['Algorithm']=['Ridge Regression','LASSO Regression','Elastic Net',
                     'Decision Tree','Random Forest','XGBoost']

# %%
result
# Out:
#           Algorithm Correlation Recursive XGBoost
# 0  Ridge Regression         NaN       NaN     NaN
# 1  LASSO Regression         NaN       NaN     NaN
# 2       Elastic Net         NaN       NaN     NaN
# 3     Decision Tree         NaN       NaN     NaN
# 4     Random Forest         NaN       NaN     NaN
# 5           XGBoost         NaN       NaN     NaN

# %% [markdown]
# ### Split the data to train and test dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=TS, random_state=200)

# %% [markdown]
# ### Ridge Regression

# %%
print(plt.rcParams["figure.figsize"])
plt.rcParams["figure.figsize"] = (8,4)
# Out:
# [6.0, 4.0]

# %%
from sklearn.linear_model import Ridge
RR=Ridge(alpha=0.001,fit_intercept=True)
RR_fit=RR.fit(x_train,y_train)

# %%
y_pred=RR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3632091597313182

# %%
y_pred=RR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][0]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][0]
# Out:
# 0.3141310962992652

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso
LR=Lasso(alpha=0.001,fit_intercept=True)
LR_fit=LR.fit(x_train,y_train)
y_pred=LR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3632613553961779

# %%
y_pred=LR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][1]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][1]
# Out:
# 0.3130718293290203

# %% [markdown]
# ### Elastic Net Model

# %%
from sklearn.linear_model import ElasticNetCV
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)
EN_fit=EN.fit(x_train, y_train)

# %%
y_pred=EN_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.36423747065967166

# %%
y_pred=EN_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][2]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][2]
# Out:
# 0.31084026913122703

# %% [markdown]
# ### Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
DT=DecisionTreeRegressor()
DT_fit=DT.fit(x_train,y_train)

# %%
y_pred=DT_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.014217272908740265

# %%
y_pred=DT_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][3]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][3]
# Out:
# 0.535401671388594

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)
RF_fit=RF.fit(x_train, y_train)

# %%
y_pred=RF_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.1471343746065449

# %%
y_pred=RF_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][4]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][4]
# Out:
# 0.3209429730969017

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=3000, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)
XG_fit=XG.fit(x_train, y_train)

# %%
y_pred=XG_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.12109639048912166

# %%
y_pred=XG_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][5]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][5]
# Out:
# 0.317223105082094

# %% [markdown]
# ### Wrapper Method - Recursive Feature Elimination Method

# %%
from sklearn.feature_selection import RFECV

# %% [markdown]
# ### Split the data to train and test dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=TS, random_state=200)

# %% [markdown]
# ### Ridge Regression

# %%
RR=Ridge(alpha=0.001,fit_intercept=True)
RM_RR=RFECV(RR, step=1, cv=20, scoring='neg_mean_squared_error')
RM_RR_fit=RM_RR.fit(x_train,y_train)
RM_RR_fit.n_features_
# Out:
# 14

# %%
y_pred=RM_RR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3632788677433318

# %%
y_pred=RM_RR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][0]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][0]
# Out:
# 0.31339189112079324

# %% [markdown]
# ### Lasso Regression

# %%
LR=Lasso(alpha=0.001,fit_intercept=True)
RM_LR=RFECV(LR, step=1, cv=20, scoring='neg_mean_squared_error')
RM_LR_fit=RM_LR.fit(x_train,y_train)
RM_LR_fit.n_features_
# Out:
# 14

# %%
y_pred=RM_LR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3633134875064921

# %%
y_pred=RM_LR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][1]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][1]
# Out:
# 0.3126856557562005

# %% [markdown]
# ### Elastic Net Model

# %%
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)
RM_EN=RFECV(EN, step=1, cv=20, scoring='neg_mean_squared_error')
RM_EN_fit=RM_EN.fit(x_train,y_train)
RM_EN_fit.n_features_
# Out:
# 14

# %%
y_pred=RM_EN_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3633387578670674

# %%
y_pred=RM_EN_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][2]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][2]
# Out:
# 0.3126294380258631

# %% [markdown]
# ### Decision Tree Model

# %%
DT=DecisionTreeRegressor()
RM_DT=RFECV(DT, step=1, cv=20, scoring='neg_mean_squared_error')
RM_DT_fit=RM_DT.fit(x_train,y_train)
RM_DT_fit.n_features_
# Out:
# 15

# %%
y_pred=RM_DT_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.014465731091714751

# %%
y_pred=RM_DT_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][3]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][3]
# Out:
# 0.5344669634259877

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)
RM_RF=RFECV(RF, step=1, cv=10, scoring='neg_mean_squared_error')
RM_RF_fit=RM_RF.fit(x_train,y_train)
RM_RF_fit.n_features_
# Out:
# 18

# %%
y_pred=RM_RF_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.14686028343011148

# %%
y_pred=RM_RF_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][4]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][4]
# Out:
# 0.31995393149251694

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=300, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)
RM_XG=RFECV(XG, step=1, cv=5, scoring='neg_mean_squared_error')
RM_XG_fit=RM_XG.fit(x_train,y_train)
RM_XG_fit.n_features_

# %%
y_pred=RM_XG_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=RM_XG_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][5]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][5]

# %% [markdown]
# ## Embedded Method - XGBoost Feature Importance

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
df_out_X=df_out.drop(columns=['SalePrice'])
df_out_y=df_out['SalePrice']
model.fit(df_out_X, df_out_y)
print(model.feature_importances_)

# %%
len(model.feature_importances_)

# %%
df_out_X.shape

# %%
df_out_X_col=df_out_X.columns.values

# %%
plt.rcParams["figure.figsize"] = (10,20)
plt.barh(df_out_X_col, model.feature_importances_)
plt.show()

# %%
df_XG=pd.DataFrame()

# %%
df_XG['Feature']=df_out_X_col
df_XG['Feature_Importance']=model.feature_importances_

# %%
df_XG.head()

# %%
df_XG=df_XG.sort_values(by=['Feature_Importance'],ascending=False)

# %%
df_XG

# %%
feature_col_XG=df_XG['Feature'][:12].values

# %%
feature_col_XG

# %% [markdown]
# ### Using the new selected features in the 6 models again.

# %%
X=df_out[feature_col_XG]
y=df_out['SalePrice']

# %%
feature_col_XG

# %% [markdown]
# ### Split the data to train and test dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=TS, random_state=200)

# %% [markdown]
# ### Ridge Regression

# %%
plt.rcParams["figure.figsize"] = (8,4)

# %%
from sklearn.linear_model import Ridge
RR=Ridge(alpha=0.0001,fit_intercept=True)
RR_fit=RR.fit(x_train,y_train)
y_pred=RR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=RR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][0]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][0]

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso
LR=Lasso(alpha=0.0001,fit_intercept=True)
LR_fit=LR.fit(x_train,y_train)
y_pred=LR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=LR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][1]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][1]

# %% [markdown]
# ### Elastic Net Model

# %%
from sklearn.linear_model import ElasticNetCV
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)
EN_fit=EN.fit(x_train, y_train)

# %%
y_pred=EN_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=EN_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][2]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][2]

# %% [markdown]
# ### Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
DT=DecisionTreeRegressor()
DT_fit=DT.fit(x_train,y_train)

# %%
y_pred=DT_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=DT_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][3]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][3]

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)
RF_fit=RF.fit(x_train, y_train)

# %%
y_pred=RF_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=RF_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][4]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][4]

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=3000, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)
XG_fit=XG.fit(x_train, y_train)

# %%
y_pred=XG_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=XG_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][5]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][5]

# %% [markdown]
# ## Examine the result

# %%
print('test-size: ',TS)

# %%
result
