# %% [markdown]
# ## 1. Data Exploration/Cleaning
# - Checking null values
# - Remove outliers
#
# ## 2. Features Selection
# - Filter Method - Correlation Matrix
# - Wrapper Method - Recursive Method
# - Embedded Method - XGBoost Feature Importance
#
#
# ## 3.	Models
# - Ridge Regression
# - LASSO Regression
# - Elastic Net Regression
# - Decision Tree
# - Random Forest
# - XGBoost
#
# ## 4.	Models Evaluation
# - RMSE (Root Mean Squred Error)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from scipy import stats
from scipy.stats import norm


from sklearn.preprocessing import StandardScaler
from sklearn import ensemble, tree, linear_model
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split, cross_val_score



import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('train.csv')

# %%
from IPython.display import display
pd.options.display.max_columns=None
df=df.reindex_axis(sorted(df.columns),axis=1)
df.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0       856       854          0   NaN             3     1Fam       TA
# 1      1262         0          0   NaN             3     1Fam       TA
# 2       920       866          0   NaN             3     1Fam       TA
# 3       961       756          0   NaN             3     1Fam       Gd
# 4      1145      1053          0   NaN             4     1Fam       TA
#
#   BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# 0           No         706           0          GLQ          Unf
# 1           Gd         978           0          ALQ          Unf
# 2           Mn         486           0          GLQ          Unf
# 3           No         216           0          ALQ          Unf
# 4           Av         655           0          GLQ          Unf
#
#    BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF CentralAir Condition1  \
# 0             1             0       Gd        150          Y       Norm
# 1             0             1       Gd        284          Y      Feedr
# 2             1             0       Gd        434          Y       Norm
# 3             1             0       TA        540          Y       Norm
# 4             1             0       Gd        490          Y       Norm
#
#   Condition2 Electrical  EnclosedPorch ExterCond ExterQual Exterior1st  \
# 0       Norm      SBrkr              0        TA        Gd     VinylSd
# 1       Norm      SBrkr              0        TA        TA     MetalSd
# 2       Norm      SBrkr              0        TA        Gd     VinylSd
# 3       Norm      SBrkr            272        TA        TA     Wd Sdng
# 4       Norm      SBrkr              0        TA        Gd     VinylSd
#
#   Exterior2nd Fence FireplaceQu  Fireplaces Foundation  FullBath Functional  \
# 0     VinylSd   NaN         NaN           0      PConc         2        Typ
# 1     MetalSd   NaN          TA           1     CBlock         2        Typ
# 2     VinylSd   NaN          TA           1      PConc         2        Typ
# 3     Wd Shng   NaN          Gd           1     BrkTil         1        Typ
# 4     VinylSd   NaN          TA           1      PConc         2        Typ
#
#    GarageArea  GarageCars GarageCond GarageFinish GarageQual GarageType  \
# 0         548           2         TA          RFn         TA     Attchd
# 1         460           2         TA          RFn         TA     Attchd
# 2         608           2         TA          RFn         TA     Attchd
# 3         642           3         TA          Unf         TA     Detchd
# 4         836           3         TA          RFn         TA     Attchd
#
#    GarageYrBlt  GrLivArea  HalfBath Heating HeatingQC HouseStyle  Id  \
# 0       2003.0       1710         1    GasA        Ex     2Story   1
# 1       1976.0       1262         0    GasA        Ex     1Story   2
# 2       2001.0       1786         1    GasA        Ex     2Story   3
# 3       1998.0       1717         0    GasA        Gd     2Story   4
# 4       2000.0       2198         1    GasA        Ex     2Story   5
#
#    KitchenAbvGr KitchenQual LandContour LandSlope  LotArea LotConfig  \
# 0             1          Gd         Lvl       Gtl     8450    Inside
# 1             1          TA         Lvl       Gtl     9600       FR2
# 2             1          Gd         Lvl       Gtl    11250    Inside
# 3             1          Gd         Lvl       Gtl     9550    Corner
# 4             1          Gd         Lvl       Gtl    14260       FR2
#
#    LotFrontage LotShape  LowQualFinSF  MSSubClass MSZoning  MasVnrArea  \
# 0         65.0      Reg             0          60       RL       196.0
# 1         80.0      Reg             0          20       RL         0.0
# 2         68.0      IR1             0          60       RL       162.0
# 3         60.0      IR1             0          70       RL         0.0
# 4         84.0      IR1             0          60       RL       350.0
#
#   MasVnrType MiscFeature  MiscVal  MoSold Neighborhood  OpenPorchSF  \
# 0    BrkFace         NaN        0       2      CollgCr           61
# 1       None         NaN        0       5      Veenker            0
# 2    BrkFace         NaN        0       9      CollgCr           42
# 3       None         NaN        0       2      Crawfor           35
# 4    BrkFace         NaN        0      12      NoRidge           84
#
#    OverallCond  OverallQual PavedDrive  PoolArea PoolQC RoofMatl RoofStyle  \
# 0            5            7          Y         0    NaN  CompShg     Gable
# 1            8            6          Y         0    NaN  CompShg     Gable
# 2            5            7          Y         0    NaN  CompShg     Gable
# 3            5            7          Y         0    NaN  CompShg     Gable
# 4            5            8          Y         0    NaN  CompShg     Gable
#
#   SaleCondition  SalePrice SaleType  ScreenPorch Street  TotRmsAbvGrd  \
# 0        Normal     208500       WD            0   Pave             8
# 1        Normal     181500       WD            0   Pave             6
# 2        Normal     223500       WD            0   Pave             6
# 3       Abnorml     140000       WD            0   Pave             7
# 4        Normal     250000       WD            0   Pave             9
#
#    TotalBsmtSF Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          856    AllPub           0       2003          2003    2008
# 1         1262    AllPub         298       1976          1976    2007
# 2          920    AllPub           0       2001          2002    2008
# 3          756    AllPub           0       1915          1970    2006
# 4         1145    AllPub         192       2000          2000    2008

# %%
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### Remove "Id" from dataset

# %%
df=df.drop(columns=['Id'])

# %%
df.shape
# Out:
# (1460, 80)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Checking NAs

# %%
null_cols=df.columns[df.isnull().any()]
df[null_cols].isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageType        81
# GarageQual        81
# GarageFinish      81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtFinType1      37
# BsmtCond          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %%
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
dg
# Out:
# PoolQC          99.520548
# MiscFeature     96.301370
# Alley           93.767123
# Fence           80.753425
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageType       5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtQual         2.534247
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# MasVnrArea       0.547945
# MasVnrType       0.547945
# Electrical       0.068493
# dtype: float64

# %%
featureName=dg.index.values
featureName
# Out:
# array(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu',
#        'LotFrontage', 'GarageYrBlt', 'GarageType', 'GarageQual',
#        'GarageFinish', 'GarageCond', 'BsmtFinType2', 'BsmtExposure',
#        'BsmtQual', 'BsmtFinType1', 'BsmtCond', 'MasVnrArea', 'MasVnrType',
#        'Electrical'], dtype=object)

# %%
def missingness(featureName):
    for i in featureName:
        print(i)
        print(df[i].value_counts(dropna=False))
        print("Value missing: %2.1f %%" % (df[i].isnull().sum()/len(df)*100))
        print()

# %% [markdown]
# ### Checking unique values of feature with more than 70% missning values

# %%
missingness(featureName)
# Out:
# PoolQC
# NaN    1453
# Gd        3
# Ex        2
# Fa        2
# Name: PoolQC, dtype: int64
# Value missing: 99.5 %
#
# MiscFeature
# NaN     1406
# Shed      49
# Othr       2
# Gar2       2
# TenC       1
# Name: MiscFeature, dtype: int64
# Value missing: 96.3 %
#
# Alley
# NaN     1369
# Grvl      50
# Pave      41
# Name: Alley, dtype: int64
# Value missing: 93.8 %
#
# Fence
# NaN      1179
# MnPrv     157
# GdPrv      59
# GdWo       54
# MnWw       11
# Name: Fence, dtype: int64
# Value missing: 80.8 %
#
# FireplaceQu
# NaN    690
# Gd     380
# TA     313
# Fa      33
# Ex      24
# Po      20
# Name: FireplaceQu, dtype: int64
# Value missing: 47.3 %
#
# LotFrontage
# NaN       259
#  60.0     143
#  70.0      70
#  80.0      69
#  50.0      57
#  75.0      53
#  65.0      44
#  85.0      40
#  78.0      25
#  21.0      23
#  90.0      23
#  68.0      19
#  24.0      19
#  64.0      19
#  73.0      18
#  72.0      17
#  79.0      17
#  63.0      17
#  55.0      17
#  100.0     16
#  51.0      15
#  66.0      15
#  74.0      15
#  52.0      14
#  59.0      13
#  71.0      12
#  67.0      12
#  57.0      12
#  82.0      12
#  43.0      12
#          ...
#  129.0      2
#  313.0      2
#  118.0      2
#  122.0      2
#  121.0      2
#  101.0      2
#  109.0      2
#  115.0      2
#  116.0      2
#  114.0      2
#  153.0      1
#  149.0      1
#  150.0      1
#  111.0      1
#  182.0      1
#  46.0       1
#  112.0      1
#  141.0      1
#  33.0       1
#  152.0      1
#  160.0      1
#  168.0      1
#  128.0      1
#  144.0      1
#  39.0       1
#  106.0      1
#  38.0       1
#  138.0      1
#  140.0      1
#  137.0      1
# Name: LotFrontage, Length: 111, dtype: int64
# Value missing: 17.7 %
#
# GarageYrBlt
# NaN        81
#  2005.0    65
#  2006.0    59
#  2004.0    53
#  2003.0    50
#  2007.0    49
#  1977.0    35
#  1998.0    31
#  1999.0    30
#  1976.0    29
#  2008.0    29
#  2000.0    27
#  2002.0    26
#  1968.0    26
#  1950.0    24
#  1993.0    22
#  1962.0    21
#  2009.0    21
#  1966.0    21
#  1965.0    21
#  1958.0    21
#  1970.0    20
#  1996.0    20
#  1957.0    20
#  2001.0    20
#  1997.0    19
#  1978.0    19
#  1960.0    19
#  1954.0    19
#  1974.0    18
#            ..
#  1916.0     5
#  1922.0     5
#  1936.0     5
#  1945.0     4
#  1946.0     4
#  1982.0     4
#  1931.0     4
#  1928.0     4
#  1935.0     4
#  1932.0     3
#  1952.0     3
#  1921.0     3
#  1938.0     3
#  2010.0     3
#  1910.0     3
#  1924.0     3
#  1923.0     3
#  1947.0     2
#  1918.0     2
#  1929.0     2
#  1914.0     2
#  1915.0     2
#  1934.0     2
#  1937.0     2
#  1942.0     2
#  1906.0     1
#  1927.0     1
#  1900.0     1
#  1908.0     1
#  1933.0     1
# Name: GarageYrBlt, Length: 98, dtype: int64
# Value missing: 5.5 %
#
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# NaN         81
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64
# Value missing: 5.5 %
#
# GarageQual
# TA     1311
# NaN      81
# Fa       48
# Gd       14
# Ex        3
# Po        3
# Name: GarageQual, dtype: int64
# Value missing: 5.5 %
#
# GarageFinish
# Unf    605
# RFn    422
# Fin    352
# NaN     81
# Name: GarageFinish, dtype: int64
# Value missing: 5.5 %
#
# GarageCond
# TA     1326
# NaN      81
# Fa       35
# Gd        9
# Po        7
# Ex        2
# Name: GarageCond, dtype: int64
# Value missing: 5.5 %
#
# BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      46
# NaN      38
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64
# Value missing: 2.6 %
#
# BsmtExposure
# No     953
# Av     221
# Gd     134
# Mn     114
# NaN     38
# Name: BsmtExposure, dtype: int64
# Value missing: 2.6 %
#
# BsmtQual
# TA     649
# Gd     618
# Ex     121
# NaN     37
# Fa      35
# Name: BsmtQual, dtype: int64
# Value missing: 2.5 %
#
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# NaN     37
# Name: BsmtFinType1, dtype: int64
# Value missing: 2.5 %
#
# BsmtCond
# TA     1311
# Gd       65
# Fa       45
# NaN      37
# Po        2
# Name: BsmtCond, dtype: int64
# Value missing: 2.5 %
#
# MasVnrArea
#  0.0       861
#  72.0        8
#  180.0       8
# NaN          8
#  108.0       8
#  120.0       7
#  16.0        7
#  106.0       6
#  80.0        6
#  340.0       6
#  200.0       6
#  132.0       5
#  170.0       5
#  360.0       5
#  84.0        5
#  320.0       5
#  270.0       4
#  183.0       4
#  100.0       4
#  168.0       4
#  252.0       4
#  178.0       4
#  246.0       4
#  196.0       4
#  288.0       4
#  216.0       4
#  160.0       4
#  220.0       4
#  336.0       4
#  210.0       4
#           ...
#  24.0        1
#  760.0       1
#  138.0       1
#  27.0        1
#  541.0       1
#  275.0       1
#  365.0       1
#  562.0       1
#  161.0       1
#  247.0       1
#  452.0       1
#  278.0       1
#  375.0       1
#  225.0       1
#  604.0       1
#  762.0       1
#  290.0       1
#  109.0       1
#  299.0       1
#  731.0       1
#  167.0       1
#  309.0       1
#  202.0       1
#  1129.0      1
#  651.0       1
#  337.0       1
#  415.0       1
#  293.0       1
#  259.0       1
#  621.0       1
# Name: MasVnrArea, Length: 328, dtype: int64
# Value missing: 0.5 %
#
# MasVnrType
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# NaN          8
# Name: MasVnrType, dtype: int64
# Value missing: 0.5 %
#
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# NaN         1
# Name: Electrical, dtype: int64
# Value missing: 0.1 %

# %% [markdown]
# ### Remove columns with more than 70% of missing values

# %%
df=df.drop(columns=['PoolQC','MiscFeature','Alley','Fence'])

# %%
df.shape
# Out:
# (1460, 76)

# %% [markdown]
# ### Checking the rest of features with missing values

# %%
null_cols=df.columns[df.isnull().any()]
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
print(dg)
nullCol=dg.index.values
nullCol
# Out:
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageType       5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtQual         2.534247
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# MasVnrType       0.547945
# MasVnrArea       0.547945
# Electrical       0.068493
# dtype: float64
# array(['FireplaceQu', 'LotFrontage', 'GarageYrBlt', 'GarageType',
#        'GarageQual', 'GarageFinish', 'GarageCond', 'BsmtFinType2',
#        'BsmtExposure', 'BsmtQual', 'BsmtFinType1', 'BsmtCond',
#        'MasVnrType', 'MasVnrArea', 'Electrical'], dtype=object)

# %% [markdown]
# ### It looks like "FireplaceQu" has "NaN" value when "Fireplaces" has "zero" value.
# ### Let's check if the number of missing value in "FireplaceQu" is the same as the number of rows with zero value in "Fireplaces"

# %%
df['FireplaceQu'].isnull().sum()
# Out:
# 690

# %%
len(df.loc[df['Fireplaces']==0])
# Out:
# 690

# %% [markdown]
# ### It turns out the number is the same.
# ### We can go ahead and replace the "NaN" in "FireplaceQu" with "0"

# %% [markdown]
# ### Also, we will change the datatype of "FireplaceQu" to a "Ordinal" Variable

# %% [markdown]
# ### First we will need to replace "NaN" with "0" value

# %%
df['FireplaceQu'].fillna(0,inplace=True)

# %%
df['FireplaceQu'].value_counts()
# Out:
# 0     690
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %% [markdown]
# ### Replace string values to ordinal value in "FireplaceQu"

# %%
#quality={'Po':1,'Fa':2,'TA':3,'Gd':4,"Ex":5}
df.FireplaceQu[df.FireplaceQu=='Po']=1
df.FireplaceQu[df.FireplaceQu=='Fa']=2
df.FireplaceQu[df.FireplaceQu=='TA']=3
df.FireplaceQu[df.FireplaceQu=='Gd']=4
df.FireplaceQu[df.FireplaceQu=='Ex']=5

# %%
df.FireplaceQu.dtypes
# Out:
# dtype('O')

# %% [markdown]
# ### Let's change the datatype of "FireplaceQu" to "int"

# %%
df=df.astype({"FireplaceQu":int})

# %%
df.FireplaceQu.dtypes
# Out:
# dtype('int32')

# %%
df['LotFrontage'].isnull().sum()
# Out:
# 259

# %% [markdown]
# ### Some Lot just does not have LotFronage.
# ### Change "NaN" value to "zero" in "LotFrontage"

# %%
df['LotFrontage'].fillna(0,inplace=True)

# %% [markdown]
# ### Check if the number of "0" value is the same as the number "NaN" value

# %%
df['LotFrontage'].value_counts()
# Out:
# 0.0      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 67.0      12
# 57.0      12
# 82.0      12
# 43.0      12
#         ...
# 129.0      2
# 313.0      2
# 118.0      2
# 122.0      2
# 121.0      2
# 101.0      2
# 109.0      2
# 115.0      2
# 116.0      2
# 114.0      2
# 153.0      1
# 149.0      1
# 150.0      1
# 111.0      1
# 182.0      1
# 46.0       1
# 112.0      1
# 141.0      1
# 33.0       1
# 152.0      1
# 160.0      1
# 168.0      1
# 128.0      1
# 144.0      1
# 39.0       1
# 106.0      1
# 38.0       1
# 138.0      1
# 140.0      1
# 137.0      1
# Name: LotFrontage, Length: 111, dtype: int64

# %% [markdown]
# ### Double check all the missing values again

# %%
null_cols=df.columns[df.isnull().any()]
df[null_cols].isnull().sum().sort_values(ascending=False)
dg=(df[null_cols].isnull().sum()/len(df)*100).sort_values(ascending=False)
dg
# Out:
# GarageYrBlt     5.547945
# GarageType      5.547945
# GarageQual      5.547945
# GarageFinish    5.547945
# GarageCond      5.547945
# BsmtFinType2    2.602740
# BsmtExposure    2.602740
# BsmtQual        2.534247
# BsmtFinType1    2.534247
# BsmtCond        2.534247
# MasVnrType      0.547945
# MasVnrArea      0.547945
# Electrical      0.068493
# dtype: float64

# %% [markdown]
# ### All the remaining variables have less than 6% of missing values.
# ### We will remove all the rows with any missing values.

# %%
df_miss=df.dropna()

# %%
df_miss.isnull().sum()
# Out:
# 1stFlrSF         0
# 2ndFlrSF         0
# 3SsnPorch        0
# BedroomAbvGr     0
# BldgType         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtFinType1     0
# BsmtFinType2     0
# BsmtFullBath     0
# BsmtHalfBath     0
# BsmtQual         0
# BsmtUnfSF        0
# CentralAir       0
# Condition1       0
# Condition2       0
# Electrical       0
# EnclosedPorch    0
# ExterCond        0
# ExterQual        0
# Exterior1st      0
# Exterior2nd      0
# FireplaceQu      0
# Fireplaces       0
# Foundation       0
# FullBath         0
# Functional       0
# GarageArea       0
#                 ..
# LotConfig        0
# LotFrontage      0
# LotShape         0
# LowQualFinSF     0
# MSSubClass       0
# MSZoning         0
# MasVnrArea       0
# MasVnrType       0
# MiscVal          0
# MoSold           0
# Neighborhood     0
# OpenPorchSF      0
# OverallCond      0
# OverallQual      0
# PavedDrive       0
# PoolArea         0
# RoofMatl         0
# RoofStyle        0
# SaleCondition    0
# SalePrice        0
# SaleType         0
# ScreenPorch      0
# Street           0
# TotRmsAbvGrd     0
# TotalBsmtSF      0
# Utilities        0
# WoodDeckSF       0
# YearBuilt        0
# YearRemodAdd     0
# YrSold           0
# Length: 76, dtype: int64

# %%
df_miss.shape
# Out:
# (1338, 76)

# %%
len(df)-len(df_miss)
# Out:
# 122

# %% [markdown]
# ### Checking the percentage of data removed

# %%
(len(df)-len(df_miss))/len(df)*100
# Out:
# 8.356164383561644

# %% [markdown]
# ## Convert all string categorical variables to ordinal categorical variables

# %%
cat_col=df_miss.select_dtypes(include=['object']).columns
cat_col
# Out:
# Index(['BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'BsmtQual', 'CentralAir', 'Condition1', 'Condition2', 'Electrical',
#        'ExterCond', 'ExterQual', 'Exterior1st', 'Exterior2nd', 'Foundation',
#        'Functional', 'GarageCond', 'GarageFinish', 'GarageQual', 'GarageType',
#        'Heating', 'HeatingQC', 'HouseStyle', 'KitchenQual', 'LandContour',
#        'LandSlope', 'LotConfig', 'LotShape', 'MSZoning', 'MasVnrType',
#        'Neighborhood', 'PavedDrive', 'RoofMatl', 'RoofStyle', 'SaleCondition',
#        'SaleType', 'Street', 'Utilities'],
#       dtype='object')

# %%
for item1 in cat_col:
    df_mean=pd.concat([df_miss[item1],df_miss['SalePrice']],axis=1)
    df_mean.head()

    g1=df_mean.groupby(item1).mean()
    g1

    df_g1=pd.DataFrame()
    df_g1=pd.DataFrame(g1)
    df_g1

    df_g2=df_g1.sort_values('SalePrice')
    df_g2

    df_g2.index

    g_col=df_g2.index.values

    df_miss[item1].value_counts()

    i=0
    for item2 in g_col:
        df_miss.loc[df_miss[item1]==item2,item1]=i
        i=i+1

# %%
df_miss[cat_col].dtypes
# Out:
# BldgType         int64
# BsmtCond         int64
# BsmtExposure     int64
# BsmtFinType1     int64
# BsmtFinType2     int64
# BsmtQual         int64
# CentralAir       int64
# Condition1       int64
# Condition2       int64
# Electrical       int64
# ExterCond        int64
# ExterQual        int64
# Exterior1st      int64
# Exterior2nd      int64
# Foundation       int64
# Functional       int64
# GarageCond       int64
# GarageFinish     int64
# GarageQual       int64
# GarageType       int64
# Heating          int64
# HeatingQC        int64
# HouseStyle       int64
# KitchenQual      int64
# LandContour      int64
# LandSlope        int64
# LotConfig        int64
# LotShape         int64
# MSZoning         int64
# MasVnrType       int64
# Neighborhood     int64
# PavedDrive       int64
# RoofMatl         int64
# RoofStyle        int64
# SaleCondition    int64
# SaleType         int64
# Street           int64
# Utilities        int64
# dtype: object

# %%
for item in cat_col:
    print(df_miss[item].value_counts())
    print()
# Out:
# 4    1138
# 3     112
# 1      38
# 2      28
# 0      22
# Name: BldgType, dtype: int64
#
# 2    1237
# 3      62
# 1      38
# 0       1
# Name: BsmtCond, dtype: int64
#
# 0    887
# 2    213
# 3    127
# 1    111
# Name: BsmtExposure, dtype: int64
#
# 5    402
# 4    392
# 3    209
# 1    141
# 0    125
# 2     69
# Name: BsmtFinType1, dtype: int64
#
# 3    1176
# 2      53
# 1      46
# 0      32
# 5      19
# 4      12
# Name: BsmtFinType2, dtype: int64
#
# 1    594
# 2    592
# 3    120
# 0     32
# Name: BsmtQual, dtype: int64
#
# 1    1277
# 0      61
# Name: CentralAir, dtype: int64
#
# 4    1162
# 2      63
# 0      43
# 3      26
# 7      19
# 1      10
# 8       8
# 6       5
# 5       2
# Name: Condition1, dtype: int64
#
# 4    1324
# 2       5
# 6       2
# 1       2
# 0       2
# 7       1
# 5       1
# 3       1
# Name: Condition2, dtype: int64
#
# 4    1242
# 3      76
# 2      17
# 1       2
# 0       1
# Name: Electrical, dtype: int64
#
# 2    1183
# 1     137
# 0      16
# 3       2
# Name: ExterCond, dtype: int64
#
# 1    803
# 2    477
# 3     51
# 0      7
# Name: ExterQual, dtype: int64
#
# 10    486
# 6     211
# 3     201
# 4     183
# 8     100
# 11     52
# 9      44
# 7      21
# 5      20
# 2      15
# 12      2
# 13      1
# 1       1
# 0       1
# Name: Exterior1st, dtype: int64
#
# 12    475
# 7     197
# 3     197
# 4     176
# 9     127
# 13     51
# 8      32
# 6      23
# 11     22
# 1      16
# 14     10
# 2       6
# 10      2
# 5       2
# 15      1
# 0       1
# Name: Exterior2nd, dtype: int64
#
# 4    620
# 1    580
# 0    129
# 2      6
# 3      3
# Name: Foundation, dtype: int64
#
# 5    1254
# 2      30
# 3      28
# 6      11
# 4      10
# 0       4
# 1       1
# Name: Functional, dtype: int64
#
# 4    1287
# 1      33
# 3       9
# 0       7
# 2       2
# Name: GarageCond, dtype: int64
#
# 0    580
# 1    413
# 2    345
# Name: GarageFinish, dtype: int64
#
# 2    1270
# 1      48
# 3      14
# 4       3
# 0       3
# Name: GarageQual, dtype: int64
#
# 4    852
# 1    369
# 5     85
# 3     19
# 0      7
# 2      6
# Name: GarageType, dtype: int64
#
# 3    1318
# 2      16
# 0       3
# 1       1
# Name: Heating, dtype: int64
#
# 4    704
# 2    380
# 3    217
# 1     36
# 0      1
# Name: HeatingQC, dtype: int64
#
# 5    657
# 6    426
# 2    134
# 4     64
# 1     30
# 0     11
# 3     10
# 7      6
# Name: HouseStyle, dtype: int64
#
# 1    650
# 2    568
# 3     97
# 0     23
# Name: KitchenQual, dtype: int64
#
# 1    1206
# 0      52
# 3      48
# 2      32
# Name: LandContour, dtype: int64
#
# 0    1265
# 1      61
# 2      12
# Name: LandSlope, dtype: int64
#
# 0    957
# 2    244
# 4     90
# 1     43
# 3      4
# Name: LotConfig, dtype: int64
#
# 0    829
# 1    459
# 3     40
# 2     10
# Name: LotShape, dtype: int64
#
# 3    1066
# 2     191
# 4      62
# 1      11
# 0       8
# Name: MSZoning, dtype: int64
#
# 1    763
# 2    432
# 3    128
# 0     15
# Name: MasVnrType, dtype: int64
#
# 10    209
# 16    146
# 3     100
# 19     83
# 14     77
# 23     75
# 12     73
# 5      70
# 7      69
# 13     53
# 17     50
# 4      47
# 11     42
# 24     41
# 21     37
# 2      29
# 18     26
# 22     25
# 8      20
# 15     17
# 1      15
# 0      12
# 20     11
# 9       9
# 6       2
# Name: Neighborhood, dtype: int64
#
# 2    1257
# 0      54
# 1      27
# Name: PavedDrive, dtype: int64
#
# 3    1314
# 4       9
# 7       6
# 5       5
# 6       1
# 2       1
# 1       1
# 0       1
# Name: RoofMatl, dtype: int64
#
# 1    1037
# 4     272
# 3      11
# 0      10
# 2       6
# 5       2
# Name: RoofStyle, dtype: int64
#
# 4    1104
# 5     120
# 2      86
# 1      20
# 3       7
# 0       1
# Name: SaleCondition, dtype: int64
#
# 4    1158
# 8     117
# 1      42
# 2       6
# 6       4
# 5       4
# 3       4
# 7       2
# 0       1
# Name: SaleType, dtype: int64
#
# 1    1333
# 0       5
# Name: Street, dtype: int64
#
# 1    1337
# 0       1
# Name: Utilities, dtype: int64

# %%
df_miss.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0       856       854          0             3         4         2
# 1      1262         0          0             3         4         2
# 2       920       866          0             3         4         2
# 3       961       756          0             3         4         3
# 4      1145      1053          0             4         4         2
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0             0         706           0             5             3
# 1             3         978           0             3             3
# 2             1         486           0             5             3
# 3             0         216           0             3             3
# 4             2         655           0             5             3
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0             1             0         2        150           1           4
# 1             0             1         2        284           1           2
# 2             1             0         2        434           1           4
# 3             1             0         1        540           1           4
# 4             1             0         2        490           1           4
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0           4           4              0          2          2           10
# 1           4           4              0          2          1            3
# 2           4           4              0          2          2           10
# 3           4           4            272          2          1            4
# 4           4           4              0          2          2           10
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0           12            0           0           4         2           5
# 1            3            3           1           1         2           5
# 2           12            3           1           4         2           5
# 3            8            4           1           0         1           5
# 4           12            3           1           4         2           5
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0         548           2           4             1           2           4
# 1         460           2           4             1           2           4
# 2         608           2           4             1           2           4
# 3         642           3           4             0           2           1
# 4         836           3           4             1           2           4
#
#    GarageYrBlt  GrLivArea  HalfBath  Heating  HeatingQC  HouseStyle  \
# 0       2003.0       1710         1        3          4           6
# 1       1976.0       1262         0        3          4           5
# 2       2001.0       1786         1        3          4           6
# 3       1998.0       1717         0        3          3           6
# 4       2000.0       2198         1        3          4           6
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope  LotArea  LotConfig  \
# 0             1            2            1          0     8450          0
# 1             1            1            1          0     9600          1
# 2             1            2            1          0    11250          0
# 3             1            2            1          0     9550          2
# 4             1            2            1          0    14260          1
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0         65.0         0             0          60         3       196.0
# 1         80.0         0             0          20         3         0.0
# 2         68.0         1             0          60         3       162.0
# 3         60.0         1             0          70         3         0.0
# 4         84.0         1             0          60         3       350.0
#
#    MasVnrType  MiscVal  MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0           2        0       2            16           61            5
# 1           1        0       5            20            0            8
# 2           2        0       9            16           42            5
# 3           1        0       2            17           35            5
# 4           2        0      12            24           84            5
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0            7           2         0         3          1              4
# 1            6           2         0         3          1              4
# 2            7           2         0         3          1              4
# 3            7           2         0         3          1              2
# 4            8           2         0         3          1              4
#
#    SalePrice  SaleType  ScreenPorch  Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0     208500         4            0       1             8          856
# 1     181500         4            0       1             6         1262
# 2     223500         4            0       1             6          920
# 3     140000         4            0       1             7          756
# 4     250000         4            0       1             9         1145
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          1           0       2003          2003    2008
# 1          1         298       1976          1976    2007
# 2          1           0       2001          2002    2008
# 3          1           0       1915          1970    2006
# 4          1         192       2000          2000    2008

# %% [markdown]
# ## Start working on Outliers

# %%
df_miss.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0       856       854          0             3         4         2
# 1      1262         0          0             3         4         2
# 2       920       866          0             3         4         2
# 3       961       756          0             3         4         3
# 4      1145      1053          0             4         4         2
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0             0         706           0             5             3
# 1             3         978           0             3             3
# 2             1         486           0             5             3
# 3             0         216           0             3             3
# 4             2         655           0             5             3
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0             1             0         2        150           1           4
# 1             0             1         2        284           1           2
# 2             1             0         2        434           1           4
# 3             1             0         1        540           1           4
# 4             1             0         2        490           1           4
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0           4           4              0          2          2           10
# 1           4           4              0          2          1            3
# 2           4           4              0          2          2           10
# 3           4           4            272          2          1            4
# 4           4           4              0          2          2           10
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0           12            0           0           4         2           5
# 1            3            3           1           1         2           5
# 2           12            3           1           4         2           5
# 3            8            4           1           0         1           5
# 4           12            3           1           4         2           5
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0         548           2           4             1           2           4
# 1         460           2           4             1           2           4
# 2         608           2           4             1           2           4
# 3         642           3           4             0           2           1
# 4         836           3           4             1           2           4
#
#    GarageYrBlt  GrLivArea  HalfBath  Heating  HeatingQC  HouseStyle  \
# 0       2003.0       1710         1        3          4           6
# 1       1976.0       1262         0        3          4           5
# 2       2001.0       1786         1        3          4           6
# 3       1998.0       1717         0        3          3           6
# 4       2000.0       2198         1        3          4           6
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope  LotArea  LotConfig  \
# 0             1            2            1          0     8450          0
# 1             1            1            1          0     9600          1
# 2             1            2            1          0    11250          0
# 3             1            2            1          0     9550          2
# 4             1            2            1          0    14260          1
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0         65.0         0             0          60         3       196.0
# 1         80.0         0             0          20         3         0.0
# 2         68.0         1             0          60         3       162.0
# 3         60.0         1             0          70         3         0.0
# 4         84.0         1             0          60         3       350.0
#
#    MasVnrType  MiscVal  MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0           2        0       2            16           61            5
# 1           1        0       5            20            0            8
# 2           2        0       9            16           42            5
# 3           1        0       2            17           35            5
# 4           2        0      12            24           84            5
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0            7           2         0         3          1              4
# 1            6           2         0         3          1              4
# 2            7           2         0         3          1              4
# 3            7           2         0         3          1              2
# 4            8           2         0         3          1              4
#
#    SalePrice  SaleType  ScreenPorch  Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0     208500         4            0       1             8          856
# 1     181500         4            0       1             6         1262
# 2     223500         4            0       1             6          920
# 3     140000         4            0       1             7          756
# 4     250000         4            0       1             9         1145
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          1           0       2003          2003    2008
# 1          1         298       1976          1976    2007
# 2          1           0       2001          2002    2008
# 3          1           0       1915          1970    2006
# 4          1         192       2000          2000    2008

# %%
df_miss.dtypes
# Out:
# 1stFlrSF           int64
# 2ndFlrSF           int64
# 3SsnPorch          int64
# BedroomAbvGr       int64
# BldgType           int64
# BsmtCond           int64
# BsmtExposure       int64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtFinType1       int64
# BsmtFinType2       int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# BsmtQual           int64
# BsmtUnfSF          int64
# CentralAir         int64
# Condition1         int64
# Condition2         int64
# Electrical         int64
# EnclosedPorch      int64
# ExterCond          int64
# ExterQual          int64
# Exterior1st        int64
# Exterior2nd        int64
# FireplaceQu        int32
# Fireplaces         int64
# Foundation         int64
# FullBath           int64
# Functional         int64
# GarageArea         int64
#                   ...
# LotConfig          int64
# LotFrontage      float64
# LotShape           int64
# LowQualFinSF       int64
# MSSubClass         int64
# MSZoning           int64
# MasVnrArea       float64
# MasVnrType         int64
# MiscVal            int64
# MoSold             int64
# Neighborhood       int64
# OpenPorchSF        int64
# OverallCond        int64
# OverallQual        int64
# PavedDrive         int64
# PoolArea           int64
# RoofMatl           int64
# RoofStyle          int64
# SaleCondition      int64
# SalePrice          int64
# SaleType           int64
# ScreenPorch        int64
# Street             int64
# TotRmsAbvGrd       int64
# TotalBsmtSF        int64
# Utilities          int64
# WoodDeckSF         int64
# YearBuilt          int64
# YearRemodAdd       int64
# YrSold             int64
# Length: 76, dtype: object

# %% [markdown]
# ### Separate data variables to continuous and categorical features

# %%
con_col=['1stFlrSF','2ndFlrSF','3SsnPorch','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF',
        'EnclosedPorch','GarageArea','GarageYrBlt','GrLivArea','LotArea','LotFrontage','LowQualFinSF',
        'MasVnrArea','MiscVal','OpenPorchSF','PoolArea','ScreenPorch','TotalBsmtSF','WoodDeckSF',
         'YearBuilt','YearRemodAdd']
con_col
# Out:
# ['1stFlrSF',
#  '2ndFlrSF',
#  '3SsnPorch',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'EnclosedPorch',
#  'GarageArea',
#  'GarageYrBlt',
#  'GrLivArea',
#  'LotArea',
#  'LotFrontage',
#  'LowQualFinSF',
#  'MasVnrArea',
#  'MiscVal',
#  'OpenPorchSF',
#  'PoolArea',
#  'ScreenPorch',
#  'TotalBsmtSF',
#  'WoodDeckSF',
#  'YearBuilt',
#  'YearRemodAdd']

# %%
for item in con_col:
    plt.scatter(x=df_miss[item],y=df_miss['SalePrice'])
    plt.xlabel(item)
    plt.ylabel('Sale Price')
    plt.show()

# %% [markdown]
# ### Remove Outliers - continuous variables

# %%
df_out=pd.DataFrame()
df_out=df_miss

# %%
df_out=df_out.drop(df_out[df_out['1stFlrSF']>3000].index)

# %%
df_out=df_out.drop(df_out[df_out['BsmtFinSF1']>5000].index)

# %%
df_out=df_out.drop(df_out[df_out['EnclosedPorch']>500].index)

# %%
df_out=df_out.drop(df_out[(df_out['GarageArea']>12000)&(df_out['SalePrice']<13.0)].index)

# %%
df_out=df_out.drop(df_out[(df_out['GrLivArea']>4000)&(df_out['SalePrice']<13.0)].index)

# %%
df_out=df_out.drop(df_out[df_out['TotalBsmtSF']>4000].index)

# %%
df_out.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0       856       854          0             3         4         2
# 1      1262         0          0             3         4         2
# 2       920       866          0             3         4         2
# 3       961       756          0             3         4         3
# 4      1145      1053          0             4         4         2
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0             0         706           0             5             3
# 1             3         978           0             3             3
# 2             1         486           0             5             3
# 3             0         216           0             3             3
# 4             2         655           0             5             3
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0             1             0         2        150           1           4
# 1             0             1         2        284           1           2
# 2             1             0         2        434           1           4
# 3             1             0         1        540           1           4
# 4             1             0         2        490           1           4
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0           4           4              0          2          2           10
# 1           4           4              0          2          1            3
# 2           4           4              0          2          2           10
# 3           4           4            272          2          1            4
# 4           4           4              0          2          2           10
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0           12            0           0           4         2           5
# 1            3            3           1           1         2           5
# 2           12            3           1           4         2           5
# 3            8            4           1           0         1           5
# 4           12            3           1           4         2           5
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0         548           2           4             1           2           4
# 1         460           2           4             1           2           4
# 2         608           2           4             1           2           4
# 3         642           3           4             0           2           1
# 4         836           3           4             1           2           4
#
#    GarageYrBlt  GrLivArea  HalfBath  Heating  HeatingQC  HouseStyle  \
# 0       2003.0       1710         1        3          4           6
# 1       1976.0       1262         0        3          4           5
# 2       2001.0       1786         1        3          4           6
# 3       1998.0       1717         0        3          3           6
# 4       2000.0       2198         1        3          4           6
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope  LotArea  LotConfig  \
# 0             1            2            1          0     8450          0
# 1             1            1            1          0     9600          1
# 2             1            2            1          0    11250          0
# 3             1            2            1          0     9550          2
# 4             1            2            1          0    14260          1
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0         65.0         0             0          60         3       196.0
# 1         80.0         0             0          20         3         0.0
# 2         68.0         1             0          60         3       162.0
# 3         60.0         1             0          70         3         0.0
# 4         84.0         1             0          60         3       350.0
#
#    MasVnrType  MiscVal  MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0           2        0       2            16           61            5
# 1           1        0       5            20            0            8
# 2           2        0       9            16           42            5
# 3           1        0       2            17           35            5
# 4           2        0      12            24           84            5
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0            7           2         0         3          1              4
# 1            6           2         0         3          1              4
# 2            7           2         0         3          1              4
# 3            7           2         0         3          1              2
# 4            8           2         0         3          1              4
#
#    SalePrice  SaleType  ScreenPorch  Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0     208500         4            0       1             8          856
# 1     181500         4            0       1             6         1262
# 2     223500         4            0       1             6          920
# 3     140000         4            0       1             7          756
# 4     250000         4            0       1             9         1145
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  YrSold
# 0          1           0       2003          2003    2008
# 1          1         298       1976          1976    2007
# 2          1           0       2001          2002    2008
# 3          1           0       1915          1970    2006
# 4          1         192       2000          2000    2008

# %% [markdown]
# ### Wrok on Categorical Variables

# %% [markdown]
# ### Create boxplot

# %%
df_cat=pd.DataFrame()
df_cat=df_out.drop(columns=con_col,axis=1)
cat_col=df_cat.columns

# %%
for item in cat_col:
    sns.boxplot(x=item,y="SalePrice",data=df_out)
    plt.show()

# %% [markdown]
# ### Remove outliers - categorical variable

# %% [markdown]
# ### Log(x+1) transformed the whole dataset

# %%
df_out=np.log1p(df_out)

# %%
df_out.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0  6.753438  6.751101        0.0      1.386294  1.609438  1.098612
# 1  7.141245  0.000000        0.0      1.386294  1.609438  1.098612
# 2  6.825460  6.765039        0.0      1.386294  1.609438  1.098612
# 3  6.869014  6.629363        0.0      1.386294  1.609438  1.386294
# 4  7.044033  6.960348        0.0      1.609438  1.609438  1.098612
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0      0.000000    6.561031         0.0      1.791759      1.386294
# 1      1.386294    6.886532         0.0      1.386294      1.386294
# 2      0.693147    6.188264         0.0      1.791759      1.386294
# 3      0.000000    5.379897         0.0      1.386294      1.386294
# 4      1.098612    6.486161         0.0      1.791759      1.386294
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0      0.693147      0.000000  1.098612   5.017280    0.693147    1.609438
# 1      0.000000      0.693147  1.098612   5.652489    0.693147    1.098612
# 2      0.693147      0.000000  1.098612   6.075346    0.693147    1.609438
# 3      0.693147      0.000000  0.693147   6.293419    0.693147    1.609438
# 4      0.693147      0.000000  1.098612   6.196444    0.693147    1.609438
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0    1.609438    1.609438       0.000000   1.098612   1.098612     2.397895
# 1    1.609438    1.609438       0.000000   1.098612   0.693147     1.386294
# 2    1.609438    1.609438       0.000000   1.098612   1.098612     2.397895
# 3    1.609438    1.609438       5.609472   1.098612   0.693147     1.609438
# 4    1.609438    1.609438       0.000000   1.098612   1.098612     2.397895
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0     2.564949     0.000000    0.000000    1.609438  1.098612    1.791759
# 1     1.386294     1.386294    0.693147    0.693147  1.098612    1.791759
# 2     2.564949     1.386294    0.693147    1.609438  1.098612    1.791759
# 3     2.197225     1.609438    0.693147    0.000000  0.693147    1.791759
# 4     2.564949     1.386294    0.693147    1.609438  1.098612    1.791759
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0    6.308098    1.098612    1.609438      0.693147    1.098612    1.609438
# 1    6.133398    1.098612    1.609438      0.693147    1.098612    1.609438
# 2    6.411818    1.098612    1.609438      0.693147    1.098612    1.609438
# 3    6.466145    1.386294    1.609438      0.000000    1.098612    0.693147
# 4    6.729824    1.386294    1.609438      0.693147    1.098612    1.609438
#
#    GarageYrBlt  GrLivArea  HalfBath   Heating  HeatingQC  HouseStyle  \
# 0     7.602900   7.444833  0.693147  1.386294   1.609438    1.945910
# 1     7.589336   7.141245  0.000000  1.386294   1.609438    1.791759
# 2     7.601902   7.488294  0.693147  1.386294   1.609438    1.945910
# 3     7.600402   7.448916  0.000000  1.386294   1.386294    1.945910
# 4     7.601402   7.695758  0.693147  1.386294   1.609438    1.945910
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope   LotArea  LotConfig  \
# 0      0.693147     1.098612     0.693147        0.0  9.042040   0.000000
# 1      0.693147     0.693147     0.693147        0.0  9.169623   0.693147
# 2      0.693147     1.098612     0.693147        0.0  9.328212   0.000000
# 3      0.693147     1.098612     0.693147        0.0  9.164401   1.098612
# 4      0.693147     1.098612     0.693147        0.0  9.565284   0.693147
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0     4.189655  0.000000           0.0    4.110874  1.386294    5.283204
# 1     4.394449  0.000000           0.0    3.044522  1.386294    0.000000
# 2     4.234107  0.693147           0.0    4.110874  1.386294    5.093750
# 3     4.110874  0.693147           0.0    4.262680  1.386294    0.000000
# 4     4.442651  0.693147           0.0    4.110874  1.386294    5.860786
#
#    MasVnrType  MiscVal    MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0    1.098612      0.0  1.098612      2.833213     4.127134     1.791759
# 1    0.693147      0.0  1.791759      3.044522     0.000000     2.197225
# 2    1.098612      0.0  2.302585      2.833213     3.761200     1.791759
# 3    0.693147      0.0  1.098612      2.890372     3.583519     1.791759
# 4    1.098612      0.0  2.564949      3.218876     4.442651     1.791759
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0     2.079442    1.098612       0.0  1.386294   0.693147       1.609438
# 1     1.945910    1.098612       0.0  1.386294   0.693147       1.609438
# 2     2.079442    1.098612       0.0  1.386294   0.693147       1.609438
# 3     2.079442    1.098612       0.0  1.386294   0.693147       1.098612
# 4     2.197225    1.098612       0.0  1.386294   0.693147       1.609438
#
#    SalePrice  SaleType  ScreenPorch    Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0  12.247699  1.609438          0.0  0.693147      2.197225     6.753438
# 1  12.109016  1.609438          0.0  0.693147      1.945910     7.141245
# 2  12.317171  1.609438          0.0  0.693147      1.945910     6.825460
# 3  11.849405  1.609438          0.0  0.693147      2.079442     6.629363
# 4  12.429220  1.609438          0.0  0.693147      2.302585     7.044033
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd    YrSold
# 0   0.693147    0.000000   7.602900      7.602900  7.605392
# 1   0.693147    5.700444   7.589336      7.589336  7.604894
# 2   0.693147    0.000000   7.601902      7.602401  7.605392
# 3   0.693147    0.000000   7.557995      7.586296  7.604396
# 4   0.693147    5.262690   7.601402      7.601402  7.605392

# %% [markdown]
# ## Standardize all the continuous variables

# %%
scaler=StandardScaler()
array_out=scaler.fit_transform(df_out)

# %%
values=array_out
col=df_out.columns
df_out=pd.DataFrame(data=values,columns=col)

# %%
df_out.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BldgType  BsmtCond  \
# 0 -0.859494  1.159487  -0.131643      0.258145  0.311308 -0.010265
# 1  0.397874 -0.884277  -0.131643      0.258145  0.311308 -0.010265
# 2 -0.625980  1.163706  -0.131643      0.258145  0.311308 -0.010265
# 3 -0.484766  1.122633  -0.131643      0.258145  0.311308  2.951701
# 4  0.082688  1.222832  -0.131643      1.257526  0.311308 -0.010265
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtFinType1  BsmtFinType2  \
# 0     -0.684757    0.740622   -0.366175      0.800687      0.236907
# 1      1.930387    0.851743   -0.366175      0.057723      0.236907
# 2      0.622815    0.613366   -0.366175      0.800687      0.236907
# 3     -0.684757    0.337403   -0.366175      0.057723      0.236907
# 4      1.387696    0.715063   -0.366175      0.800687      0.236907
#
#    BsmtFullBath  BsmtHalfBath  BsmtQual  BsmtUnfSF  CentralAir  Condition1  \
# 0      1.126396     -0.250335  0.654767  -0.487124    0.218902    0.233615
# 1     -0.858612      3.945767  0.654767  -0.093405    0.218902   -1.374042
# 2      1.126396     -0.250335  0.654767   0.168693    0.218902    0.233615
# 3      1.126396     -0.250335 -0.810812   0.303861    0.218902    0.233615
# 4      1.126396     -0.250335  0.654767   0.243753    0.218902    0.233615
#
#    Condition2  Electrical  EnclosedPorch  ExterCond  ExterQual  Exterior1st  \
# 0    0.064059    0.231275      -0.393022   0.320716   1.058599     0.929352
# 1    0.064059    0.231275      -0.393022   0.320716  -0.735317    -1.559481
# 2    0.064059    0.231275      -0.393022   0.320716   1.058599     0.929352
# 3    0.064059    0.231275       2.928174   0.320716  -0.735317    -1.010483
# 4    0.064059    0.231275      -0.393022   0.320716   1.058599     0.929352
#
#    Exterior2nd  FireplaceQu  Fireplaces  Foundation  FullBath  Functional  \
# 0     0.915461    -1.101349   -1.073695    1.005351  0.800741    0.194921
# 1    -1.509301     0.750987    0.690383   -0.649027  0.800741    0.194921
# 2     0.915461     0.750987    0.690383    1.005351  0.800741    0.194921
# 3     0.158967     1.049147    0.690383   -1.900515 -1.029856    0.194921
# 4     0.915461     0.750987    0.690383    1.005351  0.800741    0.194921
#
#    GarageArea  GarageCars  GarageCond  GarageFinish  GarageQual  GarageType  \
# 0    0.423168    0.305352    0.181116      0.426822    0.129447    0.594887
# 1   -0.039060    0.305352    0.181116      0.426822    0.129447    0.594887
# 2    0.697593    0.305352    0.181116      0.426822    0.129447    0.594887
# 3    0.841332    1.570686    0.181116     -1.078051    0.129447   -1.540957
# 4    1.538983    1.570686    0.181116      0.426822    0.129447    0.594887
#
#    GarageYrBlt  GrLivArea  HalfBath   Heating  HeatingQC  HouseStyle  \
# 0     0.983601   0.509113  1.209720  0.094507   0.821134    0.685500
# 1    -0.098086  -0.446823 -0.805636  0.094507   0.821134    0.215585
# 2     0.903977   0.645960  1.209720  0.094507   0.821134    0.685500
# 3     0.784392   0.521969 -0.805636  0.094507  -0.061575    0.685500
# 4     0.864135   1.299223  1.209720  0.094507   0.821134    0.685500
#
#    KitchenAbvGr  KitchenQual  LandContour  LandSlope   LotArea  LotConfig  \
# 0     -0.172465     0.749581    -0.043897  -0.235776 -0.159306  -0.607315
# 1     -0.172465    -0.800920    -0.043897  -0.235776  0.089911   0.651605
# 2     -0.172465     0.749581    -0.043897  -0.235776  0.399697  -0.607315
# 3     -0.172465     0.749581    -0.043897  -0.235776  0.079712   1.388026
# 4     -0.172465     0.749581    -0.043897  -0.235776  0.862787   0.651605
#
#    LotFrontage  LotShape  LowQualFinSF  MSSubClass  MSZoning  MasVnrArea  \
# 0     0.448669 -0.743768     -0.112732    0.440985  0.269762    1.140124
# 1     0.572373 -0.743768     -0.112732   -1.119523  0.269762   -0.851830
# 2     0.475519  1.056069     -0.112732    0.440985  0.269762    1.068694
# 3     0.401082  1.056069     -0.112732    0.663139  0.269762   -0.851830
# 4     0.601489  1.056069     -0.112732    0.440985  0.269762    1.357893
#
#    MasVnrType   MiscVal    MoSold  Neighborhood  OpenPorchSF  OverallCond  \
# 0    0.828303 -0.189396 -1.925272      0.628977     0.814970    -0.520935
# 1   -0.723070 -0.189396 -0.287829      0.965743    -1.116573     2.040944
# 2    0.828303 -0.189396  0.918910      0.628977     0.643709    -0.520935
# 3   -0.723070 -0.189396 -1.925272      0.720071     0.560552    -0.520935
# 4    0.828303 -0.189396  1.538701      1.243612     0.962635    -0.520935
#
#    OverallQual  PavedDrive  PoolArea  RoofMatl  RoofStyle  SaleCondition  \
# 0     0.652293    0.236987 -0.061325 -0.076429  -0.497798       0.178300
# 1    -0.069762    0.236987 -0.061325 -0.076429  -0.497798       0.178300
# 2     0.652293    0.236987 -0.061325 -0.076429  -0.497798       0.178300
# 3     0.652293    0.236987 -0.061325 -0.076429  -0.497798      -2.621044
# 4     1.289191    0.236987 -0.061325 -0.076429  -0.497798       0.178300
#
#    SalePrice  SaleType  ScreenPorch    Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0   0.491826 -0.081378    -0.307531  0.061337      0.962476    -0.523577
# 1   0.123328 -0.081378    -0.307531  0.061337     -0.256845     0.591772
# 2   0.676422 -0.081378    -0.307531  0.061337     -0.256845    -0.316438
# 3  -0.566494 -0.081378    -0.307531  0.061337      0.391019    -0.880420
# 4   0.974151 -0.081378    -0.307531  0.061337      1.473662     0.312186
#
#    Utilities  WoodDeckSF  YearBuilt  YearRemodAdd    YrSold
# 0    0.02739   -0.985937   1.010520      0.854756  0.144522
# 1    0.02739    1.203340   0.108341     -0.468884 -0.606997
# 2    0.02739   -0.985937   0.944110      0.806051  0.144522
# 3    0.02739   -0.985937  -1.976126     -0.765481 -1.358889
# 4    0.02739    1.035219   0.910880      0.708568  0.144522

# %%
df_out['SalePrice'].isnull().sum()
# Out:
# 0

# %%
df_out.describe().T
# Out:
#                 count          mean       std        min       25%       50%  \
# 1stFlrSF       1334.0  3.994140e-15  1.000375  -3.028359 -0.718826 -0.054564
# 2ndFlrSF       1334.0 -1.158494e-16  1.000375  -0.884277 -0.884277 -0.884277
# 3SsnPorch      1334.0  1.331602e-18  1.000375  -0.131643 -0.131643 -0.131643
# BedroomAbvGr   1334.0  5.592728e-16  1.000375  -5.950578 -1.030282  0.258145
# BldgType       1334.0  1.012017e-16  1.000375  -5.791361  0.311308  0.311308
# BsmtCond       1334.0  1.724091e-15  1.000375 -11.321543 -0.010265 -0.010265
# BsmtExposure   1334.0  5.592728e-17  1.000375  -0.684757 -0.684757 -0.684757
# BsmtFinSF1     1334.0  4.926927e-17  1.000375  -1.499208 -1.499208  0.555443
# BsmtFinSF2     1334.0 -1.731082e-17  1.000375  -0.366175 -0.366175 -0.366175
# BsmtFinType1   1334.0  4.527446e-16  1.000375  -2.482488 -0.469418  0.466605
# BsmtFinType2   1334.0 -5.592728e-16  1.000375  -5.211030  0.236907  0.236907
# BsmtFullBath   1334.0  6.791169e-17  1.000375  -0.858612 -0.858612 -0.858612
# BsmtHalfBath   1334.0  3.994805e-17  1.000375  -0.250335 -0.250335 -0.250335
# BsmtQual       1334.0  1.438130e-16  1.000375  -3.316236 -0.810812  0.654767
# BsmtUnfSF      1334.0 -3.129264e-16  1.000375  -3.596969 -0.177104  0.242488
# CentralAir     1334.0 -6.671325e-16  1.000375  -4.568244  0.218902  0.218902
# Condition1     1334.0  1.394853e-15  1.000375  -4.831567  0.233615  0.233615
# Condition2     1334.0  4.844367e-15  1.000375 -20.043376  0.064059  0.064059
# Electrical     1334.0  1.454109e-15  1.000375 -16.840936  0.231275  0.231275
# EnclosedPorch  1334.0 -1.331602e-17  1.000375  -0.393022 -0.393022 -0.393022
# ExterCond      1334.0  9.108157e-16  1.000375  -6.194225  0.320716  0.320716
# ExterQual      1334.0  1.238390e-16  1.000375  -3.802036 -0.735317 -0.735317
# Exterior1st    1334.0  5.419619e-16  1.000375  -4.970169 -1.010483  0.435644
# Exterior2nd    1334.0  8.895100e-16  1.000375  -4.361224 -1.050244  0.375718
# FireplaceQu    1334.0 -1.837611e-16  1.000375  -1.101349 -1.101349  0.750987
# Fireplaces     1334.0  1.704450e-16  1.000375  -1.073695 -1.073695  0.690383
# Foundation     1334.0  2.649888e-16  1.000375  -1.900515 -0.649027 -0.649027
# FullBath       1334.0 -1.178468e-16  1.000375  -4.159281 -1.029856  0.800741
# Functional     1334.0 -3.781749e-16  1.000375 -11.297279  0.194921  0.194921
# GarageArea     1334.0 -1.850261e-15  1.000375  -2.822459 -0.574795  0.095218
# ...               ...           ...       ...        ...       ...       ...
# LotConfig      1334.0 -2.263723e-17  1.000375  -0.607315 -0.607315 -0.607315
# LotFrontage    1334.0 -4.820399e-16  1.000375  -2.082059  0.175651  0.439446
# LotShape       1334.0 -1.065281e-17  1.000375  -0.743768 -0.743768 -0.743768
# LowQualFinSF   1334.0 -1.065281e-17  1.000375  -0.112732 -0.112732 -0.112732
# MSSubClass     1334.0 -2.886247e-16  1.000375  -1.119523 -1.119523  0.178964
# MSZoning       1334.0  5.313091e-16  1.000375  -8.068812  0.269762  0.269762
# MasVnrArea     1334.0  5.859048e-17  1.000375  -0.851830 -0.851830 -0.851830
# MasVnrType     1334.0  1.564632e-16  1.000375  -3.375161 -0.723070 -0.723070
# MiscVal        1334.0 -2.663204e-18  1.000375  -0.189396 -0.189396 -0.189396
# MoSold         1334.0  2.876260e-16  1.000375  -2.883115 -0.287829  0.076326
# Neighborhood   1334.0  2.343619e-16  1.000375  -3.886349 -0.572318  0.201442
# OpenPorchSF    1334.0 -1.165152e-16  1.000375  -1.116573 -1.116573  0.459358
# OverallCond    1334.0  2.032024e-15  1.000375  -4.900496 -0.520935 -0.520935
# OverallQual    1334.0 -3.621957e-16  1.000375  -4.651423 -0.903313 -0.069762
# PavedDrive     1334.0  8.149403e-16  1.000375  -4.705428  0.236987  0.236987
# PoolArea       1334.0  1.597922e-17  1.000375  -0.061325 -0.061325 -0.061325
# RoofMatl       1334.0 -6.764537e-16  1.000375 -20.039417 -0.076429 -0.076429
# RoofStyle      1334.0  2.130563e-17  1.000375  -2.325770 -0.497798 -0.497798
# SaleCondition  1334.0  2.319650e-15  1.000375  -8.641482  0.178300  0.178300
# SalePrice      1334.0  2.066646e-15  1.000375  -4.226496 -0.663127 -0.074148
# SaleType       1334.0  1.211758e-15  1.000375  -6.659760 -0.081378 -0.081378
# ScreenPorch    1334.0  3.062684e-17  1.000375  -0.307531 -0.307531 -0.307531
# Street         1334.0 -7.570156e-16  1.000375 -16.303374  0.061337  0.061337
# TotRmsAbvGrd   1334.0  4.886979e-16  1.000375  -2.971976 -1.004750 -0.256845
# TotalBsmtSF    1334.0  8.362459e-16  1.000375  -6.534495 -0.653139 -0.021392
# Utilities      1334.0  3.185192e-15  1.000375 -36.510273  0.027390  0.027390
# WoodDeckSF     1334.0 -7.456970e-17  1.000375  -0.985937 -0.985937 -0.985937
# YearBuilt      1334.0 -1.496454e-14  1.000375  -3.202305 -0.567918  0.108341
# YearRemodAdd   1334.0 -8.517991e-14  1.000375  -1.760698 -0.864547  0.439985
# YrSold         1334.0  7.698117e-13  1.000375  -1.358889 -0.606997  0.144522
#
#                     75%        max
# 1stFlrSF       0.765176   3.091781
# 2ndFlrSF       1.115757   1.426576
# 3SsnPorch     -0.131643   8.997324
# BedroomAbvGr   0.258145   2.764467
# BldgType       0.311308   0.311308
# BsmtCond      -0.010265   2.951701
# BsmtExposure   1.387696   1.930387
# BsmtFinSF1     0.752951   1.126444
# BsmtFinSF2    -0.366175   3.500567
# BsmtFinType1   0.800687   0.800687
# BsmtFinType2   0.236907   1.830326
# BsmtFullBath   1.126396   2.287552
# BsmtHalfBath  -0.250335   6.400329
# BsmtQual       0.654767   1.694611
# BsmtUnfSF      0.558417   1.210794
# CentralAir     0.218902   0.218902
# Condition1     0.233615   2.083482
# Condition2     0.064059   5.936026
# Electrical     0.231275   0.231275
# EnclosedPorch -0.393022   3.134778
# ExterCond      0.320716   2.026715
# ExterQual      1.058599   2.331403
# Exterior1st    0.929352   1.522681
# Exterior2nd    0.915461   1.342622
# FireplaceQu    1.049147   1.292761
# Fireplaces     0.690383   2.454461
# Foundation     1.005351   1.005351
# FullBath       0.800741   2.099570
# Functional     0.194921   1.183631
# GarageArea     0.585554   2.882945
# ...                 ...        ...
# LotConfig      1.388026   2.315807
# LotFrontage    0.572373   1.390816
# LotShape       1.056069   2.855905
# LowQualFinSF  -0.112732  10.031148
# MSSubClass     0.663139   2.111319
# MSZoning       0.269762   1.611972
# MasVnrArea     1.095477   1.930081
# MasVnrType     0.828303   1.929020
# MiscVal       -0.189396   7.744233
# MoSold         0.670014   1.538701
# Neighborhood   0.720071   1.243612
# OpenPorchSF    0.878407   1.834831
# OverallCond    0.453046   2.706651
# OverallQual    0.652293   2.374293
# PavedDrive     0.236987   0.236987
# PoolArea      -0.061325  16.818190
# RoofMatl      -0.076429   9.905066
# RoofStyle     -0.497798   2.399469
# SaleCondition  0.178300   1.177430
# SalePrice      0.634483   3.910955
# SaleType      -0.081378   2.321128
# ScreenPorch   -0.307531   3.918140
# Street         0.061337   0.061337
# TotRmsAbvGrd   0.391019   2.746595
# TotalBsmtSF    0.715455   3.169560
# Utilities      0.027390   0.027390
# WoodDeckSF     0.993204   1.608194
# YearBuilt      0.944110   1.242434
# YearRemodAdd   0.903437   1.195011
# YrSold         0.895666   1.646437
#
# [76 rows x 8 columns]

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### 1. Filter Method - Correlation Coefficient

# %%
corr=df_out.corr()
corr.sort_values(["SalePrice"],ascending=False,inplace=True)
dc=corr.SalePrice

# %%
dc
# Out:
# SalePrice        1.000000
# OverallQual      0.797422
# GrLivArea        0.736924
# ExterQual        0.671765
# Neighborhood     0.670524
# GarageCars       0.651936
# KitchenQual      0.642349
# BsmtQual         0.636751
# GarageArea       0.616768
# 1stFlrSF         0.613202
# TotalBsmtSF      0.598773
# FullBath         0.594681
# YearBuilt        0.573260
# YearRemodAdd     0.566939
# GarageFinish     0.563617
# TotRmsAbvGrd     0.551300
# GarageYrBlt      0.538543
# Foundation       0.525679
# FireplaceQu      0.517189
# GarageType       0.499494
# Fireplaces       0.490440
# OpenPorchSF      0.469103
# HeatingQC        0.451595
# Exterior1st      0.420974
# MasVnrType       0.410504
# Exterior2nd      0.407002
# MasVnrArea       0.398087
# MSZoning         0.394516
# LotArea          0.392175
# BsmtExposure     0.337000
#                    ...
# BedroomAbvGr     0.174354
# LandContour      0.173394
# BldgType         0.164840
# 2ndFlrSF         0.164226
# ExterCond        0.148147
# BsmtFinSF1       0.146475
# Functional       0.138044
# BsmtUnfSF        0.131943
# RoofMatl         0.123804
# LotConfig        0.113421
# Condition2       0.109318
# BsmtFinType2     0.106375
# ScreenPorch      0.086484
# Heating          0.077877
# PoolArea         0.075136
# Street           0.064900
# LandSlope        0.060912
# 3SsnPorch        0.058209
# MoSold           0.045241
# LotFrontage      0.035351
# Utilities        0.016827
# MSSubClass      -0.015314
# YrSold          -0.026313
# BsmtHalfBath    -0.027655
# LowQualFinSF    -0.051902
# OverallCond     -0.058679
# MiscVal         -0.061245
# BsmtFinSF2      -0.067431
# KitchenAbvGr    -0.122196
# EnclosedPorch   -0.221888
# Name: SalePrice, Length: 76, dtype: float64

# %%
dc.index
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'ExterQual', 'Neighborhood',
#        'GarageCars', 'KitchenQual', 'BsmtQual', 'GarageArea', '1stFlrSF',
#        'TotalBsmtSF', 'FullBath', 'YearBuilt', 'YearRemodAdd', 'GarageFinish',
#        'TotRmsAbvGrd', 'GarageYrBlt', 'Foundation', 'FireplaceQu',
#        'GarageType', 'Fireplaces', 'OpenPorchSF', 'HeatingQC', 'Exterior1st',
#        'MasVnrType', 'Exterior2nd', 'MasVnrArea', 'MSZoning', 'LotArea',
#        'BsmtExposure', 'BsmtFinType1', 'WoodDeckSF', 'SaleType', 'LotShape',
#        'HalfBath', 'CentralAir', 'HouseStyle', 'Electrical', 'SaleCondition',
#        'PavedDrive', 'BsmtFullBath', 'RoofStyle', 'GarageCond', 'GarageQual',
#        'BsmtCond', 'Condition1', 'BedroomAbvGr', 'LandContour', 'BldgType',
#        '2ndFlrSF', 'ExterCond', 'BsmtFinSF1', 'Functional', 'BsmtUnfSF',
#        'RoofMatl', 'LotConfig', 'Condition2', 'BsmtFinType2', 'ScreenPorch',
#        'Heating', 'PoolArea', 'Street', 'LandSlope', '3SsnPorch', 'MoSold',
#        'LotFrontage', 'Utilities', 'MSSubClass', 'YrSold', 'BsmtHalfBath',
#        'LowQualFinSF', 'OverallCond', 'MiscVal', 'BsmtFinSF2', 'KitchenAbvGr',
#        'EnclosedPorch'],
#       dtype='object')

# %%
dc.values
# Out:
# array([ 1.        ,  0.79742216,  0.7369236 ,  0.67176468,  0.67052375,
#         0.6519358 ,  0.64234873,  0.63675127,  0.61676781,  0.61320166,
#         0.5987734 ,  0.59468148,  0.57325962,  0.56693918,  0.56361708,
#         0.55129986,  0.53854337,  0.52567869,  0.51718928,  0.49949408,
#         0.49043991,  0.46910278,  0.45159457,  0.42097394,  0.41050413,
#         0.4070016 ,  0.39808682,  0.39451574,  0.39217543,  0.33699965,
#         0.32498823,  0.32445609,  0.31808551,  0.29859081,  0.29468513,
#         0.27899208,  0.27764992,  0.25364633,  0.24404917,  0.21971327,
#         0.21538367,  0.21190367,  0.20894283,  0.2059674 ,  0.19958891,
#         0.19957767,  0.17435399,  0.17339395,  0.16483952,  0.16422631,
#         0.14814677,  0.14647491,  0.13804392,  0.13194325,  0.12380386,
#         0.11342128,  0.10931795,  0.10637534,  0.08648357,  0.07787723,
#         0.07513569,  0.06489956,  0.06091183,  0.05820913,  0.04524074,
#         0.03535082,  0.01682734, -0.01531407, -0.02631276, -0.02765456,
#        -0.05190236, -0.05867942, -0.06124518, -0.06743068, -0.12219648,
#        -0.22188781])

# %%
dc.index.values
# Out:
# array(['SalePrice', 'OverallQual', 'GrLivArea', 'ExterQual',
#        'Neighborhood', 'GarageCars', 'KitchenQual', 'BsmtQual',
#        'GarageArea', '1stFlrSF', 'TotalBsmtSF', 'FullBath', 'YearBuilt',
#        'YearRemodAdd', 'GarageFinish', 'TotRmsAbvGrd', 'GarageYrBlt',
#        'Foundation', 'FireplaceQu', 'GarageType', 'Fireplaces',
#        'OpenPorchSF', 'HeatingQC', 'Exterior1st', 'MasVnrType',
#        'Exterior2nd', 'MasVnrArea', 'MSZoning', 'LotArea', 'BsmtExposure',
#        'BsmtFinType1', 'WoodDeckSF', 'SaleType', 'LotShape', 'HalfBath',
#        'CentralAir', 'HouseStyle', 'Electrical', 'SaleCondition',
#        'PavedDrive', 'BsmtFullBath', 'RoofStyle', 'GarageCond',
#        'GarageQual', 'BsmtCond', 'Condition1', 'BedroomAbvGr',
#        'LandContour', 'BldgType', '2ndFlrSF', 'ExterCond', 'BsmtFinSF1',
#        'Functional', 'BsmtUnfSF', 'RoofMatl', 'LotConfig', 'Condition2',
#        'BsmtFinType2', 'ScreenPorch', 'Heating', 'PoolArea', 'Street',
#        'LandSlope', '3SsnPorch', 'MoSold', 'LotFrontage', 'Utilities',
#        'MSSubClass', 'YrSold', 'BsmtHalfBath', 'LowQualFinSF',
#        'OverallCond', 'MiscVal', 'BsmtFinSF2', 'KitchenAbvGr',
#        'EnclosedPorch'], dtype=object)

# %%
dc_new=dc[(dc.values>0.5)&(dc.values<1)]
dc_new
# Out:
# OverallQual     0.797422
# GrLivArea       0.736924
# ExterQual       0.671765
# Neighborhood    0.670524
# GarageCars      0.651936
# KitchenQual     0.642349
# BsmtQual        0.636751
# GarageArea      0.616768
# 1stFlrSF        0.613202
# TotalBsmtSF     0.598773
# FullBath        0.594681
# YearBuilt       0.573260
# YearRemodAdd    0.566939
# GarageFinish    0.563617
# TotRmsAbvGrd    0.551300
# GarageYrBlt     0.538543
# Foundation      0.525679
# FireplaceQu     0.517189
# Name: SalePrice, dtype: float64

# %%
feature_col=dc_new.index.values
feature_col
# Out:
# array(['OverallQual', 'GrLivArea', 'ExterQual', 'Neighborhood',
#        'GarageCars', 'KitchenQual', 'BsmtQual', 'GarageArea', '1stFlrSF',
#        'TotalBsmtSF', 'FullBath', 'YearBuilt', 'YearRemodAdd',
#        'GarageFinish', 'TotRmsAbvGrd', 'GarageYrBlt', 'Foundation',
#        'FireplaceQu'], dtype=object)

# %% [markdown]
# ### Select the features to be used in the data analysis

# %%
X=df_out[sorted(feature_col)]
y=df_out['SalePrice']

# %%
X.head()
# Out:
#    1stFlrSF  BsmtQual  ExterQual  FireplaceQu  Foundation  FullBath  \
# 0 -0.859494  0.654767   1.058599    -1.101349    1.005351  0.800741
# 1  0.397874  0.654767  -0.735317     0.750987   -0.649027  0.800741
# 2 -0.625980  0.654767   1.058599     0.750987    1.005351  0.800741
# 3 -0.484766 -0.810812  -0.735317     1.049147   -1.900515 -1.029856
# 4  0.082688  0.654767   1.058599     0.750987    1.005351  0.800741
#
#    GarageArea  GarageCars  GarageFinish  GarageYrBlt  GrLivArea  KitchenQual  \
# 0    0.423168    0.305352      0.426822     0.983601   0.509113     0.749581
# 1   -0.039060    0.305352      0.426822    -0.098086  -0.446823    -0.800920
# 2    0.697593    0.305352      0.426822     0.903977   0.645960     0.749581
# 3    0.841332    1.570686     -1.078051     0.784392   0.521969     0.749581
# 4    1.538983    1.570686      0.426822     0.864135   1.299223     0.749581
#
#    Neighborhood  OverallQual  TotRmsAbvGrd  TotalBsmtSF  YearBuilt  \
# 0      0.628977     0.652293      0.962476    -0.523577   1.010520
# 1      0.965743    -0.069762     -0.256845     0.591772   0.108341
# 2      0.628977     0.652293     -0.256845    -0.316438   0.944110
# 3      0.720071     0.652293      0.391019    -0.880420  -1.976126
# 4      1.243612     1.289191      1.473662     0.312186   0.910880
#
#    YearRemodAdd
# 0      0.854756
# 1     -0.468884
# 2      0.806051
# 3     -0.765481
# 4      0.708568

# %%
y.head()
# Out:
# 0    0.491826
# 1    0.123328
# 2    0.676422
# 3   -0.566494
# 4    0.974151
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Specify testing size

# %%
TS=0.2

# %% [markdown]
# ### Create a Result dataframe

# %%
result_col=['Algorithm','Correlation','Recursive','XGBoost']
result=pd.DataFrame(columns=result_col)
result['Algorithm']=['Ridge Regression','LASSO Regression','Elastic Net',
                     'Decision Tree','Random Forest','XGBoost']

# %%
result
# Out:
#           Algorithm Correlation Recursive XGBoost
# 0  Ridge Regression         NaN       NaN     NaN
# 1  LASSO Regression         NaN       NaN     NaN
# 2       Elastic Net         NaN       NaN     NaN
# 3     Decision Tree         NaN       NaN     NaN
# 4     Random Forest         NaN       NaN     NaN
# 5           XGBoost         NaN       NaN     NaN

# %% [markdown]
# ### Split the data to train and test dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=TS, random_state=200)

# %% [markdown]
# ### Ridge Regression

# %%
print(plt.rcParams["figure.figsize"])
plt.rcParams["figure.figsize"] = (8,4)
# Out:
# [6.0, 4.0]

# %%
from sklearn.linear_model import Ridge
RR=Ridge(alpha=0.001,fit_intercept=True)
RR_fit=RR.fit(x_train,y_train)

# %%
y_pred=RR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3751036678457402

# %%
y_pred=RR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][0]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][0]
# Out:
# 0.33646421456653014

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso
LR=Lasso(alpha=0.001,fit_intercept=True)
LR_fit=LR.fit(x_train,y_train)
y_pred=LR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3751472220492925

# %%
y_pred=LR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][1]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][1]
# Out:
# 0.3360793355349833

# %% [markdown]
# ### Elastic Net Model

# %%
from sklearn.linear_model import ElasticNetCV
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)
EN_fit=EN.fit(x_train, y_train)

# %%
y_pred=EN_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3752526722594469

# %%
y_pred=EN_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][2]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][2]
# Out:
# 0.33590502575907905

# %% [markdown]
# ### Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
DT=DecisionTreeRegressor()
DT_fit=DT.fit(x_train,y_train)

# %%
y_pred=DT_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.014217229360315144

# %%
y_pred=DT_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][3]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][3]
# Out:
# 0.5060435326556609

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)
RF_fit=RF.fit(x_train, y_train)

# %%
y_pred=RF_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.14739410552069604

# %%
y_pred=RF_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][4]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][4]
# Out:
# 0.31936053046322205

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=3000, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)
XG_fit=XG.fit(x_train, y_train)

# %%
y_pred=XG_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.12249570260109727

# %%
y_pred=XG_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Correlation'][5]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Correlation'][5]
# Out:
# 0.3119158700225584

# %% [markdown]
# ### Wrapper Method - Recursive Feature Elimination Method

# %%
from sklearn.feature_selection import RFECV

# %% [markdown]
# ### Split the data to train and test dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=TS, random_state=200)

# %% [markdown]
# ### Ridge Regression

# %%
RR=Ridge(alpha=0.001,fit_intercept=True)
RM_RR=RFECV(RR, step=1, cv=20, scoring='neg_mean_squared_error')
RM_RR_fit=RM_RR.fit(x_train,y_train)
RM_RR_fit.n_features_
# Out:
# 15

# %%
y_pred=RM_RR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3752519512887014

# %%
y_pred=RM_RR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][0]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][0]
# Out:
# 0.3370776525143807

# %% [markdown]
# ### Lasso Regression

# %%
LR=Lasso(alpha=0.001,fit_intercept=True)
RM_LR=RFECV(LR, step=1, cv=20, scoring='neg_mean_squared_error')
RM_LR_fit=RM_LR.fit(x_train,y_train)
RM_LR_fit.n_features_
# Out:
# 13

# %%
y_pred=RM_LR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.3757884385967956

# %%
y_pred=RM_LR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][1]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][1]
# Out:
# 0.33702924293173825

# %% [markdown]
# ### Elastic Net Model

# %%
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)
RM_EN=RFECV(EN, step=1, cv=20, scoring='neg_mean_squared_error')
RM_EN_fit=RM_EN.fit(x_train,y_train)
RM_EN_fit.n_features_
# Out:
# 17

# %%
y_pred=RM_EN_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.37519226054364496

# %%
y_pred=RM_EN_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][2]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][2]
# Out:
# 0.33615563399096987

# %% [markdown]
# ### Decision Tree Model

# %%
DT=DecisionTreeRegressor()
RM_DT=RFECV(DT, step=1, cv=20, scoring='neg_mean_squared_error')
RM_DT_fit=RM_DT.fit(x_train,y_train)
RM_DT_fit.n_features_
# Out:
# 10

# %%
y_pred=RM_DT_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.01714034851384517

# %%
y_pred=RM_DT_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][3]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][3]
# Out:
# 0.49030278234751046

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)
RM_RF=RFECV(RF, step=1, cv=10, scoring='neg_mean_squared_error')
RM_RF_fit=RM_RF.fit(x_train,y_train)
RM_RF_fit.n_features_
# Out:
# 17

# %%
y_pred=RM_RF_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))
# Out:
# 0.14724322194847658

# %%
y_pred=RM_RF_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][4]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][4]
# Out:
# 0.3212469192512172

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=300, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)
RM_XG=RFECV(XG, step=1, cv=5, scoring='neg_mean_squared_error')
RM_XG_fit=RM_XG.fit(x_train,y_train)
RM_XG_fit.n_features_

# %%
y_pred=RM_XG_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=RM_XG_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['Recursive'][5]=np.sqrt(mean_squared_error(y_pred,y_test))
result['Recursive'][5]

# %% [markdown]
# ## Embedded Method - XGBoost Feature Importance

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
df_out_X=df_out.drop(columns=['SalePrice'])
df_out_y=df_out['SalePrice']
model.fit(df_out_X, df_out_y)
print(model.feature_importances_)

# %%
len(model.feature_importances_)

# %%
df_out_X.shape

# %%
df_out_X_col=df_out_X.columns.values

# %%
plt.rcParams["figure.figsize"] = (10,20)
plt.barh(df_out_X_col, model.feature_importances_)
plt.show()

# %%
df_XG=pd.DataFrame()

# %%
df_XG['Feature']=df_out_X_col
df_XG['Feature_Importance']=model.feature_importances_

# %%
df_XG.head()

# %%
df_XG=df_XG.sort_values(by=['Feature_Importance'],ascending=False)

# %%
df_XG

# %%
feature_col_XG=df_XG['Feature'][:12].values

# %%
feature_col_XG

# %% [markdown]
# ### Using the new selected features in the 6 models again.

# %%
X=df_out[feature_col_XG]
y=df_out['SalePrice']

# %%
feature_col_XG

# %% [markdown]
# ### Split the data to train and test dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=TS, random_state=200)

# %% [markdown]
# ### Ridge Regression

# %%
plt.rcParams["figure.figsize"] = (8,4)

# %%
from sklearn.linear_model import Ridge
RR=Ridge(alpha=0.0001,fit_intercept=True)
RR_fit=RR.fit(x_train,y_train)
y_pred=RR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=RR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][0]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][0]

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso
LR=Lasso(alpha=0.0001,fit_intercept=True)
LR_fit=LR.fit(x_train,y_train)
y_pred=LR_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=LR_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][1]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][1]

# %% [markdown]
# ### Elastic Net Model

# %%
from sklearn.linear_model import ElasticNetCV
EN = ElasticNetCV(alphas=[0.0001, 0.0005, 0.001, 0.01, 0.1, 1, 10], 
                       l1_ratio=[.01, .1, .5, .9, .99], max_iter=5000)
EN_fit=EN.fit(x_train, y_train)

# %%
y_pred=EN_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=EN_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][2]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][2]

# %% [markdown]
# ### Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
DT=DecisionTreeRegressor()
DT_fit=DT.fit(x_train,y_train)

# %%
y_pred=DT_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=DT_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][3]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][3]

# %% [markdown]
# ### Random Forest Model

# %%
RF = ensemble.RandomForestRegressor(n_estimators=100, random_state=0)
RF_fit=RF.fit(x_train, y_train)

# %%
y_pred=RF_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=RF_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][4]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][4]

# %% [markdown]
# ### XGBoost Model

# %%
XG = ensemble.GradientBoostingRegressor(loss='huber', learning_rate=0.05, n_estimators=3000, max_depth=10, 
                                  max_features='sqrt', min_samples_leaf=15, 
                                  min_samples_split=10)
XG_fit=XG.fit(x_train, y_train)

# %%
y_pred=XG_fit.predict(x_train)
np.sqrt(mean_squared_error(y_pred,y_train))

# %%
y_pred=XG_fit.predict(x_test)
y_err=y_pred-y_test
sns.residplot(y_pred,y_err,lowess=True,color="g")
result['XGBoost'][5]=np.sqrt(mean_squared_error(y_pred,y_test))
result['XGBoost'][5]

# %% [markdown]
# ## Examine the result

# %%
print('test-size: ',TS)

# %%
result
